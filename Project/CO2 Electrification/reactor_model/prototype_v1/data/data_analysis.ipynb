# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_140 = pd.read_csv('140W.csv')
df_280 = pd.read_csv('280W.csv')
df_420 = pd.read_csv('420W.csv')
df_140
# Out:
#               Date  Hour   Min.   Sec.   Elapse[min.]  MFC-1[sccm]  \
# 0      2025-10-31-    17      3     32           0.27        -1.74
# 1      2025-10-31-    17      3     33           0.28        70.34
# 2      2025-10-31-    17      3     34           0.30        45.70
# 3      2025-10-31-    17      3     35           0.32        46.30
# 4      2025-10-31-    17      3     36           0.33        47.46
# ...            ...   ...    ...    ...            ...          ...
# 12922  2025-10-31-    20     38     54         215.63        49.52
# 12923  2025-10-31-    20     38     55         215.65        49.51
# 12924  2025-10-31-    20     38     56         215.67        49.53
# 12925  2025-10-31-    20     38     57         215.68        49.51
# 12926  2025-10-31-    20     38     58         215.70        49.52
#
#        MFC-2[sccm]  MFC-3[sccm]  MFC-4[sccm]  MFC-5[sccm]  ...  TI-13['C]  \
# 0            -1.58        -1.52        -1.00        -0.08  ...       51.2
# ...

# %%
# 140W
print(df_140.columns)
t = df_140.loc[df_140['Curr[A]'] != 0, ' Elapse[min.]']
T1 = df_140.loc[df_140['Curr[A]'] != 0, "TI-1['C]"]
T2 = df_140.loc[df_140['Curr[A]'] != 0, "TI-2['C]"]
T3 = df_140.loc[df_140['Curr[A]'] != 0, "TI-3['C]"]
T4 = df_140.loc[df_140['Curr[A]'] != 0, "TI-4['C]"]
T5 = df_140.loc[df_140['Curr[A]'] != 0, "TI-5['C]"]
T6 = df_140.loc[df_140['Curr[A]'] != 0, "TI-6['C]"]
T7 = df_140.loc[df_140['Curr[A]'] != 0, "TI-7['C]"]
T8 = df_140.loc[df_140['Curr[A]'] != 0, "TI-8['C]"]
T9 = df_140.loc[df_140['Curr[A]'] != 0, "TI-9['C]"]
T10 = df_140.loc[df_140['Curr[A]'] != 0, "TI-10['C]"]
T11 = df_140.loc[df_140['Curr[A]'] != 0, "TI-11['C]"]
T12 = df_140.loc[df_140['Curr[A]'] != 0, "TI-12['C]"]
T13 = df_140.loc[df_140['Curr[A]'] != 0, "TI-13['C]"]
T14 = df_140.loc[df_140['Curr[A]'] != 0, "TI-14['C]"]
T15 = df_140.loc[df_140['Curr[A]'] != 0, "TI-15['C]"]
T16 = df_140.loc[df_140['Curr[A]'] != 0, "TI-16['C]"]
I = df_140.loc[df_140['Curr[A]'] != 0, 'Curr[A]']

display(T1.tail())
display(T2.tail())
display(T3.tail())
display(T4.tail())
display(T5.tail())
display(T6.tail())
display(T7.tail())
display(T8.tail())
display(T9.tail())
display(T10.tail())
display(T11.tail())
display(T12.tail())
display(T13.tail())
display(T14.tail())
display(T15.tail())
display(T16.tail())

import json

# T1부터 T16까지 마지막에서 4번째 전값을 추출해서 리스트로 저장 (숫자만)
temp_profile = []
for i in range(1, 17):
    Ti = eval(f"T{i}")
    # 마지막에서 4번째 전값: -4 인덱스
    temp_profile.append(float(Ti.iloc[-4]))

# JSON 파일로 저장 (숫자만 리스트)
with open('Temp_profile_140W.json', 'w', encoding='utf-8') as f:
    json.dump(temp_profile, f, ensure_ascii=False, indent=4)
# Out:
# Index(['Date', 'Hour', ' Min.', ' Sec.', ' Elapse[min.]', 'MFC-1[sccm]',
#        'MFC-2[sccm]', 'MFC-3[sccm]', 'MFC-4[sccm]', 'MFC-5[sccm]',
#        'MFC-6[sccm]', 'Pre-HT['C]', 'HJ['C]', 'HB-1['C]', 'HB-2['C]',
#        'HB-3['C]', 'HB-4['C]', 'HB-5['C]', 'TI-1['C]', 'TI-2['C]', 'TI-3['C]',
#        'TI-4['C]', 'TI-5['C]', 'TI-6['C]', 'TI-7['C]', 'TI-8['C]', 'TI-9['C]',
#        'TI-10['C]', 'TI-11['C]', 'TI-12['C]', 'TI-13['C]', 'TI-14['C]',
#        'TI-15['C]', 'TI-16['C]', 'TI-SP1['C]', 'TI-SP2['C]', 'PT-1[bar]',
#        'Volt[V]', 'Curr[A]', 'Unnamed: 39'],
#       dtype='object')
# 12595    469.3
# 12596    469.3
# 12597    469.3
# 12598    469.3
# 12599    469.3
# Name: TI-1['C], dtype: float64
# 12595    503.4
# 12596    503.4
# 12597    503.4
# 12598    503.4
# 12599    503.4
# Name: TI-2['C], dtype: float64
# 12595    561.9
# 12596    561.9
# 12597    561.8
# 12598    561.8
# 12599    561.8
# Name: TI-3['C], dtype: float64
# 12595    589.8
# 12596    589.8
# ...

# %%
# 280W
print(df_280.columns)
t = df_280.loc[df_280['Curr[A]'] != 0, ' Elapse[min.]']
T1 = df_280.loc[df_280['Curr[A]'] != 0, "TI-1['C]"]
T2 = df_280.loc[df_280['Curr[A]'] != 0, "TI-2['C]"]
T3 = df_280.loc[df_280['Curr[A]'] != 0, "TI-3['C]"]
T4 = df_280.loc[df_280['Curr[A]'] != 0, "TI-4['C]"]
T5 = df_280.loc[df_280['Curr[A]'] != 0, "TI-5['C]"]
T6 = df_280.loc[df_280['Curr[A]'] != 0, "TI-6['C]"]
T7 = df_280.loc[df_280['Curr[A]'] != 0, "TI-7['C]"]
T8 = df_280.loc[df_280['Curr[A]'] != 0, "TI-8['C]"]
T9 = df_280.loc[df_280['Curr[A]'] != 0, "TI-9['C]"]
T10 = df_280.loc[df_280['Curr[A]'] != 0, "TI-10['C]"]
T11 = df_280.loc[df_280['Curr[A]'] != 0, "TI-11['C]"]
T12 = df_280.loc[df_280['Curr[A]'] != 0, "TI-12['C]"]
T13 = df_280.loc[df_280['Curr[A]'] != 0, "TI-13['C]"]
T14 = df_280.loc[df_280['Curr[A]'] != 0, "TI-14['C]"]
T15 = df_280.loc[df_280['Curr[A]'] != 0, "TI-15['C]"]
T16 = df_280.loc[df_280['Curr[A]'] != 0, "TI-16['C]"]
I = df_280.loc[df_280['Curr[A]'] != 0, 'Curr[A]']

display(T1.tail())
display(T2.tail())
display(T3.tail())
display(T4.tail())
display(T5.tail())
display(T6.tail())
display(T7.tail())
display(T8.tail())
display(T9.tail())
display(T10.tail())
display(T11.tail())
display(T12.tail())
display(T13.tail())
display(T14.tail())
display(T15.tail())
display(T16.tail())

# T1부터 T16까지 마지막에서 4번째 전값을 추출해서 리스트로 저장 (숫자만)
temp_profile = []
for i in range(1, 17):
    Ti = eval(f"T{i}")
    # 마지막에서 4번째 전값: -4 인덱스
    temp_profile.append(float(Ti.iloc[-4]))

# JSON 파일로 저장 (숫자만 리스트)
with open('Temp_profile_280W.json', 'w', encoding='utf-8') as f:
    json.dump(temp_profile, f, ensure_ascii=False, indent=4)
# Out:
# Index(['Date', 'Hour', ' Min.', ' Sec.', ' Elapse[min.]', 'MFC-1[sccm]',
#        'MFC-2[sccm]', 'MFC-3[sccm]', 'MFC-4[sccm]', 'MFC-5[sccm]',
#        'MFC-6[sccm]', 'Pre-HT['C]', 'HJ['C]', 'HB-1['C]', 'HB-2['C]',
#        'HB-3['C]', 'HB-4['C]', 'HB-5['C]', 'TI-1['C]', 'TI-2['C]', 'TI-3['C]',
#        'TI-4['C]', 'TI-5['C]', 'TI-6['C]', 'TI-7['C]', 'TI-8['C]', 'TI-9['C]',
#        'TI-10['C]', 'TI-11['C]', 'TI-12['C]', 'TI-13['C]', 'TI-14['C]',
#        'TI-15['C]', 'TI-16['C]', 'TI-SP1['C]', 'TI-SP2['C]', 'PT-1[bar]',
#        'Volt[V]', 'Curr[A]'],
#       dtype='object')
# 1795    595.0
# 1796    595.0
# 1797    595.0
# 1798    595.2
# 1799    595.2
# Name: TI-1['C], dtype: float64
# 1795    634.9
# 1796    634.9
# 1797    634.9
# 1798    635.1
# 1799    635.1
# Name: TI-2['C], dtype: float64
# 1795    698.5
# 1796    698.5
# 1797    698.5
# 1798    698.8
# 1799    698.8
# Name: TI-3['C], dtype: float64
# 1795    726.3
# 1796    726.3
# 1797    726.3
# 1798    726.6
# ...

# %%
# 420W
print(df_420.columns)
t = df_420.loc[df_420['Curr[A]'] != 0, ' Elapse[min.]']
T1 = df_420.loc[df_420['Curr[A]'] != 0, "TI-1['C]"]
T2 = df_420.loc[df_420['Curr[A]'] != 0, "TI-2['C]"]
T3 = df_420.loc[df_420['Curr[A]'] != 0, "TI-3['C]"]
T4 = df_420.loc[df_420['Curr[A]'] != 0, "TI-4['C]"]
T5 = df_420.loc[df_420['Curr[A]'] != 0, "TI-5['C]"]
T6 = df_420.loc[df_420['Curr[A]'] != 0, "TI-6['C]"]
T7 = df_420.loc[df_420['Curr[A]'] != 0, "TI-7['C]"]
T8 = df_420.loc[df_420['Curr[A]'] != 0, "TI-8['C]"]
T9 = df_420.loc[df_420['Curr[A]'] != 0, "TI-9['C]"]
T10 = df_420.loc[df_420['Curr[A]'] != 0, "TI-10['C]"]
T11 = df_420.loc[df_420['Curr[A]'] != 0, "TI-11['C]"]
T12 = df_420.loc[df_420['Curr[A]'] != 0, "TI-12['C]"]
T13 = df_420.loc[df_420['Curr[A]'] != 0, "TI-13['C]"]
T14 = df_420.loc[df_420['Curr[A]'] != 0, "TI-14['C]"]
T15 = df_420.loc[df_420['Curr[A]'] != 0, "TI-15['C]"]
T16 = df_420.loc[df_420['Curr[A]'] != 0, "TI-16['C]"]
I = df_420.loc[df_420['Curr[A]'] != 0, 'Curr[A]']

display(T1.tail())
display(T2.tail())
display(T3.tail())
display(T4.tail())
display(T5.tail())
display(T6.tail())
display(T7.tail())
display(T8.tail())
display(T9.tail())
display(T10.tail())
display(T11.tail())
display(T12.tail())
display(T13.tail())
display(T14.tail())
display(T15.tail())
display(T16.tail())

# T1부터 T16까지 마지막에서 4번째 전값을 추출해서 리스트로 저장 (숫자만)
temp_profile = []
for i in range(1, 17):
    Ti = eval(f"T{i}")
    # 마지막에서 4번째 전값: -4 인덱스
    temp_profile.append(float(Ti.iloc[-4]))

# JSON 파일로 저장 (숫자만 리스트)
with open('Temp_profile_420W.json', 'w', encoding='utf-8') as f:
    json.dump(temp_profile, f, ensure_ascii=False, indent=4)
# Out:
# Index(['Date', 'Hour', ' Min.', ' Sec.', ' Elapse[min.]', 'MFC-1[sccm]',
#        'MFC-2[sccm]', 'MFC-3[sccm]', 'MFC-4[sccm]', 'MFC-5[sccm]',
#        'MFC-6[sccm]', 'Pre-HT['C]', 'HJ['C]', 'HB-1['C]', 'HB-2['C]',
#        'HB-3['C]', 'HB-4['C]', 'HB-5['C]', 'TI-1['C]', 'TI-2['C]', 'TI-3['C]',
#        'TI-4['C]', 'TI-5['C]', 'TI-6['C]', 'TI-7['C]', 'TI-8['C]', 'TI-9['C]',
#        'TI-10['C]', 'TI-11['C]', 'TI-12['C]', 'TI-13['C]', 'TI-14['C]',
#        'TI-15['C]', 'TI-16['C]', 'TI-SP1['C]', 'TI-SP2['C]', 'PT-1[bar]',
#        'Volt[V]', 'Curr[A]'],
#       dtype='object')
# 1794    783.6
# 1795    783.8
# 1796    783.8
# 1797    783.8
# 1798    784.1
# Name: TI-1['C], dtype: float64
# 1794    837.4
# 1795    837.4
# 1796    837.7
# 1797    837.7
# 1798    837.7
# Name: TI-2['C], dtype: float64
# 1794    918.2
# 1795    918.5
# 1796    918.5
# 1797    918.5
# 1798    918.8
# Name: TI-3['C], dtype: float64
# 1794    961.4
# 1795    961.4
# 1796    961.6
# 1797    961.6
# ...

# %%
tc_pos = [35e-3, 48e-3, 64e-3, 83e-3, 105e-3, 130e-3, 158e-3, 189.6e-3, 241e-3, 272e-3, 300e-3,
        325e-3, 347e-3, 366e-3, 382e-3, 395e-3]
with open('tc_pos.json', 'w', encoding='utf-8') as f:
    json.dump(tc_pos, f, ensure_ascii=False, indent=4)
