# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0,1.1,0.1)
y = np.array([0,0.0054,0.44,0.62,0.69,0.75,0.8,0.84,0.86,0.87,0.874])

# %%
plt.xlabel('Axial coordinate (m)')
plt.ylabel('Conversion')
plt.title('2rpm + 1wt cat')
plt.scatter(x,y)
