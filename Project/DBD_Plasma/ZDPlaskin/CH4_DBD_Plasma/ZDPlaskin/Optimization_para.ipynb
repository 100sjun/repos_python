# %%
import numpy as np
import math
import re
import subprocess
import pandas as pd
import signal
import scipy.constants as const
from scipy.stats import norm
from scipy.optimize import minimize

# %%
def to_fortran_double(number):
    if number == 0:
        return "0.000d0"
    abs_num = abs(number)
    sign = '-' if number < 0 else ""

    exponent = math.floor(math.log10(abs_num))
    mantissa = abs_num / (10 ** exponent)

    return f"{sign}{mantissa:.3f}d{exponent}"

# %%
def update_kinet_inp(file_path, fortran_doubles):
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()

        # 파라미터 라인을 찾아 수정
        pattern = re.compile(r'\$ double precision, parameter :: (f\d+)= .*')
        for i, line in enumerate(lines):
            match = pattern.match(line)
            if match:
                param_name = match.group(1)
                param_number = int(param_name[1:])
                if param_number < len(fortran_doubles):
                    new_value = fortran_doubles[param_number]
                    lines[i] = f'$ double precision, parameter :: {param_name}= {new_value}\n'

        # 수정된 내용을 파일에 다시 쓰기
        with open('kinet2.inp', 'w') as file:
            file.writelines(lines)

        print(f"{file_path} 파일의 파라미터가 성공적으로 업데이트되었습니다.")

    except FileNotFoundError:
        print(f"오류: {file_path} 파일을 찾을 수 없습니다.")
    except IOError as e:
        print(f"파일 처리 중 오류가 발생했습니다: {e}")
    except Exception as e:
        print(f"예상치 못한 오류가 발생했습니다: {e}")

# %%
def run_preprocessor(exe_path):
    try:
        process = subprocess.Popen(
            exe_path,
            stdout=subprocess.DEVNULL,
            stderr=subprocess.DEVNULL,
            stdin=subprocess.PIPE,
            universal_newlines=True
        )

        # 첫 번째 입력으로 'kinet2.inp' 전송
        process.stdin.write('kinet2.inp\n')
        process.stdin.flush()

        # 그 후 계속해서 '.' 입력
        while process.poll() is None:
            process.stdin.write('.\n')
            process.stdin.flush()

    except:
        pass

# %%
def compile_fortran(name):
    compile_command = [
        "gfortran",
        "-o", name,
        "dvode_f90_m.F90",
        "zdplaskin_m.F90",
        "run_plasRxn_v2.F90",
        "bolsig_x86_64_g.dll"
    ]

    try:
        # 컴파일 명령어 실행
        result = subprocess.run(compile_command, check=True, capture_output=True, text=True)
    except subprocess.CalledProcessError as e:
        # 컴파일 중 오류가 발생하면 오류 메시지 출력
        print("컴파일 실패!")
        print("오류 메시지:")
        print(e.stderr)
    except FileNotFoundError:
        # gfortran이 설치되어 있지 않거나 PATH에 없는 경우
        print("gfortran을 찾을 수 없습니다. gfortran이 설치되어 있고 시스템 PATH에 추가되어 있는지 확인하세요.")

# %%
def run_executable(exe_path):
    try:
        # 실행 파일 실행
        process = subprocess.Popen(
            exe_path,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            universal_newlines=True,
            bufsize=1
        )

        # 실시간으로 출력 읽기
        while True:
            output = process.stdout.readline()
            if "ZDPlasKin INFO: the density of species not configured for BOLSIG+ solver exceeds 1.00D+00" in output:
                print("지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.")
                process.send_signal(signal.SIGTERM)
                break
            if "PRESS ENTER TO EXIT" in output:
                print("지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.")
                process.send_signal(signal.SIGTERM)
                break
            #if output:
                #print(output.strip())

        # 프로세스 종료 대기
        return_code = process.wait()

    except:
        pass

# %%
class GaussianProcess:
    def __init__(self,kernel, noise=1e-8):
        self.kernel = kernel
        self.noise = noise
    
    def fit(self, X, y):
        self.X_train = X
        self.y_train = y
        self.K = self.kernel(self.X_train, self.X_train) + self.noise * np.eye(len(self.X_train))
        self.L = np.linalg.cholesky(self.K)
        self.alpha = np.linalg.solve(self.L.T, np.linalg.solve(self.L, self.y_train))

    def predict(self, X_test):
        K_s  = self.kernel(self.X_train, X_test)
        K_ss = self.kernel(X_test, X_test)

        Lk = np.linalg.solve(self.L, K_s)
        mu = K_s.T.dot(self.alpha)
        s2 = np.diag(K_ss) - np.sum(Lk**2, axis=0)
        return mu, s2
    
def rbf_kernel(X1, X2, l=1.0, sigma_f=1.0):
    sqdist = np.sum(X1**2, 1).reshape(-1,1) + np.sum(X2**2, 1) - 2 * np.dot(X1, X2.T)
    return sigma_f**2 * np.exp(-0.5 / l**2 * sqdist)

def expected_improvement(X, X_sample, gp, y_sample, xi=0.01):
    mu, sigma = gp.predict(X)
    mu_sample = gp.predict(X_sample)[0]
    
    sigma = sigma.reshape(-1, 1)
    mu_sample_opt = np.max(mu_sample)
    
    with np.errstate(divide='warn'):
        imp = mu - mu_sample_opt - xi
        Z = imp / sigma
        ei = imp * norm.cdf(Z) + sigma * norm.pdf(Z)
        ei[sigma == 0.0] = 0.0
        
    return ei

def propose_location(acquisition, X_sample, Y_sample, gp, bounds, n_restarts=25):
    dim = X_sample.shape[1]
    min_val = 1
    min_x = None
    
    def min_obj(X):
        return -acquisition(X.reshape(1, -1), X_sample, gp, Y_sample).ravel()
    
    for x0 in np.random.uniform(bounds[:, 0], bounds[:, 1], size=(n_restarts, dim)):
        res = minimize(min_obj, x0=x0, bounds=bounds, method='L-BFGS-B')
        if res.fun < min_val:
            min_val = res.fun
            min_x = res.x
            
    return min_x.reshape(1, -1)

# %%
# 메인 최적화 루프
def bayesian_optimization(n_iters, objective_function, bounds):
    dim = bounds.shape[0]
    X_sample = np.random.uniform(bounds[:, 0], bounds[:, 1], size=(10, dim))
    Y_sample = objective_function(X_sample)
    
    gp = GaussianProcess(kernel=rbf_kernel)
    
    for i in range(n_iters):
        gp.fit(X_sample, Y_sample)
        
        # 다음 샘플링 위치 제안
        next_sample = propose_location(expected_improvement, X_sample, Y_sample, gp, bounds)
        
        # 새 샘플에 대한 목적 함수 계산
        next_sample_value = objective_function(next_sample)
        
        # 샘플 데이터에 새 포인트 추가
        X_sample = np.vstack((X_sample, next_sample))
        Y_sample = np.concatenate([Y_sample, next_sample_value])
        
        print(f"Iteration {i+1}/{n_iters}, Best error: {Y_sample.min()}")
    
    with open('best_para.txt', 'w') as f:
        f.write(X_sample[Y_sample.argmin()])
    return X_sample[Y_sample.argmin()]

# %%
# 예시 목적 함수 (실제 모델을 여기에 연결해야 함)
def objective_function(X):
    f = np.ones(19)
    err_arr = []
    for i in range(len(X)):
        fi = f * 10 ** X[i]
        fortran_doubles = list(map(to_fortran_double, fi))

        # parameter update
        file_path = 'kinet.inp'
        update_kinet_inp(file_path, fortran_doubles)

        # zdplaskin.F90 생성
        exe_processor = r'preprocessor.exe'
        run_preprocessor(exe_processor)

        # 실행파일 생성
        exe_path="run_plasRxn_v3.exe"
        compile_fortran(exe_path)

        # 시뮬레이션 실행
        run_executable(exe_path)

        # Read raw data
        conditions = []
        with open('qt_conditions_list.txt','r') as file:
            for line in file:        
                line = line.strip()
                line = line[2:]
                conditions.append(line)
            file.close()

        species = []
        with open('qt_species_list.txt','r') as file:
            i = 0
            for line in file:        
                line = line.strip()
                if i < 9:
                    line = line[2:]
                else:
                    line = line[3:]
                species.append(line)
                i += 1
            file.close()

        reactions = []
        with open('qt_reactions_list.txt','r') as file:
            for line in file:        
                line = line.strip()
                line = line[2:]
                reactions.append(line)
            file.close()

        df_cd = pd.read_csv('qt_conditions.txt', sep=r'\s+', header=0, names=['Time [s]']+conditions)
        df_sp = pd.read_csv('qt_densities.txt', sep=r'\s+', header=0, names=['Time [s]']+species)
        df_rx = pd.read_csv('qt_rates.txt', sep=r'\s+', header=0, names=['Time [s]']+reactions)

        CH4 = (df_sp['CH4'] + df_sp['CH4(V13)'] + df_sp['CH4(V24)'])/const.N_A*16
        C2H6 = (df_sp['C2H6'] + df_sp['C2H6(V13)'] + df_sp['C2H6(V24)'])/const.N_A*30
        C2H4 = (df_sp['C2H4'] + df_sp['C2H4(V1)'] + df_sp['C2H4(V2)'])/const.N_A*28
        C2H2 = (df_sp['C2H2'] + df_sp['C2H2(V13)'] + df_sp['C2H2(V2)'] + df_sp['C2H2(V5)'])/const.N_A*26
        C3H8 = (df_sp['C3H8'] + df_sp['C3H8(V1)'] + df_sp['C3H8(V2)'])/const.N_A*44
        C3H6 = (df_sp['C3H6'] + df_sp['C3H6(V)'])/const.N_A*42
        C2H = df_sp['C2H']/const.N_A*25
        CH = df_sp['CH']/const.N_A*13
        C3H7 = df_sp['C3H7']/const.N_A*43
        C3H5 = df_sp['C3H5']/const.N_A*41
        CH3 = df_sp['CH3']/const.N_A*15
        CH2 = df_sp['CH2']/const.N_A*14
        C2H3 = df_sp['C2H3']/const.N_A*27
        C4H9 = df_sp['C4H9']/const.N_A*57
        C2H5 = df_sp['C2H5']/const.N_A*29
        C3H4 = df_sp['C3H4']/const.N_A*40
        C5H12 = df_sp['C5H12']/const.N_A*72
        C4H10 = df_sp['C4H9H']/const.N_A*58

        del_CH4 = CH4.iloc[0] - CH4.iloc[-1]
        CH4_conv_cal = del_CH4/CH4.iloc[0] * 100
        total_CH = C2H6.iloc[-1] + C2H4.iloc[-1] + C2H2.iloc[-1] + C3H8.iloc[-1] + C3H6.iloc[-1] + C2H.iloc[-1] + CH.iloc[-1] + C3H7.iloc[-1] + C3H5.iloc[-1] + CH3.iloc[-1] + CH2.iloc[-1] + C2H3.iloc[-1] + C4H9.iloc[-1] + C2H5.iloc[-1] + C3H4.iloc[-1] + C5H12.iloc[-1] + C4H10.iloc[-1]
        C2H6_sel_cal = C2H6.iloc[-1]/total_CH * 100
        C2H4_sel_cal = C2H4.iloc[-1]/total_CH * 100
        C2H2_sel_cal = C2H2.iloc[-1]/total_CH * 100
        C3H8_sel_cal = C3H8.iloc[-1]/total_CH * 100
        C3H6_sel_cal = C3H6.iloc[-1]/total_CH * 100
        C2H_sel_cal = C2H.iloc[-1]/total_CH * 100
        CH_sel_cal = CH.iloc[-1]/total_CH * 100
        C3H7_sel_cal = C3H7.iloc[-1]/total_CH * 100
        C3H5_sel_cal = C3H5.iloc[-1]/total_CH * 100
        CH3_sel_cal = CH3.iloc[-1]/total_CH * 100
        CH2_sel_cal = CH2.iloc[-1]/total_CH * 100
        C2H3_sel_cal = C2H3.iloc[-1]/total_CH * 100
        C4H9_sel_cal = C4H9.iloc[-1]/total_CH * 100
        C2H5_sel_cal = C2H5.iloc[-1]/total_CH * 100
        C3H4_sel_cal = C3H4.iloc[-1]/total_CH * 100
        C5H12_sel_cal = C5H12.iloc[-1]/total_CH * 100
        C4H10_sel_cal = C4H10.iloc[-1]/total_CH * 100    

        # error 계산
        CH4_conv_exp = 20
        C2H6_sel_exp = 40
        C2H4_sel_exp = 22
        C2H2_sel_exp = 17
        C3H8_sel_exp = 5
        C3H6_sel_exp = 10
        C4H10_sel_exp = 6
        C2H_sel_exp = 0
        CH_sel_exp = 0
        C3H7_sel_exp = 0
        C3H5_sel_exp = 0
        CH3_sel_exp = 0
        CH2_sel_exp = 0
        C2H3_sel_exp = 0
        C4H9_sel_exp = 0
        C2H5_sel_exp = 0
        C3H4_sel_exp = 0
        C5H12_sel_exp = 0
        err = 0
        err += (CH4_conv_cal - CH4_conv_exp)**2 * 10
        err += (C2H6_sel_cal - C2H6_sel_exp)**2
        err += (C2H4_sel_cal - C2H4_sel_exp)**2
        err += (C2H2_sel_cal - C2H2_sel_exp)**2
        err += (C3H8_sel_cal - C3H8_sel_exp)**2
        err += (C3H6_sel_cal - C3H6_sel_exp)**2
        err += (C4H10_sel_cal - C4H10_sel_exp)**2
        err += (C2H_sel_cal - C2H_sel_exp)**2
        err += (CH_sel_cal - CH_sel_exp)**2
        err += (C3H7_sel_cal - C3H7_sel_exp)**2
        err += (C3H5_sel_cal - C3H5_sel_exp)**2
        err += (CH3_sel_cal - CH3_sel_exp)**2
        err += (CH2_sel_cal - CH2_sel_exp)**2
        err += (C2H3_sel_cal - C2H3_sel_exp)**2
        err += (C4H9_sel_cal - C4H9_sel_exp)**2
        err += (C2H5_sel_cal - C2H5_sel_exp)**2
        err += (C3H4_sel_cal - C3H4_sel_exp)**2
        err += (C5H12_sel_cal - C5H12_sel_exp)**2
        err_arr.append(err)
    return err_arr  # 간단한 예시, 실제로는 모델의 에러를 반환해야 함

# %%
best = []

# %%
# 최적화 실행
bounds = np.array([[0, 1]] * 38)  # 각 파라미터의 범위를 -10에서 10으로 설정
best_params = bayesian_optimization(1000, objective_function, bounds)
best = best_params
print("Best parameters found:", best_params)
print("Best error:", objective_function(best_params.reshape(1, -1))[0])
# Out:
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 1/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 2/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 3/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 4/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 5/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 6/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 7/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 8/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 9/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 10/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 11/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 12/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 13/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 14/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 15/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 16/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 17/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 18/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 19/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 20/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 21/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 22/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 23/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 24/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 25/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 26/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 27/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 28/1000, Best error: 4217.090141385867
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 29/1000, Best error: 4146.102629848323
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 30/1000, Best error: 4146.102629848323
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 31/1000, Best error: 4146.102629848323
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 32/1000, Best error: 4146.102629848323
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 33/1000, Best error: 4146.102629848323
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 34/1000, Best error: 4146.102629848323
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 35/1000, Best error: 4146.102629848323
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 36/1000, Best error: 4146.102629848323
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 37/1000, Best error: 4146.102629848323
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 38/1000, Best error: 4146.102629848323
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 39/1000, Best error: 4146.102629848323
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 40/1000, Best error: 4146.102629848323
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 41/1000, Best error: 4082.2990466506526
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 42/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 43/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 44/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 45/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 46/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 47/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 48/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 49/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 50/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 51/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 52/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 53/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 54/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 55/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 56/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 57/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 58/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 59/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 60/1000, Best error: 3917.0063045811576
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 61/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 62/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 63/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 64/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 65/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 66/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 67/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 68/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 69/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 70/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 71/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 72/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 73/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 74/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 75/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 76/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 77/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 78/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 79/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 80/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 81/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 82/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 83/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 84/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 85/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 86/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 87/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 88/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 89/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 90/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 91/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 92/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 93/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 94/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 95/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 96/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 97/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 98/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 99/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 100/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 101/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 102/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 103/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 104/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 105/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 106/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 107/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 108/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 109/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 110/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 111/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 112/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 113/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 114/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 115/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 116/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 117/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 118/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 119/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 120/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 121/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 122/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 123/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 124/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 125/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 126/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 127/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 128/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 129/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 130/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 131/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 132/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 133/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 134/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 135/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 136/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 137/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 138/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 139/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 140/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 141/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 142/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 143/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 144/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 145/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 146/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 147/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 148/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 149/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 150/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 151/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 152/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 153/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 154/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 155/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 156/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 157/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 158/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 159/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 160/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 161/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 162/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 163/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 164/1000, Best error: 3769.5673685426673
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 165/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 166/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 167/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 168/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 169/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 170/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 171/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 172/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 173/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 174/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 175/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 176/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 177/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 178/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 179/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 180/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 181/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 182/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 183/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 184/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 185/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 186/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 187/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 188/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 189/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 190/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 191/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 192/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 193/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 194/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 195/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 196/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 197/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 198/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 199/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 200/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 201/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 202/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 203/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 204/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 205/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 206/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 207/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 208/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 209/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 210/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 211/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 212/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 213/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 214/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 215/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 216/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 217/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 218/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 219/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 220/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 221/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 222/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 223/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 224/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 225/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 226/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 227/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 228/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 229/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 230/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 231/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 232/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 233/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 234/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 235/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 236/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 237/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 238/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 239/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 240/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 241/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 242/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 243/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 244/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 245/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 246/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 247/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 248/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 249/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 250/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 251/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 252/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 253/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 254/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 255/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 256/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 257/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 258/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 259/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 260/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 261/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 262/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 263/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 264/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 265/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 266/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 267/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 268/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 269/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 270/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 271/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 272/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 273/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 274/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 275/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 276/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 277/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 278/1000, Best error: 3675.535934065031
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 279/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 280/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 281/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 282/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 283/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 284/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 285/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 286/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 287/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 288/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 289/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 290/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 291/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 292/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 293/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 294/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 295/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 296/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 297/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 298/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 299/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 300/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 301/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 302/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 303/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 304/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 305/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 306/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 307/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 308/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 309/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 310/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 311/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 312/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 313/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 314/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 315/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 316/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 317/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 318/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 319/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 320/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 321/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 322/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 323/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 324/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 325/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 326/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 327/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 328/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 329/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 330/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 331/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 332/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 333/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 334/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 335/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 336/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 337/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 338/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 339/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 340/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 341/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 342/1000, Best error: 3588.6700135733554
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Iteration 343/1000, Best error: 3588.6700135733554
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 # 최적화 실행
#       2 bounds = np.array([[0, 1]] * 19)  # 각 파라미터의 범위를 -10에서 10으로 설정
# ----> 3 best_params = bayesian_optimization(1000, objective_function, bounds)
#       4 best = best_params
#       5 print("Best parameters found:", best_params)
#
# Cell In[8], line 13, in bayesian_optimization(n_iters, objective_function, bounds)
#      10 gp.fit(X_sample, Y_sample)
#      12 # 다음 샘플링 위치 제안
# ---> 13 next_sample = propose_location(expected_improvement, X_sample, Y_sample, gp, bounds)
#      15 # 새 샘플에 대한 목적 함수 계산
#      16 next_sample_value = objective_function(next_sample)
#
# Cell In[7], line 50, in propose_location(acquisition, X_sample, Y_sample, gp, bounds, n_restarts)
#      47     return -acquisition(X.reshape(1, -1), X_sample, gp, Y_sample).ravel()
#      49 for x0 in np.random.uniform(bounds[:, 0], bounds[:, 1], size=(n_restarts, dim)):
# ---> 50     res = minimize(min_obj, x0=x0, bounds=bounds, method='L-BFGS-B')
#      51     if res.fun < min_val:
#      52         min_val = res.fun
#
# File c:\Python\Python312\Lib\site-packages\scipy\optimize\_minimize.py:713, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     710     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     711                              **options)
#     712 elif meth == 'l-bfgs-b':
# --> 713     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     714                            callback=callback, **options)
#     715 elif meth == 'tnc':
#     716     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     717                         **options)
#
# File c:\Python\Python312\Lib\site-packages\scipy\optimize\_lbfgsb_py.py:407, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     401 task_str = task.tobytes()
#     402 if task_str.startswith(b'FG'):
#     403     # The minimization routine wants f and g at the current x.
#     404     # Note that interruptions due to maxfun are postponed
#     405     # until the completion of the current minimization iteration.
#     406     # Overwrite f and g:
# --> 407     f, g = func_and_grad(x)
#     408 elif task_str.startswith(b'NEW_X'):
#     409     # new iteration
#     410     n_iterations += 1
#
# File c:\Python\Python312\Lib\site-packages\scipy\optimize\_differentiable_functions.py:297, in ScalarFunction.fun_and_grad(self, x)
#     295     self._update_x_impl(x)
#     296 self._update_fun()
# --> 297 self._update_grad()
#     298 return self.f, self.g
#
# File c:\Python\Python312\Lib\site-packages\scipy\optimize\_differentiable_functions.py:267, in ScalarFunction._update_grad(self)
#     265 def _update_grad(self):
#     266     if not self.g_updated:
# --> 267         self._update_grad_impl()
#     268         self.g_updated = True
#
# File c:\Python\Python312\Lib\site-packages\scipy\optimize\_differentiable_functions.py:181, in ScalarFunction.__init__.<locals>.update_grad()
#     179 self._update_fun()
#     180 self.ngev += 1
# --> 181 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     182                            **finite_diff_options)
#
# File c:\Python\Python312\Lib\site-packages\scipy\optimize\_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File c:\Python\Python312\Lib\site-packages\scipy\optimize\_numdiff.py:590, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     588     x = x0 + h_vecs[i]
#     589     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 590     df = fun(x) - f0
#     591 elif method == '3-point' and use_one_sided[i]:
#     592     x1 = x0 + h_vecs[i]
#
# File c:\Python\Python312\Lib\site-packages\scipy\optimize\_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File c:\Python\Python312\Lib\site-packages\scipy\optimize\_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# Cell In[7], line 47, in propose_location.<locals>.min_obj(X)
#      46 def min_obj(X):
# ---> 47     return -acquisition(X.reshape(1, -1), X_sample, gp, Y_sample).ravel()
#
# Cell In[7], line 28, in expected_improvement(X, X_sample, gp, y_sample, xi)
#      26 def expected_improvement(X, X_sample, gp, y_sample, xi=0.01):
#      27     mu, sigma = gp.predict(X)
# ---> 28     mu_sample = gp.predict(X_sample)[0]
#      30     sigma = sigma.reshape(-1, 1)
#      31     mu_sample_opt = np.max(mu_sample)
#
# Cell In[7], line 17, in GaussianProcess.predict(self, X_test)
#      14 K_s  = self.kernel(self.X_train, X_test)
#      15 K_ss = self.kernel(X_test, X_test)
# ---> 17 Lk = np.linalg.solve(self.L, K_s)
#      18 mu = K_s.T.dot(self.alpha)
#      19 s2 = np.diag(K_ss) - np.sum(Lk**2, axis=0)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\_linalg.py:413, in solve(a, b)
#     410 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     411 with errstate(call=_raise_linalgerror_singular, invalid='call',
#     412               over='ignore', divide='ignore', under='ignore'):
# --> 413     r = gufunc(a, b, signature=signature)
#     415 return wrap(r.astype(result_t, copy=False))
#
# KeyboardInterrupt:

# %%
print("Best parameters found:", best_params)
print("Best error:", objective_function(best_params.reshape(1, -1))[0])
# Out:
# Best parameters found: [ 3.11547284  1.59629022 -2.07221363 -1.21170692  0.8096885   0.17256316
#  -0.09055984 -1.92959856  2.96405621 -3.9160086  -0.00844079 -0.05317957
#  -2.43293842  0.69529757 -0.62474432 -1.9562296  -3.22592067 -0.53126177
#  -3.23064137  3.85559582 -0.62607182  1.04457316 -3.38972344 -3.94622671
#  -1.58709388  2.44671797  2.39676737 -2.18094136 -3.63083483  2.15826075
#   3.64658776 -0.07814103  3.63106273  0.35848401  0.7087804  -0.05970387
#  -3.68404644 -3.00742111 -3.76087901 -1.03186482  1.71581181 -1.72610961
#   1.9005566  -0.09534281 -1.51477164  1.74251698  2.48760574 -3.32908055
#   3.08914097  3.41412905  2.69545855  0.9370646  -3.90492266 -0.76497733
#   1.32524489 -1.38273259 -0.27191811 -2.62281439  0.23665241  1.98902383
#   0.41041556 -1.6408071  -3.82663258 -3.87301713  3.10079389  0.36640353
#  -1.6480377  -2.01352143 -3.85478662  1.74716724 -1.04468837 -3.87082409
#  -2.80650689  3.15454188 -3.06505711 -3.99058733  1.10139173  3.73522622
#   3.25452195  2.51221957  1.34588256  3.79621063  0.72260147  2.49430098
#  -2.14774102 -0.96775082  0.72631256  1.14391535 -2.57725653  1.04802527
#   1.28892433 -3.43909841 -2.11289554 -3.45309402 -3.17435308 -3.77601887
#   3.93502115 -1.96433541 -2.808196   -0.98887488 -1.8647168  -1.35976822
#  -3.85222594 -0.78263389  2.90943218  3.68907172  0.38762077  1.89186865
#  -1.54427244 -0.42583814 -3.63609136  0.99670023 -0.90882796  1.99346923
#   3.80567678 -1.45482418 -1.98933672 -0.63606262 -3.58965807  0.67450639
#  -3.64883736  1.15775933  3.64972012 -0.40182112 -1.44810999  1.3742018
#  -1.01697394 -2.58068569 -2.96250906  0.85456028 -2.18504323 -3.28275684
#  -3.43525511  3.13632835]
# kinet.inp 파일의 파라미터가 성공적으로 업데이트되었습니다.
# 지정된 문자열이 감지되었습니다. 프로그램을 종료합니다.
# Best error: 2894.0830467200517
