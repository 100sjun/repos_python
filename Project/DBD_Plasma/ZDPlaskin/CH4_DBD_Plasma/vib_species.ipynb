# %%
import pandas as pd

# %%
f_path = './kinetic_DB/'

i_list = list(range(22,148))
f_i = 148
for i in i_list:
    f_name = 'reaction_%d.csv'%i
    f = pd.read_csv(f_path+f_name)

    if f['Species'].loc[0].split(' ')[-1] == 'CH4':
        f_copy1 = f.copy()
        f_copy2 = f.copy()

        R_comp = f_copy1['Reaction'].loc[0].split(' ')
        R_comp[0] = 'CH4(v24)'
        R_revised = ' '.join(R_comp)
        f_copy1['Reaction'] = R_revised

        S_comp = f_copy1['Species'].loc[0].split(' ')
        S_comp[-1] = 'CH4(v24)'
        S_revised = ' '.join(S_comp)
        f_copy1['Species'] = S_revised

        F_comp = f_copy1['Formula'].loc[0].split(' ')
        F_comp[2] = 'CH4(v24)'
        F_revised = ' '.join(F_comp)
        f_copy1['Formula'] = F_revised

        R_comp = f_copy2['Reaction'].loc[0].split(' ')
        R_comp[0] = 'CH4(v13)'
        R_revised = ' '.join(R_comp)
        f_copy2['Reaction'] = R_revised

        S_comp = f_copy2['Species'].loc[0].split(' ')
        S_comp[-1] = 'CH4(v13)'
        S_revised = ' '.join(S_comp)
        f_copy2['Species'] = S_revised

        F_comp = f_copy2['Formula'].loc[0].split(' ')
        F_comp[2] = 'CH4(v13)'
        F_revised = ' '.join(F_comp)
        f_copy2['Formula'] = F_revised

        f_copy1.to_csv('./kinetic_DB/reaction_%d.csv'%f_i)
        f_i += 1
        f_copy2.to_csv('./kinetic_DB/reaction_%d.csv'%f_i)
        f_i += 1

    elif f['Species'].loc[0].split(' ')[-1] == 'C2H6':
        f_copy1 = f.copy()
        f_copy2 = f.copy()

        R_comp = f_copy1['Reaction'].loc[0].split(' ')
        R_comp[0] = 'C2H6(v24)'
        R_revised = ' '.join(R_comp)
        f_copy1['Reaction'] = R_revised

        S_comp = f_copy1['Species'].loc[0].split(' ')
        S_comp[-1] = 'C2H6(v24)'
        S_revised = ' '.join(S_comp)
        f_copy1['Species'] = S_revised

        F_comp = f_copy1['Formula'].loc[0].split(' ')
        F_comp[2] = 'C2H6(v24)'
        F_revised = ' '.join(F_comp)
        f_copy1['Formula'] = F_revised

        R_comp = f_copy2['Reaction'].loc[0].split(' ')
        R_comp[0] = 'C2H6(v13)'
        R_revised = ' '.join(R_comp)
        f_copy2['Reaction'] = R_revised

        S_comp = f_copy2['Species'].loc[0].split(' ')
        S_comp[-1] = 'C2H6(v13)'
        S_revised = ' '.join(S_comp)
        f_copy2['Species'] = S_revised

        F_comp = f_copy2['Formula'].loc[0].split(' ')
        F_comp[2] = 'C2H6(v13)'
        F_revised = ' '.join(F_comp)
        f_copy2['Formula'] = F_revised

        f_copy1.to_csv('./kinetic_DB/reaction_%d.csv'%f_i)
        f_i += 1
        f_copy2.to_csv('./kinetic_DB/reaction_%d.csv'%f_i)
        f_i += 1

    elif f['Species'].loc[0].split(' ')[-1] == 'C2H4':
        f_copy1 = f.copy()
        f_copy2 = f.copy()

        R_comp = f_copy1['Reaction'].loc[0].split(' ')
        R_comp[0] = 'C2H4(v1)'
        R_revised = ' '.join(R_comp)
        f_copy1['Reaction'] = R_revised

        S_comp = f_copy1['Species'].loc[0].split(' ')
        S_comp[-1] = 'C2H4(v1)'
        S_revised = ' '.join(S_comp)
        f_copy1['Species'] = S_revised

        F_comp = f_copy1['Formula'].loc[0].split(' ')
        F_comp[2] = 'C2H4(v1)'
        F_revised = ' '.join(F_comp)
        f_copy1['Formula'] = F_revised

        R_comp = f_copy2['Reaction'].loc[0].split(' ')
        R_comp[0] = 'C2H4(v2)'
        R_revised = ' '.join(R_comp)
        f_copy2['Reaction'] = R_revised

        S_comp = f_copy2['Species'].loc[0].split(' ')
        S_comp[-1] = 'C2H4(v2)'
        S_revised = ' '.join(S_comp)
        f_copy2['Species'] = S_revised

        F_comp = f_copy2['Formula'].loc[0].split(' ')
        F_comp[2] = 'C2H4(v2)'
        F_revised = ' '.join(F_comp)
        f_copy2['Formula'] = F_revised

        f_copy1.to_csv('./kinetic_DB/reaction_%d.csv'%f_i)
        f_i += 1
        f_copy2.to_csv('./kinetic_DB/reaction_%d.csv'%f_i)
        f_i += 1

    elif f['Species'].loc[0].split(' ')[-1] == 'C2H2':
        f_copy1 = f.copy()
        f_copy2 = f.copy()
        f_copy3 = f.copy()

        R_comp = f_copy1['Reaction'].loc[0].split(' ')
        R_comp[0] = 'C2H2(v5)'
        R_revised = ' '.join(R_comp)
        f_copy1['Reaction'] = R_revised

        S_comp = f_copy1['Species'].loc[0].split(' ')
        S_comp[-1] = 'C2H2(v5)'
        S_revised = ' '.join(S_comp)
        f_copy1['Species'] = S_revised

        F_comp = f_copy1['Formula'].loc[0].split(' ')
        F_comp[2] = 'C2H2(v5)'
        F_revised = ' '.join(F_comp)
        f_copy1['Formula'] = F_revised

        R_comp = f_copy2['Reaction'].loc[0].split(' ')
        R_comp[0] = 'C2H2(v2)'
        R_revised = ' '.join(R_comp)
        f_copy2['Reaction'] = R_revised

        S_comp = f_copy2['Species'].loc[0].split(' ')
        S_comp[-1] = 'C2H2(v2)'
        S_revised = ' '.join(S_comp)
        f_copy2['Species'] = S_revised

        F_comp = f_copy2['Formula'].loc[0].split(' ')
        F_comp[2] = 'C2H2(v2)'
        F_revised = ' '.join(F_comp)
        f_copy2['Formula'] = F_revised

        R_comp = f_copy3['Reaction'].loc[0].split(' ')
        R_comp[0] = 'C2H2(v13)'
        R_revised = ' '.join(R_comp)
        f_copy3['Reaction'] = R_revised

        S_comp = f_copy3['Species'].loc[0].split(' ')
        S_comp[-1] = 'C2H2(v13)'
        S_revised = ' '.join(S_comp)
        f_copy3['Species'] = S_revised

        F_comp = f_copy3['Formula'].loc[0].split(' ')
        F_comp[2] = 'C2H2(v13)'
        F_revised = ' '.join(F_comp)
        f_copy3['Formula'] = F_revised

        f_copy1.to_csv('./kinetic_DB/reaction_%d.csv'%f_i)
        f_i += 1
        f_copy2.to_csv('./kinetic_DB/reaction_%d.csv'%f_i)
        f_i += 1
        f_copy3.to_csv('./kinetic_DB/reaction_%d.csv'%f_i)
        f_i += 1

    elif f['Species'].loc[0].split(' ')[-1] == 'C3H8':
        f_copy1 = f.copy()
        f_copy2 = f.copy()

        R_comp = f_copy1['Reaction'].loc[0].split(' ')
        R_comp[0] = 'C3H8(v1)'
        R_revised = ' '.join(R_comp)
        f_copy1['Reaction'] = R_revised

        S_comp = f_copy1['Species'].loc[0].split(' ')
        S_comp[-1] = 'C3H8(v1)'
        S_revised = ' '.join(S_comp)
        f_copy1['Species'] = S_revised

        F_comp = f_copy1['Formula'].loc[0].split(' ')
        F_comp[2] = 'C3H8(v1)'
        F_revised = ' '.join(F_comp)
        f_copy1['Formula'] = F_revised

        R_comp = f_copy2['Reaction'].loc[0].split(' ')
        R_comp[0] = 'C3H8(v2)'
        R_revised = ' '.join(R_comp)
        f_copy2['Reaction'] = R_revised

        S_comp = f_copy2['Species'].loc[0].split(' ')
        S_comp[-1] = 'C3H8(v2)'
        S_revised = ' '.join(S_comp)
        f_copy2['Species'] = S_revised

        F_comp = f_copy2['Formula'].loc[0].split(' ')
        F_comp[2] = 'C3H8(v2)'
        F_revised = ' '.join(F_comp)
        f_copy2['Formula'] = F_revised

        f_copy1.to_csv('./kinetic_DB/reaction_%d.csv'%f_i)
        f_i += 1
        f_copy2.to_csv('./kinetic_DB/reaction_%d.csv'%f_i)
        f_i += 1

    elif f['Species'].loc[0].split(' ')[-1] == 'C3H8':
        f_copy1 = f.copy()

        R_comp = f_copy1['Reaction'].loc[0].split(' ')
        R_comp[0] = 'C3H6(v)'
        R_revised = ' '.join(R_comp)
        f_copy1['Reaction'] = R_revised

        S_comp = f_copy1['Species'].loc[0].split(' ')
        S_comp[-1] = 'C3H6(v)'
        S_revised = ' '.join(S_comp)
        f_copy1['Species'] = S_revised

        F_comp = f_copy1['Formula'].loc[0].split(' ')
        F_comp[2] = 'C3H6(v)'
        F_revised = ' '.join(F_comp)
        f_copy1['Formula'] = F_revised
        
        f_copy1.to_csv('./kinetic_DB/reaction_%d.csv'%f_i)
        f_i += 1

# %%
if f['Species'].loc[0].split(' ')[-1] == 'CH4':
    f_copy1 = f.copy()
    f_copy2 = f.copy()

    R_comp = f_copy1['Reaction'].loc[0].split(' ')
    R_comp[0] = 'CH4(v24)'
    R_revised = ' '.join(R_comp)
    f_copy1['Reaction'] = R_revised

    S_comp = f_copy1['Species'].loc[0].split(' ')
    S_comp[-1] = 'CH4(v24)'
    S_revised = ' '.join(S_comp)
    f_copy1['Species'] = S_revised

    F_comp = f_copy1['Formula'].loc[0].split(' ')
    F_comp[2] = 'CH4(v24)'
    F_revised = ' '.join(F_comp)
    f_copy1['Formula'] = F_revised

    R_comp = f_copy2['Reaction'].loc[0].split(' ')
    R_comp[0] = 'CH4(v13)'
    R_revised = ' '.join(R_comp)
    f_copy2['Reaction'] = R_revised

    S_comp = f_copy2['Species'].loc[0].split(' ')
    S_comp[-1] = 'CH4(v13)'
    S_revised = ' '.join(S_comp)
    f_copy2['Species'] = S_revised

    F_comp = f_copy2['Formula'].loc[0].split(' ')
    F_comp[2] = 'CH4(v13)'
    F_revised = ' '.join(F_comp)
    f_copy2['Formula'] = F_revised

elif f['Species'].loc[0].split(' ')[-1] == 'C2H6':
    f_copy1 = f.copy()
    f_copy2 = f.copy()

    R_comp = f_copy1['Reaction'].loc[0].split(' ')
    R_comp[0] = 'C2H6(v24)'
    R_revised = ' '.join(R_comp)
    f_copy1['Reaction'] = R_revised

    S_comp = f_copy1['Species'].loc[0].split(' ')
    S_comp[-1] = 'C2H6(v24)'
    S_revised = ' '.join(S_comp)
    f_copy1['Species'] = S_revised

    F_comp = f_copy1['Formula'].loc[0].split(' ')
    F_comp[2] = 'C2H6(v24)'
    F_revised = ' '.join(F_comp)
    f_copy1['Formula'] = F_revised

    R_comp = f_copy2['Reaction'].loc[0].split(' ')
    R_comp[0] = 'C2H6(v13)'
    R_revised = ' '.join(R_comp)
    f_copy2['Reaction'] = R_revised

    S_comp = f_copy2['Species'].loc[0].split(' ')
    S_comp[-1] = 'C2H6(v13)'
    S_revised = ' '.join(S_comp)
    f_copy2['Species'] = S_revised

    F_comp = f_copy2['Formula'].loc[0].split(' ')
    F_comp[2] = 'C2H6(v13)'
    F_revised = ' '.join(F_comp)
    f_copy2['Formula'] = F_revised

elif f['Species'].loc[0].split(' ')[-1] == 'C2H4':
    f_copy1 = f.copy()
    f_copy2 = f.copy()

    R_comp = f_copy1['Reaction'].loc[0].split(' ')
    R_comp[0] = 'C2H4(v1)'
    R_revised = ' '.join(R_comp)
    f_copy1['Reaction'] = R_revised

    S_comp = f_copy1['Species'].loc[0].split(' ')
    S_comp[-1] = 'C2H4(v1)'
    S_revised = ' '.join(S_comp)
    f_copy1['Species'] = S_revised

    F_comp = f_copy1['Formula'].loc[0].split(' ')
    F_comp[2] = 'C2H4(v1)'
    F_revised = ' '.join(F_comp)
    f_copy1['Formula'] = F_revised

    R_comp = f_copy2['Reaction'].loc[0].split(' ')
    R_comp[0] = 'C2H4(v2)'
    R_revised = ' '.join(R_comp)
    f_copy2['Reaction'] = R_revised

    S_comp = f_copy2['Species'].loc[0].split(' ')
    S_comp[-1] = 'C2H4(v2)'
    S_revised = ' '.join(S_comp)
    f_copy2['Species'] = S_revised

    F_comp = f_copy2['Formula'].loc[0].split(' ')
    F_comp[2] = 'C2H4(v2)'
    F_revised = ' '.join(F_comp)
    f_copy2['Formula'] = F_revised

elif f['Species'].loc[0].split(' ')[-1] == 'C2H2':
    f_copy1 = f.copy()
    f_copy2 = f.copy()
    f_copy3 = f.copy()

    R_comp = f_copy1['Reaction'].loc[0].split(' ')
    R_comp[0] = 'C2H2(v5)'
    R_revised = ' '.join(R_comp)
    f_copy1['Reaction'] = R_revised

    S_comp = f_copy1['Species'].loc[0].split(' ')
    S_comp[-1] = 'C2H2(v5)'
    S_revised = ' '.join(S_comp)
    f_copy1['Species'] = S_revised

    F_comp = f_copy1['Formula'].loc[0].split(' ')
    F_comp[2] = 'C2H2(v5)'
    F_revised = ' '.join(F_comp)
    f_copy1['Formula'] = F_revised

    R_comp = f_copy2['Reaction'].loc[0].split(' ')
    R_comp[0] = 'C2H2(v2)'
    R_revised = ' '.join(R_comp)
    f_copy2['Reaction'] = R_revised

    S_comp = f_copy2['Species'].loc[0].split(' ')
    S_comp[-1] = 'C2H2(v2)'
    S_revised = ' '.join(S_comp)
    f_copy2['Species'] = S_revised

    F_comp = f_copy2['Formula'].loc[0].split(' ')
    F_comp[2] = 'C2H2(v2)'
    F_revised = ' '.join(F_comp)
    f_copy2['Formula'] = F_revised

    R_comp = f_copy3['Reaction'].loc[0].split(' ')
    R_comp[0] = 'C2H2(v13)'
    R_revised = ' '.join(R_comp)
    f_copy3['Reaction'] = R_revised

    S_comp = f_copy3['Species'].loc[0].split(' ')
    S_comp[-1] = 'C2H2(v13)'
    S_revised = ' '.join(S_comp)
    f_copy3['Species'] = S_revised

    F_comp = f_copy3['Formula'].loc[0].split(' ')
    F_comp[2] = 'C2H2(v13)'
    F_revised = ' '.join(F_comp)
    f_copy3['Formula'] = F_revised

elif f['Species'].loc[0].split(' ')[-1] == 'C3H8':
    f_copy1 = f.copy()
    f_copy2 = f.copy()

    R_comp = f_copy1['Reaction'].loc[0].split(' ')
    R_comp[0] = 'C3H8(v1)'
    R_revised = ' '.join(R_comp)
    f_copy1['Reaction'] = R_revised

    S_comp = f_copy1['Species'].loc[0].split(' ')
    S_comp[-1] = 'C3H8(v1)'
    S_revised = ' '.join(S_comp)
    f_copy1['Species'] = S_revised

    F_comp = f_copy1['Formula'].loc[0].split(' ')
    F_comp[2] = 'C3H8(v1)'
    F_revised = ' '.join(F_comp)
    f_copy1['Formula'] = F_revised

    R_comp = f_copy2['Reaction'].loc[0].split(' ')
    R_comp[0] = 'C3H8(v2)'
    R_revised = ' '.join(R_comp)
    f_copy2['Reaction'] = R_revised

    S_comp = f_copy2['Species'].loc[0].split(' ')
    S_comp[-1] = 'C3H8(v2)'
    S_revised = ' '.join(S_comp)
    f_copy2['Species'] = S_revised

    F_comp = f_copy2['Formula'].loc[0].split(' ')
    F_comp[2] = 'C3H8(v2)'
    F_revised = ' '.join(F_comp)
    f_copy2['Formula'] = F_revised
elif f['Species'].loc[0].split(' ')[-1] == 'C3H8':
    f_copy1 = f.copy()

    R_comp = f_copy1['Reaction'].loc[0].split(' ')
    R_comp[0] = 'C3H6(v)'
    R_revised = ' '.join(R_comp)
    f_copy1['Reaction'] = R_revised

    S_comp = f_copy1['Species'].loc[0].split(' ')
    S_comp[-1] = 'C3H6(v)'
    S_revised = ' '.join(S_comp)
    f_copy1['Species'] = S_revised

    F_comp = f_copy1['Formula'].loc[0].split(' ')
    F_comp[2] = 'C3H6(v)'
    F_revised = ' '.join(F_comp)
    f_copy1['Formula'] = F_revised

# %%
f_copy1
# Out:
#     Num        Type             Reaction  ELoss        Species  \
# 0    38  EXCITATION  C2H6(v24) -> C2H5 H   7.45  e / C2H6(v24)
# 1    38  EXCITATION  C2H6(v24) -> C2H5 H   7.45  e / C2H6(v24)
# 2    38  EXCITATION  C2H6(v24) -> C2H5 H   7.45  e / C2H6(v24)
# 3    38  EXCITATION  C2H6(v24) -> C2H5 H   7.45  e / C2H6(v24)
# 4    38  EXCITATION  C2H6(v24) -> C2H5 H   7.45  e / C2H6(v24)
# 5    38  EXCITATION  C2H6(v24) -> C2H5 H   7.45  e / C2H6(v24)
# 6    38  EXCITATION  C2H6(v24) -> C2H5 H   7.45  e / C2H6(v24)
# 7    38  EXCITATION  C2H6(v24) -> C2H5 H   7.45  e / C2H6(v24)
# 8    38  EXCITATION  C2H6(v24) -> C2H5 H   7.45  e / C2H6(v24)
# 9    38  EXCITATION  C2H6(v24) -> C2H5 H   7.45  e / C2H6(v24)
# 10   38  EXCITATION  C2H6(v24) -> C2H5 H   7.45  e / C2H6(v24)
# 11   38  EXCITATION  C2H6(v24) -> C2H5 H   7.45  e / C2H6(v24)
# 12   38  EXCITATION  C2H6(v24) -> C2H5 H   7.45  e / C2H6(v24)
# 13   38  EXCITATION  C2H6(v24) -> C2H5 H   7.45  e / C2H6(v24)
# ...

# %%
f_copy2
# Out:
#     Num        Type             Reaction  ELoss        Species  \
# 0    38  EXCITATION  C2H6(v13) -> C2H5 H   7.45  e / C2H6(v13)
# 1    38  EXCITATION  C2H6(v13) -> C2H5 H   7.45  e / C2H6(v13)
# 2    38  EXCITATION  C2H6(v13) -> C2H5 H   7.45  e / C2H6(v13)
# 3    38  EXCITATION  C2H6(v13) -> C2H5 H   7.45  e / C2H6(v13)
# 4    38  EXCITATION  C2H6(v13) -> C2H5 H   7.45  e / C2H6(v13)
# 5    38  EXCITATION  C2H6(v13) -> C2H5 H   7.45  e / C2H6(v13)
# 6    38  EXCITATION  C2H6(v13) -> C2H5 H   7.45  e / C2H6(v13)
# 7    38  EXCITATION  C2H6(v13) -> C2H5 H   7.45  e / C2H6(v13)
# 8    38  EXCITATION  C2H6(v13) -> C2H5 H   7.45  e / C2H6(v13)
# 9    38  EXCITATION  C2H6(v13) -> C2H5 H   7.45  e / C2H6(v13)
# 10   38  EXCITATION  C2H6(v13) -> C2H5 H   7.45  e / C2H6(v13)
# 11   38  EXCITATION  C2H6(v13) -> C2H5 H   7.45  e / C2H6(v13)
# 12   38  EXCITATION  C2H6(v13) -> C2H5 H   7.45  e / C2H6(v13)
# 13   38  EXCITATION  C2H6(v13) -> C2H5 H   7.45  e / C2H6(v13)
# ...
