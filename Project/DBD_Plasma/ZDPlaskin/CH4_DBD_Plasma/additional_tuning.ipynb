# %%
import pandas as pd

# %%
i = 228
file_path = './ZDPlaskin/kinetic_DB/'
file_name = 'reaction_%d.csv'%i
df = pd.read_csv(file_path+file_name)
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Num        Type  \
# 0             0             0           0  103  IONIZATION
# 1             1             1           1  103  IONIZATION
# 2             2             2           2  103  IONIZATION
# 3             3             3           3  103  IONIZATION
# 4             4             4           4  103  IONIZATION
#
#                  Reaction  ELoss        Species  \
# 0  C2H2(v13) -> CH + CH^+   23.9  e / C2H2(v13)
# 1  C2H2(v13) -> CH + CH^+   23.9  e / C2H2(v13)
# 2  C2H2(v13) -> CH + CH^+   23.9  e / C2H2(v13)
# 3  C2H2(v13) -> CH + CH^+   23.9  e / C2H2(v13)
# 4  C2H2(v13) -> CH + CH^+   23.9  e / C2H2(v13)
#
#                               Formula  Energy(eV)  Cross_section(m2)
# 0  E + C2H2(v13) -> E + E + CH + CH^+        23.9       0.000000e+00
# 1  E + C2H2(v13) -> E + E + CH + CH^+        24.0       5.859850e-24
# 2  E + C2H2(v13) -> E + E + CH + CH^+        24.5       4.652570e-23
# 3  E + C2H2(v13) -> E + E + CH + CH^+        25.0       1.011330e-22
# 4  E + C2H2(v13) -> E + E + CH + CH^+        25.5       1.645310e-22

# %%
df['Reaction'] = 'C2H2(v13) -> CH CH^+'
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  Num        Type  \
# 0             0             0           0  103  IONIZATION
# 1             1             1           1  103  IONIZATION
# 2             2             2           2  103  IONIZATION
# 3             3             3           3  103  IONIZATION
# 4             4             4           4  103  IONIZATION
#
#                Reaction  ELoss        Species  \
# 0  C2H2(v13) -> CH CH^+   23.9  e / C2H2(v13)
# 1  C2H2(v13) -> CH CH^+   23.9  e / C2H2(v13)
# 2  C2H2(v13) -> CH CH^+   23.9  e / C2H2(v13)
# 3  C2H2(v13) -> CH CH^+   23.9  e / C2H2(v13)
# 4  C2H2(v13) -> CH CH^+   23.9  e / C2H2(v13)
#
#                               Formula  Energy(eV)  Cross_section(m2)
# 0  E + C2H2(v13) -> E + E + CH + CH^+        23.9       0.000000e+00
# 1  E + C2H2(v13) -> E + E + CH + CH^+        24.0       5.859850e-24
# 2  E + C2H2(v13) -> E + E + CH + CH^+        24.5       4.652570e-23
# 3  E + C2H2(v13) -> E + E + CH + CH^+        25.0       1.011330e-22
# 4  E + C2H2(v13) -> E + E + CH + CH^+        25.5       1.645310e-22

# %%
df.to_csv(file_path+file_name)
