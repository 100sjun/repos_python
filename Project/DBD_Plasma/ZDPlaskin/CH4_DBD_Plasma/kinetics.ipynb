# %%
import pandas as pd
import re
import io

def parse_plasma_data(num,data_string):
    # 데이터를 줄 단위로 분리
    lines = [line.strip() for line in data_string.split('\n') if line.strip()]
    
    # 메타데이터 추출
    type_ = lines[0]
    reaction = lines[1]
    eloss = float(lines[2])  # ELoss 값 추출
    species = re.search(r'SPECIES: (.+)', lines[3]).group(1)
    formula = re.search(r'PROCESS: (.+?),', lines[4]).group(1)
    
    # 데이터 부분 추출
    try:
        data_start = lines.index('-----------------------------') + 1
        data_end = lines[data_start:].index('-----------------------------') + data_start
        data_lines = lines[data_start:data_end]
    except ValueError:
        print("Warning: Could not find data section. Using all lines after metadata.")
        data_lines = lines[8:]  # Assuming metadata ends at line 8
    
    # 데이터를 DataFrame으로 변환
    data_io = io.StringIO('\n'.join(data_lines))
    df = pd.read_csv(data_io, sep=r'\s+', names=['Energy(eV)', 'Cross_section(m2)'])
    
    # 메타데이터 추가
    df['Num'] = num
    df['Type'] = type_
    df['Reaction'] = reaction
    df['ELoss'] = eloss  # 새로운 ELoss 열 추가
    df['Species'] = species
    df['Formula'] = formula
    
    # 열 순서 재배열
    df = df[['Num', 'Type', 'Reaction', 'ELoss', 'Species', 'Formula', 'Energy(eV)', 'Cross_section(m2)']]
    
    return df

# %%
# 테스트 데이터
data_string = """
IONIZATION	
H2 -> H2^+	
1.54E+01	
SPECIES: e / H2	
PROCESS: E + H2 -> E + E + H2+, Ionization	
PARAM.:  E = 15.4 eV	
COMMENT: check energy loss ?.	
UPDATED: 2012-10-17 07:25:21	
COLUMNS: Energy (eV) | Cross section (m2)	
-----------------------------	
1.54E+01	0.00E+00
1.60E+01	2.99E-22
1.65E+01	6.07E-22
1.70E+01	9.24E-22
1.75E+01	1.23E-21
1.80E+01	1.56E-21
1.85E+01	1.87E-21
1.90E+01	2.20E-21
1.95E+01	2.49E-21
2.00E+01	2.80E-21
2.05E+01	3.10E-21
2.10E+01	3.36E-21
2.15E+01	3.62E-21
2.20E+01	3.90E-21
2.25E+01	4.14E-21
2.30E+01	4.39E-21
2.35E+01	4.61E-21
2.40E+01	4.84E-21
2.45E+01	5.05E-21
2.50E+01	5.24E-21
3.00E+01	6.51E-21
3.50E+01	7.60E-21
4.00E+01	8.40E-21
4.50E+01	8.80E-21
5.00E+01	9.08E-21
5.50E+01	9.31E-21
6.00E+01	9.44E-21
6.50E+01	9.48E-21
7.00E+01	9.49E-21
7.50E+01	9.44E-21
8.00E+01	9.37E-21
8.50E+01	9.28E-21
9.00E+01	9.19E-21
9.50E+01	9.11E-21
1.00E+02	9.00E-21
1.10E+02	8.72E-21
1.20E+02	8.52E-21
1.40E+02	8.06E-21
1.60E+02	7.63E-21
1.80E+02	7.14E-21
2.00E+02	6.76E-21
2.25E+02	6.36E-21
2.50E+02	5.96E-21
2.75E+02	5.56E-21
3.00E+02	5.29E-21
3.50E+02	4.77E-21
4.00E+02	4.36E-21
4.50E+02	3.98E-21
5.00E+02	3.73E-21
5.50E+02	3.39E-21
6.00E+02	3.17E-21
6.50E+02	3.02E-21
7.00E+02	2.83E-21
7.50E+02	2.72E-21
8.00E+02	2.57E-21
8.50E+02	2.48E-21
9.00E+02	2.36E-21
9.50E+02	2.22E-21
1.00E+03	2.11E-21
-----------------------------				
"""
# 함수 실행
df = parse_plasma_data(249,data_string)
# CSV 파일로 저장
df.to_csv('./ZDPlaskin/kinetic_DB/reaction_%d.csv'%df['Num'].loc[0], index=False)

# %%
df
# Out:
#     Num        Type    Reaction  ELoss Species                Formula  \
# 0   249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 1   249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 2   249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 3   249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 4   249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 5   249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 6   249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 7   249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 8   249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 9   249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 10  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 11  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 12  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 13  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 14  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 15  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 16  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 17  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 18  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 19  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 20  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 21  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 22  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 23  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 24  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 25  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 26  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 27  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 28  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 29  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 30  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 31  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 32  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 33  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 34  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 35  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 36  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 37  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 38  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 39  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 40  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 41  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 42  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 43  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 44  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 45  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 46  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 47  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 48  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 49  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 50  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 51  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 52  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 53  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 54  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 55  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 56  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 57  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
# 58  249  IONIZATION  H2 -> H2^+   15.4  e / H2  E + H2 -> E + E + H2+
#
#     Energy(eV)  Cross_section(m2)
# 0         15.4       0.000000e+00
# 1         16.0       2.990000e-22
# 2         16.5       6.070000e-22
# 3         17.0       9.240000e-22
# 4         17.5       1.230000e-21
# 5         18.0       1.560000e-21
# 6         18.5       1.870000e-21
# 7         19.0       2.200000e-21
# 8         19.5       2.490000e-21
# 9         20.0       2.800000e-21
# 10        20.5       3.100000e-21
# 11        21.0       3.360000e-21
# 12        21.5       3.620000e-21
# 13        22.0       3.900000e-21
# 14        22.5       4.140000e-21
# 15        23.0       4.390000e-21
# 16        23.5       4.610000e-21
# 17        24.0       4.840000e-21
# 18        24.5       5.050000e-21
# 19        25.0       5.240000e-21
# 20        30.0       6.510000e-21
# 21        35.0       7.600000e-21
# 22        40.0       8.400000e-21
# 23        45.0       8.800000e-21
# 24        50.0       9.080000e-21
# 25        55.0       9.310000e-21
# 26        60.0       9.440000e-21
# 27        65.0       9.480000e-21
# 28        70.0       9.490000e-21
# 29        75.0       9.440000e-21
# 30        80.0       9.370000e-21
# 31        85.0       9.280000e-21
# 32        90.0       9.190000e-21
# 33        95.0       9.110000e-21
# 34       100.0       9.000000e-21
# 35       110.0       8.720000e-21
# 36       120.0       8.520000e-21
# 37       140.0       8.060000e-21
# 38       160.0       7.630000e-21
# 39       180.0       7.140000e-21
# 40       200.0       6.760000e-21
# 41       225.0       6.360000e-21
# 42       250.0       5.960000e-21
# 43       275.0       5.560000e-21
# 44       300.0       5.290000e-21
# 45       350.0       4.770000e-21
# 46       400.0       4.360000e-21
# 47       450.0       3.980000e-21
# 48       500.0       3.730000e-21
# 49       550.0       3.390000e-21
# 50       600.0       3.170000e-21
# 51       650.0       3.020000e-21
# 52       700.0       2.830000e-21
# 53       750.0       2.720000e-21
# 54       800.0       2.570000e-21
# 55       850.0       2.480000e-21
# 56       900.0       2.360000e-21
# 57       950.0       2.220000e-21
# 58      1000.0       2.110000e-21
