# %%
import pandas as pd
import re
import io

def parse_plasma_data(num,data_string):
    # 데이터를 줄 단위로 분리
    lines = [line.strip() for line in data_string.split('\n') if line.strip()]
    
    # 메타데이터 추출
    type_ = lines[0]
    reaction = lines[1]
    eloss = float(lines[2])  # ELoss 값 추출
    species = re.search(r'SPECIES: (.+)', lines[3]).group(1)
    formula = re.search(r'PROCESS: (.+?),', lines[4]).group(1)
    
    # 데이터 부분 추출
    try:
        data_start = lines.index('-----------------------------') + 1
        data_end = lines[data_start:].index('-----------------------------') + data_start
        data_lines = lines[data_start:data_end]
    except ValueError:
        print("Warning: Could not find data section. Using all lines after metadata.")
        data_lines = lines[8:]  # Assuming metadata ends at line 8
    
    # 데이터를 DataFrame으로 변환
    data_io = io.StringIO('\n'.join(data_lines))
    df = pd.read_csv(data_io, sep=r'\s+', names=['Energy(eV)', 'Cross_section(m2)'])
    
    # 메타데이터 추가
    df['Num'] = num
    df['Type'] = type_
    df['Reaction'] = reaction
    df['ELoss'] = eloss  # 새로운 ELoss 열 추가
    df['Species'] = species
    df['Formula'] = formula
    
    # 열 순서 재배열
    df = df[['Num', 'Type', 'Reaction', 'ELoss', 'Species', 'Formula', 'Energy(eV)', 'Cross_section(m2)']]
    
    return df

# %%
# 테스트 데이터
data_string = """
IONIZATION	
C3H4 -> C2H3 + CH+	
17.98	
SPECIES: e / C3H4	
PROCESS: E + C3H4 -> E + E + C2H3 + CH+, Ionization	
PARAM.:  E = 17.98 eV, complete set	
UPDATED: 2021-10-07 15:39:38	
COLUMNS: Energy (eV) | Cross section (m2)	
-----------------------------	
17.98	0
18	6.19441E-30
18.2	7.91054E-27
18.4	5.28342E-26
18.6	1.63218E-25
18.8	3.62789E-25
19	6.71152E-25
19.2	1.10431E-24
19.4	1.67513E-24
19.6	2.39375E-24
19.8	3.26791E-24
20	4.3033E-24
23	3.92164E-23
26	1.01356E-22
30	2.00672E-22
40	4.25864E-22
50	5.75089E-22
60	6.64038E-22
70	7.14204E-22
80	7.40166E-22
90	7.50966E-22
100	7.52187E-22
-----------------------------	

"""
# 함수 실행
df = parse_plasma_data(147,data_string)
# CSV 파일로 저장
df.to_csv('./kinetic_DB/reaction_%d.csv'%df['Num'].loc[0], index=False)

# %%
df
# Out:
#     Num        Type            Reaction  ELoss   Species  \
# 0   147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 1   147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 2   147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 3   147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 4   147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 5   147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 6   147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 7   147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 8   147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 9   147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 10  147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 11  147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 12  147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 13  147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 14  147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 15  147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 16  147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 17  147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 18  147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 19  147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 20  147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
# 21  147  IONIZATION  C3H4 -> C2H3 + CH+  17.98  e / C3H4
#
#                            Formula  Energy(eV)  Cross_section(m2)
# 0   E + C3H4 -> E + E + C2H3 + CH+       17.98       0.000000e+00
# 1   E + C3H4 -> E + E + C2H3 + CH+       18.00       6.194410e-30
# 2   E + C3H4 -> E + E + C2H3 + CH+       18.20       7.910540e-27
# 3   E + C3H4 -> E + E + C2H3 + CH+       18.40       5.283420e-26
# 4   E + C3H4 -> E + E + C2H3 + CH+       18.60       1.632180e-25
# 5   E + C3H4 -> E + E + C2H3 + CH+       18.80       3.627890e-25
# 6   E + C3H4 -> E + E + C2H3 + CH+       19.00       6.711520e-25
# 7   E + C3H4 -> E + E + C2H3 + CH+       19.20       1.104310e-24
# 8   E + C3H4 -> E + E + C2H3 + CH+       19.40       1.675130e-24
# 9   E + C3H4 -> E + E + C2H3 + CH+       19.60       2.393750e-24
# 10  E + C3H4 -> E + E + C2H3 + CH+       19.80       3.267910e-24
# 11  E + C3H4 -> E + E + C2H3 + CH+       20.00       4.303300e-24
# 12  E + C3H4 -> E + E + C2H3 + CH+       23.00       3.921640e-23
# 13  E + C3H4 -> E + E + C2H3 + CH+       26.00       1.013560e-22
# 14  E + C3H4 -> E + E + C2H3 + CH+       30.00       2.006720e-22
# 15  E + C3H4 -> E + E + C2H3 + CH+       40.00       4.258640e-22
# 16  E + C3H4 -> E + E + C2H3 + CH+       50.00       5.750890e-22
# 17  E + C3H4 -> E + E + C2H3 + CH+       60.00       6.640380e-22
# 18  E + C3H4 -> E + E + C2H3 + CH+       70.00       7.142040e-22
# 19  E + C3H4 -> E + E + C2H3 + CH+       80.00       7.401660e-22
# 20  E + C3H4 -> E + E + C2H3 + CH+       90.00       7.509660e-22
# 21  E + C3H4 -> E + E + C2H3 + CH+      100.00       7.521870e-22
