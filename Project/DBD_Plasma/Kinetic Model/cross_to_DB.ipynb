# %%
### Overview
# cross section are txt 파일을 kinetic_DB 폴더에 CSV 파일로 저장하는 모듈

# %%
# Modules
import pandas as pd
import re
import io

# %%
# cross area data path
index_ca = 158    # cross area data index
path = f'./crossA_DB/{index_ca}.txt'

# Reading a text file
with open(path, 'r') as file:
    lines = file.readlines()
    data = [line.replace('\n','').rstrip() for line in lines]
    file.close()

# Meta Data
type = data[0]
reaction = data[1]
eloss = float(data[2])
species = re.search(r'SPECIES: (.+)', data[3]).group(1)
formula = re.search(r'PROCESS: (.+?),',data[4]).group(1)

reaction = re.sub(r'(\w+)\+', r'\1^+', reaction)
species = re.sub(r'(\w+)\+', r'\1^+', species)
formula = re.sub(r'(\w+)\+', r'\1^+', formula)


# cross area data
data_start = data.index('-----------------------------') + 1
data_end = data[data_start:].index('-----------------------------') + data_start
data_lines = data[data_start:data_end]

# Dataframe
data_io = io.StringIO('\n'.join(data_lines))
df = pd.read_csv(data_io, sep=r'\s+', names=['Energy(eV)', 'Cross_section(m2)'])

# Dataframe Metadata Insertion
df['Num'] = index_ca
df['Type'] = type
df['Reaction'] = reaction
df['ELoss'] = eloss
df['Species'] = species
df['Formula'] = formula

df = df[['Num', 'Type', 'Reaction', 'ELoss', 'Species', 'Formula', 'Energy(eV)', 'Cross_section(m2)']]

# %%
df
# Out:
#     Num        Type           Reaction  ELoss   Species  \
# 0   158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 1   158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 2   158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 3   158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 4   158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 5   158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 6   158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 7   158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 8   158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 9   158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 10  158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 11  158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 12  158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 13  158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 14  158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 15  158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 16  158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 17  158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
# 18  158  IONIZATION  C2H2 -> CH + CH^+   23.9  e / C2H2
#
#                           Formula  Energy(eV)  Cross_section(m2)
# 0   E + C2H2 -> E + E + CH + CH^+        23.9       0.000000e+00
# 1   E + C2H2 -> E + E + CH + CH^+        24.0       5.859850e-24
# 2   E + C2H2 -> E + E + CH + CH^+        24.5       4.652570e-23
# 3   E + C2H2 -> E + E + CH + CH^+        25.0       1.011330e-22
# 4   E + C2H2 -> E + E + CH + CH^+        25.5       1.645310e-22
# 5   E + C2H2 -> E + E + CH + CH^+        26.0       2.331550e-22
# 6   E + C2H2 -> E + E + CH + CH^+        26.5       3.045810e-22
# 7   E + C2H2 -> E + E + CH + CH^+        27.0       3.771930e-22
# 8   E + C2H2 -> E + E + CH + CH^+        27.5       4.499460e-22
# 9   E + C2H2 -> E + E + CH + CH^+        28.0       5.221930e-22
# 10  E + C2H2 -> E + E + CH + CH^+        29.0       6.638690e-22
# 11  E + C2H2 -> E + E + CH + CH^+        30.0       8.011030e-22
# 12  E + C2H2 -> E + E + CH + CH^+        40.0       2.015160e-21
# 13  E + C2H2 -> E + E + CH + CH^+        50.0       2.960600e-21
# 14  E + C2H2 -> E + E + CH + CH^+        60.0       3.565770e-21
# 15  E + C2H2 -> E + E + CH + CH^+        70.0       3.890810e-21
# 16  E + C2H2 -> E + E + CH + CH^+        80.0       4.027110e-21
# 17  E + C2H2 -> E + E + CH + CH^+        90.0       4.045780e-21
# 18  E + C2H2 -> E + E + CH + CH^+       100.0       3.994100e-21

# %%
def cross_DB(num):
    # cross area data path
    index_ca = num    # cross area data index
    path = f'./crossA_DB/{index_ca}.txt'

    # Reading a text file
    with open(path, 'r') as file:
        lines = file.readlines()
        data = [line.replace('\n','').rstrip() for line in lines]
        file.close()

    # Meta Data
    type = data[0]
    reaction = data[1]
    eloss = float(data[2])
    species = re.search(r'SPECIES: (.+)', data[3]).group(1)
    formula = re.search(r'PROCESS: (.+?),',data[4]).group(1)

    reaction = re.sub(r'(\w+)\+', r'\1^+', reaction)
    species = re.sub(r'(\w+)\+', r'\1^+', species)
    formula = re.sub(r'(\w+)\+', r'\1^+', formula)

    # cross area data
    data_start = data.index('-----------------------------') + 1
    data_end = data[data_start:].index('-----------------------------') + data_start
    data_lines = data[data_start:data_end]

    # Dataframe
    data_io = io.StringIO('\n'.join(data_lines))
    df = pd.read_csv(data_io, sep=r'\s+', names=['Energy(eV)', 'Cross_section(m2)'])

    # Dataframe Metadata Insertion
    df['Num'] = index_ca
    df['Type'] = type
    df['Reaction'] = reaction
    df['ELoss'] = eloss
    df['Species'] = species
    df['Formula'] = formula

    df = df[['Num', 'Type', 'Reaction', 'ELoss', 'Species', 'Formula', 'Energy(eV)', 'Cross_section(m2)']]

    return df

# %%
for num in range(186):
    df = cross_DB(num)
    df.to_csv(f'./kinetic_DB/reaction_{num}.csv', index=False)
