# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
species = []
with open('qt_species_list.txt','r') as f:
    for line in f:
        comp = line[2:]
        species.append(comp.strip())
    f.close()

# %%
df_sp = pd.read_csv('qt_densities.txt', sep=r'\s+', header=0, names=['Time [s]']+species)
H2 = (df_sp['H2'])
CH4 = (df_sp['CH4'] + df_sp['CH4(V13)'] + df_sp['CH4(V24)'])
C2H2 = (df_sp['C2H2'] + df_sp['C2H2(V2)'] + df_sp['C2H2(V5)'] + df_sp['C2H2(V13)'])
C2H4 = (df_sp['C2H4'] + df_sp['C2H4(V1)'] + df_sp['C2H4(V2)'])
C2H6 = (df_sp['C2H6'] + df_sp['C2H6(V13)'] + df_sp['C2H6(V24)'])
C3H6 = (df_sp['C3H6'] + df_sp['C3H6(V)'])
C3H8 = (df_sp['C3H8'] + df_sp['C3H8(V1)'] + df_sp['C3H8(V2)'])
C4H10 = (df_sp['C4H9H'])
C5H12 = (df_sp['C5H12'])
C = (df_sp['C'])
CH = (df_sp['CH'])
CH2 = (df_sp['CH2'])
CH3 = (df_sp['CH3'])
C2H3 = (df_sp['C2H3'])
C2H5 = (df_sp['C2H5'])
C3H7 = (df_sp['C3H7'])
H = (df_sp['H'])
CH3_plus = (df_sp['CH3^+'])
CH4_plus = df_sp['CH4^+']
CH5_plus = df_sp['CH5^+']
C2H2_plus = df_sp['C2H2^+']
C2H4_plus = df_sp['C2H4^+']
C2H5_plus = df_sp['C2H5^+']
C2H6_plus = df_sp['C2H6^+']
C3H6_plus = df_sp['C3H6^+']
C3H8_plus = df_sp['C3H8^+']

# %%
all_sp = df_sp.sum(axis=1) - df_sp['E']

# %%
df_sp
# Out:
#         Time [s]          E             C         CH           CH2  \
# 0       0.000000  1000000.0  0.000000e+00        0.0  0.000000e+00
# 1       0.000001  1000000.0  1.384500e+05    47939.0  1.970700e+09
# 2       0.000002  1000000.0  4.687300e+07  2489900.0  3.062300e+10
# 3       0.000003  1000000.0  1.160300e+08  3202300.0  6.522500e+10
# 4       0.000004  1000000.0  1.891500e+08  3327300.0  1.007700e+11
# ...          ...        ...           ...        ...           ...
# 1032  195.100000   938730.0  1.566500e+16  3955100.0  8.501100e+10
# 1033  196.200000   938350.0  1.576700e+16  3963800.0  8.416500e+10
# 1034  197.300000   937980.0  1.586900e+16  3971100.0  8.330600e+10
# 1035  198.400000   937600.0  1.597200e+16  3977900.0  8.245000e+10
# 1036  199.500000   937230.0  1.607400e+16  3987000.0  8.163000e+10
#
#                CH3         CH3^+           CH4      CH4(V13)      CH4(V24)  \
# 0     0.000000e+00  0.000000e+00  2.158600e+19  0.000000e+00  0.000000e+00
# 1     6.538600e+06  2.134400e-20  2.158600e+19  1.545100e+05  1.569200e+05
# 2     7.159800e+07  2.709800e-18  2.158600e+19  2.889600e+05  3.246900e+05
# 3     1.492300e+08  6.802400e-18  2.158600e+19  4.174800e+05  4.911300e+05
# 4     2.288400e+08  1.074000e-17  2.158600e+19  5.450600e+05  6.573300e+05
# ...            ...           ...           ...           ...           ...
# 1032  2.196700e+16  5.324200e-09  4.621500e+18  5.074100e+12  6.705800e+12
# 1033  2.192100e+16  5.417900e-09  4.577400e+18  5.052300e+12  6.677700e+12
# 1034  2.187500e+16  5.464900e-09  4.533600e+18  5.030300e+12  6.649300e+12
# 1035  2.183000e+16  5.506900e-09  4.490200e+18  5.008100e+12  6.620800e+12
# 1036  2.178400e+16  5.564800e-09  4.447100e+18  4.985800e+12  6.592100e+12
#
#       ...        C3H6^+          C3H7          C3H8      C3H8(V1)  \
# 0     ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1     ...  1.148900e-38  5.185400e-25  2.779500e-17  1.116000e-31
# 2     ...  6.948700e-34  1.012700e-19  8.652600e-13  3.302500e-27
# 3     ...  2.693900e-32  7.263300e-18  3.015000e-11  2.051300e-25
# 4     ...  2.306500e-31  9.582600e-17  2.596300e-10  2.605500e-24
# ...   ...           ...           ...           ...           ...
# 1032  ...  2.934300e+01  7.822500e+07  1.653200e+18  3.018700e+12
# 1033  ...  2.949200e+01  7.761700e+07  1.658500e+18  3.047900e+12
# 1034  ...  2.964100e+01  7.699200e+07  1.663700e+18  3.077100e+12
# 1035  ...  2.979000e+01  7.636500e+07  1.668800e+18  3.106400e+12
# 1036  ...  2.993800e+01  7.578100e+07  1.674000e+18  3.135800e+12
#
#           C3H8(V2)        C3H8^+         C4H9H         C5H12             H  \
# 0     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1     8.469700e-32  5.832700e-43  3.724200e-24  3.866500e-34  1.799000e+09
# 2     2.634700e-27  4.125000e-37  3.010200e-17  4.853700e-26  9.509500e+10
# 3     1.649900e-25  3.218700e-35  4.631500e-15  2.903100e-23  2.150100e+11
# 4     2.098400e-24  4.236300e-34  9.812200e-14  1.422700e-21  3.392700e+11
# ...            ...           ...           ...           ...           ...
# 1032  2.440500e+12  6.776700e+02  1.346000e+17  2.066000e+18  1.588700e+13
# 1033  2.464100e+12  6.847100e+02  1.348200e+17  2.071800e+18  1.586300e+13
# 1034  2.487800e+12  6.917800e+02  1.350400e+17  2.077500e+18  1.583500e+13
# 1035  2.511600e+12  6.988800e+02  1.352500e+17  2.083100e+18  1.580500e+13
# 1036  2.535400e+12  7.060100e+02  1.354700e+17  2.088700e+18  1.578200e+13
#
#                 H2
# 0     0.000000e+00
# 1     2.867400e+09
# 2     7.813700e+10
# 3     1.726600e+11
# 4     2.702900e+11
# ...            ...
# 1032  1.321500e+19
# 1033  1.325100e+19
# 1034  1.328600e+19
# 1035  1.332100e+19
# 1036  1.335600e+19
#
# [1037 rows x 40 columns]

# %%
rH2 = H2 - 0.5*CH3 - 0.5*CH3_plus - CH2 - 0.5*C2H3 + 0.5*C2H5 + 0.5*C2H5_plus + 0.5*H + 0.5*C3H7 + 0.5*CH5_plus - 1.5*CH
rCH4 = CH4 + CH3 + CH2 + CH + CH5_plus + CH3_plus + CH4_plus
rC2H6 = C2H6 + C2H6_plus
rC2H4 = C2H4 + C2H4_plus + C2H3 + C2H5 + C2H5_plus
rC2H2 = C2H2 + C2H2_plus
rC3H8 = C3H8 + C3H8_plus
rC3H6 = C3H6 + C3H6_plus + C3H7
rC4H10 = C4H10
rC5H12 = C5H12
rC = C

# %%
time = df_sp['Time [s]']
X_CH4 = (rCH4[0] - rCH4)/rCH4[0]*100
S_H2 = (rH2)/(rCH4[0] - rCH4)*100*0.5
S_C2H6 = (rC2H6)/(rCH4[0] - rCH4)*100*2
S_C2H4 = (rC2H4)/(rCH4[0] - rCH4)*100*2
S_C2H2 = (rC2H2)/(rCH4[0] - rCH4)*100*2
S_C3H8 = (rC3H8)/(rCH4[0] - rCH4)*100*3
S_C3H6 = (rC3H6)/(rCH4[0] - rCH4)*100*3
S_C4H10 = (rC4H10)/(rCH4[0] - rCH4)*100*4
S_Inert = (rC5H12 + rC)/(rCH4[0] - rCH4)*100

# %%
plt.plot(time.iloc[461:], X_CH4.iloc[461:])

# %%
plt.plot(time.iloc[461:], S_C2H6.iloc[461:])

# %%
plt.plot(time.iloc[461:], S_C2H4.iloc[461:])

# %%
plt.plot(time.iloc[461:], S_C2H2.iloc[461:])

# %%
plt.plot(time.iloc[461:], S_C3H8.iloc[461:])

# %%
plt.plot(time.iloc[461:], S_C3H6.iloc[461:])

# %%
plt.plot(time.iloc[461:], S_C4H10.iloc[461:])

# %%
plt.plot(time.iloc[461:], S_Inert.iloc[461:])

# %%
plt.plot(time.iloc[461:], S_H2.iloc[461:])

# %%
# time이 0.1s인 지점의 인덱스와 값을 찾는 코드입니다.
t_0_1_idx = abs(df_sp['Time [s]'] - 1).idxmin()
t_0_1_val = df_sp['Time [s]'].iloc[t_0_1_idx]
print(f"0.1초에 가장 가까운 인덱스: {t_0_1_idx}, 시간 값: {t_0_1_val}")
# Out:
# 0.1초에 가장 가까운 인덱스: 461, 시간 값: 1.000001

# %%
# time이 0.1s인 지점의 인덱스와 값을 찾는 코드입니다.
t_0_1_idx = abs(df_sp['Time [s]'] - 16.96).idxmin()
t_0_1_val = df_sp['Time [s]'].iloc[t_0_1_idx]
print(f"0.1초에 가장 가까운 인덱스: {t_0_1_idx}, 시간 값: {t_0_1_val}")
# Out:
# 0.1초에 가장 가까운 인덱스: 621, 시간 값: 17.0

# %%
# X_CH4가 40에 가장 가까운 지점의 인덱스와 값을 찾는 코드입니다.
x_ch4_40_idx = abs(X_CH4 - 40).idxmin()
x_ch4_40_val = X_CH4.iloc[x_ch4_40_idx]
print(f"X_CH4가 40에 가장 가까운 인덱스: {x_ch4_40_idx}, X_CH4 값: {x_ch4_40_val}, 시간: {time.iloc[x_ch4_40_idx]}")
# Out:
# X_CH4가 40에 가장 가까운 인덱스: 846, X_CH4 값: 40.08844073416639, 시간: 68.1

# %%
print(f'CH4 전환율: {X_CH4[846]}')
print(f'C2H6 선택도: {S_C2H6[846]}')
print(f'C2H4 선택도: {S_C2H4[846]}')
print(f'C2H2 선택도: {S_C2H2[846]}')
print(f'C3H8 선택도: {S_C3H8[846]}')
print(f'C3H6 선택도: {S_C3H6[846]}')
print(f'C4H10 선택도: {S_C4H10[846]}')
print(f'Inert 선택도: {S_Inert[846]}')
print(f'H2 선택도: {S_H2[846]}')
# Out:
# CH4 전환율: 40.08844073416639
# C2H6 선택도: 10.735094061187175
# C2H4 선택도: 0.8075270413297722
# C2H2 선택도: 3.2375382664390515
# C3H8 선택도: 26.231290685405238
# C3H6 선택도: 0.5537534392244339
# C4H10 선택도: 3.6724139046890327
# Inert 선택도: 10.99884798102129
# H2 선택도: 37.85210719264857

# %%
mf_CH4 = rCH4/all_sp*100
mf_C2H6 = rC2H6/all_sp*100
mf_C2H4 = rC2H4/all_sp*100
mf_C2H2 = rC2H2/all_sp*100
mf_C3H8 = rC3H8/all_sp*100
mf_C3H6 = rC3H6/all_sp*100
mf_C4H10 = rC4H10/all_sp*100
mf_inert = (rC5H12+rC)/all_sp*100
mf_H2 = rH2/all_sp*100

# %%
print(f'CH4 몰분율: {mf_CH4[846]}')
print(f'C2H6 몰분율: {mf_C2H6[846]}')
print(f'C2H4 몰분율: {mf_C2H4[846]}')
print(f'C2H2 몰분율: {mf_C2H2[846]}')
print(f'C3H8 몰분율: {mf_C3H8[846]}')
print(f'C3H6 몰분율: {mf_C3H6[846]}')
print(f'C4H10 몰분율: {mf_C4H10[846]}')
print(f'Inert 몰분율: {mf_inert[846]}')
print(f'H2 몰분율: {mf_H2[846]}')
# Out:
# CH4 몰분율: 58.94549549474124
# C2H6 몰분율: 2.117069048476685
# C2H4 몰분율: 0.15925249422715845
# C2H2 몰분율: 0.6384752679455329
# C3H8 몰분율: 3.4487170952355157
# C3H6 몰분율: 0.07280385000122472
# C4H10 몰분율: 0.3621185695485542
# Inert 몰분율: 4.338167974458413
# H2 몰분율: 29.859272438760897

# %%
mf_CH4[846] + mf_C2H6[846] + mf_C2H4[846] + mf_C2H2[846] + mf_C3H8[846] + mf_C3H6[846] + mf_C4H10[846] + mf_inert[846] + mf_H2[846]
# Out:
# np.float64(99.94137223339523)

# %%
print(f'CH4 몰분율: {mf_CH4[546]}')
print(f'C2H6 몰분율: {mf_C2H6[546]}')
print(f'C2H4 몰분율: {mf_C2H4[546]}')
print(f'C2H2 몰분율: {mf_C2H2[546]}')
print(f'C3H8 몰분율: {mf_C3H8[546]}')
print(f'C3H6 몰분율: {mf_C3H6[546]}')
print(f'C4H10 몰분율: {mf_C4H10[546]}')
print(f'Inert 몰분율: {mf_inert[546]}')
print(f'H2 몰분율: {mf_H2[546]}')
# Out:
# CH4 몰분율: 92.8655660289071
# C2H6 몰분율: 1.4635558177193737
# C2H4 몰분율: 0.13468448837772096
# C2H2 몰분율: 0.08938748675698428
# C3H8 몰분율: 0.4141536033825496
# C3H6 몰분율: 0.02590692099017498
# C4H10 몰분율: 0.058186061454855595
# Inert 몰분율: 0.3608190011240874
# H2 몰분율: 4.518348577695723

# %%
rx = []
with open('qt_reactions_list.txt','r') as f:
    for line in f:
        comp = line[3:]
        rx.append(comp.strip())
    f.close()

# %%
df_rx = pd.read_csv('qt_rates.txt', sep=r'\s+', header=0, names=['Time [s]']+rx)

# %%
df_rx
# Out:
#         Time [s]  bolsig:CH4->CH4(V24)  bolsig:CH4->CH4(V13)  \
# 0       0.000000          1.569200e+11          1.545100e+11
# 1       0.000001          1.569200e+11          1.545100e+11
# 2       0.000002          1.677700e+11          1.344500e+11
# 3       0.000003          1.664400e+11          1.285000e+11
# 4       0.000004          1.661800e+11          1.275000e+11
# ...          ...                   ...                   ...
# 1032  195.100000          3.296600e+10          2.441900e+10
# 1033  196.200000          3.263200e+10          2.416300e+10
# 1034  197.300000          3.230200e+10          2.391000e+10
# 1035  198.400000          3.197600e+10          2.366000e+10
# 1036  199.500000          3.164900e+10          2.341000e+10
#
#       bolsig:CH4(V24)->CH4  bolsig:CH4(V13)->CH4  bolsig:C2H6->C2H6(V24)  \
# 0                 0.000000              0.000000            0.000000e+00
# 1                 0.001180              0.001192            1.972600e-19
# 2                 0.002564              0.001863            3.136600e-14
# 3                 0.003842              0.002564            1.160100e-12
# 4                 0.005134              0.003320            1.028700e-11
# ...                    ...                   ...                     ...
# 1032          48482.000000          27605.000000            1.991800e+09
# 1033          48251.000000          27458.000000            1.976000e+09
# 1034          48019.000000          27314.000000            1.960400e+09
# 1035          47787.000000          27169.000000            1.945000e+09
# 1036          47550.000000          27022.000000            1.929500e+09
#
#       bolsig:C2H6->C2H6(V13)  bolsig:C2H6(V24)->C2H6  bolsig:C2H6(V13)->C2H6  \
# 0               0.000000e+00            0.000000e+00            0.000000e+00
# 1               1.879200e-19            3.602600e-34            3.414900e-34
# 2               2.804800e-14            5.903300e-29            4.815300e-29
# 3               1.027600e-12            3.932500e-27            3.142100e-27
# 4               9.097700e-12            5.177600e-26            4.123200e-26
# ...                      ...                     ...                     ...
# 1032            1.749000e+09            4.748100e+02            3.728400e+02
# 1033            1.735000e+09            4.706900e+02            3.695500e+02
# 1034            1.721200e+09            4.666300e+02            3.663100e+02
# 1035            1.707600e+09            4.626000e+02            3.631100e+02
# 1036            1.693800e+09            4.585500e+02            3.598900e+02
#
#       bolsig:C2H4->C2H4(V2)  ...  C2H4(V2)+CH5^+=>CH4+C2H5^+  C3H7+H=>C3H8  \
# 0              0.000000e+00  ...                0.000000e+00  0.000000e+00
# 1              2.647900e+00  ...                5.399300e-12  9.536400e-28
# 2              1.111100e+02  ...                2.362400e-10  9.844600e-21
# 3              2.428100e+02  ...                9.502200e-10  1.596500e-18
# 4              3.809900e+02  ...                2.219100e-09  3.323600e-17
# ...                     ...  ...                         ...           ...
# 1032           3.527700e+07  ...                7.987100e-09  1.270500e+09
# 1033           3.503500e+07  ...                7.938100e-09  1.258700e+09
# 1034           3.479700e+07  ...                7.887300e-09  1.246300e+09
# 1035           3.456100e+07  ...                7.835100e-09  1.233800e+09
# 1036           3.432500e+07  ...                7.786900e-09  1.222600e+09
#
#       C2H3+H=>C2H2+H2  C3H8+CH2=>C4H9H  C3H8(V1)+CH2=>C4H9H  \
# 0        0.000000e+00     0.000000e+00         0.000000e+00
# 1        4.775400e-02     1.061800e-21         4.263100e-36
# 2        8.604900e+02     5.136400e-16         1.960400e-30
# 3        9.079100e+03     3.812100e-14         2.593600e-28
# 4        3.484400e+04     5.071500e-13         5.089500e-27
# ...               ...              ...                  ...
# 1032     9.392600e+14     2.724400e+15         4.974600e+09
# 1033     9.348100e+14     2.705800e+15         4.972600e+09
# 1034     9.300000e+14     2.686600e+15         4.969100e+09
# 1035     9.250600e+14     2.667300e+15         4.964900e+09
# 1036     9.206400e+14     2.648900e+15         4.962000e+09
#
#       C3H8(V2)+CH2=>C4H9H  CH4+CH3^+=>H2+C2H5^+  CH4(V24)+CH3^+=>H2+C2H5^+  \
# 0            0.000000e+00          0.000000e+00               0.000000e+00
# 1            3.235500e-36          5.038600e-12               3.662800e-26
# 2            1.564000e-30          6.396800e-10               9.622000e-24
# 3            2.086100e-28          1.605800e-09               3.653600e-23
# 4            4.099100e-27          2.535200e-09               7.720200e-23
# ...                   ...                   ...                        ...
# 1032         4.021700e+09          2.690900e-01               3.904500e-07
# 1033         4.020200e+09          2.712100e-01               3.956500e-07
# 1034         4.017500e+09          2.709400e-01               3.973900e-07
# 1035         4.014200e+09          2.704100e-01               3.987300e-07
# 1036         4.012000e+09          2.706300e-01               4.011700e-07
#
#       CH4(V13)+CH3^+=>H2+C2H5^+       H+H=>H2
# 0                  0.000000e+00  0.000000e+00
# 1                  3.606600e-26  4.341900e-14
# 2                  8.563200e-24  1.213200e-10
# 3                  3.105700e-23  6.202200e-10
# 4                  6.401700e-23  1.544200e-09
# ...                         ...           ...
# 1032               2.954400e-07  3.386100e-06
# 1033               2.993500e-07  3.376000e-06
# 1034               3.006300e-07  3.363900e-06
# 1035               3.016000e-07  3.351200e-06
# 1036               3.034200e-07  3.341600e-06
#
# [1037 rows x 115 columns]

# %%
reaction_extents = {}
reaction_extents['Time [s]'] = df_rx['Time [s]']
for i in range(len(rx)):
    reaction = []
    for j in range(len(df_rx)):
        if j == 0:
            reaction.append(0)
        else:
            reaction.append(reaction[j-1] +df_rx[rx[i]].iloc[j-1]*(df_rx['Time [s]'].iloc[j]-df_rx['Time [s]'].iloc[j-1]))
    reaction_extents[rx[i]] = reaction

# %%
df_rex = pd.DataFrame(reaction_extents)

# %%
rx_1696 = df_rex.iloc[621]

# %%
rx_analysis = rx_1696.drop('Time [s]').sort_values(ascending=False)

# %%
rx_analysis.to_csv('rx_analysis.csv')
