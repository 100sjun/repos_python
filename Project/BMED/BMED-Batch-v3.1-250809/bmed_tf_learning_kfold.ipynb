# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence, PackedSequence
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from torch.utils.data import Subset
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def df_treat(name):
    df = pd.read_csv(name)
    ndf = pd.DataFrame()
    range_mm={
        'V': {'min':df['V'].min()*0.8, 'max': df['V'].max()*1.2},
        'E': {'min':df['E'].min()*0.8, 'max': df['E'].max()*1.2},
        'VF': {'min':df['VF'].min()*0.8, 'max': df['VF'].max()*1.2},
        'VA': {'min':df['VA'].min()*0.8, 'max': df['VA'].max()*1.2},
        'VB': {'min':df['VB'].min()*0.8, 'max': df['VB'].max()*1.2},
        'CFLA': {'min':0, 'max': df['CFLA'].max()*1.2},
        'CALA': {'min':0, 'max': df['CALA'].max()*1.2},
        'CFK': {'min':0, 'max': df['CFK'].max()*1.2},
        'CBK': {'min':0, 'max': df['CBK'].max()*1.2},
        'I': {'min':0, 'max': df['I'].max()*1.2},
    }
    ndf['exp'] = df['exp']; ndf['t'] = df['t']

    for col in ['V', 'E', 'VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']:
        if col in range_mm:
            ndf[col] = (df[col] - range_mm[col]['min'])/(range_mm[col]['max'] - range_mm[col]['min'])
        else:
            ndf[col] = df[col]

    exp_num_list = sorted(ndf['exp'].unique())

    return df, ndf, range_mm, exp_num_list

# %%
def seq_data(ndf, exp_num_list):
    seq = []
    feature_cols = ['V', 'E', 'VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']
    
    for exp in exp_num_list:
        exp_df = ndf[ndf['exp'] == exp]
        seq.append(exp_df[feature_cols].values)
    
    return seq

# %%
def pad_seq(seq):
    max_len = max([len(s) for s in seq])
    seq_len = [len(s) for s in seq]
    pad_seq = pad_sequence([torch.tensor(s) for s in seq], batch_first=True, padding_value=-1)

    return pad_seq, seq_len, max_len

# %%
def gen_dataset(pad_seq, seq_len):
    input_tensor = pad_seq.float()
    seq_len_tensor = torch.tensor(seq_len)
    dataset = TensorDataset(input_tensor, seq_len_tensor)
    return dataset

# %%
class LayerNormLSTM(nn.Module):
    """LSTM layer with layer normalization applied to gates"""
    def __init__(self, input_node, hidden_node):
        super().__init__()
        self.input_node = input_node
        self.hidden_node = hidden_node

        self.w_i = nn.Linear(input_node, 4 * hidden_node, bias=False)
        self.w_h = nn.Linear(hidden_node, 4 * hidden_node, bias=False)

        self.ln_i = nn.LayerNorm(hidden_node)
        self.ln_h = nn.LayerNorm(hidden_node)
        self.ln_g = nn.LayerNorm(hidden_node)
        self.ln_o = nn.LayerNorm(hidden_node)

        self.ln_c = nn.LayerNorm(hidden_node)

    def forward(self, input, hidden):
        h_prev, c_prev = hidden

        gi = self.w_i(input)
        gh = self.w_h(h_prev)
        i_i, i_f, i_g, i_o = gi.chunk(4, dim=-1)
        h_i, h_f, h_g, h_o = gh.chunk(4, dim=-1)

        i_g = torch.sigmoid(self.ln_i(i_i + h_i))
        f_g = torch.sigmoid(self.ln_h(i_f + h_f))
        g_g = torch.tanh(self.ln_g(i_g + h_g))
        o_g = torch.sigmoid(self.ln_o(i_o + h_o))

        c_new = f_g * c_prev + i_g * g_g
        c_new = self.ln_c(c_new)

        h_new = o_g * torch.tanh(c_new)

        return h_new, c_new

# %%
class StateExtr(nn.Module):
    def __init__(self, input_node, hidden_node, n_layer, dropout):
        super().__init__()
        self.hidden_node = hidden_node
        self.n_layer = n_layer
        self.input_node = input_node

        self.lstm_cells = nn.ModuleList()

        self.lstm_cells.append(LayerNormLSTM(input_node, hidden_node))

        for _ in range(n_layer - 1):
            self.lstm_cells.append(LayerNormLSTM(hidden_node, hidden_node))

        self.dropout = nn.Dropout(dropout)

        self.final_layer_norm = nn.LayerNorm(hidden_node)
        self.final_dropout = nn.Dropout(dropout)

    def forward(self, x, seq_len):
        batch_size, max_len, input_node = x.size()
        device = x.device

        h_states = []
        c_states = []
        for _ in range(self.n_layer):
            h_states.append(torch.zeros(batch_size, self.hidden_node, device=device))
            c_states.append(torch.zeros(batch_size, self.hidden_node, device=device))
        
        outputs = []
        for t in range(max_len):
            x_t = x[:, t, :]

            layer_input = x_t
            for layer_idx, lstm_cell in enumerate(self.lstm_cells):
                h_new, c_new = lstm_cell(layer_input, (h_states[layer_idx], c_states[layer_idx]))

                # Inplace 연산 대신 새로운 텐서 생성
                h_states[layer_idx] = h_new
                c_states[layer_idx] = c_new

                if layer_idx < len(self.lstm_cells) - 1:
                    layer_input = self.dropout(h_new)
                else:
                    layer_input = h_new

            outputs.append(layer_input)
        
        output_tensor = torch.stack(outputs, dim=1)
        seq_len_cpu = seq_len.detach().cpu().long()
        mask = torch.arange(max_len, device='cpu')[None, :] < seq_len_cpu[:, None]
        mask = mask.float().to(device).unsqueeze(-1)

        masked_output = output_tensor * mask

        normalized = self.final_layer_norm(masked_output)
        return self.final_dropout(normalized)

# %%
class PhysicalChangeDecoder(nn.Module):
    def __init__(self, input_node, output_node, n_layer, hidden_node, dropout):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(nn.Linear(input_node, hidden_node))
        self.layers.append(nn.LayerNorm(hidden_node))
        self.layers.append(nn.ReLU())
        self.layers.append(nn.Dropout(dropout))

        for i in range(n_layer - 1):
            self.layers.append(nn.Linear(hidden_node, hidden_node))
            self.layers.append(nn.LayerNorm(hidden_node))
            self.layers.append(nn.ReLU())
            self.layers.append(nn.Dropout(dropout))

        self.layers.append(nn.Linear(hidden_node, output_node))
    
    def forward(self, hidden_states):
        x = hidden_states
        for layer in self.layers:
            x = layer(x)
        return x

# %%
class CurrentPredictor(nn.Module):
    def __init__(self, input_node, hidden_node, n_layer, dropout):
        super().__init__()
        
        self.layers = nn.ModuleList()
        
        self.layers.append(nn.Linear(input_node, hidden_node))
        self.layers.append(nn.LayerNorm(hidden_node))
        self.layers.append(nn.ReLU())
        self.layers.append(nn.Dropout(dropout))
        
        for i in range(n_layer - 1):
            self.layers.append(nn.Linear(hidden_node, hidden_node))
            self.layers.append(nn.LayerNorm(hidden_node))
            self.layers.append(nn.ReLU())
            self.layers.append(nn.Dropout(dropout))
        
        self.layers.append(nn.Linear(hidden_node, 1))
    
    def forward(self, new_state):
        x = new_state
        for layer in self.layers:
            x = layer(x)
        return x

# %%
class PhysicsConstraintLayer(nn.Module):
    def __init__(self, range_mm, current_predictor, eps=1e-2):
        super().__init__()
        self.sps = eps
        self.current_predictor = current_predictor
        self.register_buffer('range_mm_tensor', self._convert_range_to_tensor(range_mm))

    def _convert_range_to_tensor(self, range_mm):
        feature_names = ['V','E','VF','VA','VB','CFLA','CALA','CFK','CBK','I']
        ranges = torch.zeros(len(feature_names),2)

        for i, name in enumerate(feature_names):
            if name in range_mm:
                ranges[i, 0] = range_mm[name]['min']
                ranges[i, 1] = range_mm[name]['max']
        
        return ranges
    
    def normalize(self, data, feature_idx):
        min_val = self.range_mm_tensor[feature_idx, 0]
        max_val = self.range_mm_tensor[feature_idx, 1]
        return (data - min_val) / (max_val - min_val)

    def denormalize(self, data, feature_idx):
        min_val = self.range_mm_tensor[feature_idx, 0]
        max_val = self.range_mm_tensor[feature_idx, 1]
        return data * (max_val - min_val) + min_val

    def forward(self, physical_changes, current_state):
        V_idx, E_idx, VF_idx, VA_idx, VB_idx = 0, 1, 2, 3, 4
        CFLA_idx, CALA_idx, CFK_idx, CBK_idx, I_idx = 5, 6, 7, 8, 9

        VF = self.denormalize(current_state[..., 2:3], VF_idx)
        VA = self.denormalize(current_state[..., 3:4], VA_idx)
        VB = self.denormalize(current_state[..., 4:5], VB_idx)
        CFLA = self.denormalize(current_state[..., 5:6], CFLA_idx)
        CALA = self.denormalize(current_state[..., 6:7], CALA_idx)
        CFK = self.denormalize(current_state[..., 7:8], CFK_idx)
        CBK = self.denormalize(current_state[..., 8:9], CBK_idx)

        dVA = physical_changes[..., 0:1]
        dVB = physical_changes[..., 1:2]
        dNALA = physical_changes[..., 2:3]
        dNBK = physical_changes[..., 3:4]

        NFLA = CFLA * VF
        NALA = CALA * VA
        NFK = CFK * VF
        NBK = CBK * VB

        nVF = VF - dVA - dVB
        nVA = VA + dVA
        nVB = VB + dVB

        nVF = torch.clamp(nVF, min=self.sps)
        nVA = torch.clamp(nVA, min=self.sps)
        nVB = torch.clamp(nVB, min=self.sps)
        
        nNFLA = NFLA - torch.clamp(dNALA, min=0.0)
        nNALA = NALA + torch.clamp(dNALA, min=0.0)
        nNFK = NFK - torch.clamp(dNBK, min=0.0)
        nNBK = NBK + torch.clamp(dNBK, min=0.0)

        nNFLA = torch.clamp(nNFLA, min=0.0)
        nNALA = torch.clamp(nNALA, min=0.0)
        nNFK = torch.clamp(nNFK, min=0.0)
        nNBK = torch.clamp(nNBK, min=0.0)

        nCFLA = nNFLA / nVF
        nCALA = nNALA / nVA
        nCFK = nNFK / nVF
        nCBK = nNBK / nVB

        V = current_state[..., 0:1]
        E = current_state[..., 1:2]
        nVF_norm = self.normalize(nVF, VF_idx)
        nVA_norm = self.normalize(nVA, VA_idx)
        nVB_norm = self.normalize(nVB, VB_idx)
        nCFLA_norm = self.normalize(nCFLA, CFLA_idx)
        nCALA_norm = self.normalize(nCALA, CALA_idx)
        nCFK_norm = self.normalize(nCFK, CFK_idx)
        nCBK_norm = self.normalize(nCBK, CBK_idx)

        # Create temporary state without I for current prediction
        temp_state = torch.cat([
            V, E, nVF_norm, nVA_norm, nVB_norm, nCFLA_norm, nCALA_norm, nCFK_norm, nCBK_norm
        ], dim=-1)
        
        # Predict new I using the current predictor
        nI_pred_norm = self.current_predictor(temp_state)
        
        # Scale predicted I to actual range
        nI_real = self.denormalize(nI_pred_norm, I_idx)
        nI_real = torch.clamp(nI_real, min=0.0)
        nI_norm = self.normalize(nI_real, I_idx)

        # Create final next state with predicted I
        next_state = torch.cat([
            V, E, nVF_norm, nVA_norm, nVB_norm, nCFLA_norm, nCALA_norm, nCFK_norm, nCBK_norm, nI_norm
        ], dim=-1)
        
        return next_state

# %%
class BMEDAutoregressiveModel(nn.Module):
    def __init__(self, state_extr_params, decoder_params, current_predictor_params, range_mm):
        super().__init__()
        self.state_extr = StateExtr(**state_extr_params)
        self.physical_decoder = PhysicalChangeDecoder(**decoder_params)
        self.current_predictor = CurrentPredictor(**current_predictor_params)
        self.physics_constraint = PhysicsConstraintLayer(range_mm, self.current_predictor)

    def forward(self, x, seq_len):
        hidden_states = self.state_extr(x, seq_len)
        physical_changes = self.physical_decoder(hidden_states)
        new_x = self.physics_constraint(physical_changes, x)
        
        return new_x

# %%
def masked_mse_loss(pred, target, seq_len):
    batch_size, max_len, features = pred.shape
    seq_len_cpu = seq_len.detach().cpu().long()

    mask = torch.arange(max_len, device='cpu')[None, :] < seq_len_cpu[:, None]
    mask = mask.float().to(pred.device)

    loss = F.mse_loss(pred, target, reduction='none')
    masked_loss = loss * mask.unsqueeze(-1)

    total_loss = masked_loss.sum()
    total_elements = mask.sum()

    masked_loss = total_loss / total_elements
    return masked_loss

# %%
def tf_data(input_seq, seq_len):
    inputs = input_seq[:, :-1, :-1]
    targets = input_seq[:, 1:, :]

    target_seq_len = seq_len - 1

    return inputs, targets, target_seq_len

# %%
class NoamScheduler:
    def __init__(self, optimizer, model_size, warmup_epochs, factor=1.0):
        self.optimizer = optimizer
        self.model_size = model_size
        self.warmup_epochs = warmup_epochs
        self.factor = factor
        self.epoch_num = 0

    def step_epoch(self):
        self.epoch_num += 1
        lr = self.factor * (
            self.model_size ** (-0.5) *
            min(self.epoch_num ** (-0.5), self.epoch_num * self.warmup_epochs ** (-1.5))
        )
    
        for param_group in self.optimizer.param_groups:
            param_group['lr'] = lr

        return lr

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
df, ndf, range_mm, exp_num_list = df_treat('BMED_DATA_AG.csv')
seq = seq_data(ndf, exp_num_list)
pad, seq_len, max_len = pad_seq(seq)
dataset = gen_dataset(pad, seq_len)
dataloader = DataLoader(dataset, batch_size=4, shuffle=False)

# %%
state_extr_params = {
    'input_node': 9,
    'hidden_node': 48,
    'n_layer': 4,
    'dropout': 0.3
}

decoder_params = {
    'input_node': state_extr_params['hidden_node'],
    'hidden_node': 48,
    'n_layer': 3,
    'dropout': 0.4,
    'output_node': 4
}

current_predictor_params = {
    'input_node': 9,
    'hidden_node': 48,
    'n_layer': 4,
    'dropout': 0.4
}

model = BMEDAutoregressiveModel(state_extr_params, decoder_params, current_predictor_params, range_mm)
model = model.to(device)
print(f"Model architecture:")
print(f"  Input features: {state_extr_params['input_node']} (without current)")
print(f"  State Extractor Hidden size: {state_extr_params['hidden_node']}")
print(f"  State Extractor layers: {state_extr_params['n_layer']}")
print(f"  Decoder layers: {decoder_params['n_layer']}")
print(f"  Decoder Hidden size: {decoder_params['hidden_node']}")
print(f"  Current Predictor layers: {current_predictor_params['n_layer']}")
print(f"  Current Predictor Hidden size: {current_predictor_params['hidden_node']}")
print(f"  Model parameters: {sum(p.numel() for p in model.parameters()):,}")
print(f"  Physics constraints: Volume conservation with denormalization")

num_epochs = 10000
optimizer = torch.optim.AdamW(model.parameters(), lr=1.0)
warmup_epochs = int(num_epochs * 0.2)
scheduler = NoamScheduler(optimizer, model_size=state_extr_params['hidden_node'], warmup_epochs=warmup_epochs, factor=1)

print(f"\nTraining configuration:")
print(f"  Total epochs: {num_epochs:,}")
print(f"  Warmup epochs: {warmup_epochs:,} (10%)")
peak_lr = 1.0 * (48 ** (-0.5)) * (warmup_epochs ** (-0.5))
print(f"  Peak learning rate: {peak_lr:.2e}")
# Out:
# Model architecture:
#   Input features: 9 (without current)
#   State Extractor Hidden size: 48
#   State Extractor layers: 4
#   Decoder layers: 3
#   Decoder Hidden size: 48
#   Current Predictor layers: 4
#   Current Predictor Hidden size: 48
#   Model parameters: 83,765
#   Physics constraints: Volume conservation with denormalization
#
# Training configuration:
#   Total epochs: 10,000
#   Warmup epochs: 2,000 (10%)
#   Peak learning rate: 3.23e-03

# %%
train_samples = len(dataloader.dataset)
best_train_loss = float('inf')
best_epoch = 0
train_losses = []
learning_rates = []

best_model = None

print("Training started...")
print(f"Total batches per epoch: {len(dataloader)}")

for epoch in range(num_epochs):
    current_lr = scheduler.step_epoch()

    model.train()
    train_loss = 0.0
    train_batches = 0

    for batch_idx, (input_seq, seq_len) in enumerate(dataloader):
        try:
            input_seq = input_seq.to(device)
            seq_len = seq_len.to(device)

            inputs, targets, target_seq_len = tf_data(input_seq, seq_len)
            
            optimizer.zero_grad()
            pred = model(inputs, target_seq_len)
            loss = masked_mse_loss(pred, targets, target_seq_len)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            train_loss += loss.item()
            train_batches += 1

        except Exception as e:
            print(f"Training batch {batch_idx} error: {str(e)}")
            print(f"Input shape: {input_seq.shape if 'input_seq' in locals() else 'N/A'}")
            print(f"Seq lengths: {seq_len if 'seq_lengths' in locals() else 'N/A'}")
            import traceback
            traceback.print_exc()
            continue
    
    if train_batches == 0:
        print("No valid training batches")
        break

    train_losses.append(train_loss)
    learning_rates.append(current_lr)

    if train_loss < best_train_loss:
        best_train_loss = train_loss
        best_epoch = epoch + 1
        best_status = " ★ NEW BEST"
        
        # Best model을 메모리에 복사하여 저장
        import copy
        best_model = copy.deepcopy(model)
        print(f"          Best model saved in memory at epoch {best_epoch}")
    else:
        best_status = ""

    # Warmup 구간 표시
    if epoch + 1 <= warmup_epochs:
        warmup_status = " [WARMUP]"
    else:
        warmup_status = ""

    # 매 에포크마다 로깅 - best 성능 정보 포함
    print(f"Epoch {epoch+1:4d}: Train: {train_loss:.6f}, LR: {current_lr:.2e}{best_status}{warmup_status}")    

    if epoch == 0:
        print(f"          Best: Train: {best_train_loss:.6f}, (Epoch {best_epoch})")
    elif train_loss < best_train_loss:
        print(f"          ✓ Updated Best: Train: {best_train_loss:.6f}")
    else:
        print(f"          Best: Train: {best_train_loss:.6f} (Epoch {best_epoch})")

print(f"\nTraining completed!")
print(f"=" * 60)

# 안전한 결과 출력
if len(train_losses) > 0:
    print(f"Best Performance (Epoch {best_epoch}):")
    print(f"  Best Train Loss:  {best_train_loss:.6f}")
    print(f"=" * 60)
    print(f"Final Performance (Epoch {len(train_losses)}):")
    print(f"  Final Train Loss: {train_losses[-1]:.6f}")
    print(f"  Final LR:         {current_lr:.2e}")
    print(f"=" * 60)
    if len(learning_rates) > 0:
        print(f"Warmup completed at epoch {warmup_epochs} with peak LR: {max(learning_rates):.2e}")
else:
    print("⚠️ No training completed - check error messages above")

# Best model이 저장되었는지 확인
if best_model is not None:
    print(f"\n✅ Best model (Epoch {best_epoch}) successfully saved in memory!")
    print(f"   Best model loss: {best_train_loss:.6f}")
else:
    print("\n⚠️ No best model was saved (training may have failed)")
    best_model = model  # fallback to current model
# Out:
# Training started...
# Total batches per epoch: 6
#           Best model saved in memory at epoch 1
# Epoch    1: Train: 987.807000, LR: 1.61e-06 ★ NEW BEST [WARMUP]
#           Best: Train: 987.807000, (Epoch 1)
# Epoch    2: Train: 1140.804726, LR: 3.23e-06 [WARMUP]
#           Best: Train: 987.807000 (Epoch 1)
# Epoch    3: Train: 1052.763958, LR: 4.84e-06 [WARMUP]
#           Best: Train: 987.807000 (Epoch 1)
# Epoch    4: Train: 1086.593201, LR: 6.45e-06 [WARMUP]
#           Best: Train: 987.807000 (Epoch 1)
# Epoch    5: Train: 1270.312839, LR: 8.07e-06 [WARMUP]
#           Best: Train: 987.807000 (Epoch 1)
# Epoch    6: Train: 1047.757710, LR: 9.68e-06 [WARMUP]
#           Best: Train: 987.807000 (Epoch 1)
# Epoch    7: Train: 1496.614075, LR: 1.13e-05 [WARMUP]
#           Best: Train: 987.807000 (Epoch 1)
# Epoch    8: Train: 996.667618, LR: 1.29e-05 [WARMUP]
#           Best: Train: 987.807000 (Epoch 1)
# Epoch    9: Train: 1132.270565, LR: 1.45e-05 [WARMUP]
#           Best: Train: 987.807000 (Epoch 1)
#           Best model saved in memory at epoch 10
# Epoch   10: Train: 756.512117, LR: 1.61e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 756.512117 (Epoch 10)
# Epoch   11: Train: 1214.019203, LR: 1.78e-05 [WARMUP]
#           Best: Train: 756.512117 (Epoch 10)
# Epoch   12: Train: 1538.170525, LR: 1.94e-05 [WARMUP]
#           Best: Train: 756.512117 (Epoch 10)
# Epoch   13: Train: 1274.593759, LR: 2.10e-05 [WARMUP]
#           Best: Train: 756.512117 (Epoch 10)
# Epoch   14: Train: 1179.673597, LR: 2.26e-05 [WARMUP]
#           Best: Train: 756.512117 (Epoch 10)
#           Best model saved in memory at epoch 15
# Epoch   15: Train: 710.555580, LR: 2.42e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 710.555580 (Epoch 15)
#           Best model saved in memory at epoch 16
# Epoch   16: Train: 646.159166, LR: 2.58e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 646.159166 (Epoch 16)
# Epoch   17: Train: 1298.649364, LR: 2.74e-05 [WARMUP]
#           Best: Train: 646.159166 (Epoch 16)
#           Best model saved in memory at epoch 18
# Epoch   18: Train: 510.437673, LR: 2.90e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   19: Train: 769.458677, LR: 3.07e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   20: Train: 732.071831, LR: 3.23e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   21: Train: 755.114655, LR: 3.39e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   22: Train: 1102.436464, LR: 3.55e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   23: Train: 690.836091, LR: 3.71e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   24: Train: 853.653578, LR: 3.87e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   25: Train: 809.179985, LR: 4.03e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   26: Train: 855.310599, LR: 4.20e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   27: Train: 545.256096, LR: 4.36e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   28: Train: 976.924082, LR: 4.52e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   29: Train: 641.001272, LR: 4.68e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   30: Train: 526.602513, LR: 4.84e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   31: Train: 604.075699, LR: 5.00e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   32: Train: 908.942631, LR: 5.16e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
# Epoch   33: Train: 1002.858362, LR: 5.33e-05 [WARMUP]
#           Best: Train: 510.437673 (Epoch 18)
#           Best model saved in memory at epoch 34
# Epoch   34: Train: 355.068691, LR: 5.49e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 355.068691 (Epoch 34)
# Epoch   35: Train: 849.562298, LR: 5.65e-05 [WARMUP]
#           Best: Train: 355.068691 (Epoch 34)
# Epoch   36: Train: 716.481848, LR: 5.81e-05 [WARMUP]
#           Best: Train: 355.068691 (Epoch 34)
#           Best model saved in memory at epoch 37
# Epoch   37: Train: 341.390401, LR: 5.97e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 341.390401 (Epoch 37)
# Epoch   38: Train: 462.306398, LR: 6.13e-05 [WARMUP]
#           Best: Train: 341.390401 (Epoch 37)
# Epoch   39: Train: 575.667946, LR: 6.29e-05 [WARMUP]
#           Best: Train: 341.390401 (Epoch 37)
# Epoch   40: Train: 388.275203, LR: 6.45e-05 [WARMUP]
#           Best: Train: 341.390401 (Epoch 37)
# Epoch   41: Train: 364.628014, LR: 6.62e-05 [WARMUP]
#           Best: Train: 341.390401 (Epoch 37)
# Epoch   42: Train: 505.168963, LR: 6.78e-05 [WARMUP]
#           Best: Train: 341.390401 (Epoch 37)
# Epoch   43: Train: 457.561717, LR: 6.94e-05 [WARMUP]
#           Best: Train: 341.390401 (Epoch 37)
# Epoch   44: Train: 524.782798, LR: 7.10e-05 [WARMUP]
#           Best: Train: 341.390401 (Epoch 37)
# Epoch   45: Train: 539.195061, LR: 7.26e-05 [WARMUP]
#           Best: Train: 341.390401 (Epoch 37)
# Epoch   46: Train: 536.126542, LR: 7.42e-05 [WARMUP]
#           Best: Train: 341.390401 (Epoch 37)
# Epoch   47: Train: 348.354390, LR: 7.58e-05 [WARMUP]
#           Best: Train: 341.390401 (Epoch 37)
# Epoch   48: Train: 371.658895, LR: 7.75e-05 [WARMUP]
#           Best: Train: 341.390401 (Epoch 37)
#           Best model saved in memory at epoch 49
# Epoch   49: Train: 218.909737, LR: 7.91e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 218.909737 (Epoch 49)
#           Best model saved in memory at epoch 50
# Epoch   50: Train: 194.513718, LR: 8.07e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 194.513718 (Epoch 50)
# Epoch   51: Train: 602.521890, LR: 8.23e-05 [WARMUP]
#           Best: Train: 194.513718 (Epoch 50)
# Epoch   52: Train: 302.786708, LR: 8.39e-05 [WARMUP]
#           Best: Train: 194.513718 (Epoch 50)
# Epoch   53: Train: 298.438834, LR: 8.55e-05 [WARMUP]
#           Best: Train: 194.513718 (Epoch 50)
#           Best model saved in memory at epoch 54
# Epoch   54: Train: 157.579899, LR: 8.71e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 157.579899 (Epoch 54)
# Epoch   55: Train: 641.151024, LR: 8.88e-05 [WARMUP]
#           Best: Train: 157.579899 (Epoch 54)
# Epoch   56: Train: 338.101645, LR: 9.04e-05 [WARMUP]
#           Best: Train: 157.579899 (Epoch 54)
# Epoch   57: Train: 298.342100, LR: 9.20e-05 [WARMUP]
#           Best: Train: 157.579899 (Epoch 54)
# Epoch   58: Train: 254.801159, LR: 9.36e-05 [WARMUP]
#           Best: Train: 157.579899 (Epoch 54)
#           Best model saved in memory at epoch 59
# Epoch   59: Train: 142.203966, LR: 9.52e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 142.203966 (Epoch 59)
# Epoch   60: Train: 218.161461, LR: 9.68e-05 [WARMUP]
#           Best: Train: 142.203966 (Epoch 59)
# Epoch   61: Train: 303.447107, LR: 9.84e-05 [WARMUP]
#           Best: Train: 142.203966 (Epoch 59)
# Epoch   62: Train: 244.738380, LR: 1.00e-04 [WARMUP]
#           Best: Train: 142.203966 (Epoch 59)
# Epoch   63: Train: 177.190188, LR: 1.02e-04 [WARMUP]
#           Best: Train: 142.203966 (Epoch 59)
# Epoch   64: Train: 498.769112, LR: 1.03e-04 [WARMUP]
#           Best: Train: 142.203966 (Epoch 59)
#           Best model saved in memory at epoch 65
# Epoch   65: Train: 102.585680, LR: 1.05e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 102.585680 (Epoch 65)
# Epoch   66: Train: 170.985835, LR: 1.07e-04 [WARMUP]
#           Best: Train: 102.585680 (Epoch 65)
# Epoch   67: Train: 256.869670, LR: 1.08e-04 [WARMUP]
#           Best: Train: 102.585680 (Epoch 65)
# Epoch   68: Train: 315.002120, LR: 1.10e-04 [WARMUP]
#           Best: Train: 102.585680 (Epoch 65)
# Epoch   69: Train: 111.426233, LR: 1.11e-04 [WARMUP]
#           Best: Train: 102.585680 (Epoch 65)
# Epoch   70: Train: 137.381036, LR: 1.13e-04 [WARMUP]
#           Best: Train: 102.585680 (Epoch 65)
# Epoch   71: Train: 210.653879, LR: 1.15e-04 [WARMUP]
#           Best: Train: 102.585680 (Epoch 65)
# Epoch   72: Train: 352.307229, LR: 1.16e-04 [WARMUP]
#           Best: Train: 102.585680 (Epoch 65)
# Epoch   73: Train: 403.149740, LR: 1.18e-04 [WARMUP]
#           Best: Train: 102.585680 (Epoch 65)
#           Best model saved in memory at epoch 74
# Epoch   74: Train: 81.614891, LR: 1.19e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 81.614891 (Epoch 74)
#           Best model saved in memory at epoch 75
# Epoch   75: Train: 64.094644, LR: 1.21e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 64.094644 (Epoch 75)
# Epoch   76: Train: 201.087811, LR: 1.23e-04 [WARMUP]
#           Best: Train: 64.094644 (Epoch 75)
# Epoch   77: Train: 221.454328, LR: 1.24e-04 [WARMUP]
#           Best: Train: 64.094644 (Epoch 75)
# Epoch   78: Train: 236.514347, LR: 1.26e-04 [WARMUP]
#           Best: Train: 64.094644 (Epoch 75)
# Epoch   79: Train: 212.977849, LR: 1.27e-04 [WARMUP]
#           Best: Train: 64.094644 (Epoch 75)
# Epoch   80: Train: 70.203370, LR: 1.29e-04 [WARMUP]
#           Best: Train: 64.094644 (Epoch 75)
# Epoch   81: Train: 159.137096, LR: 1.31e-04 [WARMUP]
#           Best: Train: 64.094644 (Epoch 75)
# Epoch   82: Train: 143.587557, LR: 1.32e-04 [WARMUP]
#           Best: Train: 64.094644 (Epoch 75)
#           Best model saved in memory at epoch 83
# Epoch   83: Train: 39.765857, LR: 1.34e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 39.765857 (Epoch 83)
# Epoch   84: Train: 176.245644, LR: 1.36e-04 [WARMUP]
#           Best: Train: 39.765857 (Epoch 83)
# Epoch   85: Train: 138.936474, LR: 1.37e-04 [WARMUP]
#           Best: Train: 39.765857 (Epoch 83)
# Epoch   86: Train: 156.195421, LR: 1.39e-04 [WARMUP]
#           Best: Train: 39.765857 (Epoch 83)
# Epoch   87: Train: 168.222657, LR: 1.40e-04 [WARMUP]
#           Best: Train: 39.765857 (Epoch 83)
# Epoch   88: Train: 91.233880, LR: 1.42e-04 [WARMUP]
#           Best: Train: 39.765857 (Epoch 83)
# Epoch   89: Train: 271.391771, LR: 1.44e-04 [WARMUP]
#           Best: Train: 39.765857 (Epoch 83)
# Epoch   90: Train: 191.834848, LR: 1.45e-04 [WARMUP]
#           Best: Train: 39.765857 (Epoch 83)
# Epoch   91: Train: 60.800796, LR: 1.47e-04 [WARMUP]
#           Best: Train: 39.765857 (Epoch 83)
# Epoch   92: Train: 50.881552, LR: 1.48e-04 [WARMUP]
#           Best: Train: 39.765857 (Epoch 83)
# Epoch   93: Train: 41.976413, LR: 1.50e-04 [WARMUP]
#           Best: Train: 39.765857 (Epoch 83)
#           Best model saved in memory at epoch 94
# Epoch   94: Train: 36.355002, LR: 1.52e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 36.355002 (Epoch 94)
#           Best model saved in memory at epoch 95
# Epoch   95: Train: 15.347824, LR: 1.53e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 15.347824 (Epoch 95)
#           Best model saved in memory at epoch 96
# Epoch   96: Train: 7.554955, LR: 1.55e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch   97: Train: 87.361757, LR: 1.57e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch   98: Train: 74.878335, LR: 1.58e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch   99: Train: 116.678574, LR: 1.60e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch  100: Train: 179.725596, LR: 1.61e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch  101: Train: 37.881512, LR: 1.63e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch  102: Train: 224.864130, LR: 1.65e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch  103: Train: 166.445789, LR: 1.66e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch  104: Train: 19.071507, LR: 1.68e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch  105: Train: 16.965472, LR: 1.69e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch  106: Train: 18.992531, LR: 1.71e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch  107: Train: 69.404942, LR: 1.73e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch  108: Train: 127.550319, LR: 1.74e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch  109: Train: 16.098641, LR: 1.76e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch  110: Train: 47.051950, LR: 1.78e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch  111: Train: 18.218888, LR: 1.79e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
# Epoch  112: Train: 30.672042, LR: 1.81e-04 [WARMUP]
#           Best: Train: 7.554955 (Epoch 96)
#           Best model saved in memory at epoch 113
# Epoch  113: Train: 1.216877, LR: 1.82e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 1.216877 (Epoch 113)
#           Best model saved in memory at epoch 114
# Epoch  114: Train: 1.167159, LR: 1.84e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 1.167159 (Epoch 114)
# Epoch  115: Train: 9.317132, LR: 1.86e-04 [WARMUP]
#           Best: Train: 1.167159 (Epoch 114)
# Epoch  116: Train: 1.216044, LR: 1.87e-04 [WARMUP]
#           Best: Train: 1.167159 (Epoch 114)
# Epoch  117: Train: 1.370039, LR: 1.89e-04 [WARMUP]
#           Best: Train: 1.167159 (Epoch 114)
#           Best model saved in memory at epoch 118
# Epoch  118: Train: 1.051501, LR: 1.90e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 1.051501 (Epoch 118)
#           Best model saved in memory at epoch 119
# Epoch  119: Train: 1.031002, LR: 1.92e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 1.031002 (Epoch 119)
# Epoch  120: Train: 1.485394, LR: 1.94e-04 [WARMUP]
#           Best: Train: 1.031002 (Epoch 119)
#           Best model saved in memory at epoch 121
# Epoch  121: Train: 0.729367, LR: 1.95e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.729367 (Epoch 121)
# Epoch  122: Train: 1.866455, LR: 1.97e-04 [WARMUP]
#           Best: Train: 0.729367 (Epoch 121)
#           Best model saved in memory at epoch 123
# Epoch  123: Train: 0.723157, LR: 1.98e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.723157 (Epoch 123)
#           Best model saved in memory at epoch 124
# Epoch  124: Train: 0.631189, LR: 2.00e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.631189 (Epoch 124)
#           Best model saved in memory at epoch 125
# Epoch  125: Train: 0.628282, LR: 2.02e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.628282 (Epoch 125)
#           Best model saved in memory at epoch 126
# Epoch  126: Train: 0.585135, LR: 2.03e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.585135 (Epoch 126)
#           Best model saved in memory at epoch 127
# Epoch  127: Train: 0.560013, LR: 2.05e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.560013 (Epoch 127)
#           Best model saved in memory at epoch 128
# Epoch  128: Train: 0.537653, LR: 2.07e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.537653 (Epoch 128)
#           Best model saved in memory at epoch 129
# Epoch  129: Train: 0.511752, LR: 2.08e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.511752 (Epoch 129)
#           Best model saved in memory at epoch 130
# Epoch  130: Train: 0.487624, LR: 2.10e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.487624 (Epoch 130)
#           Best model saved in memory at epoch 131
# Epoch  131: Train: 0.485355, LR: 2.11e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.485355 (Epoch 131)
#           Best model saved in memory at epoch 132
# Epoch  132: Train: 0.445121, LR: 2.13e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.445121 (Epoch 132)
#           Best model saved in memory at epoch 133
# Epoch  133: Train: 0.427644, LR: 2.15e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.427644 (Epoch 133)
#           Best model saved in memory at epoch 134
# Epoch  134: Train: 0.411159, LR: 2.16e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.411159 (Epoch 134)
#           Best model saved in memory at epoch 135
# Epoch  135: Train: 0.391104, LR: 2.18e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.391104 (Epoch 135)
#           Best model saved in memory at epoch 136
# Epoch  136: Train: 0.375706, LR: 2.19e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.375706 (Epoch 136)
#           Best model saved in memory at epoch 137
# Epoch  137: Train: 0.368483, LR: 2.21e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.368483 (Epoch 137)
# Epoch  138: Train: 0.372075, LR: 2.23e-04 [WARMUP]
#           Best: Train: 0.368483 (Epoch 137)
#           Best model saved in memory at epoch 139
# Epoch  139: Train: 0.347981, LR: 2.24e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.347981 (Epoch 139)
#           Best model saved in memory at epoch 140
# Epoch  140: Train: 0.330242, LR: 2.26e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.330242 (Epoch 140)
# Epoch  141: Train: 0.333400, LR: 2.28e-04 [WARMUP]
#           Best: Train: 0.330242 (Epoch 140)
#           Best model saved in memory at epoch 142
# Epoch  142: Train: 0.316922, LR: 2.29e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.316922 (Epoch 142)
#           Best model saved in memory at epoch 143
# Epoch  143: Train: 0.288319, LR: 2.31e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.288319 (Epoch 143)
# Epoch  144: Train: 0.289796, LR: 2.32e-04 [WARMUP]
#           Best: Train: 0.288319 (Epoch 143)
#           Best model saved in memory at epoch 145
# Epoch  145: Train: 0.278113, LR: 2.34e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.278113 (Epoch 145)
# Epoch  146: Train: 0.296683, LR: 2.36e-04 [WARMUP]
#           Best: Train: 0.278113 (Epoch 145)
#           Best model saved in memory at epoch 147
# Epoch  147: Train: 0.256725, LR: 2.37e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.256725 (Epoch 147)
# Epoch  148: Train: 0.266208, LR: 2.39e-04 [WARMUP]
#           Best: Train: 0.256725 (Epoch 147)
# Epoch  149: Train: 0.259843, LR: 2.40e-04 [WARMUP]
#           Best: Train: 0.256725 (Epoch 147)
#           Best model saved in memory at epoch 150
# Epoch  150: Train: 0.242846, LR: 2.42e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.242846 (Epoch 150)
#           Best model saved in memory at epoch 151
# Epoch  151: Train: 0.239337, LR: 2.44e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.239337 (Epoch 151)
# Epoch  152: Train: 0.253175, LR: 2.45e-04 [WARMUP]
#           Best: Train: 0.239337 (Epoch 151)
#           Best model saved in memory at epoch 153
# Epoch  153: Train: 0.221678, LR: 2.47e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.221678 (Epoch 153)
#           Best model saved in memory at epoch 154
# Epoch  154: Train: 0.213995, LR: 2.49e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.213995 (Epoch 154)
# Epoch  155: Train: 0.226664, LR: 2.50e-04 [WARMUP]
#           Best: Train: 0.213995 (Epoch 154)
# Epoch  156: Train: 0.229430, LR: 2.52e-04 [WARMUP]
#           Best: Train: 0.213995 (Epoch 154)
#           Best model saved in memory at epoch 157
# Epoch  157: Train: 0.194973, LR: 2.53e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.194973 (Epoch 157)
#           Best model saved in memory at epoch 158
# Epoch  158: Train: 0.190459, LR: 2.55e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.190459 (Epoch 158)
# Epoch  159: Train: 0.198719, LR: 2.57e-04 [WARMUP]
#           Best: Train: 0.190459 (Epoch 158)
#           Best model saved in memory at epoch 160
# Epoch  160: Train: 0.185156, LR: 2.58e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.185156 (Epoch 160)
#           Best model saved in memory at epoch 161
# Epoch  161: Train: 0.169250, LR: 2.60e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.169250 (Epoch 161)
# Epoch  162: Train: 0.182004, LR: 2.61e-04 [WARMUP]
#           Best: Train: 0.169250 (Epoch 161)
# Epoch  163: Train: 0.182069, LR: 2.63e-04 [WARMUP]
#           Best: Train: 0.169250 (Epoch 161)
# Epoch  164: Train: 0.196499, LR: 2.65e-04 [WARMUP]
#           Best: Train: 0.169250 (Epoch 161)
# Epoch  165: Train: 0.175552, LR: 2.66e-04 [WARMUP]
#           Best: Train: 0.169250 (Epoch 161)
# Epoch  166: Train: 0.184105, LR: 2.68e-04 [WARMUP]
#           Best: Train: 0.169250 (Epoch 161)
# Epoch  167: Train: 0.180408, LR: 2.69e-04 [WARMUP]
#           Best: Train: 0.169250 (Epoch 161)
#           Best model saved in memory at epoch 168
# Epoch  168: Train: 0.158746, LR: 2.71e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.158746 (Epoch 168)
# Epoch  169: Train: 0.163098, LR: 2.73e-04 [WARMUP]
#           Best: Train: 0.158746 (Epoch 168)
# Epoch  170: Train: 0.164810, LR: 2.74e-04 [WARMUP]
#           Best: Train: 0.158746 (Epoch 168)
# Epoch  171: Train: 0.169718, LR: 2.76e-04 [WARMUP]
#           Best: Train: 0.158746 (Epoch 168)
#           Best model saved in memory at epoch 172
# Epoch  172: Train: 0.155242, LR: 2.78e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.155242 (Epoch 172)
#           Best model saved in memory at epoch 173
# Epoch  173: Train: 0.151106, LR: 2.79e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.151106 (Epoch 173)
# Epoch  174: Train: 0.155568, LR: 2.81e-04 [WARMUP]
#           Best: Train: 0.151106 (Epoch 173)
# Epoch  175: Train: 0.163746, LR: 2.82e-04 [WARMUP]
#           Best: Train: 0.151106 (Epoch 173)
# Epoch  176: Train: 0.151644, LR: 2.84e-04 [WARMUP]
#           Best: Train: 0.151106 (Epoch 173)
#           Best model saved in memory at epoch 177
# Epoch  177: Train: 0.148945, LR: 2.86e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.148945 (Epoch 177)
# Epoch  178: Train: 0.158292, LR: 2.87e-04 [WARMUP]
#           Best: Train: 0.148945 (Epoch 177)
#           Best model saved in memory at epoch 179
# Epoch  179: Train: 0.137126, LR: 2.89e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.137126 (Epoch 179)
# Epoch  180: Train: 0.141310, LR: 2.90e-04 [WARMUP]
#           Best: Train: 0.137126 (Epoch 179)
# Epoch  181: Train: 0.144353, LR: 2.92e-04 [WARMUP]
#           Best: Train: 0.137126 (Epoch 179)
# Epoch  182: Train: 0.138321, LR: 2.94e-04 [WARMUP]
#           Best: Train: 0.137126 (Epoch 179)
# Epoch  183: Train: 0.147188, LR: 2.95e-04 [WARMUP]
#           Best: Train: 0.137126 (Epoch 179)
# Epoch  184: Train: 0.154835, LR: 2.97e-04 [WARMUP]
#           Best: Train: 0.137126 (Epoch 179)
#           Best model saved in memory at epoch 185
# Epoch  185: Train: 0.135127, LR: 2.99e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.135127 (Epoch 185)
# Epoch  186: Train: 0.141227, LR: 3.00e-04 [WARMUP]
#           Best: Train: 0.135127 (Epoch 185)
#           Best model saved in memory at epoch 187
# Epoch  187: Train: 0.124821, LR: 3.02e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.124821 (Epoch 187)
#           Best model saved in memory at epoch 188
# Epoch  188: Train: 0.124610, LR: 3.03e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.124610 (Epoch 188)
# Epoch  189: Train: 0.134597, LR: 3.05e-04 [WARMUP]
#           Best: Train: 0.124610 (Epoch 188)
# Epoch  190: Train: 0.130849, LR: 3.07e-04 [WARMUP]
#           Best: Train: 0.124610 (Epoch 188)
# Epoch  191: Train: 0.140105, LR: 3.08e-04 [WARMUP]
#           Best: Train: 0.124610 (Epoch 188)
# Epoch  192: Train: 0.129616, LR: 3.10e-04 [WARMUP]
#           Best: Train: 0.124610 (Epoch 188)
#           Best model saved in memory at epoch 193
# Epoch  193: Train: 0.118505, LR: 3.11e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.118505 (Epoch 193)
#           Best model saved in memory at epoch 194
# Epoch  194: Train: 0.115386, LR: 3.13e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.115386 (Epoch 194)
# Epoch  195: Train: 0.139244, LR: 3.15e-04 [WARMUP]
#           Best: Train: 0.115386 (Epoch 194)
# Epoch  196: Train: 0.131079, LR: 3.16e-04 [WARMUP]
#           Best: Train: 0.115386 (Epoch 194)
# Epoch  197: Train: 0.132418, LR: 3.18e-04 [WARMUP]
#           Best: Train: 0.115386 (Epoch 194)
# Epoch  198: Train: 0.123149, LR: 3.20e-04 [WARMUP]
#           Best: Train: 0.115386 (Epoch 194)
# Epoch  199: Train: 0.127431, LR: 3.21e-04 [WARMUP]
#           Best: Train: 0.115386 (Epoch 194)
# Epoch  200: Train: 0.119300, LR: 3.23e-04 [WARMUP]
#           Best: Train: 0.115386 (Epoch 194)
# Epoch  201: Train: 0.122089, LR: 3.24e-04 [WARMUP]
#           Best: Train: 0.115386 (Epoch 194)
# Epoch  202: Train: 0.127492, LR: 3.26e-04 [WARMUP]
#           Best: Train: 0.115386 (Epoch 194)
# Epoch  203: Train: 0.116556, LR: 3.28e-04 [WARMUP]
#           Best: Train: 0.115386 (Epoch 194)
# Epoch  204: Train: 0.124425, LR: 3.29e-04 [WARMUP]
#           Best: Train: 0.115386 (Epoch 194)
# Epoch  205: Train: 0.119981, LR: 3.31e-04 [WARMUP]
#           Best: Train: 0.115386 (Epoch 194)
# Epoch  206: Train: 0.132693, LR: 3.32e-04 [WARMUP]
#           Best: Train: 0.115386 (Epoch 194)
#           Best model saved in memory at epoch 207
# Epoch  207: Train: 0.113094, LR: 3.34e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.113094 (Epoch 207)
# Epoch  208: Train: 0.114574, LR: 3.36e-04 [WARMUP]
#           Best: Train: 0.113094 (Epoch 207)
# Epoch  209: Train: 0.125123, LR: 3.37e-04 [WARMUP]
#           Best: Train: 0.113094 (Epoch 207)
# Epoch  210: Train: 0.115594, LR: 3.39e-04 [WARMUP]
#           Best: Train: 0.113094 (Epoch 207)
# Epoch  211: Train: 0.118107, LR: 3.40e-04 [WARMUP]
#           Best: Train: 0.113094 (Epoch 207)
#           Best model saved in memory at epoch 212
# Epoch  212: Train: 0.108118, LR: 3.42e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.108118 (Epoch 212)
# Epoch  213: Train: 0.108835, LR: 3.44e-04 [WARMUP]
#           Best: Train: 0.108118 (Epoch 212)
# Epoch  214: Train: 0.109867, LR: 3.45e-04 [WARMUP]
#           Best: Train: 0.108118 (Epoch 212)
# Epoch  215: Train: 0.121363, LR: 3.47e-04 [WARMUP]
#           Best: Train: 0.108118 (Epoch 212)
#           Best model saved in memory at epoch 216
# Epoch  216: Train: 0.107034, LR: 3.49e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.107034 (Epoch 216)
# Epoch  217: Train: 0.116072, LR: 3.50e-04 [WARMUP]
#           Best: Train: 0.107034 (Epoch 216)
# Epoch  218: Train: 0.120455, LR: 3.52e-04 [WARMUP]
#           Best: Train: 0.107034 (Epoch 216)
# Epoch  219: Train: 0.109841, LR: 3.53e-04 [WARMUP]
#           Best: Train: 0.107034 (Epoch 216)
# Epoch  220: Train: 0.113279, LR: 3.55e-04 [WARMUP]
#           Best: Train: 0.107034 (Epoch 216)
# Epoch  221: Train: 0.113405, LR: 3.57e-04 [WARMUP]
#           Best: Train: 0.107034 (Epoch 216)
# Epoch  222: Train: 0.115040, LR: 3.58e-04 [WARMUP]
#           Best: Train: 0.107034 (Epoch 216)
#           Best model saved in memory at epoch 223
# Epoch  223: Train: 0.105325, LR: 3.60e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.105325 (Epoch 223)
#           Best model saved in memory at epoch 224
# Epoch  224: Train: 0.103633, LR: 3.61e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.103633 (Epoch 224)
# Epoch  225: Train: 0.108961, LR: 3.63e-04 [WARMUP]
#           Best: Train: 0.103633 (Epoch 224)
# Epoch  226: Train: 0.106809, LR: 3.65e-04 [WARMUP]
#           Best: Train: 0.103633 (Epoch 224)
# Epoch  227: Train: 0.105423, LR: 3.66e-04 [WARMUP]
#           Best: Train: 0.103633 (Epoch 224)
#           Best model saved in memory at epoch 228
# Epoch  228: Train: 0.101988, LR: 3.68e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.101988 (Epoch 228)
#           Best model saved in memory at epoch 229
# Epoch  229: Train: 0.099299, LR: 3.70e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.099299 (Epoch 229)
#           Best model saved in memory at epoch 230
# Epoch  230: Train: 0.098358, LR: 3.71e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.098358 (Epoch 230)
# Epoch  231: Train: 0.099974, LR: 3.73e-04 [WARMUP]
#           Best: Train: 0.098358 (Epoch 230)
# Epoch  232: Train: 0.102081, LR: 3.74e-04 [WARMUP]
#           Best: Train: 0.098358 (Epoch 230)
# Epoch  233: Train: 0.098503, LR: 3.76e-04 [WARMUP]
#           Best: Train: 0.098358 (Epoch 230)
# Epoch  234: Train: 0.105144, LR: 3.78e-04 [WARMUP]
#           Best: Train: 0.098358 (Epoch 230)
# Epoch  235: Train: 0.099045, LR: 3.79e-04 [WARMUP]
#           Best: Train: 0.098358 (Epoch 230)
# Epoch  236: Train: 0.101914, LR: 3.81e-04 [WARMUP]
#           Best: Train: 0.098358 (Epoch 230)
# Epoch  237: Train: 0.099589, LR: 3.82e-04 [WARMUP]
#           Best: Train: 0.098358 (Epoch 230)
#           Best model saved in memory at epoch 238
# Epoch  238: Train: 0.097621, LR: 3.84e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.097621 (Epoch 238)
# Epoch  239: Train: 0.099429, LR: 3.86e-04 [WARMUP]
#           Best: Train: 0.097621 (Epoch 238)
# Epoch  240: Train: 0.100161, LR: 3.87e-04 [WARMUP]
#           Best: Train: 0.097621 (Epoch 238)
#           Best model saved in memory at epoch 241
# Epoch  241: Train: 0.094939, LR: 3.89e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.094939 (Epoch 241)
#           Best model saved in memory at epoch 242
# Epoch  242: Train: 0.094781, LR: 3.91e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.094781 (Epoch 242)
# Epoch  243: Train: 0.102243, LR: 3.92e-04 [WARMUP]
#           Best: Train: 0.094781 (Epoch 242)
#           Best model saved in memory at epoch 244
# Epoch  244: Train: 0.091445, LR: 3.94e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.091445 (Epoch 244)
# Epoch  245: Train: 0.093098, LR: 3.95e-04 [WARMUP]
#           Best: Train: 0.091445 (Epoch 244)
# Epoch  246: Train: 0.093366, LR: 3.97e-04 [WARMUP]
#           Best: Train: 0.091445 (Epoch 244)
#           Best model saved in memory at epoch 247
# Epoch  247: Train: 0.089520, LR: 3.99e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0
-04 [WARMUP]
#           Best: Train: 0.075365 (Epoch 285)
# Epoch  303: Train: 0.082234, LR: 4.89e-04 [WARMUP]
#           Best: Train: 0.075365 (Epoch 285)
# Epoch  304: Train: 0.076903, LR: 4.91e-04 [WARMUP]
#           Best: Train: 0.075365 (Epoch 285)
# Epoch  305: Train: 0.076295, LR: 4.92e-04 [WARMUP]
#           Best: Train: 0.075365 (Epoch 285)
#           Best model saved in memory at epoch 306
# Epoch  306: Train: 0.072310, LR: 4.94e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.072310 (Epoch 306)
# Epoch  307: Train: 0.080318, LR: 4.95e-04 [WARMUP]
#           Best: Train: 0.072310 (Epoch 306)
# Epoch  308: Train: 0.073094, LR: 4.97e-04 [WARMUP]
#           Best: Train: 0.072310 (Epoch 306)
# Epoch  309: Train: 0.077430, LR: 4.99e-04 [WARMUP]
#           Best: Train: 0.072310 (Epoch 306)
# Epoch  310: Train: 0.082731, LR: 5.00e-04 [WARMUP]
#           Best: Train: 0.072310 (Epoch 306)
#           Best model saved in memory at epoch 311
# Epoch  311: Train: 0.070964, LR: 5.02e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.070964 (Epoch 311)
# Epoch  312: Train: 0.077156, LR: 5.03e-04 [WARMUP]
#           Best: Train: 0.070964 (Epoch 311)
# Epoch  313: Train: 0.078445, LR: 5.05e-04 [WARMUP]
#           Best: Train: 0.070964 (Epoch 311)
# Epoch  314: Train: 0.072592, LR: 5.07e-04 [WARMUP]
#           Best: Train: 0.070964 (Epoch 311)
# Epoch  315: Train: 0.081756, LR: 5.08e-04 [WARMUP]
#           Best: Train: 0.070964 (Epoch 311)
# Epoch  316: Train: 0.080227, LR: 5.10e-04 [WARMUP]
#           Best: Train: 0.070964 (Epoch 311)
# Epoch  317: Train: 0.073539, LR: 5.12e-04 [WARMUP]
#           Best: Train: 0.070964 (Epoch 311)
#           Best model saved in memory at epoch 318
# Epoch  318: Train: 0.069144, LR: 5.13e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
# Epoch  319: Train: 0.078691, LR: 5.15e-04 [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
# Epoch  320: Train: 0.082632, LR: 5.16e-04 [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
# Epoch  321: Train: 0.073997, LR: 5.18e-04 [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
# Epoch  322: Train: 0.074823, LR: 5.20e-04 [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
# Epoch  323: Train: 0.080572, LR: 5.21e-04 [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
# Epoch  324: Train: 0.075844, LR: 5.23e-04 [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
# Epoch  325: Train: 0.074683, LR: 5.24e-04 [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
# Epoch  326: Train: 0.074017, LR: 5.26e-04 [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
# Epoch  327: Train: 0.080475, LR: 5.28e-04 [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
# Epoch  328: Train: 0.072497, LR: 5.29e-04 [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
# Epoch  329: Train: 0.073475, LR: 5.31e-04 [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
# Epoch  330: Train: 0.073989, LR: 5.33e-04 [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
# Epoch  331: Train: 0.081201, LR: 5.34e-04 [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
# Epoch  332: Train: 0.077076, LR: 5.36e-04 [WARMUP]
#           Best: Train: 0.069144 (Epoch 318)
#           Best model saved in memory at epoch 333
# Epoch  333: Train: 0.064017, LR: 5.37e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  334: Train: 0.074088, LR: 5.39e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  335: Train: 0.073111, LR: 5.41e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  336: Train: 0.071913, LR: 5.42e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  337: Train: 0.079872, LR: 5.44e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  338: Train: 0.078676, LR: 5.45e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  339: Train: 0.076020, LR: 5.47e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  340: Train: 0.070277, LR: 5.49e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  341: Train: 0.066221, LR: 5.50e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  342: Train: 0.072627, LR: 5.52e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  343: Train: 0.067561, LR: 5.54e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  344: Train: 0.074652, LR: 5.55e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  345: Train: 0.075289, LR: 5.57e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  346: Train: 0.067465, LR: 5.58e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  347: Train: 0.074582, LR: 5.60e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  348: Train: 0.069093, LR: 5.62e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
# Epoch  349: Train: 0.078566, LR: 5.63e-04 [WARMUP]
#           Best: Train: 0.064017 (Epoch 333)
#           Best model saved in memory at epoch 350
# Epoch  350: Train: 0.063414, LR: 5.65e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.063414 (Epoch 350)
# Epoch  351: Train: 0.064563, LR: 5.66e-04 [WARMUP]
#           Best: Train: 0.063414 (Epoch 350)
# Epoch  352: Train: 0.070470, LR: 5.68e-04 [WARMUP]
#           Best: Train: 0.063414 (Epoch 350)
# Epoch  353: Train: 0.067797, LR: 5.70e-04 [WARMUP]
#           Best: Train: 0.063414 (Epoch 350)
# Epoch  354: Train: 0.069041, LR: 5.71e-04 [WARMUP]
#           Best: Train: 0.063414 (Epoch 350)
# Epoch  355: Train: 0.066223, LR: 5.73e-04 [WARMUP]
#           Best: Train: 0.063414 (Epoch 350)
# Epoch  356: Train: 0.071465, LR: 5.74e-04 [WARMUP]
#           Best: Train: 0.063414 (Epoch 350)
# Epoch  357: Train: 0.071519, LR: 5.76e-04 [WARMUP]
#           Best: Train: 0.063414 (Epoch 350)
# Epoch  358: Train: 0.071801, LR: 5.78e-04 [WARMUP]
#           Best: Train: 0.063414 (Epoch 350)
# Epoch  359: Train: 0.073727, LR: 5.79e-04 [WARMUP]
#           Best: Train: 0.063414 (Epoch 350)
#           Best model saved in memory at epoch 360
# Epoch  360: Train: 0.062761, LR: 5.81e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.062761 (Epoch 360)
# Epoch  361: Train: 0.065090, LR: 5.83e-04 [WARMUP]
#           Best: Train: 0.062761 (Epoch 360)
# Epoch  362: Train: 0.065495, LR: 5.84e-04 [WARMUP]
#           Best: Train: 0.062761 (Epoch 360)
# Epoch  363: Train: 0.067912, LR: 5.86e-04 [WARMUP]
#           Best: Train: 0.062761 (Epoch 360)
# Epoch  364: Train: 0.072014, LR: 5.87e-04 [WARMUP]
#           Best: Train: 0.062761 (Epoch 360)
# Epoch  365: Train: 0.068775, LR: 5.89e-04 [WARMUP]
#           Best: Train: 0.062761 (Epoch 360)
# Epoch  366: Train: 0.070577, LR: 5.91e-04 [WARMUP]
#           Best: Train: 0.062761 (Epoch 360)
# Epoch  367: Train: 0.071784, LR: 5.92e-04 [WARMUP]
#           Best: Train: 0.062761 (Epoch 360)
#           Best model saved in memory at epoch 368
# Epoch  368: Train: 0.062614, LR: 5.94e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  369: Train: 0.071286, LR: 5.95e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  370: Train: 0.064153, LR: 5.97e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  371: Train: 0.072264, LR: 5.99e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  372: Train: 0.065410, LR: 6.00e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  373: Train: 0.065901, LR: 6.02e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  374: Train: 0.068786, LR: 6.04e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  375: Train: 0.067885, LR: 6.05e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  376: Train: 0.070072, LR: 6.07e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  377: Train: 0.067260, LR: 6.08e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  378: Train: 0.064239, LR: 6.10e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  379: Train: 0.064823, LR: 6.12e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  380: Train: 0.067531, LR: 6.13e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  381: Train: 0.066753, LR: 6.15e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  382: Train: 0.072134, LR: 6.16e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  383: Train: 0.075089, LR: 6.18e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  384: Train: 0.067332, LR: 6.20e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  385: Train: 0.071640, LR: 6.21e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  386: Train: 0.063429, LR: 6.23e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  387: Train: 0.070764, LR: 6.25e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  388: Train: 0.065238, LR: 6.26e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
# Epoch  389: Train: 0.066875, LR: 6.28e-04 [WARMUP]
#           Best: Train: 0.062614 (Epoch 368)
#           Best model saved in memory at epoch 390
# Epoch  390: Train: 0.062542, LR: 6.29e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.062542 (Epoch 390)
# Epoch  391: Train: 0.066933, LR: 6.31e-04 [WARMUP]
#           Best: Train: 0.062542 (Epoch 390)
# Epoch  392: Train: 0.069831, LR: 6.33e-04 [WARMUP]
#           Best: Train: 0.062542 (Epoch 390)
#           Best model saved in memory at epoch 393
# Epoch  393: Train: 0.061975, LR: 6.34e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.061975 (Epoch 393)
# Epoch  394: Train: 0.065323, LR: 6.36e-04 [WARMUP]
#           Best: Train: 0.061975 (Epoch 393)
# Epoch  395: Train: 0.067539, LR: 6.37e-04 [WARMUP]
#           Best: Train: 0.061975 (Epoch 393)
# Epoch  396: Train: 0.069427, LR: 6.39e-04 [WARMUP]
#           Best: Train: 0.061975 (Epoch 393)
#           Best model saved in memory at epoch 397
# Epoch  397: Train: 0.059410, LR: 6.41e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.059410 (Epoch 397)
# Epoch  398: Train: 0.071884, LR: 6.42e-04 [WARMUP]
#           Best: Train: 0.059410 (Epoch 397)
# Epoch  399: Train: 0.066674, LR: 6.44e-04 [WARMUP]
#           Best: Train: 0.059410 (Epoch 397)
# Epoch  400: Train: 0.062719, LR: 6.45e-04 [WARMUP]
#           Best: Train: 0.059410 (Epoch 397)
# Epoch  401: Train: 0.072149, LR: 6.47e-04 [WARMUP]
#           Best: Train: 0.059410 (Epoch 397)
# Epoch  402: Train: 0.065472, LR: 6.49e-04 [WARMUP]
#           Best: Train: 0.059410 (Epoch 397)
# Epoch  403: Train: 0.068428, LR: 6.50e-04 [WARMUP]
#           Best: Train: 0.059410 (Epoch 397)
#           Best model saved in memory at epoch 404
# Epoch  404: Train: 0.057427, LR: 6.52e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.057427 (Epoch 404)
# Epoch  405: Train: 0.069274, LR: 6.54e-04 [WARMUP]
#           Best: Train: 0.057427 (Epoch 404)
# Epoch  406: Train: 0.061074, LR: 6.55e-04 [WARMUP]
#           Best: Train: 0.057427 (Epoch 404)
# Epoch  407: Train: 0.065698, LR: 6.57e-04 [WARMUP]
#           Best: Train: 0.057427 (Epoch 404)
# Epoch