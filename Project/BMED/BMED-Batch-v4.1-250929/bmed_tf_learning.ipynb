# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence, PackedSequence
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from torch.utils.data import Subset
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def df_treat(name):
    df = pd.read_csv(name)
    ndf = pd.DataFrame()
    range_mm={
        'V': {'min':df['V'].min()*0.8, 'max': df['V'].max()*1.2},
        'E': {'min':df['E'].min()*0.8, 'max': df['E'].max()*1.2},
        'VF': {'min':df['VF'].min()*0.8, 'max': df['VF'].max()*1.2},
        'VA': {'min':df['VA'].min()*0.8, 'max': df['VA'].max()*1.2},
        'VB': {'min':df['VB'].min()*0.8, 'max': df['VB'].max()*1.2},
        'CFLA': {'min':0, 'max': df['CFLA'].max()*1.2},
        'CALA': {'min':0, 'max': df['CALA'].max()*1.2},
        'CFK': {'min':0, 'max': df['CFK'].max()*1.2},
        'CBK': {'min':0, 'max': df['CBK'].max()*1.2},
        'I': {'min':0, 'max': df['I'].max()*1.2},
    }
    ndf['exp'] = df['exp']; ndf['t'] = df['t']

    for col in ['V', 'E', 'VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']:
        if col in range_mm:
            ndf[col] = (df[col] - range_mm[col]['min'])/(range_mm[col]['max'] - range_mm[col]['min'])
        else:
            ndf[col] = df[col]

    exp_num_list = sorted(ndf['exp'].unique())

    return df, ndf, range_mm, exp_num_list

# %%
def seq_data(ndf, exp_num_list):
    seq = []
    feature_cols = ['V', 'E', 'VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']
    
    for exp in exp_num_list:
        exp_df = ndf[ndf['exp'] == exp]
        seq.append(exp_df[feature_cols].values)
    
    return seq

# %%
def pad_seq(seq):
    max_len = max([len(s) for s in seq])
    seq_len = [len(s) for s in seq]
    pad_seq = pad_sequence([torch.tensor(s) for s in seq], batch_first=True, padding_value=-1)

    return pad_seq, seq_len, max_len

# %%
def gen_dataset(pad_seq, seq_len):
    input_tensor = pad_seq.float()
    seq_len_tensor = torch.tensor(seq_len)
    dataset = TensorDataset(input_tensor, seq_len_tensor)
    return dataset

# %%
class LayerNormLSTM(nn.Module):
    """LSTM layer with layer normalization applied to gates"""
    def __init__(self, input_node, hidden_node):
        super().__init__()
        self.input_node = input_node
        self.hidden_node = hidden_node

        self.w_i = nn.Linear(input_node, 4 * hidden_node, bias=False)
        self.w_h = nn.Linear(hidden_node, 4 * hidden_node, bias=False)

        self.ln_i = nn.LayerNorm(hidden_node)
        self.ln_h = nn.LayerNorm(hidden_node)
        self.ln_g = nn.LayerNorm(hidden_node)
        self.ln_o = nn.LayerNorm(hidden_node)

        self.ln_c = nn.LayerNorm(hidden_node)

    def forward(self, input, hidden):
        h_prev, c_prev = hidden

        gi = self.w_i(input)
        gh = self.w_h(h_prev)
        i_i, i_f, i_g, i_o = gi.chunk(4, dim=-1)
        h_i, h_f, h_g, h_o = gh.chunk(4, dim=-1)

        i_g = torch.sigmoid(self.ln_i(i_i + h_i))
        f_g = torch.sigmoid(self.ln_h(i_f + h_f))
        g_g = torch.tanh(self.ln_g(i_g + h_g))
        o_g = torch.sigmoid(self.ln_o(i_o + h_o))

        c_new = f_g * c_prev + i_g * g_g
        c_new = self.ln_c(c_new)

        h_new = o_g * torch.tanh(c_new)

        return h_new, c_new

# %%
class StateExtr(nn.Module):
    def __init__(self, input_node, hidden_node, n_layer, dropout):
        super().__init__()
        self.hidden_node = hidden_node
        self.n_layer = n_layer
        self.input_node = input_node

        self.lstm_cells = nn.ModuleList()

        self.lstm_cells.append(LayerNormLSTM(input_node, hidden_node))

        for _ in range(n_layer - 1):
            self.lstm_cells.append(LayerNormLSTM(hidden_node, hidden_node))

        self.dropout = nn.Dropout(dropout)

        self.final_layer_norm = nn.LayerNorm(hidden_node)
        self.final_dropout = nn.Dropout(dropout)

    def forward(self, x, seq_len):
        batch_size, max_len, input_node = x.size()
        device = x.device

        h_states = []
        c_states = []
        for _ in range(self.n_layer):
            h_states.append(torch.zeros(batch_size, self.hidden_node, device=device))
            c_states.append(torch.zeros(batch_size, self.hidden_node, device=device))
        
        outputs = []
        for t in range(max_len):
            x_t = x[:, t, :]

            layer_input = x_t
            for layer_idx, lstm_cell in enumerate(self.lstm_cells):
                h_new, c_new = lstm_cell(layer_input, (h_states[layer_idx], c_states[layer_idx]))

                # Inplace 연산 대신 새로운 텐서 생성
                h_states[layer_idx] = h_new
                c_states[layer_idx] = c_new

                if layer_idx < len(self.lstm_cells) - 1:
                    layer_input = self.dropout(h_new)
                else:
                    layer_input = h_new

            outputs.append(layer_input)
        
        output_tensor = torch.stack(outputs, dim=1)
        seq_len_cpu = seq_len.detach().cpu().long()
        mask = torch.arange(max_len, device='cpu')[None, :] < seq_len_cpu[:, None]
        mask = mask.float().to(device).unsqueeze(-1)

        masked_output = output_tensor * mask

        normalized = self.final_layer_norm(masked_output)
        return self.final_dropout(normalized)

# %%
class PhysicalChangeDecoder(nn.Module):
    def __init__(self, input_node, output_node, n_layer, hidden_node, dropout):
        super().__init__()

        self.layers = nn.ModuleList()

        self.layers.append(nn.Linear(input_node, hidden_node))
        self.layers.append(nn.LayerNorm(hidden_node))
        self.layers.append(nn.ReLU())
        self.layers.append(nn.Dropout(dropout))

        for i in range(n_layer - 1):
            self.layers.append(nn.Linear(hidden_node, hidden_node))
            self.layers.append(nn.LayerNorm(hidden_node))
            self.layers.append(nn.ReLU())
            self.layers.append(nn.Dropout(dropout))

        self.layers.append(nn.Linear(hidden_node, output_node))
    
    def forward(self, hidden_states):
        x = hidden_states
        for layer in self.layers:
            x = layer(x)
        return x

# %%
class CurrentPredictor(nn.Module):
    def __init__(self, input_node, hidden_node, n_layer, dropout):
        super().__init__()
        
        self.layers = nn.ModuleList()
        
        self.layers.append(nn.Linear(input_node, hidden_node))
        self.layers.append(nn.LayerNorm(hidden_node))
        self.layers.append(nn.ReLU())
        self.layers.append(nn.Dropout(dropout))
        
        for i in range(n_layer - 1):
            self.layers.append(nn.Linear(hidden_node, hidden_node))
            self.layers.append(nn.LayerNorm(hidden_node))
            self.layers.append(nn.ReLU())
            self.layers.append(nn.Dropout(dropout))
        
        self.layers.append(nn.Linear(hidden_node, 1))
    
    def forward(self, new_state):
        x = new_state
        for layer in self.layers:
            x = layer(x)
        return x

# %%
class PhysicsConstraintLayer(nn.Module):
    def __init__(self, range_mm, current_predictor, eps=1e-2):
        super().__init__()
        self.sps = eps
        self.current_predictor = current_predictor
        self.register_buffer('range_mm_tensor', self._convert_range_to_tensor(range_mm))

    def _convert_range_to_tensor(self, range_mm):
        feature_names = ['V','E','VF','VA','VB','CFLA','CALA','CFK','CBK','I']
        ranges = torch.zeros(len(feature_names),2)

        for i, name in enumerate(feature_names):
            if name in range_mm:
                ranges[i, 0] = range_mm[name]['min']
                ranges[i, 1] = range_mm[name]['max']
        
        return ranges
    
    def normalize(self, data, feature_idx):
        min_val = self.range_mm_tensor[feature_idx, 0]
        max_val = self.range_mm_tensor[feature_idx, 1]
        return (data - min_val) / (max_val - min_val)

    def denormalize(self, data, feature_idx):
        min_val = self.range_mm_tensor[feature_idx, 0]
        max_val = self.range_mm_tensor[feature_idx, 1]
        return data * (max_val - min_val) + min_val

    def forward(self, physical_changes, current_state):
        V_idx, E_idx, VF_idx, VA_idx, VB_idx = 0, 1, 2, 3, 4
        CFLA_idx, CALA_idx, CFK_idx, CBK_idx, I_idx = 5, 6, 7, 8, 9

        VF = self.denormalize(current_state[..., 2:3], VF_idx)
        VA = self.denormalize(current_state[..., 3:4], VA_idx)
        VB = self.denormalize(current_state[..., 4:5], VB_idx)
        CFLA = self.denormalize(current_state[..., 5:6], CFLA_idx)
        CALA = self.denormalize(current_state[..., 6:7], CALA_idx)
        CFK = self.denormalize(current_state[..., 7:8], CFK_idx)
        CBK = self.denormalize(current_state[..., 8:9], CBK_idx)

        dVA = physical_changes[..., 0:1]
        dVB = physical_changes[..., 1:2]
        rratio = physical_changes[..., 2:3]
        dNBK = physical_changes[..., 3:4]

        ratio = torch.sigmoid(rratio)
        dNALA = ratio * dNBK

        NFLA = CFLA * VF
        NALA = CALA * VA
        NFK = CFK * VF
        NBK = CBK * VB

        nVF = VF - dVA - dVB
        nVA = VA + dVA
        nVB = VB + dVB

        nVF = torch.clamp(nVF, min=self.sps)
        nVA = torch.clamp(nVA, min=self.sps)
        nVB = torch.clamp(nVB, min=self.sps)
        
        nNFLA = NFLA - torch.clamp(dNALA, min=0.0)
        nNALA = NALA + torch.clamp(dNALA, min=0.0)
        nNFK = NFK - torch.clamp(dNBK, min=0.0)
        nNBK = NBK + torch.clamp(dNBK, min=0.0)

        nNFLA = torch.clamp(nNFLA, min=0.0)
        nNALA = torch.clamp(nNALA, min=0.0)
        nNFK = torch.clamp(nNFK, min=0.0)
        nNBK = torch.clamp(nNBK, min=0.0)

        nCFLA = nNFLA / nVF
        nCALA = nNALA / nVA
        nCFK = nNFK / nVF
        nCBK = nNBK / nVB

        V = current_state[..., 0:1]
        E = current_state[..., 1:2]
        nVF_norm = self.normalize(nVF, VF_idx)
        nVA_norm = self.normalize(nVA, VA_idx)
        nVB_norm = self.normalize(nVB, VB_idx)
        nCFLA_norm = self.normalize(nCFLA, CFLA_idx)
        nCALA_norm = self.normalize(nCALA, CALA_idx)
        nCFK_norm = self.normalize(nCFK, CFK_idx)
        nCBK_norm = self.normalize(nCBK, CBK_idx)

        # Create temporary state without I for current prediction
        temp_state = torch.cat([
            V, E, nVF_norm, nVA_norm, nVB_norm, nCFLA_norm, nCALA_norm, nCFK_norm, nCBK_norm
        ], dim=-1)
        
        # Predict new I using the current predictor
        nI_pred_norm = self.current_predictor(temp_state)
        
        # Scale predicted I to actual range
        nI_real = self.denormalize(nI_pred_norm, I_idx)
        nI_real = torch.clamp(nI_real, min=0.0)
        nI_norm = self.normalize(nI_real, I_idx)

        # Create final next state with predicted I
        next_state = torch.cat([
            V, E, nVF_norm, nVA_norm, nVB_norm, nCFLA_norm, nCALA_norm, nCFK_norm, nCBK_norm, nI_norm
        ], dim=-1)
        
        return next_state

# %%
class BMEDAutoregressiveModel(nn.Module):
    def __init__(self, state_extr_params, decoder_params, current_predictor_params, range_mm):
        super().__init__()
        self.state_extr = StateExtr(**state_extr_params)
        self.physical_decoder = PhysicalChangeDecoder(**decoder_params)
        self.current_predictor = CurrentPredictor(**current_predictor_params)
        self.physics_constraint = PhysicsConstraintLayer(range_mm, self.current_predictor)

    def forward(self, x, seq_len):
        hidden_states = self.state_extr(x, seq_len)
        physical_changes = self.physical_decoder(hidden_states)
        new_x = self.physics_constraint(physical_changes, x)
        
        return new_x

# %%
def masked_mse_loss(pred, target, seq_len):
    batch_size, max_len, features = pred.shape
    seq_len_cpu = seq_len.detach().cpu().long()

    mask = torch.arange(max_len, device='cpu')[None, :] < seq_len_cpu[:, None]
    mask = mask.float().to(pred.device)

    loss = F.mse_loss(pred, target, reduction='none')
    masked_loss = loss * mask.unsqueeze(-1)

    total_loss = masked_loss.sum()
    total_elements = mask.sum()

    masked_loss = total_loss / total_elements
    return masked_loss

# %%
def tf_data(input_seq, seq_len):
    inputs = input_seq[:, :-1, :-1]
    targets = input_seq[:, 1:, :]

    target_seq_len = seq_len - 1

    return inputs, targets, target_seq_len

# %%
class NoamScheduler:
    def __init__(self, optimizer, model_size, warmup_epochs, factor=1.0):
        self.optimizer = optimizer
        self.model_size = model_size
        self.warmup_epochs = warmup_epochs
        self.factor = factor
        self.epoch_num = 0

    def step_epoch(self):
        self.epoch_num += 1
        lr = self.factor * (
            self.model_size ** (-0.5) *
            min(self.epoch_num ** (-0.5), self.epoch_num * self.warmup_epochs ** (-1.5))
        )
    
        for param_group in self.optimizer.param_groups:
            param_group['lr'] = lr

        return lr

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
df, ndf, range_mm, exp_num_list = df_treat('BMED_DATA_AG.csv')
seq = seq_data(ndf, exp_num_list)
pad, seq_len, max_len = pad_seq(seq)
dataset = gen_dataset(pad, seq_len)
dataloader = DataLoader(dataset, batch_size=8, shuffle=False)

# %%
state_extr_params = {
    'input_node': 9,
    'hidden_node': 32,
    'n_layer': 3,
    'dropout': 0.4
}

decoder_params = {
    'input_node': state_extr_params['hidden_node'],
    'hidden_node': 96,
    'n_layer': 4,
    'dropout': 0.2,
    'output_node': 4
}

current_predictor_params = {
    'input_node': 9,
    'hidden_node': 48,
    'n_layer': 3,
    'dropout': 0.1
}

model = BMEDAutoregressiveModel(state_extr_params, decoder_params, current_predictor_params, range_mm)
model = model.to(device)
print(f"Model architecture:")
print(f"  Input features: {state_extr_params['input_node']} (without current)")
print(f"  State Extractor Hidden size: {state_extr_params['hidden_node']}")
print(f"  State Extractor layers: {state_extr_params['n_layer']}")
print(f"  Decoder layers: {decoder_params['n_layer']}")
print(f"  Decoder Hidden size: {decoder_params['hidden_node']}")
print(f"  Current Predictor layers: {current_predictor_params['n_layer']}")
print(f"  Current Predictor Hidden size: {current_predictor_params['hidden_node']}")
print(f"  Model parameters: {sum(p.numel() for p in model.parameters()):,}")
print(f"  Physics constraints: Volume conservation with denormalization")

num_epochs = 10000
optimizer = torch.optim.AdamW(model.parameters(), lr=1.0)
warmup_epochs = int(num_epochs * 0.25)
scheduler = NoamScheduler(optimizer, model_size=state_extr_params['hidden_node'], warmup_epochs=warmup_epochs, factor=0.6)

print(f"\nTraining configuration:")
print(f"  Total epochs: {num_epochs:,}")
print(f"  Warmup epochs: {warmup_epochs:,} (10%)")
peak_lr = 1.0 * (48 ** (-0.5)) * (warmup_epochs ** (-0.5))
print(f"  Peak learning rate: {peak_lr:.2e}")
# Out:
# Model architecture:
#   Input features: 9 (without current)
#   State Extractor Hidden size: 32
#   State Extractor layers: 3
#   Decoder layers: 4
#   Decoder Hidden size: 96
#   Current Predictor layers: 3
#   Current Predictor Hidden size: 48
#   Model parameters: 60,437
#   Physics constraints: Volume conservation with denormalization
#
# Training configuration:
#   Total epochs: 10,000
#   Warmup epochs: 2,500 (10%)
#   Peak learning rate: 2.89e-03

# %%
train_samples = len(dataloader.dataset)
best_train_loss = float('inf')
best_epoch = 0
train_losses = []
learning_rates = []

best_model = None

print("Training started...")
print(f"Total batches per epoch: {len(dataloader)}")

for epoch in range(num_epochs):
    current_lr = scheduler.step_epoch()

    model.train()
    train_loss = 0.0
    train_batches = 0

    for batch_idx, (input_seq, seq_len) in enumerate(dataloader):
        try:
            input_seq = input_seq.to(device)
            seq_len = seq_len.to(device)

            inputs, targets, target_seq_len = tf_data(input_seq, seq_len)
            
            optimizer.zero_grad()
            pred = model(inputs, target_seq_len)
            loss = masked_mse_loss(pred, targets, target_seq_len)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            train_loss += loss.item()
            train_batches += 1

        except Exception as e:
            print(f"Training batch {batch_idx} error: {str(e)}")
            print(f"Input shape: {input_seq.shape if 'input_seq' in locals() else 'N/A'}")
            print(f"Seq lengths: {seq_len if 'seq_lengths' in locals() else 'N/A'}")
            import traceback
            traceback.print_exc()
            continue
    
    if train_batches == 0:
        print("No valid training batches")
        break

    train_losses.append(train_loss)
    learning_rates.append(current_lr)

    if train_loss < best_train_loss:
        best_train_loss = train_loss
        best_epoch = epoch + 1
        best_status = " ★ NEW BEST"
        
        # Best model을 메모리에 복사하여 저장
        import copy
        best_model = copy.deepcopy(model)
        print(f"          Best model saved in memory at epoch {best_epoch}")
        
        # 오늘 날짜로 모델 파일 저장
        from datetime import datetime
        today = datetime.now().strftime("%y%m%d")
        model_filename = f"BMED_TF_{today}.pth"
        torch.save({
            'model_state_dict': best_model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'epoch': best_epoch,
            'best_train_loss': best_train_loss,
            'model_config': {
                'state_extr_params': state_extr_params,
                'decoder_params': decoder_params,
                'current_predictor_params': current_predictor_params,
                'range_mm': range_mm
            }
        }, model_filename)
        print(f"          Best model saved to {model_filename}")
    else:
        best_status = ""

    # Warmup 구간 표시
    if epoch + 1 <= warmup_epochs:
        warmup_status = " [WARMUP]"
    else:
        warmup_status = ""

    # 매 에포크마다 로깅 - best 성능 정보 포함
    print(f"Epoch {epoch+1:4d}: Train: {train_loss:.6f}, LR: {current_lr:.2e}{best_status}{warmup_status}")    

    if epoch == 0:
        print(f"          Best: Train: {best_train_loss:.6f}, (Epoch {best_epoch})")
    elif train_loss < best_train_loss:
        print(f"          ✓ Updated Best: Train: {best_train_loss:.6f}")
    else:
        print(f"          Best: Train: {best_train_loss:.6f} (Epoch {best_epoch})")

print(f"\nTraining completed!")
print(f"=" * 60)

# 안전한 결과 출력
if len(train_losses) > 0:
    print(f"Best Performance (Epoch {best_epoch}):")
    print(f"  Best Train Loss:  {best_train_loss:.6f}")
    print(f"=" * 60)
    print(f"Final Performance (Epoch {len(train_losses)}):")
    print(f"  Final Train Loss: {train_losses[-1]:.6f}")
    print(f"  Final LR:         {current_lr:.2e}")
    print(f"=" * 60)
    if len(learning_rates) > 0:
        print(f"Warmup completed at epoch {warmup_epochs} with peak LR: {max(learning_rates):.2e}")
else:
    print("⚠️ No training completed - check error messages above")

# Best model이 저장되었는지 확인
if best_model is not None:
    print(f"\n✅ Best model (Epoch {best_epoch}) successfully saved in memory!")
    print(f"   Best model loss: {best_train_loss:.6f}")
    from datetime import datetime
    today = datetime.now().strftime("%y%m%d")
    model_filename = f"BMED_TF_{today}.pth"
    print(f"   Best model also saved to file: {model_filename}")
else:
    print("\n⚠️ No best model was saved (training may have failed)")
    best_model = model  # fallback to current model
# Out:
# Training started...
# Total batches per epoch: 2
#           Best model saved in memory at epoch 1
#           Best model saved to BMED_TF_250904.pth
# Epoch    1: Train: 2541.358887, LR: 8.49e-07 ★ NEW BEST [WARMUP]
#           Best: Train: 2541.358887, (Epoch 1)
#           Best model saved in memory at epoch 2
#           Best model saved to BMED_TF_250904.pth
# Epoch    2: Train: 2481.989136, LR: 1.70e-06 ★ NEW BEST [WARMUP]
#           Best: Train: 2481.989136 (Epoch 2)
# Epoch    3: Train: 2950.114258, LR: 2.55e-06 [WARMUP]
#           Best: Train: 2481.989136 (Epoch 2)
#           Best model saved in memory at epoch 4
#           Best model saved to BMED_TF_250904.pth
# Epoch    4: Train: 2417.614807, LR: 3.39e-06 ★ NEW BEST [WARMUP]
#           Best: Train: 2417.614807 (Epoch 4)
# Epoch    5: Train: 2689.742676, LR: 4.24e-06 [WARMUP]
#           Best: Train: 2417.614807 (Epoch 4)
#           Best model saved in memory at epoch 6
#           Best model saved to BMED_TF_250904.pth
# Epoch    6: Train: 2375.009460, LR: 5.09e-06 ★ NEW BEST [WARMUP]
#           Best: Train: 2375.009460 (Epoch 6)
# Epoch    7: Train: 2997.157471, LR: 5.94e-06 [WARMUP]
#           Best: Train: 2375.009460 (Epoch 6)
# Epoch    8: Train: 2451.722534, LR: 6.79e-06 [WARMUP]
#           Best: Train: 2375.009460 (Epoch 6)
# Epoch    9: Train: 2474.596436, LR: 7.64e-06 [WARMUP]
#           Best: Train: 2375.009460 (Epoch 6)
# Epoch   10: Train: 2577.878662, LR: 8.49e-06 [WARMUP]
#           Best: Train: 2375.009460 (Epoch 6)
# Epoch   11: Train: 2801.097717, LR: 9.33e-06 [WARMUP]
#           Best: Train: 2375.009460 (Epoch 6)
# Epoch   12: Train: 2563.964722, LR: 1.02e-05 [WARMUP]
#           Best: Train: 2375.009460 (Epoch 6)
#           Best model saved in memory at epoch 13
#           Best model saved to BMED_TF_250904.pth
# Epoch   13: Train: 1913.192261, LR: 1.10e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 1913.192261 (Epoch 13)
# Epoch   14: Train: 2600.669800, LR: 1.19e-05 [WARMUP]
#           Best: Train: 1913.192261 (Epoch 13)
# Epoch   15: Train: 2802.520142, LR: 1.27e-05 [WARMUP]
#           Best: Train: 1913.192261 (Epoch 13)
# Epoch   16: Train: 2291.265381, LR: 1.36e-05 [WARMUP]
#           Best: Train: 1913.192261 (Epoch 13)
# Epoch   17: Train: 2035.329529, LR: 1.44e-05 [WARMUP]
#           Best: Train: 1913.192261 (Epoch 13)
# Epoch   18: Train: 2334.854858, LR: 1.53e-05 [WARMUP]
#           Best: Train: 1913.192261 (Epoch 13)
#           Best model saved in memory at epoch 19
#           Best model saved to BMED_TF_250904.pth
# Epoch   19: Train: 1857.615540, LR: 1.61e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 1857.615540 (Epoch 19)
#           Best model saved in memory at epoch 20
#           Best model saved to BMED_TF_250904.pth
# Epoch   20: Train: 1824.487732, LR: 1.70e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 1824.487732 (Epoch 20)
# Epoch   21: Train: 1891.886475, LR: 1.78e-05 [WARMUP]
#           Best: Train: 1824.487732 (Epoch 20)
# Epoch   22: Train: 2125.032135, LR: 1.87e-05 [WARMUP]
#           Best: Train: 1824.487732 (Epoch 20)
#           Best model saved in memory at epoch 23
#           Best model saved to BMED_TF_250904.pth
# Epoch   23: Train: 1695.911560, LR: 1.95e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 1695.911560 (Epoch 23)
#           Best model saved in memory at epoch 24
#           Best model saved to BMED_TF_250904.pth
# Epoch   24: Train: 1448.196350, LR: 2.04e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 1448.196350 (Epoch 24)
# Epoch   25: Train: 1758.603882, LR: 2.12e-05 [WARMUP]
#           Best: Train: 1448.196350 (Epoch 24)
# Epoch   26: Train: 1468.813293, LR: 2.21e-05 [WARMUP]
#           Best: Train: 1448.196350 (Epoch 24)
# Epoch   27: Train: 1542.146362, LR: 2.29e-05 [WARMUP]
#           Best: Train: 1448.196350 (Epoch 24)
#           Best model saved in memory at epoch 28
#           Best model saved to BMED_TF_250904.pth
# Epoch   28: Train: 1385.488281, LR: 2.38e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 1385.488281 (Epoch 28)
#           Best model saved in memory at epoch 29
#           Best model saved to BMED_TF_250904.pth
# Epoch   29: Train: 1145.970642, LR: 2.46e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 1145.970642 (Epoch 29)
# Epoch   30: Train: 1193.980011, LR: 2.55e-05 [WARMUP]
#           Best: Train: 1145.970642 (Epoch 29)
#           Best model saved in memory at epoch 31
#           Best model saved to BMED_TF_250904.pth
# Epoch   31: Train: 975.373901, LR: 2.63e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 975.373901 (Epoch 31)
#           Best model saved in memory at epoch 32
#           Best model saved to BMED_TF_250904.pth
# Epoch   32: Train: 965.911377, LR: 2.72e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 965.911377 (Epoch 32)
#           Best model saved in memory at epoch 33
#           Best model saved to BMED_TF_250904.pth
# Epoch   33: Train: 908.752533, LR: 2.80e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 908.752533 (Epoch 33)
#           Best model saved in memory at epoch 34
#           Best model saved to BMED_TF_250904.pth
# Epoch   34: Train: 849.817383, LR: 2.88e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 849.817383 (Epoch 34)
# Epoch   35: Train: 1096.769257, LR: 2.97e-05 [WARMUP]
#           Best: Train: 849.817383 (Epoch 34)
# Epoch   36: Train: 884.342804, LR: 3.05e-05 [WARMUP]
#           Best: Train: 849.817383 (Epoch 34)
#           Best model saved in memory at epoch 37
#           Best model saved to BMED_TF_250904.pth
# Epoch   37: Train: 678.793762, LR: 3.14e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 678.793762 (Epoch 37)
# Epoch   38: Train: 705.544891, LR: 3.22e-05 [WARMUP]
#           Best: Train: 678.793762 (Epoch 37)
#           Best model saved in memory at epoch 39
#           Best model saved to BMED_TF_250904.pth
# Epoch   39: Train: 518.476166, LR: 3.31e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 518.476166 (Epoch 39)
#           Best model saved in memory at epoch 40
#           Best model saved to BMED_TF_250904.pth
# Epoch   40: Train: 440.777054, LR: 3.39e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 440.777054 (Epoch 40)
# Epoch   41: Train: 462.463173, LR: 3.48e-05 [WARMUP]
#           Best: Train: 440.777054 (Epoch 40)
# Epoch   42: Train: 681.675262, LR: 3.56e-05 [WARMUP]
#           Best: Train: 440.777054 (Epoch 40)
#           Best model saved in memory at epoch 43
#           Best model saved to BMED_TF_250904.pth
# Epoch   43: Train: 270.209320, LR: 3.65e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 270.209320 (Epoch 43)
# Epoch   44: Train: 383.192612, LR: 3.73e-05 [WARMUP]
#           Best: Train: 270.209320 (Epoch 43)
# Epoch   45: Train: 329.175102, LR: 3.82e-05 [WARMUP]
#           Best: Train: 270.209320 (Epoch 43)
# Epoch   46: Train: 291.724113, LR: 3.90e-05 [WARMUP]
#           Best: Train: 270.209320 (Epoch 43)
#           Best model saved in memory at epoch 47
#           Best model saved to BMED_TF_250904.pth
# Epoch   47: Train: 178.453537, LR: 3.99e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 178.453537 (Epoch 47)
# Epoch   48: Train: 251.275135, LR: 4.07e-05 [WARMUP]
#           Best: Train: 178.453537 (Epoch 47)
# Epoch   49: Train: 207.787567, LR: 4.16e-05 [WARMUP]
#           Best: Train: 178.453537 (Epoch 47)
#           Best model saved in memory at epoch 50
#           Best model saved to BMED_TF_250904.pth
# Epoch   50: Train: 149.521053, LR: 4.24e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 149.521053 (Epoch 50)
#           Best model saved in memory at epoch 51
#           Best model saved to BMED_TF_250904.pth
# Epoch   51: Train: 62.935838, LR: 4.33e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 62.935838 (Epoch 51)
# Epoch   52: Train: 110.098618, LR: 4.41e-05 [WARMUP]
#           Best: Train: 62.935838 (Epoch 51)
#           Best model saved in memory at epoch 53
#           Best model saved to BMED_TF_250904.pth
# Epoch   53: Train: 47.045650, LR: 4.50e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 47.045650 (Epoch 53)
#           Best model saved in memory at epoch 54
#           Best model saved to BMED_TF_250904.pth
# Epoch   54: Train: 40.607368, LR: 4.58e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 40.607368 (Epoch 54)
#           Best model saved in memory at epoch 55
#           Best model saved to BMED_TF_250904.pth
# Epoch   55: Train: 29.964871, LR: 4.67e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 29.964871 (Epoch 55)
# Epoch   56: Train: 51.422246, LR: 4.75e-05 [WARMUP]
#           Best: Train: 29.964871 (Epoch 55)
#           Best model saved in memory at epoch 57
#           Best model saved to BMED_TF_250904.pth
# Epoch   57: Train: 4.472153, LR: 4.84e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 4.472153 (Epoch 57)
# Epoch   58: Train: 14.074837, LR: 4.92e-05 [WARMUP]
#           Best: Train: 4.472153 (Epoch 57)
# Epoch   59: Train: 52.450829, LR: 5.01e-05 [WARMUP]
#           Best: Train: 4.472153 (Epoch 57)
# Epoch   60: Train: 61.901999, LR: 5.09e-05 [WARMUP]
#           Best: Train: 4.472153 (Epoch 57)
# Epoch   61: Train: 36.413991, LR: 5.18e-05 [WARMUP]
#           Best: Train: 4.472153 (Epoch 57)
# Epoch   62: Train: 70.339058, LR: 5.26e-05 [WARMUP]
#           Best: Train: 4.472153 (Epoch 57)
# Epoch   63: Train: 58.046252, LR: 5.35e-05 [WARMUP]
#           Best: Train: 4.472153 (Epoch 57)
#           Best model saved in memory at epoch 64
#           Best model saved to BMED_TF_250904.pth
# Epoch   64: Train: 3.928326, LR: 5.43e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 3.928326 (Epoch 64)
# Epoch   65: Train: 13.153044, LR: 5.52e-05 [WARMUP]
#           Best: Train: 3.928326 (Epoch 64)
# Epoch   66: Train: 9.096961, LR: 5.60e-05 [WARMUP]
#           Best: Train: 3.928326 (Epoch 64)
# Epoch   67: Train: 14.669614, LR: 5.69e-05 [WARMUP]
#           Best: Train: 3.928326 (Epoch 64)
#           Best model saved in memory at epoch 68
#           Best model saved to BMED_TF_250904.pth
# Epoch   68: Train: 1.976276, LR: 5.77e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 1.976276 (Epoch 68)
# Epoch   69: Train: 5.718964, LR: 5.85e-05 [WARMUP]
#           Best: Train: 1.976276 (Epoch 68)
#           Best model saved in memory at epoch 70
#           Best model saved to BMED_TF_250904.pth
# Epoch   70: Train: 0.913986, LR: 5.94e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 0.913986 (Epoch 70)
#           Best model saved in memory at epoch 71
#           Best model saved to BMED_TF_250904.pth
# Epoch   71: Train: 0.691376, LR: 6.02e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 0.691376 (Epoch 71)
# Epoch   72: Train: 0.863857, LR: 6.11e-05 [WARMUP]
#           Best: Train: 0.691376 (Epoch 71)
# Epoch   73: Train: 4.216653, LR: 6.19e-05 [WARMUP]
#           Best: Train: 0.691376 (Epoch 71)
# Epoch   74: Train: 0.739165, LR: 6.28e-05 [WARMUP]
#           Best: Train: 0.691376 (Epoch 71)
# Epoch   75: Train: 0.731476, LR: 6.36e-05 [WARMUP]
#           Best: Train: 0.691376 (Epoch 71)
# Epoch   76: Train: 35.590396, LR: 6.45e-05 [WARMUP]
#           Best: Train: 0.691376 (Epoch 71)
# Epoch   77: Train: 1.968656, LR: 6.53e-05 [WARMUP]
#           Best: Train: 0.691376 (Epoch 71)
# Epoch   78: Train: 21.988842, LR: 6.62e-05 [WARMUP]
#           Best: Train: 0.691376 (Epoch 71)
# Epoch   79: Train: 51.655300, LR: 6.70e-05 [WARMUP]
#           Best: Train: 0.691376 (Epoch 71)
# Epoch   80: Train: 49.018159, LR: 6.79e-05 [WARMUP]
#           Best: Train: 0.691376 (Epoch 71)
# Epoch   81: Train: 0.752172, LR: 6.87e-05 [WARMUP]
#           Best: Train: 0.691376 (Epoch 71)
#           Best model saved in memory at epoch 82
#           Best model saved to BMED_TF_250904.pth
# Epoch   82: Train: 0.610413, LR: 6.96e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 0.610413 (Epoch 82)
# Epoch   83: Train: 2.541243, LR: 7.04e-05 [WARMUP]
#           Best: Train: 0.610413 (Epoch 82)
# Epoch   84: Train: 1.947113, LR: 7.13e-05 [WARMUP]
#           Best: Train: 0.610413 (Epoch 82)
# Epoch   85: Train: 0.689037, LR: 7.21e-05 [WARMUP]
#           Best: Train: 0.610413 (Epoch 82)
# Epoch   86: Train: 7.208582, LR: 7.30e-05 [WARMUP]
#           Best: Train: 0.610413 (Epoch 82)
# Epoch   87: Train: 0.940866, LR: 7.38e-05 [WARMUP]
#           Best: Train: 0.610413 (Epoch 82)
# Epoch   88: Train: 0.745740, LR: 7.47e-05 [WARMUP]
#           Best: Train: 0.610413 (Epoch 82)
# Epoch   89: Train: 1.385953, LR: 7.55e-05 [WARMUP]
#           Best: Train: 0.610413 (Epoch 82)
#           Best model saved in memory at epoch 90
#           Best model saved to BMED_TF_250904.pth
# Epoch   90: Train: 0.548804, LR: 7.64e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 0.548804 (Epoch 90)
# Epoch   91: Train: 0.971257, LR: 7.72e-05 [WARMUP]
#           Best: Train: 0.548804 (Epoch 90)
#           Best model saved in memory at epoch 92
#           Best model saved to BMED_TF_250904.pth
# Epoch   92: Train: 0.511834, LR: 7.81e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 0.511834 (Epoch 92)
# Epoch   93: Train: 0.736204, LR: 7.89e-05 [WARMUP]
#           Best: Train: 0.511834 (Epoch 92)
#           Best model saved in memory at epoch 94
#           Best model saved to BMED_TF_250904.pth
# Epoch   94: Train: 0.469385, LR: 7.98e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 0.469385 (Epoch 94)
# Epoch   95: Train: 1.978850, LR: 8.06e-05 [WARMUP]
#           Best: Train: 0.469385 (Epoch 94)
# Epoch   96: Train: 0.564564, LR: 8.15e-05 [WARMUP]
#           Best: Train: 0.469385 (Epoch 94)
# Epoch   97: Train: 0.496838, LR: 8.23e-05 [WARMUP]
#           Best: Train: 0.469385 (Epoch 94)
#           Best model saved in memory at epoch 98
#           Best model saved to BMED_TF_250904.pth
# Epoch   98: Train: 0.378967, LR: 8.32e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 0.378967 (Epoch 98)
# Epoch   99: Train: 0.531259, LR: 8.40e-05 [WARMUP]
#           Best: Train: 0.378967 (Epoch 98)
# Epoch  100: Train: 0.464824, LR: 8.49e-05 [WARMUP]
#           Best: Train: 0.378967 (Epoch 98)
# Epoch  101: Train: 0.395164, LR: 8.57e-05 [WARMUP]
#           Best: Train: 0.378967 (Epoch 98)
# Epoch  102: Train: 0.414036, LR: 8.65e-05 [WARMUP]
#           Best: Train: 0.378967 (Epoch 98)
#           Best model saved in memory at epoch 103
#           Best model saved to BMED_TF_250904.pth
# Epoch  103: Train: 0.344330, LR: 8.74e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 0.344330 (Epoch 103)
# Epoch  104: Train: 0.488121, LR: 8.82e-05 [WARMUP]
#           Best: Train: 0.344330 (Epoch 103)
# Epoch  105: Train: 0.652725, LR: 8.91e-05 [WARMUP]
#           Best: Train: 0.344330 (Epoch 103)
# Epoch  106: Train: 10.479033, LR: 8.99e-05 [WARMUP]
#           Best: Train: 0.344330 (Epoch 103)
# Epoch  107: Train: 3.472160, LR: 9.08e-05 [WARMUP]
#           Best: Train: 0.344330 (Epoch 103)
#           Best model saved in memory at epoch 108
#           Best model saved to BMED_TF_250904.pth
# Epoch  108: Train: 0.294118, LR: 9.16e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 0.294118 (Epoch 108)
# Epoch  109: Train: 0.357234, LR: 9.25e-05 [WARMUP]
#           Best: Train: 0.294118 (Epoch 108)
#           Best model saved in memory at epoch 110
#           Best model saved to BMED_TF_250904.pth
# Epoch  110: Train: 0.290619, LR: 9.33e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 0.290619 (Epoch 110)
# Epoch  111: Train: 0.300472, LR: 9.42e-05 [WARMUP]
#           Best: Train: 0.290619 (Epoch 110)
# Epoch  112: Train: 0.356694, LR: 9.50e-05 [WARMUP]
#           Best: Train: 0.290619 (Epoch 110)
# Epoch  113: Train: 0.325224, LR: 9.59e-05 [WARMUP]
#           Best: Train: 0.290619 (Epoch 110)
#           Best model saved in memory at epoch 114
#           Best model saved to BMED_TF_250904.pth
# Epoch  114: Train: 0.286791, LR: 9.67e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 0.286791 (Epoch 114)
# Epoch  115: Train: 0.303097, LR: 9.76e-05 [WARMUP]
#           Best: Train: 0.286791 (Epoch 114)
#           Best model saved in memory at epoch 116
#           Best model saved to BMED_TF_250904.pth
# Epoch  116: Train: 0.245853, LR: 9.84e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 0.245853 (Epoch 116)
# Epoch  117: Train: 0.298320, LR: 9.93e-05 [WARMUP]
#           Best: Train: 0.245853 (Epoch 116)
#           Best model saved in memory at epoch 118
#           Best model saved to BMED_TF_250904.pth
# Epoch  118: Train: 0.244609, LR: 1.00e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.244609 (Epoch 118)
# Epoch  119: Train: 0.244748, LR: 1.01e-04 [WARMUP]
#           Best: Train: 0.244609 (Epoch 118)
#           Best model saved in memory at epoch 120
#           Best model saved to BMED_TF_250904.pth
# Epoch  120: Train: 0.225938, LR: 1.02e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.225938 (Epoch 120)
#           Best model saved in memory at epoch 121
#           Best model saved to BMED_TF_250904.pth
# Epoch  121: Train: 0.208780, LR: 1.03e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.208780 (Epoch 121)
# Epoch  122: Train: 0.221642, LR: 1.04e-04 [WARMUP]
#           Best: Train: 0.208780 (Epoch 121)
# Epoch  123: Train: 0.229942, LR: 1.04e-04 [WARMUP]
#           Best: Train: 0.208780 (Epoch 121)
# Epoch  124: Train: 0.239633, LR: 1.05e-04 [WARMUP]
#           Best: Train: 0.208780 (Epoch 121)
# Epoch  125: Train: 0.232206, LR: 1.06e-04 [WARMUP]
#           Best: Train: 0.208780 (Epoch 121)
#           Best model saved in memory at epoch 126
#           Best model saved to BMED_TF_250904.pth
# Epoch  126: Train: 0.195046, LR: 1.07e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.195046 (Epoch 126)
# Epoch  127: Train: 0.196659, LR: 1.08e-04 [WARMUP]
#           Best: Train: 0.195046 (Epoch 126)
#           Best model saved in memory at epoch 128
#           Best model saved to BMED_TF_250904.pth
# Epoch  128: Train: 0.176831, LR: 1.09e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.176831 (Epoch 128)
# Epoch  129: Train: 0.180820, LR: 1.09e-04 [WARMUP]
#           Best: Train: 0.176831 (Epoch 128)
# Epoch  130: Train: 0.188946, LR: 1.10e-04 [WARMUP]
#           Best: Train: 0.176831 (Epoch 128)
# Epoch  131: Train: 0.216505, LR: 1.11e-04 [WARMUP]
#           Best: Train: 0.176831 (Epoch 128)
# Epoch  132: Train: 0.182029, LR: 1.12e-04 [WARMUP]
#           Best: Train: 0.176831 (Epoch 128)
#           Best model saved in memory at epoch 133
#           Best model saved to BMED_TF_250904.pth
# Epoch  133: Train: 0.149484, LR: 1.13e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.149484 (Epoch 133)
# Epoch  134: Train: 0.180951, LR: 1.14e-04 [WARMUP]
#           Best: Train: 0.149484 (Epoch 133)
# Epoch  135: Train: 0.164462, LR: 1.15e-04 [WARMUP]
#           Best: Train: 0.149484 (Epoch 133)
# Epoch  136: Train: 0.174880, LR: 1.15e-04 [WARMUP]
#           Best: Train: 0.149484 (Epoch 133)
# Epoch  137: Train: 0.151494, LR: 1.16e-04 [WARMUP]
#           Best: Train: 0.149484 (Epoch 133)
# Epoch  138: Train: 0.149755, LR: 1.17e-04 [WARMUP]
#           Best: Train: 0.149484 (Epoch 133)
#           Best model saved in memory at epoch 139
#           Best model saved to BMED_TF_250904.pth
# Epoch  139: Train: 0.146013, LR: 1.18e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.146013 (Epoch 139)
# Epoch  140: Train: 0.173698, LR: 1.19e-04 [WARMUP]
#           Best: Train: 0.146013 (Epoch 139)
#           Best model saved in memory at epoch 141
#           Best model saved to BMED_TF_250904.pth
# Epoch  141: Train: 0.143261, LR: 1.20e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.143261 (Epoch 141)
#           Best model saved in memory at epoch 142
#           Best model saved to BMED_TF_250904.pth
# Epoch  142: Train: 0.134930, LR: 1.20e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.134930 (Epoch 142)
# Epoch  143: Train: 0.148518, LR: 1.21e-04 [WARMUP]
#           Best: Train: 0.134930 (Epoch 142)
# Epoch  144: Train: 0.140759, LR: 1.22e-04 [WARMUP]
#           Best: Train: 0.134930 (Epoch 142)
# Epoch  145: Train: 0.142668, LR: 1.23e-04 [WARMUP]
#           Best: Train: 0.134930 (Epoch 142)
#           Best model saved in memory at epoch 146
#           Best model saved to BMED_TF_250904.pth
# Epoch  146: Train: 0.118678, LR: 1.24e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.118678 (Epoch 146)
# Epoch  147: Train: 0.145354, LR: 1.25e-04 [WARMUP]
#           Best: Train: 0.118678 (Epoch 146)
# Epoch  148: Train: 0.129031, LR: 1.26e-04 [WARMUP]
#           Best: Train: 0.118678 (Epoch 146)
# Epoch  149: Train: 0.135861, LR: 1.26e-04 [WARMUP]
#           Best: Train: 0.118678 (Epoch 146)
# Epoch  150: Train: 0.126259, LR: 1.27e-04 [WARMUP]
#           Best: Train: 0.118678 (Epoch 146)
# Epoch  151: Train: 0.126979, LR: 1.28e-04 [WARMUP]
#           Best: Train: 0.118678 (Epoch 146)
#           Best model saved in memory at epoch 152
#           Best model saved to BMED_TF_250904.pth
# Epoch  152: Train: 0.112540, LR: 1.29e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.112540 (Epoch 152)
# Epoch  153: Train: 0.116839, LR: 1.30e-04 [WARMUP]
#           Best: Train: 0.112540 (Epoch 152)
# Epoch  154: Train: 0.115718, LR: 1.31e-04 [WARMUP]
#           Best: Train: 0.112540 (Epoch 152)
# Epoch  155: Train: 0.115050, LR: 1.32e-04 [WARMUP]
#           Best: Train: 0.112540 (Epoch 152)
#           Best model saved in memory at epoch 156
#           Best model saved to BMED_TF_250904.pth
# Epoch  156: Train: 0.110035, LR: 1.32e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.110035 (Epoch 156)
#           Best model saved in memory at epoch 157
#           Best model saved to BMED_TF_250904.pth
# Epoch  157: Train: 0.108150, LR: 1.33e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.108150 (Epoch 157)
#           Best model saved in memory at epoch 158
#           Best model saved to BMED_TF_250904.pth
# Epoch  158: Train: 0.096679, LR: 1.34e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.096679 (Epoch 158)
# Epoch  159: Train: 0.101490, LR: 1.35e-04 [WARMUP]
#           Best: Train: 0.096679 (Epoch 158)
# Epoch  160: Train: 0.113273, LR: 1.36e-04 [WARMUP]
#           Best: Train: 0.096679 (Epoch 158)
# Epoch  161: Train: 0.102066, LR: 1.37e-04 [WARMUP]
#           Best: Train: 0.096679 (Epoch 158)
#           Best model saved in memory at epoch 162
#           Best model saved to BMED_TF_250904.pth
# Epoch  162: Train: 0.094371, LR: 1.37e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.094371 (Epoch 162)
# Epoch  163: Train: 0.099250, LR: 1.38e-04 [WARMUP]
#           Best: Train: 0.094371 (Epoch 162)
# Epoch  164: Train: 0.098100, LR: 1.39e-04 [WARMUP]
#           Best: Train: 0.094371 (Epoch 162)
#           Best model saved in memory at epoch 165
#           Best model saved to BMED_TF_250904.pth
# Epoch  165: Train: 0.087530, LR: 1.40e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.087530 (Epoch 165)
# Epoch  166: Train: 0.099369, LR: 1.41e-04 [WARMUP]
#           Best: Train: 0.087530 (Epoch 165)
# Epoch  167: Train: 0.091616, LR: 1.42e-04 [WARMUP]
#           Best: Train: 0.087530 (Epoch 165)
# Epoch  168: Train: 0.105279, LR: 1.43e-04 [WARMUP]
#           Best: Train: 0.087530 (Epoch 165)
#           Best model saved in memory at epoch 169
#           Best model saved to BMED_TF_250904.pth
# Epoch  169: Train: 0.086205, LR: 1.43e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.086205 (Epoch 169)
# Epoch  170: Train: 0.087433, LR: 1.44e-04 [WARMUP]
#           Best: Train: 0.086205 (Epoch 169)
# Epoch  171: Train: 0.088813, LR: 1.45e-04 [WARMUP]
#           Best: Train: 0.086205 (Epoch 169)
#           Best model saved in memory at epoch 172
#           Best model saved to BMED_TF_250904.pth
# Epoch  172: Train: 0.081344, LR: 1.46e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.081344 (Epoch 172)
# Epoch  173: Train: 0.089643, LR: 1.47e-04 [WARMUP]
#           Best: Train: 0.081344 (Epoch 172)
#           Best model saved in memory at epoch 174
#           Best model saved to BMED_TF_250904.pth
# Epoch  174: Train: 0.078764, LR: 1.48e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.078764 (Epoch 174)
# Epoch  175: Train: 0.087722, LR: 1.48e-04 [WARMUP]
#           Best: Train: 0.078764 (Epoch 174)
#           Best model saved in memory at epoch 176
#           Best model saved to BMED_TF_250904.pth
# Epoch  176: Train: 0.078602, LR: 1.49e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.078602 (Epoch 176)
#           Best model saved in memory at epoch 177
#           Best model saved to BMED_TF_250904.pth
# Epoch  177: Train: 0.077011, LR: 1.50e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.077011 (Epoch 177)
# Epoch  178: Train: 0.081956, LR: 1.51e-04 [WARMUP]
#           Best: Train: 0.077011 (Epoch 177)
# Epoch  179: Train: 0.082653, LR: 1.52e-04 [WARMUP]
#           Best: Train: 0.077011 (Epoch 177)
# Epoch  180: Train: 0.083537, LR: 1.53e-04 [WARMUP]
#           Best: Train: 0.077011 (Epoch 177)
#           Best model saved in memory at epoch 181
#           Best model saved to BMED_TF_250904.pth
# Epoch  181: Train: 0.076299, LR: 1.54e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.076299 (Epoch 181)
# Epoch  182: Train: 0.082370, LR: 1.54e-04 [WARMUP]
#           Best: Train: 0.076299 (Epoch 181)
# Epoch  183: Train: 0.076740, LR: 1.55e-04 [WARMUP]
#           Best: Train: 0.076299 (Epoch 181)
#           Best model saved in memory at epoch 184
#           Best model saved to BMED_TF_250904.pth
# Epoch  184: Train: 0.074698, LR: 1.56e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.074698 (Epoch 184)
#           Best model saved in memory at epoch 185
#           Best model saved to BMED_TF_250904.pth
# Epoch  185: Train: 0.065053, LR: 1.57e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.065053 (Epoch 185)
# Epoch  186: Train: 0.077077, LR: 1.58e-04 [WARMUP]
#           Best: Train: 0.065053 (Epoch 185)
# Epoch  187: Train: 0.076139, LR: 1.59e-04 [WARMUP]
#           Best: Train: 0.065053 (Epoch 185)
# Epoch  188: Train: 0.070698, LR: 1.60e-04 [WARMUP]
#           Best: Train: 0.065053 (Epoch 185)
# Epoch  189: Train: 0.066636, LR: 1.60e-04 [WARMUP]
#           Best: Train: 0.065053 (Epoch 185)
# Epoch  190: Train: 0.068980, LR: 1.61e-04 [WARMUP]
#           Best: Train: 0.065053 (Epoch 185)
# Epoch  191: Train: 0.069006, LR: 1.62e-04 [WARMUP]
#           Best: Train: 0.065053 (Epoch 185)
# Epoch  192: Train: 0.065632, LR: 1.63e-04 [WARMUP]
#           Best: Train: 0.065053 (Epoch 185)
#           Best model saved in memory at epoch 193
#           Best model saved to BMED_TF_250904.pth
# Epoch  193: Train: 0.063077, LR: 1.64e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.063077 (Epoch 193)
# Epoch  194: Train: 0.070406, LR: 1.65e-04 [WARMUP]
#           Best: Train: 0.063077 (Epoch 193)
# Epoch  195: Train: 0.072128, LR: 1.65e-04 [WARMUP]
#           Best: Train: 0.063077 (Epoch 193)
# Epoch  196: Train: 0.068807, LR: 1.66e-04 [WARMUP]
#           Best: Train: 0.063077 (Epoch 193)
# Epoch  197: Train: 0.069101, LR: 1.67e-04 [WARMUP]
#           Best: Train: 0.063077 (Epoch 193)
# Epoch  198: Train: 0.066748, LR: 1.68e-04 [WARMUP]
#           Best: Train: 0.063077 (Epoch 193)
# Epoch  199: Train: 0.069641, LR: 1.69e-04 [WARMUP]
#           Best: Train: 0.063077 (Epoch 193)
#           Best model saved in memory at epoch 200
#           Best model saved to BMED_TF_250904.pth
# Epoch  200: Train: 0.061646, LR: 1.70e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.061646 (Epoch 200)
# Epoch  201: Train: 0.064147, LR: 1.71e-04 [WARMUP]
#           Best: Train: 0.061646 (Epoch 200)
# Epoch  202: Train: 0.070401, LR: 1.71e-04 [WARMUP]
#           Best: Train: 0.061646 (Epoch 200)
# Epoch  203: Train: 0.065780, LR: 1.72e-04 [WARMUP]
#           Best: Train: 0.061646 (Epoch 200)
# Epoch  204: Train: 0.061692, LR: 1.73e-04 [WARMUP]
#           Best: Train: 0.061646 (Epoch 200)
# Epoch  205: Train: 0.064168, LR: 1.74e-04 [WARMUP]
#           Best: Train: 0.061646 (Epoch 200)
#           Best model saved in memory at epoch 206
#           Best model saved to BMED_TF_250904.pth
# Epoch  206: Train: 0.060895, LR: 1.75e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.060895 (Epoch 206)
# Epoch  207: Train: 0.065564, LR: 1.76e-04 [WARMUP]
#           Best: Train: 0.060895 (Epoch 206)
# Epoch  208: Train: 0.062626, LR: 1.76e-04 [WARMUP]
#           Best: Train: 0.060895 (Epoch 206)
#           Best model saved in memory at epoch 209
#           Best model saved to BMED_TF_250904.pth
# Epoch  209: Train: 0.055857, LR: 1.77e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.055857 (Epoch 209)
# Epoch  210: Train: 0.060341, LR: 1.78e-04 [WARMUP]
#           Best: Train: 0.055857 (Epoch 209)
# Epoch  211: Train: 0.061441, LR: 1.79e-04 [WARMUP]
#           Best: Train: 0.055857 (Epoch 209)
# Epoch  212: Train: 0.060562, LR: 1.80e-04 [WARMUP]
#           Best: Train: 0.055857 (Epoch 209)
# Epoch  213: Train: 0.060069, LR: 1.81e-04 [WARMUP]
#           Best: Train: 0.055857 (Epoch 209)
#           Best model saved in memory at epoch 214
#           Best model saved to BMED_TF_250904.pth
# Epoch  214: Train: 0.055098, LR: 1.82e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.055098 (Epoch 214)
# Epoch  215: Train: 0.060229, LR: 1.82e-04 [WARMUP]
#           Best: Train: 0.055098 (Epoch 214)
#           Best model saved in memory at epoch 216
#           Best model saved to BMED_TF_250904.pth
# Epoch  216: Train: 0.051826, LR: 1.83e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.051826 (Epoch 216)
# Epoch  217: Train: 0.058272, LR: 1.84e-04 [WARMUP]
#           Best: Train: 0.051826 (Epoch 216)
# Epoch  218: Train: 0.062049, LR: 1.85e-04 [WARMUP]
#           Best: Train: 0.051826 (Epoch 216)
# Epoch  219: Train: 0.058911, LR: 1.86e-04 [WARMUP]
#           Best: Train: 0.051826 (Epoch 216)
# Epoch  220: Train: 0.060025, LR: 1.87e-04 [WARMUP]
#           Best: Train: 0.051826 (Epoch 216)
# Epoch  221: Train: 0.056044, LR: 1.88e-04 [WARMUP]
#           Best: Train: 0.051826 (Epoch 216)
# Epoch  222: Train: 0.053909, LR: 1.88e-04 [WARMUP]
#           Best: Train: 0.051826 (Epoch 216)
# Epoch  223: Train: 0.055827, LR: 1.89e-04 [WARMUP]
#           Best: Train: 0.051826 (Epoch 216)
# Epoch  224: Train: 0.055199, LR: 1.90e-04 [WARMUP]
#           Best: Train: 0.051826 (Epoch 216)
# Epoch  225: Train: 0.055022, LR: 1.91e-04 [WARMUP]
#           Best: Train: 0.051826 (Epoch 216)
#           Best model saved in memory at epoch 226
#           Best model saved to BMED_TF_250904.pth
# Epoch  226: Train: 0.050283, LR: 1.92e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.050283 (Epoch 226)
# Epoch  227: Train: 0.053956, LR: 1.93e-04 [WARMUP]
#           Best: Train: 0.050283 (Epoch 226)
#           Best model saved in memory at epoch 228
#           Best model saved to BMED_TF_250904.pth
# Epoch  228: Train: 0.049944, LR: 1.93e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.049944 (Epoch 228)
# Epoch  229: Train: 0.052880, LR: 1.94e-04 [WARMUP]
#           Best: Train: 0.049944 (Epoch 228)
#           Best model saved in memory at epoch 230
#           Best model saved to BMED_TF_250904.pth
# Epoch  230: Train: 0.048876, LR: 1.95e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.048876 (Epoch 230)
# Epoch  231: Train: 0.049915, LR: 1.96e-04 [WARMUP]
#           Best: Train: 0.048876 (Epoch 230)
# Epoch  232: Train: 0.051208, LR: 1.97e-04 [WARMUP]
#           Best: Train: 0.048876 (Epoch 230)
# Epoch  233: Train: 0.049862, LR: 1.98e-04 [WARMUP]
#           Best: Train: 0.048876 (Epoch 230)
#           Best model saved in memory at epoch 234
#           Best model saved to BMED_TF_250904.pth
# Epoch  234: Train: 0.048256, LR: 1.99e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.048256 (Epoch 234)
# Epoch  235: Train: 0.050336, LR: 1.99e-04 [WARMUP]
#           Best: Train: 0.048256 (Epoch 234)
# Epoch  236: Train: 0.051394, LR: 2.00e-04 [WARMUP]
#           Best: Train: 0.048256 (Epoch 234)
#           Best model saved in memory at epoch 237
#           Best model saved to BMED_TF_250904.pth
# Epoch  237: Train: 0.047112, LR: 2.01e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.047112 (Epoch 237)
# Epoch  238: Train: 0.053050, LR: 2.02e-04 [WARMUP]
#           Best: Train: 0.047112 (Epoch 237)
# Epoch  239: Train: 0.048744, LR: 2.03e-04 [WARMUP]
#           Best: Train: 0.047112 (Epoch 237)
# Epoch  240: Train: 0.049352, LR: 2.04e-04 [WARMUP]
#           Best: Train: 0.047112 (Epoch 237)
#           Best model saved in memory at epoch 241
#           Best model saved to BMED_TF_250904.pth
# Epoch  241: Train: 0.044788, LR: 2.04e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.044788 (Epoch 241)
#           Best model saved in memory at epoch 242
#           Best model saved to BMED_TF_250904.pth
# Epoch  242: Train: 0.044410, LR: 2.05e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.044410 (Epoch 242)
# Epoch  243: Train: 0.046923, LR: 2.06e-04 [WARMUP]
#           Best: Train: 0.044410 (Epoch 242)
# Epoch  244: Train: 0.044594, LR: 2.07e-04 [WARMUP]
#           Best: Train: 0.044410 (Epoch 242)
# Epoch  245: Train: 0.046840, LR: 2.08e-04 [WARMUP]
#           Best: Train: 0.044410 (Epoch 242)
# Epoch  246: Train: 0.045654, LR: 2.09e-04 [WARMUP]
#           Best: Train: 0.044410 (Epoch 242)
# Epoch  247: Train: 0.045330, LR: 2.10e-04 [WARMUP]
#           Best: Train: 0.044410 (Epoch 242)
#           Best model saved in memory at epoch 248
#           Best model saved to BMED_TF_250904.pth
# Epoch  248: Train: 0.042590, LR: 2.10e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.042590 (Epoch 248)
# Epoch  249: Train: 0.046283, LR: 2.11e-04 [WARMUP]
#           Best: Train: 0.042590 (Epoch 248)
# Epoch  250: Train: 0.046474, LR: 2.12e-04 [WARMUP]
#           Best: Train: 0.042590 (Epoch 248)
# Epoch  251: Train: 0.043406, LR: 2.13e-04 [WARMUP]
#           Best: Train: 0.042590 (Epoch 248)
#           Best model saved in memory at epoch 252
#           Best model saved to BMED_TF_250904.pth
# Epoch  252: Train: 0.041593, LR: 2.14e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.041593 (Epoch 252)
# Epoch  253: Train: 0.043111, LR: 2.15e-04 [WARMUP]
#           Best: Train: 0.041593 (Epoch 252)
# Epoch  254: Train: 0.043991, LR: 2.16e-04 [WARMUP]
#           Best: Train: 0.041593 (Epoch 252)
# Epoch  255: Train: 0.046436, LR: 2.16e-04 [WARMUP]
#           Best: Train: 0.041593 (Epoch 252)
#           Best model saved in memory at epoch 256
#           Best model saved to BMED_TF_250904.pth
# Epoch  256: Train: 0.041365, LR: 2.17e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.041365 (Epoch 256)
#           Best model saved in memory at epoch 257
#           Best model saved to BMED_TF_250904.pth
# Epoch  257: Train: 0.038633, LR: 2.18e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.038633 (Epoch 257)
# Epoch  258: Train: 0.042440, LR: 2.19e-04 [WARMUP]
#           Best: Train: 0.038633 (Epoch 257)
# Epoch  259: Train: 0.039872, LR: 2.20e-04 [WARMUP]
#           Best: Train: 0.038633 (Epoch 257)
# Epoch  260: Train: 0.039194, LR: 2.21e-04 [WARMUP]
#           Best: Train: 0.038633 (Epoch 257)
# Epoch  261: Train: 0.043162, LR: 2.21e-04 [WARMUP]
#           Best: Train: 0.038633 (Epoch 257)
# Epoch  262: Train: 0.040776, LR: 2.22e-04 [WARMUP]
#           Best: Train: 0.038633 (Epoch 257)
# Epoch  263: Train: 0.042764, LR: 2.23e-04 [WARMUP]
#           Best: Train: 0.038633 (Epoch 257)
# Epoch  264: Train: 0.041540, LR: 2.24e-04 [WARMUP]
#           Best: Train: 0.038633 (Epoch 257)
# Epoch  265: Train: 0.044020, LR: 2.25e-04 [WARMUP]
#           Best: Train: 0.038633 (Epoch 257)
# Epoch  266: Train: 0.040184, LR: 2.26e-04 [WARMUP]
#           Best: Train: 0.038633 (Epoch 257)
# Epoch  267: Train: 0.039844, LR: 2.27e-04 [WARMUP]
#           Best: Train: 0.038633 (Epoch 257)
# Epoch  268: Train: 0.040656, LR: 2.27e-04 [WARMUP]
#           Best: Train: 0.038633 (Epoch 257)
# Epoch  269: Train: 0.041010, LR: 2.28e-04 [WARMUP]
#           Best: Train: 0.038633 (Epoch 257)
#           Best model saved in memory at epoch 270
#           Best model saved to BMED_TF_250904.pth
# Epoch  270: Train: 0.038497, LR: 2.29e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.038497 (Epoch 270)
# Epoch  271: Train: 0.039524, LR: 2.30e-04 [WARMUP]
#           Best: Train: 0.038497 (Epoch 270)
#           Best model saved in memory at epoch 272
#           Best model saved to BMED_TF_250904.pth
# Epoch  272: Train: 0.036016, LR: 2.31e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.036016 (Epoch 272)
# Epoch  273: Train: 0.038599, LR: 2.32e-04 [WARMUP]
#           Best: Train: 0.036016 (Epoch 272)
# Epoch  274: Train: 0.039613, LR: 2.32e-04 [WARMUP]
#           Best: Train: 0.036016 (Epoch 272)
# Epoch  275: Train: 0.036632, LR: 2.33e-04 [WARMUP]
#           Best: Train: 0.036016 (Epoch 272)
# Epoch  276: Train: 0.038847, LR: 2.34e-04 [WARMUP]
#           Best: Train: 0.036016 (Epoch 272)
# Epoch  277: Train: 0.037948, LR: 2.35e-04 [WARMUP]
#           Best: Train: 0.036016 (Epoch 272)
# Epoch  278: Train: 0.039317, LR: 2.36e-04 [WARMUP]
#           Best: Train: 0.036016 (Epoch 272)
# Epoch  279: Train: 0.036323, LR: 2.37e-04 [WARMUP]
#           Best: Train: 0.036016 (Epoch 272)
# Epoch  280: Train: 0.036512, LR: 2.38e-04 [WARMUP]
#           Best: Train: 0.036016 (Epoch 272)
# Epoch  281: Train: 0.037095, LR: 2.38e-04 [WARMUP]
#           Best: Train: 0.036016 (Epoch 272)
#           Best model saved in memory at epoch 282
#           Best model saved to BMED_TF_250904.pth
# Epoch  282: Train: 0.035627, LR: 2.39e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.035627 (Epoch 282)
#           Best model saved in memory at epoch 283
#           Best model saved to BMED_TF_250904.pth
# Epoch  283: Train: 0.035230, LR: 2.40e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.035230 (Epoch 283)
# Epoch  284: Train: 0.038748, LR: 2.41e-04 [WARMUP]
#           Best: Train: 0.035230 (Epoch 283)
# Epoch  285: Train: 0.037686, LR: 2.42e-04 [WARMUP]
#           Best: Train: 0.035230 (Epoch 283)
#           Best model saved in memory at epoch 286
#           Best model saved to BMED_TF_250904.pth
# Epoch  286: Train: 0.032358, LR: 2.43e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  287: Train: 0.038660, LR: 2.44e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  288: Train: 0.032441, LR: 2.44e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  289: Train: 0.032534, LR: 2.45e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  290: Train: 0.034656, LR: 2.46e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  291: Train: 0.036016, LR: 2.47e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  292: Train: 0.034426, LR: 2.48e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  293: Train: 0.035635, LR: 2.49e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  294: Train: 0.033312, LR: 2.49e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  295: Train: 0.032927, LR: 2.50e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  296: Train: 0.034330, LR: 2.51e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  297: Train: 0.034498, LR: 2.52e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  298: Train: 0.034126, LR: 2.53e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  299: Train: 0.034505, LR: 2.54e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  300: Train: 0.035008, LR: 2.55e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
# Epoch  301: Train: 0.032886, LR: 2.55e-04 [WARMUP]
#           Best: Train: 0.032358 (Epoch 286)
#           Best model saved in memory at epoch 302
#           Best model saved to BMED_TF_250904.pth
# Epoch  302: Train: 0.030175, LR: 2.56e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.030175 (Epoch 302)
# Epoch  303: Train: 0.033963, LR: 2.57e-04 [WARMUP]
#           Best: Train: 0.030175 (Epoch 302)
# Epoch  304: Train: 0.034248, LR: 2.58e-04 [WARMUP]
#           Best: Train: 0.030175 (Epoch 302)
# Epoch  305: Train: 0.031128, LR: 2.59e-04 [WARMUP]
#           Best: Train: 0.030175 (Epoch 302)
# Epoch  306: Train: 0.031978, LR: 2.60e-04 [WARMUP]
#           Best: Train: 0.030175 (Epoch 302)
#           Best model saved in memory at epoch 307
#           Best model saved to BMED_TF_250904.pth
# Epoch  307: Train: 0.029741, LR: 2.60e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.029741 (Epoch 307)
# Epoch  308: Train: 0.031464, LR: 2.61e-04 [WARMUP]
#           Best: Train: 0.029741 (Epoch 307)
# Epoch  309: Train: 0.034172, LR: 2.62e-04 [WARMUP]
#           Best: Train: 0.029741 (Epoch 307)
# Epoch  310: Train: 0.032792, LR: 2.63e-04 [WARMUP]
#           Best: Train: 0.029741 (Epoch 307)
# Epoch  311: Train: 0.035106, LR: 2.64e-04 [WARMUP]
#           Best: Train: 0.029741 (Epoch 307)
# Epoch  312: Train: 0.030226, LR: 2.65e-04 [WARMUP]
#           Best: Train: 0.029741 (Epoch 307)
# Epoch  313: Train: 0.030375, LR: 2.66e-04 [WARMUP]
#           Best: Train: 0.029741 (Epoch 307)
# Epoch  314: Train: 0.030814, LR: 2.66e-04 [WARMUP]
#           Best: Train: 0.029741 (Epoch 307)
# Epoch  315: Train: 0.030936, LR: 2.67e-04 [WARMUP]
#           Best: Train: 0.029741 (Epoch 307)
# Epoch  316: Train: 0.031125, LR: 2.68e-04 [WARMUP]
#           Best: Train: 0.029741 (Epoch 307)
# Epoch  317: Train: 0.034617, LR: 2.69e-04 [WARMUP]
#           Best: Train: 0.029741 (Epoch 307)
# Epoch  318: Train: 0.030605, LR: 2.70e-04 [WARMUP]
#           Best: Train: 0.029741 (Epoch 307)
#           Best model saved in memory at epoch 319
#           Best model saved to BMED_TF_250904.pth
# Epoch  319: Train: 0.029064, LR: 2.71e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.029064 (Epoch 319)
# Epoch  320: Train: 0.029506, LR: 2.72e-04 [WARMUP]
#           Best: Train: 0.029064 (Epoch 319)
# Epoch  321: Train: 0.029289, LR: 2.72e-04 [WARMUP]
#           Best: Train: 0.029064 (Epoch 319)
# Epoch  322: Train: 0.032373, LR: 2.73e-04 [WARMUP]
#           Best: Train: 0.029064 (Epoch 319)
# Epoch  323: Train: 0.029315, LR: 2.74e-04 [WARMUP]
#           Best: Train: 0.029064 (Epoch 319)
# Epoch  324: Train: 0.030580, LR: 2.75e-04 [WARMUP]
#           Best: Train: 0.029064 (Epoch 319)
#           Best model saved in memory at epoch 325
#           Best model saved to BMED_TF_250904.pth
# Epoch  325: Train: 0.028089, LR: 2.76e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.028089 (Epoch 325)
# Epoch  326: Train: 0.029048, LR: 2.77e-04 [WARMUP]
#           Best: Train: 0.028089 (Epoch 325)
# Epoch  327: Train: 0.029303, LR: 2.77e-04 [WARMUP]
#           Best: Train: 0.028089 (Epoch 325)
#           Best model saved in memory at epoch 328
#           Best model saved to BMED_TF_250904.pth
# Epoch  328: Train: 0.027776, LR: 2.78e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.027776 (Epoch 328)
# Epoch  329: Train: 0.033365, LR: 2.79e-04 [WARMUP]
#           Best: Train: 0.027776 (Epoch 328)
# Epoch  330: Train: 0.029046, LR: 2.80e-04 [WARMUP]
#           Best: Train: 0.027776 (Epoch 328)
# Epoch  331: Train: 0.028173, LR: 2.81e-04 [WARMUP]
#           Best: Train: 0.027776 (Epoch 328)
# Epoch  332: Train: 0.028120, LR: 2.82e-04 [WARMUP]
#           Best: Train: 0.027776 (Epoch 328)
# Epoch  333: Train: 0.030445, LR: 2.83e-04 [WARMUP]
#           Best: Train: 0.027776 (Epoch 328)
# Epoch  334: Train: 0.029167, LR: 2.83e-04 [WARMUP]
#           Best: Train: 0.027776 (Epoch 328)
#           Best model saved in memory at epoch 335
#           Best model saved to BMED_TF_250904.pth
# Epoch  335: Train: 0.026908, LR: 2.84e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.026908 (Epoch 335)
# Epoch  336: Train: 0.028353, LR: 2.85e-04 [WARMUP]
#           Best: Train: 0.026908 (Epoch 335)
# Epoch  337: Train: 0.027061, LR: 2.86e-04 [WARMUP]
#           Best: Train: 0.026908 (Epoch 335)
# Epoch  338: Train: 0.027272, LR: 2.87e-04 [WARMUP]
#           Best: Train: 0.026908 (Epoch 335)
# Epoch  339: Train: 0.028604, LR: 2.88e-04 [WARMUP]
#           Best: Train: 0.026908 (Epoch 335)
#           Best model saved in memory at epoch 340
#           Best model saved to BMED_TF_250904.pth
# Epoch  340: Train: 0.025754, LR: 2.88e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.025754 (Epoch 340)
# Epoch  341: Train: 0.026549, LR: 2.89e-04 [WARMUP]
#           Best: Train: 0.025754 (Epoch 340)
# Epoch  342: Train: 0.027807, LR: 2.90e-04 [WARMUP]
#           Best: Train: 0.025754 (Epoch 340)
# Epoch  343: Train: 0.026371, LR: 2.91e-04 [WARMUP]
#           Best: Train: 0.025754 (Epoch 340)
#           Best model saved in memory at epoch 344
#           Best model saved to BMED_TF_250904.pth
# Epoch  344: Train: 0.024003, LR: 2.92e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  345: Train: 0.026608, LR: 2.93e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  346: Train: 0.026104, LR: 2.94e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  347: Train: 0.026426, LR: 2.94e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  348: Train: 0.026464, LR: 2.95e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  349: Train: 0.025839, LR: 2.96e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  350: Train: 0.026437, LR: 2.97e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  351: Train: 0.027448, LR: 2.98e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  352: Train: 0.027385, LR: 2.99e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  353: Train: 0.024892, LR: 3.00e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  354: Train: 0.024613, LR: 3.00e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  355: Train: 0.024663, LR: 3.01e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  356: Train: 0.024785, LR: 3.02e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  357: Train: 0.025398, LR: 3.03e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  358: Train: 0.028059, LR: 3.04e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  359: Train: 0.025473, LR: 3.05e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  360: Train: 0.025018, LR: 3.05e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  361: Train: 0.025148, LR: 3.06e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
# Epoch  362: Train: 0.025839, LR: 3.07e-04 [WARMUP]
#           Best: Train: 0.024003 (Epoch 344)
#           Best model saved in memory at epoch 363
#           Best model saved to BMED_TF_250904.pth
# Epoch  363: Train: 0.022775, LR: 3.08e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.022775 (Epoch 363)
# Epoch  364: Train: 0.025231, LR: 3.09e-04 [WARMUP]
#           Best: Train: 0.022775 (Epoch 363)
# Epoch  365: Train: 0.023076, LR: 3.10e-04 [WARMUP]
#           Best: Train: 0.022775 (Epoch 363)
# Epoch  366: Train: 0.025003, LR: 3.11e-04 [WARMUP]
#           Best: Train: 0.022775 (Epoch 363)
# Epoch  367: Train: 0.025463, LR: 3.11e-04 [WARMUP]
#           Best: Train: 0.022775 (Epoch 363)
# Epoch  368: Train: 0.024371, LR: 3.12e-04 [WARMUP]
#           Best: Train: 0.022775 (Epoch 363)
# Epoch  369: Train: 0.025553, LR: 3.13e-04 [WARMUP]
#           Best: Train: 0.022775 (Epoch 363)
# Epoch  370: Train: 0.023898, LR: 3.14e-04 [WARMUP]
#           Best: Train: 0.022775 (Epoch 363)
# Epoch  371: Train: 0.025807, LR: 3.15e-04 [WARMUP]
#           Best: Train: 0.022775 (Epoch 363)
#           Best model saved in memory at epoch 372
#           Best model saved to BMED_TF_250904.pth
# Epoch  372: Train: 0.020508, LR: 3.16e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  373: Train: 0.022719, LR: 3.17e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  374: Train: 0.021297, LR: 3.17e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  375: Train: 0.022075, LR: 3.18e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  376: Train: 0.023959, LR: 3.19e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  377: Train: 0.023305, LR: 3.20e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  378: Train: 0.022996, LR: 3.21e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  379: Train: 0.021660, LR: 3.22e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  380: Train: 0.022668, LR: 3.22e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  381: Train: 0.024126, LR: 3.23e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  382: Train: 0.022305, LR: 3.24e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  383: Train: 0.022457, LR: 3.25e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  384: Train: 0.024001, LR: 3.26e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  385: Train: 0.022002, LR: 3.27e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  386: Train: 0.023018, LR: 3.28e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  387: Train: 0.023539, LR: 3.28e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  388: Train: 0.023466, LR: 3.29e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  389: Train: 0.020912, LR: 3.30e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  390: Train: 0.023155, LR: 3.31e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  391: Train: 0.022949, LR: 3.32e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# Epoch  392: Train: 0.022540, LR: 3.33e-04 [WARMUP]
#           Best: Train: 0.020508 (Epoch 372)
# ...
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9824: Train: 0.003828, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9825: Train: 0.003837, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9826: Train: 0.003996, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9827: Train: 0.003990, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9828: Train: 0.004078, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9829: Train: 0.003901, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9830: Train: 0.003860, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9831: Train: 0.003991, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9832: Train: 0.004065, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9833: Train: 0.004218, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9834: Train: 0.004287, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9835: Train: 0.004097, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9836: Train: 0.004322, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9837: Train: 0.004300, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9838: Train: 0.004205, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9839: Train: 0.004077, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9840: Train: 0.004062, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9841: Train: 0.003992, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9842: Train: 0.003997, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9843: Train: 0.004128, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9844: Train: 0.004174, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9845: Train: 0.003976, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9846: Train: 0.003961, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9847: Train: 0.004015, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9848: Train: 0.003896, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9849: Train: 0.003945, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9850: Train: 0.003851, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9851: Train: 0.004071, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9852: Train: 0.003974, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9853: Train: 0.003934, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9854: Train: 0.004064, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9855: Train: 0.003941, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9856: Train: 0.003977, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9857: Train: 0.003939, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9858: Train: 0.004021, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9859: Train: 0.003996, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9860: Train: 0.004044, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9861: Train: 0.004154, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9862: Train: 0.003930, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9863: Train: 0.003747, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9864: Train: 0.004037, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9865: Train: 0.003793, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9866: Train: 0.004017, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9867: Train: 0.003944, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9868: Train: 0.004213, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9869: Train: 0.004022, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9870: Train: 0.003755, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9871: Train: 0.004000, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9872: Train: 0.003909, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9873: Train: 0.003995, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9874: Train: 0.004062, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9875: Train: 0.003879, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9876: Train: 0.003936, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9877: Train: 0.004006, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9878: Train: 0.004037, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9879: Train: 0.004128, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9880: Train: 0.003978, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9881: Train: 0.003961, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9882: Train: 0.004017, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9883: Train: 0.003914, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9884: Train: 0.003947, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9885: Train: 0.003904, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9886: Train: 0.003996, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9887: Train: 0.003807, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9888: Train: 0.003947, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9889: Train: 0.004026, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9890: Train: 0.003765, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9891: Train: 0.003903, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9892: Train: 0.004054, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9893: Train: 0.003856, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9894: Train: 0.004070, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9895: Train: 0.003886, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9896: Train: 0.003934, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9897: Train: 0.003965, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9898: Train: 0.004082, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9899: Train: 0.003771, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9900: Train: 0.004005, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9901: Train: 0.003938, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9902: Train: 0.004031, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9903: Train: 0.004015, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9904: Train: 0.004030, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9905: Train: 0.003979, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9906: Train: 0.004069, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9907: Train: 0.004124, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9908: Train: 0.003933, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9909: Train: 0.003970, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9910: Train: 0.003970, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9911: Train: 0.003867, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9912: Train: 0.003864, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9913: Train: 0.003928, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9914: Train: 0.003901, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9915: Train: 0.003965, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9916: Train: 0.003870, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9917: Train: 0.003886, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9918: Train: 0.004130, LR: 1.07e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9919: Train: 0.003949, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9920: Train: 0.003843, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9921: Train: 0.003788, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9922: Train: 0.003858, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9923: Train: 0.003874, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9924: Train: 0.003944, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9925: Train: 0.003928, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9926: Train: 0.003799, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9927: Train: 0.003946, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9928: Train: 0.003925, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9929: Train: 0.003921, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9930: Train: 0.003862, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9931: Train: 0.004026, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9932: Train: 0.003855, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9933: Train: 0.004079, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9934: Train: 0.003901, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9935: Train: 0.003993, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9936: Train: 0.003959, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9937: Train: 0.003941, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9938: Train: 0.003905, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9939: Train: 0.003880, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9940: Train: 0.003791, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9941: Train: 0.003917, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9942: Train: 0.004109, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9943: Train: 0.003880, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9944: Train: 0.003906, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9945: Train: 0.004024, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9946: Train: 0.003910, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9947: Train: 0.003870, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9948: Train: 0.004048, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9949: Train: 0.003978, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9950: Train: 0.003809, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9951: Train: 0.003774, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9952: Train: 0.003968, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9953: Train: 0.003899, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9954: Train: 0.003878, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9955: Train: 0.004030, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9956: Train: 0.003914, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9957: Train: 0.003967, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9958: Train: 0.003819, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9959: Train: 0.003917, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9960: Train: 0.003863, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9961: Train: 0.004059, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9962: Train: 0.004060, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9963: Train: 0.003873, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9964: Train: 0.003986, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9965: Train: 0.003829, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9966: Train: 0.003923, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9967: Train: 0.004046, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9968: Train: 0.004044, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9969: Train: 0.003861, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9970: Train: 0.003927, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9971: Train: 0.004041, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9972: Train: 0.003866, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9973: Train: 0.003837, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9974: Train: 0.003946, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9975: Train: 0.003936, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9976: Train: 0.003824, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9977: Train: 0.003919, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9978: Train: 0.003855, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9979: Train: 0.004077, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9980: Train: 0.003769, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9981: Train: 0.004002, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9982: Train: 0.003810, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9983: Train: 0.003854, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9984: Train: 0.003889, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9985: Train: 0.003849, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9986: Train: 0.003934, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9987: Train: 0.004028, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9988: Train: 0.003980, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9989: Train: 0.003885, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9990: Train: 0.003790, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9991: Train: 0.003963, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9992: Train: 0.004026, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9993: Train: 0.003969, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9994: Train: 0.004035, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9995: Train: 0.003804, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9996: Train: 0.004016, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9997: Train: 0.004194, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9998: Train: 0.004026, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 9999: Train: 0.003922, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
# Epoch 10000: Train: 0.003981, LR: 1.06e-03
#           Best: Train: 0.003680 (Epoch 9042)
#
# Training completed!
# ============================================================
# Best Performance (Epoch 9042):
#   Best Train Loss:  0.003680
# ============================================================
# Final Performance (Epoch 10000):
#   Final Train Loss: 0.003981
#   Final LR:         1.06e-03
# ============================================================
# Warmup completed at epoch 2500 with peak LR: 2.12e-03
#
# ✅ Best model (Epoch 9042) successfully saved in memory!
#    Best model loss: 0.003680
#    Best model also saved to file: BMED_TF_250904.pth

# %%
# 모델 평가: 실제 vs 예측 데이터 비교 (denormalized 원본 단위, Best Model 사용)
import matplotlib.pyplot as plt
import numpy as np

# normalization에 사용된 range_mm 복원 (전체 데이터 기준)
original_df = pd.read_csv('BMED_DATA_AG.csv')

range_mm = {
    'V': {'min': original_df['V'].min()*0.8, 'max': original_df['V'].max()*1.2},
    'E': {'min': original_df['E'].min()*0.8, 'max': original_df['E'].max()*1.2},
    'VF': {'min': original_df['VF'].min()*0.8, 'max': original_df['VF'].max()*1.2},
    'VA': {'min': original_df['VA'].min()*0.8, 'max': original_df['VA'].max()*1.2},
    'VB': {'min': original_df['VB'].min()*0.8, 'max': original_df['VB'].max()*1.2},
    'CFLA': {'min': 0, 'max': original_df['CFLA'].max()*1.2},
    'CALA': {'min': 0, 'max': original_df['CALA'].max()*1.2},
    'CFK': {'min': 0, 'max': original_df['CFK'].max()*1.2},
    'CBK': {'min': 0, 'max': original_df['CBK'].max()*1.2},
    'I': {'min': 0, 'max': original_df['I'].max()*1.2},
}

def denormalize_data(normalized_data, feature_name):
    """정규화된 데이터를 원래 단위로 복원"""
    if feature_name in range_mm:
        min_val = range_mm[feature_name]['min']
        max_val = range_mm[feature_name]['max']
        return normalized_data * (max_val - min_val) + min_val
    return normalized_data

# feature 정보 정의
feature_names = ['VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']
feature_indices = [2, 3, 4, 5, 6, 7, 8, 9]
feature_units = ['L', 'L', 'L', 'mol/L', 'mol/L', 'mol/L', 'mol/L', 'A']

# Best model 확인
if best_model is None:
    print("❌ Best model이 저장되지 않았습니다. 현재 모델을 사용합니다.")
    evaluation_model = model
    model_info = "Current Model"
else:
    evaluation_model = best_model
    model_info = f"Best Model (Epoch {best_epoch}, Loss: {best_train_loss:.6f})"
    print(f"✅ {model_info} 사용하여 평가를 진행합니다.")

# 전체 실험 데이터 정보 확인
print("🔍 전체 실험 데이터 분석 중...")

# 실험 번호와 데이터로더 인덱스 매핑 생성
exp_num_to_dataloader_idx = {}
dataloader_idx_to_exp_num = {}

for i, exp_num in enumerate(sorted(ndf['exp'].unique())):
    exp_num_to_dataloader_idx[exp_num] = i
    dataloader_idx_to_exp_num[i] = exp_num

print(f"📋 실험 번호 매핑:")
print(f"   - CSV 실험 번호 → 데이터로더 인덱스: {exp_num_to_dataloader_idx}")
print(f"   - 데이터로더 인덱스 → CSV 실험 번호: {dataloader_idx_to_exp_num}")

# 모든 실험 정보 수집
all_experiments_info = []
for i, (input_seq, seq_lengths) in enumerate(dataloader):
    seq_len = seq_lengths[0].item()
    duration = seq_len * 0.25
    
    # 첫 번째 시점의 조건 추출
    initial_conditions = input_seq[0, 0]  # 첫 번째 배치, 첫 번째 시점
    voltage = denormalize_data(initial_conditions[0].item(), 'V')
    electrolyte = denormalize_data(initial_conditions[1].item(), 'E')
    
    # 실제 실험 번호 가져오기
    actual_exp_num = dataloader_idx_to_exp_num[i]
    
    all_experiments_info.append({
        'dataloader_idx': i,
        'actual_exp_num': actual_exp_num,
        'seq_length': seq_len,
        'duration_hours': duration,
        'voltage': voltage,
        'electrolyte': electrolyte
    })

# 사용 가능한 실험 목록 출력
print("\n📋 사용 가능한 전체 실험 목록:")
print("="*90)
print(f"{'실험번호':<8} {'데이터로더인덱스':<12} {'시간길이':<10} {'전압(V)':<10} {'전해질농도(M)':<15} {'설명'}")
print("-"*90)

for exp_info in all_experiments_info:
    print(f"{exp_info['actual_exp_num']:<8} {exp_info['dataloader_idx']:<12} {exp_info['duration_hours']:<10.2f} {exp_info['voltage']:<10.1f} {exp_info['electrolyte']:<15.3f} "
          f"실험조건 {exp_info['actual_exp_num']}")

print("="*90)

# 실험 선택 옵션 - 실제 실험 번호 사용
available_exp_nums = [exp['actual_exp_num'] for exp in all_experiments_info]
print(f"\n🎯 실험 선택 옵션:")
print(f"   - 사용 가능한 실험 번호: {available_exp_nums}")
print(f"   - 총 {len(available_exp_nums)}개 실험 데이터 available")

# 기본값 설정 - 실제 실험 번호 사용
exp_to_evaluate = 1  # 원하는 실험 번호로 변경 가능 
print(f"\n📊 현재 선택된 실험: {exp_to_evaluate}")

# 선택된 실험이 유효한지 확인
if exp_to_evaluate not in available_exp_nums:
    print(f"⚠️  실험 {exp_to_evaluate}을 찾을 수 없습니다. 첫 번째 실험({available_exp_nums[0]})을 사용합니다.")
    exp_to_evaluate = available_exp_nums[0]
else:
    print(f"✅ 실험 {exp_to_evaluate}이 발견되었습니다!")

# 실제 실험 번호를 데이터로더 인덱스로 변환
dataloader_idx_to_use = exp_num_to_dataloader_idx[exp_to_evaluate]

# 선택된 실험 정보 출력
selected_exp_info = all_experiments_info[dataloader_idx_to_use]
print(f"\n🔬 선택된 실험 {exp_to_evaluate} 상세 정보:")
print(f"   - 데이터로더 인덱스: {dataloader_idx_to_use}")
print(f"   - 시퀀스 길이: {selected_exp_info['seq_length']} 시점")
print(f"   - 실험 시간: {selected_exp_info['duration_hours']:.2f} 시간")
print(f"   - 전압: {selected_exp_info['voltage']:.1f} V")
print(f"   - 외부 전해질 농도: {selected_exp_info['electrolyte']:.3f} M")

evaluation_model.eval()
with torch.no_grad():
    # 선택된 실험의 데이터 가져오기 (데이터로더 인덱스 사용)
    for i, (input_seq, seq_lengths) in enumerate(dataloader):
        if i == dataloader_idx_to_use:
            selected_input_seq = input_seq.to(device)
            selected_seq_lengths = seq_lengths.to(device)
            break
    else:
        print(f"⚠️ 데이터로더에서 인덱스 {dataloader_idx_to_use}를 찾을 수 없습니다. 첫 번째 실험을 사용합니다.")
        selected_input_seq, selected_seq_lengths = next(iter(dataloader))
        selected_input_seq = selected_input_seq.to(device)
        selected_seq_lengths = selected_seq_lengths.to(device)
        exp_to_evaluate = available_exp_nums[0]
        dataloader_idx_to_use = 0
        selected_exp_info = all_experiments_info[0]  # 첫 번째 실험 정보로 업데이트
    
    # Teacher forcing 데이터 준비
    inputs, targets, target_seq_lengths = tf_data(selected_input_seq, selected_seq_lengths)
    
    # Best model로 예측
    predictions = evaluation_model(inputs, target_seq_lengths)
    
    # CPU로 이동하여 시각화 준비
    predictions = predictions.cpu().numpy()
    targets = targets.cpu().numpy()
    input_seq_cpu = selected_input_seq.cpu().numpy()
    
    # 첫 번째 샘플 (batch의 첫 번째) 사용
    pred_sample = predictions[0]
    actual_sample = targets[0]
    initial_sample = input_seq_cpu[0]  # 초기값 포함된 전체 시퀀스
    seq_len = target_seq_lengths[0].item()
    full_seq_len = selected_seq_lengths[0].item()
    
    # 실제 시퀀스 길이만큼만 사용
    pred_sample = pred_sample[:seq_len]
    actual_sample = actual_sample[:seq_len]
    initial_sample = initial_sample[:full_seq_len]

# 실험 조건 정보 출력
print(f"🔬 실험 조건:")
print(f"   - 실험 번호: {exp_to_evaluate}")
print(f"   - 전압(V): {denormalize_data(initial_sample[0, 0], 'V'):.1f} V")
print(f"   - 외부 전해질 농도(E): {denormalize_data(initial_sample[0, 1], 'E'):.2f} M")
print(f"   - 시퀀스 길이: {full_seq_len} 시점 ({full_seq_len*0.25:.2f} 시간)")

# 시간 축 생성
time_points = np.arange(full_seq_len) * 0.25  # 전체 시간축 (0.0부터)

# 예측값을 초기값과 연결하여 전체 시퀀스 구성
prediction_full = np.zeros((full_seq_len, 10))
# 첫 번째 시점은 초기값 사용
prediction_full[0] = initial_sample[0]
# 나머지 시점은 모델 예측값 사용
prediction_full[1:seq_len+1] = pred_sample

# 2x4 subplot 생성
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
fig.suptitle(f'BMED Model Evaluation: Actual vs Predicted (Exp {exp_to_evaluate})\n{model_info}', fontsize=16, fontweight='bold')

for i, (feature_name, feature_idx, unit) in enumerate(zip(feature_names, feature_indices, feature_units)):
    row = i // 4
    col = i % 4
    ax = axes[row, col]
    
    # 데이터를 원래 단위로 denormalize
    actual_denorm = denormalize_data(initial_sample[:, feature_idx], feature_name)
    pred_denorm = denormalize_data(prediction_full[:seq_len+1, feature_idx], feature_name)
    
    # 실제 데이터 (전체 시퀀스)
    ax.plot(time_points, actual_denorm, 'b-', linewidth=2, label='Actual', marker='o', markersize=4)
    
    # 예측 데이터 (초기값부터 연결된 전체 시퀀스)
    ax.plot(time_points[:seq_len+1], pred_denorm, 'r--', linewidth=2, label='Predicted', marker='s', markersize=4)
    
    # 초기값 강조 표시
    ax.plot(time_points[0], actual_denorm[0], 'go', markersize=8, label='Initial Value')
    
    # 예측 시작점 표시
    ax.axvline(x=time_points[1], color='gray', linestyle=':', alpha=0.7, label='Prediction Start')
    
    # 그래프 설정
    ax.set_title(f'{feature_name}', fontsize=12, fontweight='bold')
    ax.set_xlabel('Time (hours)', fontsize=10)
    ax.set_ylabel(f'{feature_name} ({unit})', fontsize=10)
    ax.grid(True, alpha=0.3)
    ax.legend(fontsize=8)
    
    # RMSE 계산 및 표시 (denormalized 값으로, 예측 구간만)
    actual_pred_denorm = denormalize_data(actual_sample[:, feature_idx], feature_name)
    pred_pred_denorm = denormalize_data(pred_sample[:, feature_idx], feature_name)
    rmse = np.sqrt(np.mean((actual_pred_denorm - pred_pred_denorm)**2))
    ax.text(0.02, 0.98, f'RMSE: {rmse:.4f} {unit}', transform=ax.transAxes, 
            verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    
    # y축 범위 설정 (전체 데이터 고려)
    all_values = np.concatenate([actual_denorm, pred_denorm])
    y_min = all_values.min()
    y_max = all_values.max()
    y_range = y_max - y_min
    if y_range > 0:
        ax.set_ylim(y_min - 0.1 * y_range, y_max + 0.1 * y_range)
    
    # x축 범위 설정
    ax.set_xlim(-0.1, time_points[seq_len] + 0.1)

plt.tight_layout()
plt.show()

# 전체 성능 지표 계산 (denormalized)
print("="*80)
print(f"MODEL EVALUATION RESULTS - Experiment {exp_to_evaluate}")
print(f"{model_info}")
print("="*80)
print(f"Initial time point: t = {time_points[0]:.2f} hours")
print(f"Prediction starts from: t = {time_points[1]:.2f} hours")
print(f"Total sequence length: {full_seq_len} points")
print(f"Prediction sequence length: {seq_len} points")
print("-"*80)

total_rmse = 0
for i, (feature_name, unit) in enumerate(zip(feature_names, feature_units)):
    feature_idx = feature_indices[i]
    
    # denormalized 값으로 성능 지표 계산
    actual_vals_denorm = denormalize_data(actual_sample[:, feature_idx], feature_name)
    pred_vals_denorm = denormalize_data(pred_sample[:, feature_idx], feature_name)
    initial_val_denorm = denormalize_data(initial_sample[0, feature_idx], feature_name)
    
    # 성능 지표 계산
    rmse = np.sqrt(np.mean((actual_vals_denorm - pred_vals_denorm)**2))
    mae = np.mean(np.abs(actual_vals_denorm - pred_vals_denorm))
    mape = np.mean(np.abs((actual_vals_denorm - pred_vals_denorm) / (actual_vals_denorm + 1e-8))) * 100  # MAPE (%)
    r2 = 1 - (np.sum((actual_vals_denorm - pred_vals_denorm)**2) / np.sum((actual_vals_denorm - np.mean(actual_vals_denorm))**2))
    
    print(f"{feature_name:6s}: Initial={initial_val_denorm:.4f} {unit}, RMSE={rmse:.4f} {unit}, MAE={mae:.4f} {unit}, MAPE={mape:.2f}%, R²={r2:.4f}")
    total_rmse += rmse

avg_rmse = total_rmse / len(feature_names)
print("-"*80)
print(f"AVERAGE: RMSE={avg_rmse:.4f} (mixed units)")
if best_model is not None:
    print(f"✅ Best training loss: {best_train_loss:.6f} (Epoch {best_epoch})")
print("="*80)

# 실험 변경 방법 안내
print(f"\n💡 다른 실험을 평가하려면:")
print(f"   - 코드의 'exp_to_evaluate = {exp_to_evaluate}' 부분을 원하는 실험 번호로 수정하세요")
print(f"   - 사용 가능한 실험 번호: {available_exp_nums}")
print(f"   - 현재 설정: Experiment {exp_to_evaluate} (데이터로더 인덱스: {dataloader_idx_to_use})")
print(f"   - 총 {len(available_exp_nums)}개 실험 중에서 선택 가능합니다")

# 실험 번호 매핑 정보 출력
print(f"\n🔄 실험 번호 매핑 정보:")
for exp_info in all_experiments_info:
    print(f"   - 실험 {exp_info['actual_exp_num']} → 데이터로더 인덱스 {exp_info['dataloader_idx']}")

# 추가 분석을 위한 함수 정의
def evaluate_specific_experiment(exp_num):
    """특정 실험을 평가하는 함수"""
    if exp_num not in available_exp_nums:
        print(f"❌ 실험 {exp_num}는 사용할 수 없습니다. 사용 가능한 실험: {available_exp_nums}")
        return
    
    dataloader_idx = exp_num_to_dataloader_idx[exp_num]
    print(f"\n🔄 실험 {exp_num} (데이터로더 인덱스: {dataloader_idx}) 평가를 시작합니다...")
    # 여기에 평가 코드를 추가할 수 있습니다
    
print(f"\n📌 함수 사용법:")
print(f"   evaluate_specific_experiment(실험번호)  # 예: evaluate_specific_experiment(3)")
print(f"   실제 실험 번호를 입력하여 개별 평가를 수행할 수 있습니다.")
# Out:
# ✅ Best Model (Epoch 9042, Loss: 0.003680) 사용하여 평가를 진행합니다.
# 🔍 전체 실험 데이터 분석 중...
# 📋 실험 번호 매핑:
#    - CSV 실험 번호 → 데이터로더 인덱스: {np.int64(0): 0, np.int64(1): 1, np.int64(2): 2, np.int64(3): 3, np.int64(4): 4, np.int64(5): 5, np.int64(6): 6, np.int64(7): 7, np.int64(8): 8, np.int64(9): 9, np.int64(10): 10, np.int64(11): 11, np.int64(12): 12, np.int64(13): 13, np.int64(14): 14}
#    - 데이터로더 인덱스 → CSV 실험 번호: {0: np.int64(0), 1: np.int64(1), 2: np.int64(2), 3: np.int64(3), 4: np.int64(4), 5: np.int64(5), 6: np.int64(6), 7: np.int64(7), 8: np.int64(8), 9: np.int64(9), 10: np.int64(10), 11: np.int64(11), 12: np.int64(12), 13: np.int64(13), 14: np.int64(14)}
#
# 📋 사용 가능한 전체 실험 목록:
# ==========================================================================================
# 실험번호     데이터로더인덱스     시간길이       전압(V)      전해질농도(M)        설명
# ------------------------------------------------------------------------------------------
# 0        0            4.25       20.0       0.250           실험조건 0
# 1        1            8.25       30.0       0.250           실험조건 1
# ==========================================================================================
#
# 🎯 실험 선택 옵션:
#    - 사용 가능한 실험 번호: [np.int64(0), np.int64(1)]
#    - 총 2개 실험 데이터 available
#
# 📊 현재 선택된 실험: 1
# ✅ 실험 1이 발견되었습니다!
#
# 🔬 선택된 실험 1 상세 정보:
#    - 데이터로더 인덱스: 1
#    - 시퀀스 길이: 33 시점
#    - 실험 시간: 8.25 시간
#    - 전압: 30.0 V
#    - 외부 전해질 농도: 0.250 M
# 🔬 실험 조건:
#    - 실험 번호: 1
#    - 전압(V): 30.0 V
#    - 외부 전해질 농도(E): 0.25 M
#    - 시퀀스 길이: 33 시점 (8.25 시간)
# ================================================================================
# MODEL EVALUATION RESULTS - Experiment 1
# Best Model (Epoch 9042, Loss: 0.003680)
# ================================================================================
# Initial time point: t = 0.00 hours
# Prediction starts from: t = 0.25 hours
# Total sequence length: 33 points
# Prediction sequence length: 32 points
# --------------------------------------------------------------------------------
# VF    : Initial=1.0000 L, RMSE=0.0337 L, MAE=0.0304 L, MAPE=4.25%, R²=0.9772
# VA    : Initial=1.0000 L, RMSE=0.0182 L, MAE=0.0154 L, MAPE=1.24%, R²=0.9888
# VB    : Initial=6.0000 L, RMSE=0.0167 L, MAE=0.0153 L, MAPE=0.26%, R²=0.9170
# CFLA  : Initial=2.8993 mol/L, RMSE=0.0772 mol/L, MAE=0.0503 mol/L, MAPE=4.82%, R²=0.9830
# CALA  : Initial=0.0093 mol/L, RMSE=0.0605 mol/L, MAE=0.0568 mol/L, MAPE=14.14%, R²=0.9889
# CFK   : Initial=5.2645 mol/L, RMSE=0.1208 mol/L, MAE=0.1183 mol/L, MAPE=8.84%, R²=0.9929
# CBK   : Initial=0.0362 mol/L, RMSE=0.0278 mol/L, MAE=0.0258 mol/L, MAPE=8.92%, R²=0.9900
# I     : Initial=0.1000 A, RMSE=0.0387 A, MAE=0.0305 A, MAPE=1.86%, R²=0.9933
# --------------------------------------------------------------------------------
# AVERAGE: RMSE=0.0492 (mixed units)
# ✅ Best training loss: 0.003680 (Epoch 9042)
# ================================================================================
#
# 💡 다른 실험을 평가하려면:
#    - 코드의 'exp_to_evaluate = 1' 부분을 원하는 실험 번호로 수정하세요
#    - 사용 가능한 실험 번호: [np.int64(0), np.int64(1)]
#    - 현재 설정: Experiment 1 (데이터로더 인덱스: 1)
#    - 총 2개 실험 중에서 선택 가능합니다
#
# 🔄 실험 번호 매핑 정보:
#    - 실험 0 → 데이터로더 인덱스 0
#    - 실험 1 → 데이터로더 인덱스 1
#
# 📌 함수 사용법:
#    evaluate_specific_experiment(실험번호)  # 예: evaluate_specific_experiment(3)
#    실제 실험 번호를 입력하여 개별 평가를 수행할 수 있습니다.

# %%
# 전체 실험 데이터에 대한 종합적인 시각화 - 8개 feature별 개별 플롯 (수정됨)
# 각 플롯은 모든 실험을 서브플롯으로 표시

print("🚀 전체 실험 데이터 comprehensive evaluation 시작...")

# Device 및 모델 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
evaluation_model = best_model if best_model is not None else model

# feature 정보 재정의
feature_names = ['VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']
feature_indices = [2, 3, 4, 5, 6, 7, 8, 9]
feature_units = ['L', 'L', 'L', 'mol/L', 'mol/L', 'mol/L', 'mol/L', 'A']
feature_titles = ['Feed Volume', 'Acid Volume', 'Base Volume', 'Feed LA Conc.', 'Acid LA Conc.', 'Feed K Conc.', 'Base K Conc.', 'Current']

# 전체 실험 데이터 수집
all_experiment_results = {}
available_exp_nums = sorted(ndf['exp'].unique())
total_experiments = len(available_exp_nums)

print(f"📋 전체 {total_experiments}개 실험 데이터 수집 중...")
print(f"🔧 데이터로더 배치 크기: {dataloader.batch_size}")
print(f"🔧 총 배치 개수: {len(dataloader)}")

evaluation_model.eval()
with torch.no_grad():
    experiment_counter = 0
    
    for batch_idx, (input_seq, seq_lengths) in enumerate(dataloader):
        try:
            batch_size = input_seq.size(0)
            print(f"📦 배치 {batch_idx}: {batch_size}개 실험 처리 중...")
            
            input_seq = input_seq.to(device)
            seq_lengths = seq_lengths.to(device)
            
            # Teacher forcing 데이터 준비
            inputs, targets, target_seq_lengths = tf_data(input_seq, seq_lengths)
            
            # 모델 예측
            predictions = evaluation_model(inputs, target_seq_lengths)
            
            # CPU로 이동
            predictions_cpu = predictions.cpu().numpy()
            targets_cpu = targets.cpu().numpy()
            input_seq_cpu = input_seq.cpu().numpy()
            
            # 배치 내 모든 샘플 처리
            for sample_idx in range(batch_size):
                if experiment_counter >= total_experiments:
                    break
                    
                # 현재 실험 번호
                actual_exp_num = available_exp_nums[experiment_counter]
                
                # 샘플 데이터 추출
                pred_sample = predictions_cpu[sample_idx]
                actual_sample = targets_cpu[sample_idx]
                initial_sample = input_seq_cpu[sample_idx]
                seq_len = target_seq_lengths[sample_idx].item()
                full_seq_len = seq_lengths[sample_idx].item()
                
                # 실제 시퀀스 길이만큼만 사용
                pred_sample = pred_sample[:seq_len]
                actual_sample = actual_sample[:seq_len]
                initial_sample = initial_sample[:full_seq_len]
                
                # 시간 축 생성
                time_points = np.arange(full_seq_len) * 0.25
                
                # 예측값을 초기값과 연결
                prediction_full = np.zeros((full_seq_len, 10))
                prediction_full[0] = initial_sample[0]
                prediction_full[1:seq_len+1] = pred_sample
                
                # 실험 조건 정보
                voltage = denormalize_data(initial_sample[0, 0], 'V')
                electrolyte = denormalize_data(initial_sample[0, 1], 'E')
                
                # 결과 저장
                all_experiment_results[actual_exp_num] = {
                    'time_points': time_points,
                    'actual_data': initial_sample,
                    'predicted_data': prediction_full,
                    'seq_len': seq_len,
                    'full_seq_len': full_seq_len,
                    'voltage': voltage,
                    'electrolyte': electrolyte,
                    'actual_sample': actual_sample,
                    'pred_sample': pred_sample
                }
                
                print(f"✅ 실험 {actual_exp_num}: {full_seq_len*0.25:.1f}h, {voltage:.1f}V, {electrolyte:.3f}M")
                experiment_counter += 1
            
        except Exception as e:
            print(f"❌ 배치 {batch_idx} 오류: {str(e)}")
            import traceback
            traceback.print_exc()
            continue

print(f"📊 총 {len(all_experiment_results)}개 실험 데이터 수집 완료!")

# 서브플롯 배치 계산
import math
sqrt_exp = math.ceil(math.sqrt(total_experiments))
if sqrt_exp * (sqrt_exp - 1) >= total_experiments:
    grid_rows, grid_cols = sqrt_exp - 1, sqrt_exp
else:
    grid_rows, grid_cols = sqrt_exp, sqrt_exp

print(f"📐 각 feature당 {grid_rows}x{grid_cols} 서브플롯 그리드 사용")

# 8개 feature별로 개별 figure 생성
for feature_idx, (feature_name, feature_index, unit, title) in enumerate(zip(feature_names, feature_indices, feature_units, feature_titles)):
    print(f"🎨 Feature {feature_idx+1}/8: {feature_name} ({title}) 생성 중...")
    
    # 새 figure 생성
    fig, axes = plt.subplots(grid_rows, grid_cols, figsize=(4*grid_cols, 3*grid_rows))
    if best_model is not None:
        suptitle = f'{title} ({feature_name}) - All Experiments\nBest Model (Epoch {best_epoch}, Loss: {best_train_loss:.6f})'
    else:
        suptitle = f'{title} ({feature_name}) - All Experiments\nCurrent Model'
    fig.suptitle(suptitle, fontsize=16, fontweight='bold')
    
    # axes 처리 (1차원으로 변환)
    if grid_rows * grid_cols == 1:
        axes = [axes]
    else:
        axes = axes.flatten() if hasattr(axes, 'flatten') else [axes]
    
    # 성능 지표 수집
    rmse_values = []
    r2_values = []
    
    # 각 실험별 subplot
    for plot_idx, exp_num in enumerate(sorted(all_experiment_results.keys())):
        if plot_idx >= len(axes):
            break
            
        ax = axes[plot_idx]
        exp_data = all_experiment_results[exp_num]
        
        # 데이터 denormalize
        actual_denorm = denormalize_data(exp_data['actual_data'][:, feature_index], feature_name)
        pred_denorm = denormalize_data(exp_data['predicted_data'][:exp_data['seq_len']+1, feature_index], feature_name)
        
        # 플롯 생성
        ax.plot(exp_data['time_points'], actual_denorm, 'b-', linewidth=1.5, label='Actual', alpha=0.8)
        ax.plot(exp_data['time_points'][:exp_data['seq_len']+1], pred_denorm, 'r--', linewidth=1.5, label='Predicted', alpha=0.8)
        
        # 시작점 표시
        ax.plot(exp_data['time_points'][0], actual_denorm[0], 'go', markersize=3)
        ax.axvline(x=exp_data['time_points'][1], color='gray', linestyle=':', alpha=0.5)
        
        # 성능 지표 계산
        actual_pred_denorm = denormalize_data(exp_data['actual_sample'][:, feature_index], feature_name)
        pred_pred_denorm = denormalize_data(exp_data['pred_sample'][:, feature_index], feature_name)
        
        rmse = np.sqrt(np.mean((actual_pred_denorm - pred_pred_denorm)**2))
        if np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2) > 0:
            r2 = 1 - (np.sum((actual_pred_denorm - pred_pred_denorm)**2) / np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2))
        else:
            r2 = 0.0
            
        rmse_values.append(rmse)
        r2_values.append(r2)
        
        # 서브플롯 설정
        condition_text = f'{exp_data["voltage"]:.1f}V, {exp_data["electrolyte"]:.2f}M'
        ax.set_title(f'Exp {exp_num}: {condition_text}\nRMSE: {rmse:.3f} {unit}', fontsize=9)
        ax.set_xlabel('Time (hours)', fontsize=8)
        ax.set_ylabel(f'{feature_name} ({unit})', fontsize=8)
        ax.grid(True, alpha=0.3)
        ax.tick_params(labelsize=7)
        
        # 첫 번째 subplot에만 범례 추가
        if plot_idx == 0:
            ax.legend(fontsize=8, loc='upper right')
    
    # 빈 subplot 숨기기
    for plot_idx in range(len(all_experiment_results), len(axes)):
        axes[plot_idx].set_visible(False)
    
    # 전체 성능 요약
    avg_rmse = np.mean(rmse_values)
    std_rmse = np.std(rmse_values)
    avg_r2 = np.mean(r2_values)
    std_r2 = np.std(r2_values)
    
    # 성능 요약 텍스트 박스
    summary_text = f'Overall Performance:\nRMSE: {avg_rmse:.4f} ± {std_rmse:.4f} {unit}\nR²: {avg_r2:.3f} ± {std_r2:.3f}\nExperiments: {len(rmse_values)}'
    fig.text(0.02, 0.02, summary_text, fontsize=10, 
             bbox=dict(boxstyle='round,pad=0.5', facecolor='lightblue', alpha=0.8))
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.92, bottom=0.12, left=0.05, right=0.98)
    plt.show()
    
    print(f"✅ {feature_name} 완료: 평균 RMSE = {avg_rmse:.4f} {unit}, 평균 R² = {avg_r2:.3f}")

# 전체 요약 출력
print("\n" + "="*80)
print("COMPREHENSIVE EVALUATION SUMMARY - ALL EXPERIMENTS")
print("="*80)

for feature_idx, (feature_name, feature_index, unit) in enumerate(zip(feature_names, feature_indices, feature_units)):
    # 각 feature별 전체 성능 통계
    all_rmse = []
    all_mae = []
    all_r2 = []
    
    for exp_num in sorted(all_experiment_results.keys()):
        exp_data = all_experiment_results[exp_num]
        
        actual_pred_denorm = denormalize_data(exp_data['actual_sample'][:, feature_index], feature_name)
        pred_pred_denorm = denormalize_data(exp_data['pred_sample'][:, feature_index], feature_name)
        
        rmse = np.sqrt(np.mean((actual_pred_denorm - pred_pred_denorm)**2))
        mae = np.mean(np.abs(actual_pred_denorm - pred_pred_denorm))
        
        if np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2) > 0:
            r2 = 1 - (np.sum((actual_pred_denorm - pred_pred_denorm)**2) / np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2))
        else:
            r2 = 0.0
        
        all_rmse.append(rmse)
        all_mae.append(mae)
        all_r2.append(r2)
    
    print(f"{feature_name:6s}: RMSE={np.mean(all_rmse):.4f}±{np.std(all_rmse):.4f} {unit}, "
          f"MAE={np.mean(all_mae):.4f}±{np.std(all_mae):.4f} {unit}, "
          f"R²={np.mean(all_r2):.3f}±{np.std(all_r2):.3f}")

print("-"*80)
print(f"📊 Total experiments analyzed: {len(all_experiment_results)}")
if best_model is not None:
    print(f"🏆 Best model used: Epoch {best_epoch}, Loss: {best_train_loss:.6f}")
else:
    print("📋 Current model used")
print("="*80)

print("🎉 Comprehensive evaluation 완료! 8개의 feature별 플롯이 모든 실험 데이터를 포함하여 생성되었습니다.")
# Out:
# 🚀 전체 실험 데이터 comprehensive evaluation 시작...
# 📋 전체 15개 실험 데이터 수집 중...
# 🔧 데이터로더 배치 크기: 8
# 🔧 총 배치 개수: 2
# 📦 배치 0: 8개 실험 처리 중...
# ✅ 실험 0: 4.2h, 20.0V, 0.250M
# ✅ 실험 1: 5.2h, 30.0V, 0.250M
# ✅ 실험 2: 5.2h, 30.0V, 0.250M
# ✅ 실험 3: 5.2h, 30.0V, 0.250M
# ✅ 실험 4: 7.2h, 20.0V, 0.250M
# ✅ 실험 5: 9.2h, 20.0V, 0.250M
# ✅ 실험 6: 4.2h, 10.0V, 0.250M
# ✅ 실험 7: 7.2h, 10.0V, 0.250M
# 📦 배치 1: 7개 실험 처리 중...
# ✅ 실험 8: 8.2h, 30.0V, 0.250M
# ✅ 실험 9: 5.2h, 30.0V, 0.250M
# ✅ 실험 10: 6.2h, 30.0V, 0.250M
# ✅ 실험 11: 6.2h, 35.0V, 0.500M
# ✅ 실험 12: 5.2h, 35.0V, 0.250M
# ✅ 실험 13: 5.2h, 35.0V, 1.000M
# ✅ 실험 14: 4.8h, 30.0V, 0.250M
# 📊 총 15개 실험 데이터 수집 완료!
# 📐 각 feature당 4x4 서브플롯 그리드 사용
# 🎨 Feature 1/8: VF (Feed Volume) 생성 중...
# ✅ VF 완료: 평균 RMSE = 0.0188 L, 평균 R² = 0.934
# 🎨 Feature 2/8: VA (Acid Volume) 생성 중...
# ✅ VA 완료: 평균 RMSE = 0.0087 L, 평균 R² = 0.957
# 🎨 Feature 3/8: VB (Base Volume) 생성 중...
# ✅ VB 완료: 평균 RMSE = 0.0156 L, 평균 R² = 0.827
# 🎨 Feature 4/8: CFLA (Feed LA Conc.) 생성 중...
# ✅ CFLA 완료: 평균 RMSE = 0.0335 mol/L, 평균 R² = 0.978
# 🎨 Feature 5/8: CALA (Acid LA Conc.) 생성 중...
# ✅ CALA 완료: 평균 RMSE = 0.0425 mol/L, 평균 R² = 0.970
# 🎨 Feature 6/8: CFK (Feed K Conc.) 생성 중...
# ✅ CFK 완료: 평균 RMSE = 0.0723 mol/L, 평균 R² = 0.980
# 🎨 Feature 7/8: CBK (Base K Conc.) 생성 중...
# ✅ CBK 완료: 평균 RMSE = 0.0463 mol/L, 평균 R² = 0.972
# 🎨 Feature 8/8: I (Current) 생성 중...
# ✅ I 완료: 평균 RMSE = 0.0358 A, 평균 R² = 0.968
#
# ================================================================================
# COMPREHENSIVE EVALUATION SUMMARY - ALL EXPERIMENTS
# ================================================================================
# VF    : RMSE=0.0188±0.0108 L, MAE=0.0168±0.0095 L, R²=0.934±0.071
# VA    : RMSE=0.0087±0.0069 L, MAE=0.0066±0.0052 L, R²=0.957±0.047
# VB    : RMSE=0.0156±0.0094 L, MAE=0.0143±0.0082 L, R²=0.827±0.183
# CFLA  : RMSE=0.0335±0.0240 mol/L, MAE=0.0241±0.0163 mol/L, R²=0.978±0.020
# CALA  : RMSE=0.0425±0.0259 mol/L, MAE=0.0372±0.0239 mol/L, R²=0.970±0.016
# CFK   : RMSE=0.0723±0.0321 mol/L, MAE=0.0669±0.0307 mol/L, R²=0.980±0.020
# CBK   : RMSE=0.0463±0.0208 mol/L, MAE=0.0418±0.0183 mol/L, R²=0.972±0.020
# I     : RMSE=0.0358±0.0135 A, MAE=0.0292±0.0110 A, R²=0.968±0.064
# --------------------------------------------------------------------------------
# 📊 Total experiments analyzed: 15
# 🏆 Best model used: Epoch 9042, Loss: 0.003680
# ================================================================================
# 🎉 Comprehensive evaluation 완료! 8개의 feature별 플롯이 모든 실험 데이터를 포함하여 생성되었습니다.
