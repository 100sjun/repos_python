# %%
import pandas as pd
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# %%
def df_treat(name):
    df = pd.read_csv(name)
    ndf = pd.DataFrame()
    range_mm={
        'V': {'min':df['V'].min()*0.8, 'max': df['V'].max()*1.2},
        'E': {'min':df['E'].min()*0.8, 'max': df['E'].max()*1.2},
        'VF': {'min':df['VF'].min()*0.8, 'max': df['VF'].max()*1.2},
        'VA': {'min':df['VA'].min()*0.8, 'max': df['VA'].max()*1.2},
        'VB': {'min':df['VB'].min()*0.8, 'max': df['VB'].max()*1.2},
        'CFLA': {'min':0, 'max': df['CFLA'].max()*1.2},
        'CALA': {'min':0, 'max': df['CALA'].max()*1.2},
        'CFK': {'min':0, 'max': df['CFK'].max()*1.2},
        'CBK': {'min':0, 'max': df['CBK'].max()*1.2},
        'I': {'min':0, 'max': df['I'].max()*1.2},
    }
    ndf['exp'] = df['exp']; ndf['t'] = df['t']

    for col in ['V', 'E', 'VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']:
        if col in range_mm:
            ndf[col] = (df[col] - range_mm[col]['min'])/(range_mm[col]['max'] - range_mm[col]['min'])
        else:
            ndf[col] = df[col]

    exp_num_list = sorted(ndf['exp'].unique())

    return df, ndf, range_mm, exp_num_list

# %%
def seq_data(ndf, exp_num_list):
    seq = []
    feature_cols = ['V', 'E', 'VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']
    
    for exp in exp_num_list:
        exp_df = ndf[ndf['exp'] == exp]
        seq.append(exp_df[feature_cols].values)
    
    return seq

# %%
def pad_seq(seq):
    max_len = max([len(s) for s in seq])
    seq_len = [len(s) for s in seq]
    pad_seq = pad_sequence([torch.tensor(s) for s in seq], batch_first=True, padding_value=-1)

    return pad_seq, seq_len, max_len

# %%
def gen_dataset(pad_seq, seq_len):
    input_tensor = pad_seq.float()
    seq_len_tensor = torch.tensor(seq_len)
    dataset = TensorDataset(input_tensor, seq_len_tensor)
    return dataset

# %%
# LSTM with layer normalization
class LayerNormLSTM(nn.Module):
    def __init__(self, input_node, hidden_node):
        super().__init__()
        self.input_node = input_node
        self.hidden_node = hidden_node

        self.w_i = nn.Linear(input_node, 4*hidden_node, bias=False)
        self.w_h = nn.Linear(hidden_node, 4*hidden_node, bias=False)

        self.ln_i = nn.LayerNorm(hidden_node)
        self.ln_f = nn.LayerNorm(hidden_node)
        self.ln_w = nn.LayerNorm(hidden_node)
        self.ln_o = nn.LayerNorm(hidden_node)
        self.ln_c = nn.LayerNorm(hidden_node)

    def forward(self, input, hidden):
        h_prev, c_prev = hidden

        gi = self.w_i(input)
        gh = self.w_h(h_prev)
        i_i, i_f, i_w, i_o = gi.chunk(4, dim=-1)
        h_i, h_f, h_w, h_o = gh.chunk(4, dim=-1)

        i_g = torch.sigmoid(self.ln_i(i_i + h_i))
        f_g = torch.sigmoid(self.ln_f(i_f + h_f))
        w_g = torch.tanh(self.ln_w(i_w + h_w))
        o_g = torch.sigmoid(self.ln_o(i_o + h_o))
        

        c_new = f_g * c_prev + i_g * w_g
        c_new = self.ln_c(c_new)

        h_new = o_g * torch.tanh(c_new)

        return h_new, c_new

# %%
# State feature extractor using LayerNorm LSTM
class StateExtr(nn.Module):
    def __init__(self, input_node, hidden_node, n_layer, dropout):
        super().__init__()
        self.hidden_node = hidden_node
        self.n_layer = n_layer
        self.input_node = input_node

        self.lstm_cells = nn.ModuleList()
        self.lstm_cells.append(LayerNormLSTM(input_node, hidden_node))

        for i in range(n_layer - 1):
            self.lstm_cells.append(LayerNormLSTM(hidden_node, hidden_node))

        self.dropout = nn.Dropout(dropout)
        self.layernorm = nn.LayerNorm(hidden_node)

    def forward(self, x, seq_len):
        batch_size, max_len, _ = x.size()
        device = x.device

        h_states = []
        c_states = []

        for _ in range(self.n_layer):
            h_states.append(torch.zeros(batch_size, self.hidden_node, device=device))
            c_states.append(torch.zeros(batch_size, self.hidden_node, device=device))

        outputs = []
        for t in range(max_len):
            x_t = x[:, t, :]

            layer_input = x_t # initialize layer input with input tensor
            for layer_idx, lstm_cell in enumerate(self.lstm_cells):
                h_new, c_new = lstm_cell(layer_input, (h_states[layer_idx], c_states[layer_idx]))
                
                h_states[layer_idx] = h_new
                c_states[layer_idx] = c_new

                if layer_idx < len(self.lstm_cells) - 1:
                    layer_input = self.dropout(h_new)
                else:
                    layer_input = h_new

            outputs.append(layer_input)

        output_tensor = torch.stack(outputs, dim=1)
        seq_len_cpu = seq_len.detach().cpu().long()
        mask = torch.arange(max_len, device='cpu')[None, :] < seq_len_cpu[:, None]
        mask = mask.float().to(device).unsqueeze(-1)

        masked_output = output_tensor * mask
        normed_output = self.layernorm(masked_output)
        return self.dropout(normed_output)

# %%
# Physical change regressor
class PhysRegr(nn.Module):
    def __init__(self, input_node, output_node, n_layer, hidden_node, dropout):
        super().__init__()

        layers = []

        layers.extend([
            nn.Linear(input_node, hidden_node),
            nn.LayerNorm(hidden_node),
            nn.ReLU(),
            nn.Dropout(dropout)
        ])

        for _ in range(n_layer - 1):
            layers.extend([
                nn.Linear(hidden_node, hidden_node),
                nn.LayerNorm(hidden_node),
                nn.ReLU(),
                nn.Dropout(dropout)
            ])
        
        layers.append(nn.Linear(hidden_node, output_node))
        layers.append(nn.Sigmoid())

        self.layers = nn.Sequential(*layers)

    def forward(self, hidden_states):
        return self.layers(hidden_states)

# %%
# Current regressor
class CurrRegr(nn.Module):
    def __init__(self, input_node, hidden_node, n_layer, dropout):
        super().__init__()

        layers = []

        layers.extend([
            nn.Linear(input_node, hidden_node),
            nn.LayerNorm(hidden_node),
            nn.ReLU(),
            nn.Dropout(dropout)
        ])

        for _ in range(n_layer - 1):
            layers.extend([
                nn.Linear(hidden_node, hidden_node),
                nn.LayerNorm(hidden_node),
                nn.ReLU(),
                nn.Dropout(dropout)
            ])
        
        layers.append(nn.Linear(hidden_node, 1))

        self.layers = nn.Sequential(*layers)

    def forward(self, hidden_states):
        return self.layers(hidden_states)

# %%
class PhysConstr(nn.Module):
    def __init__(self, range_mm, curr_regr, eps=1e-2):
        super().__init__()
        self.eps = eps
        self.curr_regr = curr_regr
        self.register_buffer('range_mm_tensor', self._range2tensor(range_mm))

    def _range2tensor(self, range_mm):
        feature_names = ['V','E','VF','VA','VB','CFLA','CALA','CFK','CBK','I']
        ranges = torch.zeros(len(feature_names),2)

        for i, name in enumerate(feature_names):
            if name in range_mm:
                ranges[i, 0] = range_mm[name]['min']
                ranges[i, 1] = range_mm[name]['max']
        
        return ranges
    
    def _norm_tensor(self, data, feature_idx):
        min_val = self.range_mm_tensor[feature_idx, 0]
        max_val = self.range_mm_tensor[feature_idx, 1]
        return (data - min_val) / (max_val - min_val)

    def _denorm_tensor(self, norm_data, feature_idx):
        min_val = self.range_mm_tensor[feature_idx, 0]
        max_val = self.range_mm_tensor[feature_idx, 1]
        return norm_data * (max_val - min_val) + min_val

    def forward(self, phys_chng, cur_state):
        V_idx, E_idx, VF_idx, VA_idx, VB_idx = 0, 1, 2, 3, 4
        CFLA_idx, CALA_idx, CFK_idx, CBK_idx, I_idx = 5, 6, 7, 8, 9

        VF = self._denorm_tensor(cur_state[..., 2:3], VF_idx)
        VA = self._denorm_tensor(cur_state[..., 3:4], VA_idx)
        VB = self._denorm_tensor(cur_state[..., 4:5], VB_idx)
        CFLA = self._denorm_tensor(cur_state[..., 5:6], CFLA_idx)
        CALA = self._denorm_tensor(cur_state[..., 6:7], CALA_idx)
        CFK = self._denorm_tensor(cur_state[..., 7:8], CFK_idx)
        CBK = self._denorm_tensor(cur_state[..., 8:9], CBK_idx)

        NFLA = CFLA * VF
        NALA = CALA * VA
        NFK = CFK * VF
        NBK = CBK * VB

        rdVA = phys_chng[..., 0:1]
        rdVB = phys_chng[..., 1:2]
        rdNALA = phys_chng[..., 2:3]
        rdNBK = phys_chng[..., 3:4]

        dVA = VF*(rdVA -0.5)
        dVB = VF*(rdVB - 0.5)
        dNBK = NFK*rdNBK
        dNALA = NFLA*rdNALA

        nVF = VF - dVA - dVB
        nVA = VA + dVA
        nVB = VB + dVB
        
        nNFLA = NFLA - dNALA
        nNALA = NALA + dNALA
        nNFK = NFK - dNBK
        nNBK = NBK + dNBK

        nCFLA = nNFLA / nVF
        nCALA = nNALA / nVA
        nCFK = nNFK / nVF
        nCBK = nNBK / nVB

        V = cur_state[..., 0:1]
        E = cur_state[..., 1:2]
        nVF_norm = self._norm_tensor(nVF, VF_idx)
        nVA_norm = self._norm_tensor(nVA, VA_idx)
        nVB_norm = self._norm_tensor(nVB, VB_idx)
        nCFLA_norm = self._norm_tensor(nCFLA, CFLA_idx)
        nCALA_norm = self._norm_tensor(nCALA, CALA_idx)
        nCFK_norm = self._norm_tensor(nCFK, CFK_idx)
        nCBK_norm = self._norm_tensor(nCBK, CBK_idx)

        # Create temporary state without I for current prediction
        temp_state = torch.cat([
            V, E, nVF_norm, nVA_norm, nVB_norm, nCFLA_norm, nCALA_norm, nCFK_norm, nCBK_norm
        ], dim=-1)
        
        # Predict new I using the current predictor
        nI_pred = self.curr_regr(temp_state)
        nI_real = self._denorm_tensor(nI_pred, I_idx)
        nI_real = torch.clamp(nI_real, min=0.0)
        nI_norm = self._norm_tensor(nI_real, I_idx)

        # Create final next state with predicted I
        next_state = torch.cat([
            V, E, nVF_norm, nVA_norm, nVB_norm, nCFLA_norm, nCALA_norm, nCFK_norm, nCBK_norm, nI_norm
        ], dim=-1)
        
        return next_state

# %%
class BMEDAutoregressiveModel(nn.Module):
    def __init__(self, state_extr_params, phys_regr_params, curr_regr_params, range_mm):
        super().__init__()
        self.state_extr = StateExtr(**state_extr_params)
        self.phys_regr = PhysRegr(**phys_regr_params)
        self.curr_regr = CurrRegr(**curr_regr_params)
        self.phys_constr = PhysConstr(range_mm, self.curr_regr)

    def forward(self, x, seq_len):
        hidden_states = self.state_extr(x, seq_len)
        phys_chng = self.phys_regr(hidden_states)
        new_x = self.phys_constr(phys_chng, x)
        
        return new_x

# %%
def masked_mse_loss(pred, target, seq_len):
    _, max_len, _ = pred.shape
    seq_len_cpu = seq_len.detach().cpu().long()

    mask = torch.arange(max_len, device='cpu')[None, :] < seq_len_cpu[:, None]
    mask = mask.float().to(pred.device)

    loss = F.mse_loss(pred, target, reduction='none')
    masked_loss = loss * mask.unsqueeze(-1)

    total_loss = masked_loss.sum()
    total_elements = mask.sum()

    masked_loss = total_loss / total_elements
    return masked_loss

# %%
def tf_data(input_seq, seq_len):
    inputs = input_seq[:, :-1, :-1]
    targets = input_seq[:, 1:, :]

    target_seq_len = seq_len - 1

    return inputs, targets, target_seq_len

# %%
class NoamScheduler:
    def __init__(self, optimizer, model_size, warmup_epochs, factor=1.0):
        self.optimizer = optimizer
        self.model_size = model_size
        self.warmup_epochs = warmup_epochs
        self.factor = factor
        self.epoch_num = 0

    def step_epoch(self):
        self.epoch_num += 1
        lr = self.factor * (
            self.model_size ** (-0.5) *
            min(self.epoch_num ** (-0.5), self.epoch_num * self.warmup_epochs ** (-1.5))
        )
    
        for param_group in self.optimizer.param_groups:
            param_group['lr'] = lr

        return lr

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
df, ndf, range_mm, exp_num_list = df_treat('BMED_DATA_AG.csv')
seq = seq_data(ndf, exp_num_list)
pad, seq_len, max_len = pad_seq(seq)
dataset = gen_dataset(pad, seq_len)
dataloader = DataLoader(dataset, batch_size=3, shuffle=False)

# %%
state_extr_params = {
    'input_node': 9,
    'hidden_node': 72,
    'n_layer': 4,
    'dropout': 0.4
}

phys_regr_params = {
    'input_node': state_extr_params['hidden_node'],
    'hidden_node': 96,
    'n_layer': 3,
    'dropout': 0.4,
    'output_node': 4
}

curr_regr_params = {
    'input_node': 9,
    'hidden_node': 48,
    'n_layer': 2,
    'dropout': 0.1
}

model = BMEDAutoregressiveModel(state_extr_params, phys_regr_params, curr_regr_params, range_mm)
model = model.to(device)
print(f"Model architecture:")
print(f"  Input features: {state_extr_params['input_node']} (without current)")
print(f"  State Extractor Hidden size: {state_extr_params['hidden_node']}")
print(f"  State Extractor layers: {state_extr_params['n_layer']}")
print(f"  Phys Regressor layers: {phys_regr_params['n_layer']}")
print(f"  Phys Regressor Hidden size: {phys_regr_params['hidden_node']}")
print(f"  Current Predictor layers: {curr_regr_params['n_layer']}")
print(f"  Current Predictor Hidden size: {curr_regr_params['hidden_node']}")
print(f"  Model parameters: {sum(p.numel() for p in model.parameters()):,}")
print(f"  Physics constraints: Volume conservation with denormalization")

num_epochs = 2000
optimizer = torch.optim.AdamW(model.parameters(), lr=1.0)
warmup_epochs = int(num_epochs * 0.1)
scheduler = NoamScheduler(optimizer, model_size=state_extr_params['hidden_node'], warmup_epochs=warmup_epochs, factor=1)

print(f"\nTraining configuration:")
print(f"  Total epochs: {num_epochs:,}")
print(f"  Warmup epochs: {warmup_epochs:,} (10%)")
peak_lr = 1 * (48 ** (-0.5)) * (warmup_epochs ** (-0.5))
print(f"  Peak learning rate: {peak_lr:.2e}")
# Out:
# Model architecture:
#   Input features: 9 (without current)
#   State Extractor Hidden size: 72
#   State Extractor layers: 4
#   Phys Regressor layers: 3
#   Phys Regressor Hidden size: 96
#   Current Predictor layers: 2
#   Current Predictor Hidden size: 48
#   Model parameters: 180,437
#   Physics constraints: Volume conservation with denormalization
#
# Training configuration:
#   Total epochs: 2,000
#   Warmup epochs: 200 (10%)
#   Peak learning rate: 1.02e-02

# %%
train_samples = len(dataloader.dataset)
best_train_loss = float('inf')
best_epoch = 0
train_losses = []
learning_rates = []

best_model = None

print("Training started...")
print(f"Total batches per epoch: {len(dataloader)}")

for epoch in range(num_epochs):
    current_lr = scheduler.step_epoch()

    model.train()
    train_loss = 0.0
    train_batches = 0

    for batch_idx, (input_seq, seq_len) in enumerate(dataloader):
        try:
            input_seq = input_seq.to(device)
            seq_len = seq_len.to(device)

            inputs, targets, target_seq_len = tf_data(input_seq, seq_len)
            
            optimizer.zero_grad()
            pred = model(inputs, target_seq_len)
            loss = masked_mse_loss(pred, targets, target_seq_len)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            train_loss += loss.item()
            train_batches += 1

        except Exception as e:
            print(f"Training batch {batch_idx} error: {str(e)}")
            print(f"Input shape: {input_seq.shape if 'input_seq' in locals() else 'N/A'}")
            print(f"Seq lengths: {seq_len if 'seq_lengths' in locals() else 'N/A'}")
            import traceback
            traceback.print_exc()
            continue
    
    if train_batches == 0:
        print("No valid training batches")
        break

    train_losses.append(train_loss)
    learning_rates.append(current_lr)

    if train_loss < best_train_loss:
        best_train_loss = train_loss
        best_epoch = epoch + 1
        best_status = " ★ NEW BEST"
        
        # Best model을 메모리에 복사하여 저장
        import copy
        best_model = copy.deepcopy(model)
        print(f"          Best model saved in memory at epoch {best_epoch}")
        
        # 오늘 날짜로 모델 파일 저장
        from datetime import datetime
        today = datetime.now().strftime("%y%m%d")
        model_filename = f"BMED_TF_{today}.pth"
        torch.save({
            'model_state_dict': best_model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'epoch': best_epoch,
            'best_train_loss': best_train_loss,
            'model_config': {
                'state_extr_params': state_extr_params,
                'phys_regr_params': phys_regr_params,
                'curr_regr_params': curr_regr_params,
                'range_mm': range_mm
            }
        }, model_filename)
        print(f"          Best model saved to {model_filename}")
    else:
        best_status = ""

    # Warmup 구간 표시
    if epoch + 1 <= warmup_epochs:
        warmup_status = " [WARMUP]"
    else:
        warmup_status = ""

    # 매 에포크마다 로깅 - best 성능 정보 포함
    print(f"Epoch {epoch+1:4d}: Train: {train_loss:.6f}, LR: {current_lr:.2e}{best_status}{warmup_status}")    

    if epoch == 0:
        print(f"          Best: Train: {best_train_loss:.6f}, (Epoch {best_epoch})")
    elif train_loss < best_train_loss:
        print(f"          ✓ Updated Best: Train: {best_train_loss:.6f}")
    else:
        print(f"          Best: Train: {best_train_loss:.6f} (Epoch {best_epoch})")

print(f"\nTraining completed!")
print(f"=" * 60)

# 안전한 결과 출력
if len(train_losses) > 0:
    print(f"Best Performance (Epoch {best_epoch}):")
    print(f"  Best Train Loss:  {best_train_loss:.6f}")
    print(f"=" * 60)
    print(f"Final Performance (Epoch {len(train_losses)}):")
    print(f"  Final Train Loss: {train_losses[-1]:.6f}")
    print(f"  Final LR:         {current_lr:.2e}")
    print(f"=" * 60)
    if len(learning_rates) > 0:
        print(f"Warmup completed at epoch {warmup_epochs} with peak LR: {max(learning_rates):.2e}")
else:
    print("⚠️ No training completed - check error messages above")

# Best model이 저장되었는지 확인
if best_model is not None:
    print(f"\n✅ Best model (Epoch {best_epoch}) successfully saved in memory!")
    print(f"   Best model loss: {best_train_loss:.6f}")
    from datetime import datetime
    today = datetime.now().strftime("%y%m%d")
    model_filename = f"BMED_TF_{today}.pth"
    print(f"   Best model also saved to file: {model_filename}")
else:
    print("\n⚠️ No best model was saved (training may have failed)")
    best_model = model  # fallback to current model
# Out:
# Training started...
# Total batches per epoch: 5
#           Best model saved in memory at epoch 1
#           Best model saved to BMED_TF_250930.pth
# Epoch    1: Train: 2.521523, LR: 4.17e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 2.521523, (Epoch 1)
#           Best model saved in memory at epoch 2
#           Best model saved to BMED_TF_250930.pth
# Epoch    2: Train: 2.459975, LR: 8.33e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 2.459975 (Epoch 2)
#           Best model saved in memory at epoch 3
#           Best model saved to BMED_TF_250930.pth
# Epoch    3: Train: 2.066183, LR: 1.25e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 2.066183 (Epoch 3)
#           Best model saved in memory at epoch 4
#           Best model saved to BMED_TF_250930.pth
# Epoch    4: Train: 1.773135, LR: 1.67e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 1.773135 (Epoch 4)
#           Best model saved in memory at epoch 5
#           Best model saved to BMED_TF_250930.pth
# Epoch    5: Train: 1.500462, LR: 2.08e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 1.500462 (Epoch 5)
#           Best model saved in memory at epoch 6
#           Best model saved to BMED_TF_250930.pth
# Epoch    6: Train: 1.191872, LR: 2.50e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 1.191872 (Epoch 6)
#           Best model saved in memory at epoch 7
#           Best model saved to BMED_TF_250930.pth
# Epoch    7: Train: 0.941098, LR: 2.92e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.941098 (Epoch 7)
#           Best model saved in memory at epoch 8
#           Best model saved to BMED_TF_250930.pth
# Epoch    8: Train: 0.826890, LR: 3.33e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.826890 (Epoch 8)
#           Best model saved in memory at epoch 9
#           Best model saved to BMED_TF_250930.pth
# Epoch    9: Train: 0.608857, LR: 3.75e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.608857 (Epoch 9)
#           Best model saved in memory at epoch 10
#           Best model saved to BMED_TF_250930.pth
# Epoch   10: Train: 0.434781, LR: 4.17e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.434781 (Epoch 10)
#           Best model saved in memory at epoch 11
#           Best model saved to BMED_TF_250930.pth
# Epoch   11: Train: 0.398133, LR: 4.58e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.398133 (Epoch 11)
#           Best model saved in memory at epoch 12
#           Best model saved to BMED_TF_250930.pth
# Epoch   12: Train: 0.315202, LR: 5.00e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.315202 (Epoch 12)
#           Best model saved in memory at epoch 13
#           Best model saved to BMED_TF_250930.pth
# Epoch   13: Train: 0.290471, LR: 5.42e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.290471 (Epoch 13)
#           Best model saved in memory at epoch 14
#           Best model saved to BMED_TF_250930.pth
# Epoch   14: Train: 0.247735, LR: 5.83e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.247735 (Epoch 14)
#           Best model saved in memory at epoch 15
#           Best model saved to BMED_TF_250930.pth
# Epoch   15: Train: 0.207489, LR: 6.25e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.207489 (Epoch 15)
#           Best model saved in memory at epoch 16
#           Best model saved to BMED_TF_250930.pth
# Epoch   16: Train: 0.189387, LR: 6.67e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.189387 (Epoch 16)
#           Best model saved in memory at epoch 17
#           Best model saved to BMED_TF_250930.pth
# Epoch   17: Train: 0.180952, LR: 7.08e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.180952 (Epoch 17)
#           Best model saved in memory at epoch 18
#           Best model saved to BMED_TF_250930.pth
# Epoch   18: Train: 0.158879, LR: 7.50e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.158879 (Epoch 18)
#           Best model saved in memory at epoch 19
#           Best model saved to BMED_TF_250930.pth
# Epoch   19: Train: 0.130643, LR: 7.92e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.130643 (Epoch 19)
# Epoch   20: Train: 0.136866, LR: 8.33e-04 [WARMUP]
#           Best: Train: 0.130643 (Epoch 19)
# Epoch   21: Train: 0.133727, LR: 8.75e-04 [WARMUP]
#           Best: Train: 0.130643 (Epoch 19)
#           Best model saved in memory at epoch 22
#           Best model saved to BMED_TF_250930.pth
# Epoch   22: Train: 0.104240, LR: 9.17e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.104240 (Epoch 22)
# Epoch   23: Train: 0.110748, LR: 9.58e-04 [WARMUP]
#           Best: Train: 0.104240 (Epoch 22)
# Epoch   24: Train: 0.104788, LR: 1.00e-03 [WARMUP]
#           Best: Train: 0.104240 (Epoch 22)
#           Best model saved in memory at epoch 25
#           Best model saved to BMED_TF_250930.pth
# Epoch   25: Train: 0.087712, LR: 1.04e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.087712 (Epoch 25)
# Epoch   26: Train: 0.089656, LR: 1.08e-03 [WARMUP]
#           Best: Train: 0.087712 (Epoch 25)
#           Best model saved in memory at epoch 27
#           Best model saved to BMED_TF_250930.pth
# Epoch   27: Train: 0.082340, LR: 1.12e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.082340 (Epoch 27)
#           Best model saved in memory at epoch 28
#           Best model saved to BMED_TF_250930.pth
# Epoch   28: Train: 0.081414, LR: 1.17e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.081414 (Epoch 28)
#           Best model saved in memory at epoch 29
#           Best model saved to BMED_TF_250930.pth
# Epoch   29: Train: 0.074679, LR: 1.21e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.074679 (Epoch 29)
# Epoch   30: Train: 0.079343, LR: 1.25e-03 [WARMUP]
#           Best: Train: 0.074679 (Epoch 29)
#           Best model saved in memory at epoch 31
#           Best model saved to BMED_TF_250930.pth
# Epoch   31: Train: 0.064217, LR: 1.29e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.064217 (Epoch 31)
#           Best model saved in memory at epoch 32
#           Best model saved to BMED_TF_250930.pth
# Epoch   32: Train: 0.062339, LR: 1.33e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.062339 (Epoch 32)
#           Best model saved in memory at epoch 33
#           Best model saved to BMED_TF_250930.pth
# Epoch   33: Train: 0.059447, LR: 1.37e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.059447 (Epoch 33)
# Epoch   34: Train: 0.060477, LR: 1.42e-03 [WARMUP]
#           Best: Train: 0.059447 (Epoch 33)
# Epoch   35: Train: 0.061399, LR: 1.46e-03 [WARMUP]
#           Best: Train: 0.059447 (Epoch 33)
#           Best model saved in memory at epoch 36
#           Best model saved to BMED_TF_250930.pth
# Epoch   36: Train: 0.057277, LR: 1.50e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.057277 (Epoch 36)
#           Best model saved in memory at epoch 37
#           Best model saved to BMED_TF_250930.pth
# Epoch   37: Train: 0.053781, LR: 1.54e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.053781 (Epoch 37)
# Epoch   38: Train: 0.056136, LR: 1.58e-03 [WARMUP]
#           Best: Train: 0.053781 (Epoch 37)
#           Best model saved in memory at epoch 39
#           Best model saved to BMED_TF_250930.pth
# Epoch   39: Train: 0.049281, LR: 1.62e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.049281 (Epoch 39)
#           Best model saved in memory at epoch 40
#           Best model saved to BMED_TF_250930.pth
# Epoch   40: Train: 0.048427, LR: 1.67e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.048427 (Epoch 40)
# Epoch   41: Train: 0.050809, LR: 1.71e-03 [WARMUP]
#           Best: Train: 0.048427 (Epoch 40)
#           Best model saved in memory at epoch 42
#           Best model saved to BMED_TF_250930.pth
# Epoch   42: Train: 0.048369, LR: 1.75e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.048369 (Epoch 42)
#           Best model saved in memory at epoch 43
#           Best model saved to BMED_TF_250930.pth
# Epoch   43: Train: 0.047152, LR: 1.79e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.047152 (Epoch 43)
#           Best model saved in memory at epoch 44
#           Best model saved to BMED_TF_250930.pth
# Epoch   44: Train: 0.042842, LR: 1.83e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.042842 (Epoch 44)
# Epoch   45: Train: 0.046900, LR: 1.87e-03 [WARMUP]
#           Best: Train: 0.042842 (Epoch 44)
# Epoch   46: Train: 0.048957, LR: 1.92e-03 [WARMUP]
#           Best: Train: 0.042842 (Epoch 44)
# Epoch   47: Train: 0.046513, LR: 1.96e-03 [WARMUP]
#           Best: Train: 0.042842 (Epoch 44)
# Epoch   48: Train: 0.044225, LR: 2.00e-03 [WARMUP]
#           Best: Train: 0.042842 (Epoch 44)
#           Best model saved in memory at epoch 49
#           Best model saved to BMED_TF_250930.pth
# Epoch   49: Train: 0.038607, LR: 2.04e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.038607 (Epoch 49)
# Epoch   50: Train: 0.042093, LR: 2.08e-03 [WARMUP]
#           Best: Train: 0.038607 (Epoch 49)
# Epoch   51: Train: 0.039407, LR: 2.12e-03 [WARMUP]
#           Best: Train: 0.038607 (Epoch 49)
#           Best model saved in memory at epoch 52
#           Best model saved to BMED_TF_250930.pth
# Epoch   52: Train: 0.036851, LR: 2.17e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.036851 (Epoch 52)
# Epoch   53: Train: 0.042905, LR: 2.21e-03 [WARMUP]
#           Best: Train: 0.036851 (Epoch 52)
# Epoch   54: Train: 0.043317, LR: 2.25e-03 [WARMUP]
#           Best: Train: 0.036851 (Epoch 52)
# Epoch   55: Train: 0.041608, LR: 2.29e-03 [WARMUP]
#           Best: Train: 0.036851 (Epoch 52)
# Epoch   56: Train: 0.039166, LR: 2.33e-03 [WARMUP]
#           Best: Train: 0.036851 (Epoch 52)
# Epoch   57: Train: 0.048315, LR: 2.37e-03 [WARMUP]
#           Best: Train: 0.036851 (Epoch 52)
# Epoch   58: Train: 0.037140, LR: 2.42e-03 [WARMUP]
#           Best: Train: 0.036851 (Epoch 52)
#           Best model saved in memory at epoch 59
#           Best model saved to BMED_TF_250930.pth
# Epoch   59: Train: 0.034804, LR: 2.46e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.034804 (Epoch 59)
# Epoch   60: Train: 0.038613, LR: 2.50e-03 [WARMUP]
#           Best: Train: 0.034804 (Epoch 59)
#           Best model saved in memory at epoch 61
#           Best model saved to BMED_TF_250930.pth
# Epoch   61: Train: 0.034101, LR: 2.54e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.034101 (Epoch 61)
# Epoch   62: Train: 0.037198, LR: 2.58e-03 [WARMUP]
#           Best: Train: 0.034101 (Epoch 61)
#           Best model saved in memory at epoch 63
#           Best model saved to BMED_TF_250930.pth
# Epoch   63: Train: 0.031630, LR: 2.63e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.031630 (Epoch 63)
#           Best model saved in memory at epoch 64
#           Best model saved to BMED_TF_250930.pth
# Epoch   64: Train: 0.031326, LR: 2.67e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.031326 (Epoch 64)
# Epoch   65: Train: 0.034329, LR: 2.71e-03 [WARMUP]
#           Best: Train: 0.031326 (Epoch 64)
# Epoch   66: Train: 0.033548, LR: 2.75e-03 [WARMUP]
#           Best: Train: 0.031326 (Epoch 64)
# Epoch   67: Train: 0.034144, LR: 2.79e-03 [WARMUP]
#           Best: Train: 0.031326 (Epoch 64)
# Epoch   68: Train: 0.034069, LR: 2.83e-03 [WARMUP]
#           Best: Train: 0.031326 (Epoch 64)
# Epoch   69: Train: 0.033190, LR: 2.87e-03 [WARMUP]
#           Best: Train: 0.031326 (Epoch 64)
#           Best model saved in memory at epoch 70
#           Best model saved to BMED_TF_250930.pth
# Epoch   70: Train: 0.030108, LR: 2.92e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.030108 (Epoch 70)
# Epoch   71: Train: 0.030496, LR: 2.96e-03 [WARMUP]
#           Best: Train: 0.030108 (Epoch 70)
# Epoch   72: Train: 0.030400, LR: 3.00e-03 [WARMUP]
#           Best: Train: 0.030108 (Epoch 70)
# Epoch   73: Train: 0.030381, LR: 3.04e-03 [WARMUP]
#           Best: Train: 0.030108 (Epoch 70)
# Epoch   74: Train: 0.033740, LR: 3.08e-03 [WARMUP]
#           Best: Train: 0.030108 (Epoch 70)
# Epoch   75: Train: 0.036587, LR: 3.12e-03 [WARMUP]
#           Best: Train: 0.030108 (Epoch 70)
# Epoch   76: Train: 0.036120, LR: 3.17e-03 [WARMUP]
#           Best: Train: 0.030108 (Epoch 70)
# Epoch   77: Train: 0.033064, LR: 3.21e-03 [WARMUP]
#           Best: Train: 0.030108 (Epoch 70)
# Epoch   78: Train: 0.032335, LR: 3.25e-03 [WARMUP]
#           Best: Train: 0.030108 (Epoch 70)
# Epoch   79: Train: 0.030679, LR: 3.29e-03 [WARMUP]
#           Best: Train: 0.030108 (Epoch 70)
#           Best model saved in memory at epoch 80
#           Best model saved to BMED_TF_250930.pth
# Epoch   80: Train: 0.027762, LR: 3.33e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.027762 (Epoch 80)
#           Best model saved in memory at epoch 81
#           Best model saved to BMED_TF_250930.pth
# Epoch   81: Train: 0.024919, LR: 3.37e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   82: Train: 0.030854, LR: 3.42e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   83: Train: 0.036653, LR: 3.46e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   84: Train: 0.039194, LR: 3.50e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   85: Train: 0.033621, LR: 3.54e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   86: Train: 0.032314, LR: 3.58e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   87: Train: 0.026401, LR: 3.62e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   88: Train: 0.025538, LR: 3.67e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   89: Train: 0.027332, LR: 3.71e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   90: Train: 0.026853, LR: 3.75e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   91: Train: 0.026382, LR: 3.79e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   92: Train: 0.027202, LR: 3.83e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   93: Train: 0.034119, LR: 3.87e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   94: Train: 0.039031, LR: 3.92e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   95: Train: 0.036494, LR: 3.96e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   96: Train: 0.038042, LR: 4.00e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   97: Train: 0.032494, LR: 4.04e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   98: Train: 0.031680, LR: 4.08e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch   99: Train: 0.027886, LR: 4.13e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch  100: Train: 0.026000, LR: 4.17e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch  101: Train: 0.030078, LR: 4.21e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch  102: Train: 0.026949, LR: 4.25e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch  103: Train: 0.034278, LR: 4.29e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
# Epoch  104: Train: 0.026125, LR: 4.33e-03 [WARMUP]
#           Best: Train: 0.024919 (Epoch 81)
#           Best model saved in memory at epoch 105
#           Best model saved to BMED_TF_250930.pth
# Epoch  105: Train: 0.024280, LR: 4.38e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.024280 (Epoch 105)
# Epoch  106: Train: 0.025752, LR: 4.42e-03 [WARMUP]
#           Best: Train: 0.024280 (Epoch 105)
# Epoch  107: Train: 0.028486, LR: 4.46e-03 [WARMUP]
#           Best: Train: 0.024280 (Epoch 105)
# Epoch  108: Train: 0.025319, LR: 4.50e-03 [WARMUP]
#           Best: Train: 0.024280 (Epoch 105)
# Epoch  109: Train: 0.026550, LR: 4.54e-03 [WARMUP]
#           Best: Train: 0.024280 (Epoch 105)
# Epoch  110: Train: 0.032326, LR: 4.58e-03 [WARMUP]
#           Best: Train: 0.024280 (Epoch 105)
# Epoch  111: Train: 0.032178, LR: 4.62e-03 [WARMUP]
#           Best: Train: 0.024280 (Epoch 105)
# Epoch  112: Train: 0.029651, LR: 4.67e-03 [WARMUP]
#           Best: Train: 0.024280 (Epoch 105)
# Epoch  113: Train: 0.031640, LR: 4.71e-03 [WARMUP]
#           Best: Train: 0.024280 (Epoch 105)
# Epoch  114: Train: 0.031036, LR: 4.75e-03 [WARMUP]
#           Best: Train: 0.024280 (Epoch 105)
# Epoch  115: Train: 0.026945, LR: 4.79e-03 [WARMUP]
#           Best: Train: 0.024280 (Epoch 105)
#           Best model saved in memory at epoch 116
#           Best model saved to BMED_TF_250930.pth
# Epoch  116: Train: 0.024245, LR: 4.83e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.024245 (Epoch 116)
# Epoch  117: Train: 0.028411, LR: 4.87e-03 [WARMUP]
#           Best: Train: 0.024245 (Epoch 116)
# Epoch  118: Train: 0.031703, LR: 4.92e-03 [WARMUP]
#           Best: Train: 0.024245 (Epoch 116)
# Epoch  119: Train: 0.024767, LR: 4.96e-03 [WARMUP]
#           Best: Train: 0.024245 (Epoch 116)
# Epoch  120: Train: 0.027654, LR: 5.00e-03 [WARMUP]
#           Best: Train: 0.024245 (Epoch 116)
# Epoch  121: Train: 0.027314, LR: 5.04e-03 [WARMUP]
#           Best: Train: 0.024245 (Epoch 116)
# Epoch  122: Train: 0.040156, LR: 5.08e-03 [WARMUP]
#           Best: Train: 0.024245 (Epoch 116)
# Epoch  123: Train: 0.033090, LR: 5.13e-03 [WARMUP]
#           Best: Train: 0.024245 (Epoch 116)
# Epoch  124: Train: 0.037415, LR: 5.17e-03 [WARMUP]
#           Best: Train: 0.024245 (Epoch 116)
# Epoch  125: Train: 0.035410, LR: 5.21e-03 [WARMUP]
#           Best: Train: 0.024245 (Epoch 116)
# Epoch  126: Train: 0.030207, LR: 5.25e-03 [WARMUP]
#           Best: Train: 0.024245 (Epoch 116)
# Epoch  127: Train: 0.025320, LR: 5.29e-03 [WARMUP]
#           Best: Train: 0.024245 (Epoch 116)
# Epoch  128: Train: 0.026851, LR: 5.33e-03 [WARMUP]
#           Best: Train: 0.024245 (Epoch 116)
#           Best model saved in memory at epoch 129
#           Best model saved to BMED_TF_250930.pth
# Epoch  129: Train: 0.021684, LR: 5.37e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.021684 (Epoch 129)
#           Best model saved in memory at epoch 130
#           Best model saved to BMED_TF_250930.pth
# Epoch  130: Train: 0.019767, LR: 5.42e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.019767 (Epoch 130)
# Epoch  131: Train: 0.024849, LR: 5.46e-03 [WARMUP]
#           Best: Train: 0.019767 (Epoch 130)
# Epoch  132: Train: 0.023155, LR: 5.50e-03 [WARMUP]
#           Best: Train: 0.019767 (Epoch 130)
# Epoch  133: Train: 0.022313, LR: 5.54e-03 [WARMUP]
#           Best: Train: 0.019767 (Epoch 130)
# Epoch  134: Train: 0.023552, LR: 5.58e-03 [WARMUP]
#           Best: Train: 0.019767 (Epoch 130)
#           Best model saved in memory at epoch 135
#           Best model saved to BMED_TF_250930.pth
# Epoch  135: Train: 0.019341, LR: 5.62e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.019341 (Epoch 135)
# Epoch  136: Train: 0.019808, LR: 5.67e-03 [WARMUP]
#           Best: Train: 0.019341 (Epoch 135)
#           Best model saved in memory at epoch 137
#           Best model saved to BMED_TF_250930.pth
# Epoch  137: Train: 0.018663, LR: 5.71e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.018663 (Epoch 137)
# Epoch  138: Train: 0.019721, LR: 5.75e-03 [WARMUP]
#           Best: Train: 0.018663 (Epoch 137)
# Epoch  139: Train: 0.022138, LR: 5.79e-03 [WARMUP]
#           Best: Train: 0.018663 (Epoch 137)
# Epoch  140: Train: 0.023646, LR: 5.83e-03 [WARMUP]
#           Best: Train: 0.018663 (Epoch 137)
# Epoch  141: Train: 0.028349, LR: 5.87e-03 [WARMUP]
#           Best: Train: 0.018663 (Epoch 137)
# Epoch  142: Train: 0.031366, LR: 5.92e-03 [WARMUP]
#           Best: Train: 0.018663 (Epoch 137)
# Epoch  143: Train: 0.028374, LR: 5.96e-03 [WARMUP]
#           Best: Train: 0.018663 (Epoch 137)
# Epoch  144: Train: 0.033757, LR: 6.00e-03 [WARMUP]
#           Best: Train: 0.018663 (Epoch 137)
# Epoch  145: Train: 0.027442, LR: 6.04e-03 [WARMUP]
#           Best: Train: 0.018663 (Epoch 137)
# Epoch  146: Train: 0.022869, LR: 6.08e-03 [WARMUP]
#           Best: Train: 0.018663 (Epoch 137)
# Epoch  147: Train: 0.024136, LR: 6.12e-03 [WARMUP]
#           Best: Train: 0.018663 (Epoch 137)
# Epoch  148: Train: 0.022274, LR: 6.17e-03 [WARMUP]
#           Best: Train: 0.018663 (Epoch 137)
# Epoch  149: Train: 0.023181, LR: 6.21e-03 [WARMUP]
#           Best: Train: 0.018663 (Epoch 137)
# Epoch  150: Train: 0.019109, LR: 6.25e-03 [WARMUP]
#           Best: Train: 0.018663 (Epoch 137)
#           Best model saved in memory at epoch 151
#           Best model saved to BMED_TF_250930.pth
# Epoch  151: Train: 0.018181, LR: 6.29e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  152: Train: 0.018468, LR: 6.33e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  153: Train: 0.018741, LR: 6.37e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  154: Train: 0.018312, LR: 6.42e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  155: Train: 0.022302, LR: 6.46e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  156: Train: 0.028510, LR: 6.50e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  157: Train: 0.033129, LR: 6.54e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  158: Train: 0.030538, LR: 6.58e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  159: Train: 0.031078, LR: 6.62e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  160: Train: 0.030596, LR: 6.67e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  161: Train: 0.035815, LR: 6.71e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  162: Train: 0.040202, LR: 6.75e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  163: Train: 0.033368, LR: 6.79e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  164: Train: 0.035220, LR: 6.83e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  165: Train: 0.038882, LR: 6.88e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  166: Train: 0.038597, LR: 6.92e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  167: Train: 0.039810, LR: 6.96e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  168: Train: 0.037527, LR: 7.00e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  169: Train: 0.048806, LR: 7.04e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  170: Train: 0.034499, LR: 7.08e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  171: Train: 0.033838, LR: 7.13e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  172: Train: 0.035705, LR: 7.17e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  173: Train: 0.042800, LR: 7.21e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  174: Train: 0.025858, LR: 7.25e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  175: Train: 0.026144, LR: 7.29e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
# Epoch  176: Train: 0.024249, LR: 7.33e-03 [WARMUP]
#           Best: Train: 0.018181 (Epoch 151)
#           Best model saved in memory at epoch 177
#           Best model saved to BMED_TF_250930.pth
# Epoch  177: Train: 0.017653, LR: 7.37e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.017653 (Epoch 177)
# Epoch  178: Train: 0.021890, LR: 7.42e-03 [WARMUP]
#           Best: Train: 0.017653 (Epoch 177)
# Epoch  179: Train: 0.024234, LR: 7.46e-03 [WARMUP]
#           Best: Train: 0.017653 (Epoch 177)
# Epoch  180: Train: 0.020858, LR: 7.50e-03 [WARMUP]
#           Best: Train: 0.017653 (Epoch 177)
# Epoch  181: Train: 0.024161, LR: 7.54e-03 [WARMUP]
#           Best: Train: 0.017653 (Epoch 177)
# Epoch  182: Train: 0.021834, LR: 7.58e-03 [WARMUP]
#           Best: Train: 0.017653 (Epoch 177)
# Epoch  183: Train: 0.028290, LR: 7.62e-03 [WARMUP]
#           Best: Train: 0.017653 (Epoch 177)
# Epoch  184: Train: 0.020090, LR: 7.67e-03 [WARMUP]
#           Best: Train: 0.017653 (Epoch 177)
# Epoch  185: Train: 0.025451, LR: 7.71e-03 [WARMUP]
#           Best: Train: 0.017653 (Epoch 177)
# Epoch  186: Train: 0.021883, LR: 7.75e-03 [WARMUP]
#           Best: Train: 0.017653 (Epoch 177)
# Epoch  187: Train: 0.017786, LR: 7.79e-03 [WARMUP]
#           Best: Train: 0.017653 (Epoch 177)
#           Best model saved in memory at epoch 188
#           Best model saved to BMED_TF_250930.pth
# Epoch  188: Train: 0.016458, LR: 7.83e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.016458 (Epoch 188)
#           Best model saved in memory at epoch 189
#           Best model saved to BMED_TF_250930.pth
# Epoch  189: Train: 0.016163, LR: 7.88e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.016163 (Epoch 189)
#           Best model saved in memory at epoch 190
#           Best model saved to BMED_TF_250930.pth
# Epoch  190: Train: 0.014380, LR: 7.92e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  191: Train: 0.014665, LR: 7.96e-03 [WARMUP]
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  192: Train: 0.017834, LR: 8.00e-03 [WARMUP]
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  193: Train: 0.014659, LR: 8.04e-03 [WARMUP]
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  194: Train: 0.016805, LR: 8.08e-03 [WARMUP]
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  195: Train: 0.020367, LR: 8.13e-03 [WARMUP]
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  196: Train: 0.019446, LR: 8.17e-03 [WARMUP]
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  197: Train: 0.014507, LR: 8.21e-03 [WARMUP]
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  198: Train: 0.018491, LR: 8.25e-03 [WARMUP]
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  199: Train: 0.025373, LR: 8.29e-03 [WARMUP]
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  200: Train: 0.023074, LR: 8.33e-03 [WARMUP]
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  201: Train: 0.022808, LR: 8.31e-03
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  202: Train: 0.024942, LR: 8.29e-03
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  203: Train: 0.030201, LR: 8.27e-03
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  204: Train: 0.024462, LR: 8.25e-03
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  205: Train: 0.026421, LR: 8.23e-03
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  206: Train: 0.020471, LR: 8.21e-03
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  207: Train: 0.019630, LR: 8.19e-03
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  208: Train: 0.017020, LR: 8.17e-03
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  209: Train: 0.017993, LR: 8.15e-03
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  210: Train: 0.020834, LR: 8.13e-03
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  211: Train: 0.018652, LR: 8.11e-03
#           Best: Train: 0.014380 (Epoch 190)
# Epoch  212: Train: 0.014420, LR: 8.09e-03
#           Best: Train: 0.014380 (Epoch 190)
#           Best model saved in memory at epoch 213
#           Best model saved to BMED_TF_250930.pth
# Epoch  213: Train: 0.012124, LR: 8.08e-03 ★ NEW BEST
#           Best: Train: 0.012124 (Epoch 213)
# Epoch  214: Train: 0.016841, LR: 8.06e-03
#           Best: Train: 0.012124 (Epoch 213)
# Epoch  215: Train: 0.013932, LR: 8.04e-03
#           Best: Train: 0.012124 (Epoch 213)
# Epoch  216: Train: 0.012306, LR: 8.02e-03
#           Best: Train: 0.012124 (Epoch 213)
# Epoch  217: Train: 0.015894, LR: 8.00e-03
#           Best: Train: 0.012124 (Epoch 213)
# Epoch  218: Train: 0.013767, LR: 7.98e-03
#           Best: Train: 0.012124 (Epoch 213)
#           Best model saved in memory at epoch 219
#           Best model saved to BMED_TF_250930.pth
# Epoch  219: Train: 0.011258, LR: 7.96e-03 ★ NEW BEST
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  220: Train: 0.013290, LR: 7.95e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  221: Train: 0.013738, LR: 7.93e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  222: Train: 0.014509, LR: 7.91e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  223: Train: 0.014920, LR: 7.89e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  224: Train: 0.016641, LR: 7.87e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  225: Train: 0.015218, LR: 7.86e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  226: Train: 0.017019, LR: 7.84e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  227: Train: 0.015727, LR: 7.82e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  228: Train: 0.012732, LR: 7.80e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  229: Train: 0.013836, LR: 7.79e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  230: Train: 0.014103, LR: 7.77e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  231: Train: 0.016223, LR: 7.75e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  232: Train: 0.013884, LR: 7.74e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  233: Train: 0.015107, LR: 7.72e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  234: Train: 0.014797, LR: 7.70e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  235: Train: 0.014553, LR: 7.69e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  236: Train: 0.012358, LR: 7.67e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  237: Train: 0.012575, LR: 7.66e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  238: Train: 0.013988, LR: 7.64e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  239: Train: 0.012472, LR: 7.62e-03
#           Best: Train: 0.011258 (Epoch 219)
# Epoch  240: Train: 0.012143, LR: 7.61e-03
#           Best: Train: 0.011258 (Epoch 219)
#           Best model saved in memory at epoch 241
#           Best model saved to BMED_TF_250930.pth
# Epoch  241: Train: 0.010879, LR: 7.59e-03 ★ NEW BEST
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  242: Train: 0.011562, LR: 7.58e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  243: Train: 0.012839, LR: 7.56e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  244: Train: 0.011646, LR: 7.54e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  245: Train: 0.011534, LR: 7.53e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  246: Train: 0.014057, LR: 7.51e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  247: Train: 0.011376, LR: 7.50e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  248: Train: 0.015317, LR: 7.48e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  249: Train: 0.017362, LR: 7.47e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  250: Train: 0.017428, LR: 7.45e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  251: Train: 0.017641, LR: 7.44e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  252: Train: 0.016559, LR: 7.42e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  253: Train: 0.015168, LR: 7.41e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  254: Train: 0.015036, LR: 7.39e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  255: Train: 0.012913, LR: 7.38e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  256: Train: 0.012398, LR: 7.37e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  257: Train: 0.012873, LR: 7.35e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  258: Train: 0.015003, LR: 7.34e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  259: Train: 0.017198, LR: 7.32e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  260: Train: 0.017793, LR: 7.31e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  261: Train: 0.016030, LR: 7.29e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  262: Train: 0.013958, LR: 7.28e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  263: Train: 0.013605, LR: 7.27e-03
#           Best: Train: 0.010879 (Epoch 241)
# Epoch  264: Train: 0.012532, LR: 7.25e-03
#           Best: Train: 0.010879 (Epoch 241)
#           Best model saved in memory at epoch 265
#           Best model saved to BMED_TF_250930.pth
# Epoch  265: Train: 0.010711, LR: 7.24e-03 ★ NEW BEST
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  266: Train: 0.012680, LR: 7.23e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  267: Train: 0.014497, LR: 7.21e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  268: Train: 0.013082, LR: 7.20e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  269: Train: 0.015102, LR: 7.19e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  270: Train: 0.015511, LR: 7.17e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  271: Train: 0.013921, LR: 7.16e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  272: Train: 0.012327, LR: 7.15e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  273: Train: 0.012825, LR: 7.13e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  274: Train: 0.013096, LR: 7.12e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  275: Train: 0.013868, LR: 7.11e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  276: Train: 0.013545, LR: 7.09e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  277: Train: 0.012415, LR: 7.08e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  278: Train: 0.012414, LR: 7.07e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  279: Train: 0.013197, LR: 7.06e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  280: Train: 0.014476, LR: 7.04e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  281: Train: 0.011879, LR: 7.03e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  282: Train: 0.013596, LR: 7.02e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  283: Train: 0.011614, LR: 7.01e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  284: Train: 0.011083, LR: 6.99e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  285: Train: 0.011899, LR: 6.98e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  286: Train: 0.013552, LR: 6.97e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  287: Train: 0.018291, LR: 6.96e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  288: Train: 0.021101, LR: 6.94e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  289: Train: 0.028389, LR: 6.93e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  290: Train: 0.028184, LR: 6.92e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  291: Train: 0.037596, LR: 6.91e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  292: Train: 0.038446, LR: 6.90e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  293: Train: 0.026406, LR: 6.88e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  294: Train: 0.022599, LR: 6.87e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  295: Train: 0.016499, LR: 6.86e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  296: Train: 0.014557, LR: 6.85e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  297: Train: 0.013766, LR: 6.84e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  298: Train: 0.016210, LR: 6.83e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  299: Train: 0.015710, LR: 6.82e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  300: Train: 0.013985, LR: 6.80e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  301: Train: 0.012690, LR: 6.79e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  302: Train: 0.013978, LR: 6.78e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  303: Train: 0.014074, LR: 6.77e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  304: Train: 0.015855, LR: 6.76e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  305: Train: 0.014884, LR: 6.75e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  306: Train: 0.012632, LR: 6.74e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  307: Train: 0.012451, LR: 6.73e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  308: Train: 0.011903, LR: 6.72e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  309: Train: 0.012455, LR: 6.70e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  310: Train: 0.011549, LR: 6.69e-03
#           Best: Train: 0.010711 (Epoch 265)
# Epoch  311: Train: 0.011053, LR: 6.68e-03
#           Best: Train: 0.010711 (Epoch 265)
#           Best model saved in memory at epoch 312
#           Best model saved to BMED_TF_250930.pth
# Epoch  312: Train: 0.010625, LR: 6.67e-03 ★ NEW BEST
#           Best: Train: 0.010625 (Epoch 312)
# Epoch  313: Train: 0.010804, LR: 6.66e-03
#           Best: Train: 0.010625 (Epoch 312)
#           Best model saved in memory at epoch 314
#           Best model saved to BMED_TF_250930.pth
# Epoch  314: Train: 0.010032, LR: 6.65e-03 ★ NEW BEST
#           Best: Train: 0.010032 (Epoch 314)
# Epoch  315: Train: 0.010773, LR: 6.64e-03
#           Best: Train: 0.010032 (Epoch 314)
# Epoch  316: Train: 0.010093, LR: 6.63e-03
#           Best: Train: 0.010032 (Epoch 314)
#           Best model saved in memory at epoch 317
#           Best model saved to BMED_TF_250930.pth
# Epoch  317: Train: 0.008889, LR: 6.62e-03 ★ NEW BEST
#           Best: Train: 0.008889 (Epoch 317)
# Epoch  318: Train: 0.010510, LR: 6.61e-03
#           Best: Train: 0.008889 (Epoch 317)
# Epoch  319: Train: 0.011805, LR: 6.60e-03
#           Best: Train: 0.008889 (Epoch 317)
# Epoch  320: Train: 0.012564, LR: 6.59e-03
#           Best: Train: 0.008889 (Epoch 317)
# Epoch  321: Train: 0.010220, LR: 6.58e-03
#           Best: Train: 0.008889 (Epoch 317)
# Epoch  322: Train: 0.010402, LR: 6.57e-03
#           Best: Train: 0.008889 (Epoch 317)
# Epoch  323: Train: 0.011805, LR: 6.56e-03
#           Best: Train: 0.008889 (Epoch 317)
# Epoch  324: Train: 0.012211, LR: 6.55e-03
#           Best: Train: 0.008889 (Epoch 317)
# Epoch  325: Train: 0.012572, LR: 6.54e-03
#           Best: Train: 0.008889 (Epoch 317)
# Epoch  326: Train: 0.011176, LR: 6.53e-03
#           Best: Train: 0.008889 (Epoch 317)
# Epoch  327: Train: 0.009977, LR: 6.52e-03
#           Best: Train: 0.008889 (Epoch 317)
# Epoch  328: Train: 0.010004, LR: 6.51e-03
#           Best: Train: 0.008889 (Epoch 317)
# Epoch  329: Train: 0.008944, LR: 6.50e-03
#           Best: Train: 0.008889 (Epoch 317)
# Epoch  330: Train: 0.009779, LR: 6.49e-03
#           Best: Train: 0.008889 (Epoch 317)
# Epoch  331: Train: 0.009550, LR: 6.48e-03
#           Best: Train: 0.008889 (Epoch 317)
#           Best model saved in memory at epoch 332
#           Best model saved to BMED_TF_250930.pth
# Epoch  332: Train: 0.008873, LR: 6.47e-03 ★ NEW BEST
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  333: Train: 0.009224, LR: 6.46e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  334: Train: 0.011034, LR: 6.45e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  335: Train: 0.010325, LR: 6.44e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  336: Train: 0.011649, LR: 6.43e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  337: Train: 0.013814, LR: 6.42e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  338: Train: 0.013645, LR: 6.41e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  339: Train: 0.014014, LR: 6.40e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  340: Train: 0.013931, LR: 6.39e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  341: Train: 0.015927, LR: 6.38e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  342: Train: 0.013956, LR: 6.37e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  343: Train: 0.011438, LR: 6.36e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  344: Train: 0.013293, LR: 6.35e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  345: Train: 0.011724, LR: 6.34e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  346: Train: 0.012131, LR: 6.34e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  347: Train: 0.010921, LR: 6.33e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  348: Train: 0.010234, LR: 6.32e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  349: Train: 0.009251, LR: 6.31e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  350: Train: 0.010823, LR: 6.30e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  351: Train: 0.010743, LR: 6.29e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  352: Train: 0.010001, LR: 6.28e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  353: Train: 0.011229, LR: 6.27e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  354: Train: 0.010112, LR: 6.26e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  355: Train: 0.010758, LR: 6.25e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  356: Train: 0.011042, LR: 6.25e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  357: Train: 0.009576, LR: 6.24e-03
#           Best: Train: 0.008873 (Epoch 332)
# Epoch  358: Train: 0.009647, LR: 6.23e-03
#           Best: Train: 0.008873 (Epoch 332)
#           Best model saved in memory at epoch 359
#           Best model saved to BMED_TF_250930.pth
# Epoch  359: Train: 0.008606, LR: 6.22e-03 ★ NEW BEST
#           Best: Train: 0.008606 (Epoch 359)
#           Best model saved in memory at epoch 360
#           Best model saved to BMED_TF_250930.pth
# Epoch  360: Train: 0.008038, LR: 6.21e-03 ★ NEW BEST
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  361: Train: 0.010257, LR: 6.20e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  362: Train: 0.011082, LR: 6.19e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  363: Train: 0.011444, LR: 6.19e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  364: Train: 0.010464, LR: 6.18e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  365: Train: 0.010425, LR: 6.17e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  366: Train: 0.011100, LR: 6.16e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  367: Train: 0.012841, LR: 6.15e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  368: Train: 0.013344, LR: 6.14e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  369: Train: 0.013862, LR: 6.14e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  370: Train: 0.015256, LR: 6.13e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  371: Train: 0.012328, LR: 6.12e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  372: Train: 0.012181, LR: 6.11e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  373: Train: 0.010752, LR: 6.10e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  374: Train: 0.008345, LR: 6.09e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  375: Train: 0.009055, LR: 6.09e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  376: Train: 0.008962, LR: 6.08e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  377: Train: 0.008551, LR: 6.07e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  378: Train: 0.008805, LR: 6.06e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  379: Train: 0.010001, LR: 6.05e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  380: Train: 0.010958, LR: 6.05e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  381: Train: 0.009567, LR: 6.04e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  382: Train: 0.010862, LR: 6.03e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  383: Train: 0.013154, LR: 6.02e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  384: Train: 0.016215, LR: 6.01e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  385: Train: 0.016721, LR: 6.01e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  386: Train: 0.018189, LR: 6.00e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  387: Train: 0.022702, LR: 5.99e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  388: Train: 0.027610, LR: 5.98e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  389: Train: 0.016909, LR: 5.98e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  390: Train: 0.014726, LR: 5.97e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  391: Train: 0.016269, LR: 5.96e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  392: Train: 0.015109, LR: 5.95e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  393: Train: 0.013572, LR: 5.94e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  394: Train: 0.009060, LR: 5.94e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  395: Train: 0.008916, LR: 5.93e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  396: Train: 0.008614, LR: 5.92e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  397: Train: 0.009868, LR: 5.91e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  398: Train: 0.009992, LR: 5.91e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  399: Train: 0.009091, LR: 5.90e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  400: Train: 0.009159, LR: 5.89e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  401: Train: 0.008439, LR: 5.89e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  402: Train: 0.008858, LR: 5.88e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  403: Train: 0.009256, LR: 5.87e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  404: Train: 0.009266, LR: 5.86e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  405: Train: 0.010670, LR: 5.86e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  406: Train: 0.008831, LR: 5.85e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  407: Train: 0.008925, LR: 5.84e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  408: Train: 0.008447, LR: 5.83e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  409: Train: 0.009380, LR: 5.83e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  410: Train: 0.008374, LR: 5.82e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  411: Train: 0.008575, LR: 5.81e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  412: Train: 0.009610, LR: 5.81e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  413: Train: 0.011161, LR: 5.80e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  414: Train: 0.010863, LR: 5.79e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  415: Train: 0.014675, LR: 5.79e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  416: Train: 0.014819, LR: 5.78e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  417: Train: 0.018772, LR: 5.77e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  418: Train: 0.017798, LR: 5.76e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  419: Train: 0.020366, LR: 5.76e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  420: Train: 0.017073, LR: 5.75e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  421: Train: 0.016033, LR: 5.74e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  422: Train: 0.013006, LR: 5.74e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  423: Train: 0.009729, LR: 5.73e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  424: Train: 0.011214, LR: 5.72e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  425: Train: 0.013025, LR: 5.72e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  426: Train: 0.011357, LR: 5.71e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  427: Train: 0.009836, LR: 5.70e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  428: Train: 0.010625, LR: 5.70e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  429: Train: 0.011229, LR: 5.69e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  430: Train: 0.012003, LR: 5.68e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  431: Train: 0.012337, LR: 5.68e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  432: Train: 0.009814, LR: 5.67e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  433: Train: 0.012202, LR: 5.66e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  434: Train: 0.011395, LR: 5.66e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  435: Train: 0.010051, LR: 5.65e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  436: Train: 0.008314, LR: 5.64e-03
#           Best: Train: 0.008038 (Epoch 360)
# Epoch  437: Train: 0.009554, LR: 5.64e-03
#           Best: Train: 0.008038 (Epoch 360)
#           Best model saved in memory at epoch 438
#           Best model saved to BMED_TF_250930.pth
# Epoch  438: Train: 0.007672, LR: 5.63e-03 ★ NEW BEST
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  439: Train: 0.009086, LR: 5.62e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  440: Train: 0.009113, LR: 5.62e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  441: Train: 0.009142, LR: 5.61e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  442: Train: 0.008878, LR: 5.61e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  443: Train: 0.007753, LR: 5.60e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  444: Train: 0.008807, LR: 5.59e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  445: Train: 0.008667, LR: 5.59e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  446: Train: 0.008580, LR: 5.58e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  447: Train: 0.008768, LR: 5.57e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  448: Train: 0.007951, LR: 5.57e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  449: Train: 0.008354, LR: 5.56e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  450: Train: 0.008255, LR: 5.56e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  451: Train: 0.009492, LR: 5.55e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  452: Train: 0.009378, LR: 5.54e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  453: Train: 0.009458, LR: 5.54e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  454: Train: 0.010253, LR: 5.53e-03
#           Best: Train: 0.007672 (Epoch 438)
# Epoch  455: Train: 0.010011, LR: 5.52e-03
#           Best: Train: 0.007672 (Epoch 438)
# ...
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1824: Train: 0.004274, LR: 2.76e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1825: Train: 0.004309, LR: 2.76e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1826: Train: 0.004384, LR: 2.76e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1827: Train: 0.004508, LR: 2.76e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1828: Train: 0.004267, LR: 2.76e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1829: Train: 0.004906, LR: 2.76e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1830: Train: 0.004722, LR: 2.75e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1831: Train: 0.004697, LR: 2.75e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1832: Train: 0.005152, LR: 2.75e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1833: Train: 0.004498, LR: 2.75e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1834: Train: 0.004641, LR: 2.75e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1835: Train: 0.005355, LR: 2.75e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1836: Train: 0.004877, LR: 2.75e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1837: Train: 0.004942, LR: 2.75e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1838: Train: 0.004965, LR: 2.75e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1839: Train: 0.005170, LR: 2.75e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1840: Train: 0.003903, LR: 2.75e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1841: Train: 0.005178, LR: 2.75e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1842: Train: 0.004313, LR: 2.75e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1843: Train: 0.004816, LR: 2.75e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1844: Train: 0.003914, LR: 2.74e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1845: Train: 0.004446, LR: 2.74e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1846: Train: 0.004637, LR: 2.74e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1847: Train: 0.005027, LR: 2.74e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1848: Train: 0.004399, LR: 2.74e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1849: Train: 0.004796, LR: 2.74e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1850: Train: 0.004122, LR: 2.74e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1851: Train: 0.005154, LR: 2.74e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1852: Train: 0.004539, LR: 2.74e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1853: Train: 0.004205, LR: 2.74e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1854: Train: 0.004454, LR: 2.74e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1855: Train: 0.003995, LR: 2.74e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1856: Train: 0.005353, LR: 2.74e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1857: Train: 0.005901, LR: 2.73e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1858: Train: 0.006844, LR: 2.73e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1859: Train: 0.007250, LR: 2.73e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1860: Train: 0.006527, LR: 2.73e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1861: Train: 0.005530, LR: 2.73e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1862: Train: 0.005127, LR: 2.73e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1863: Train: 0.004509, LR: 2.73e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1864: Train: 0.005541, LR: 2.73e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1865: Train: 0.005312, LR: 2.73e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1866: Train: 0.004872, LR: 2.73e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1867: Train: 0.005283, LR: 2.73e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1868: Train: 0.005376, LR: 2.73e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1869: Train: 0.005251, LR: 2.73e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1870: Train: 0.004343, LR: 2.73e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1871: Train: 0.004864, LR: 2.72e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1872: Train: 0.006550, LR: 2.72e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1873: Train: 0.005441, LR: 2.72e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1874: Train: 0.005823, LR: 2.72e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1875: Train: 0.006421, LR: 2.72e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1876: Train: 0.005556, LR: 2.72e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1877: Train: 0.006062, LR: 2.72e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1878: Train: 0.004772, LR: 2.72e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1879: Train: 0.005498, LR: 2.72e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1880: Train: 0.005603, LR: 2.72e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1881: Train: 0.004655, LR: 2.72e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1882: Train: 0.004312, LR: 2.72e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1883: Train: 0.005677, LR: 2.72e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1884: Train: 0.004558, LR: 2.72e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1885: Train: 0.004729, LR: 2.71e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1886: Train: 0.005224, LR: 2.71e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1887: Train: 0.005513, LR: 2.71e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1888: Train: 0.004931, LR: 2.71e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1889: Train: 0.005949, LR: 2.71e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1890: Train: 0.004925, LR: 2.71e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1891: Train: 0.004870, LR: 2.71e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1892: Train: 0.004586, LR: 2.71e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1893: Train: 0.004640, LR: 2.71e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1894: Train: 0.004368, LR: 2.71e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1895: Train: 0.003957, LR: 2.71e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1896: Train: 0.004311, LR: 2.71e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1897: Train: 0.005692, LR: 2.71e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1898: Train: 0.005993, LR: 2.71e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1899: Train: 0.006067, LR: 2.70e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1900: Train: 0.006471, LR: 2.70e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1901: Train: 0.005568, LR: 2.70e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1902: Train: 0.005957, LR: 2.70e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1903: Train: 0.005527, LR: 2.70e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1904: Train: 0.005950, LR: 2.70e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1905: Train: 0.005781, LR: 2.70e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1906: Train: 0.004892, LR: 2.70e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1907: Train: 0.004894, LR: 2.70e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1908: Train: 0.004359, LR: 2.70e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1909: Train: 0.004657, LR: 2.70e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1910: Train: 0.004738, LR: 2.70e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1911: Train: 0.004659, LR: 2.70e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1912: Train: 0.004260, LR: 2.70e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1913: Train: 0.004261, LR: 2.69e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1914: Train: 0.005366, LR: 2.69e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1915: Train: 0.004920, LR: 2.69e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1916: Train: 0.004311, LR: 2.69e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1917: Train: 0.004103, LR: 2.69e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1918: Train: 0.004677, LR: 2.69e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1919: Train: 0.003767, LR: 2.69e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1920: Train: 0.003853, LR: 2.69e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1921: Train: 0.003707, LR: 2.69e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1922: Train: 0.003985, LR: 2.69e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1923: Train: 0.004396, LR: 2.69e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1924: Train: 0.004684, LR: 2.69e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1925: Train: 0.004294, LR: 2.69e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1926: Train: 0.004068, LR: 2.69e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1927: Train: 0.004817, LR: 2.68e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1928: Train: 0.004383, LR: 2.68e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1929: Train: 0.004682, LR: 2.68e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1930: Train: 0.003912, LR: 2.68e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1931: Train: 0.005066, LR: 2.68e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1932: Train: 0.004803, LR: 2.68e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1933: Train: 0.005050, LR: 2.68e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1934: Train: 0.005081, LR: 2.68e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1935: Train: 0.005977, LR: 2.68e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1936: Train: 0.005294, LR: 2.68e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1937: Train: 0.005100, LR: 2.68e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1938: Train: 0.005000, LR: 2.68e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1939: Train: 0.004860, LR: 2.68e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1940: Train: 0.005066, LR: 2.68e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1941: Train: 0.004675, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1942: Train: 0.004856, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1943: Train: 0.004170, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1944: Train: 0.004485, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1945: Train: 0.004063, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1946: Train: 0.004384, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1947: Train: 0.004330, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1948: Train: 0.004588, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1949: Train: 0.004342, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1950: Train: 0.004314, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1951: Train: 0.003916, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1952: Train: 0.004856, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1953: Train: 0.005463, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1954: Train: 0.004590, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1955: Train: 0.004776, LR: 2.67e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1956: Train: 0.004436, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1957: Train: 0.004118, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1958: Train: 0.004583, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1959: Train: 0.004195, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1960: Train: 0.004506, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1961: Train: 0.004423, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1962: Train: 0.004428, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1963: Train: 0.004119, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1964: Train: 0.004691, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1965: Train: 0.004935, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1966: Train: 0.004758, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1967: Train: 0.004032, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1968: Train: 0.004558, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1969: Train: 0.004319, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1970: Train: 0.004198, LR: 2.66e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1971: Train: 0.004298, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1972: Train: 0.004780, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1973: Train: 0.004521, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1974: Train: 0.004284, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1975: Train: 0.004398, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1976: Train: 0.004541, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1977: Train: 0.004159, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1978: Train: 0.005757, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1979: Train: 0.005173, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1980: Train: 0.005501, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1981: Train: 0.005092, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1982: Train: 0.005879, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1983: Train: 0.005645, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1984: Train: 0.005781, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1985: Train: 0.004901, LR: 2.65e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1986: Train: 0.005074, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1987: Train: 0.004579, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1988: Train: 0.004475, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1989: Train: 0.004751, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1990: Train: 0.005707, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1991: Train: 0.005305, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1992: Train: 0.007167, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1993: Train: 0.005422, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1994: Train: 0.005878, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1995: Train: 0.004598, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1996: Train: 0.003901, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1997: Train: 0.004093, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1998: Train: 0.003966, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 1999: Train: 0.003962, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
# Epoch 2000: Train: 0.003898, LR: 2.64e-03
#           Best: Train: 0.003650 (Epoch 1807)
#
# Training completed!
# ============================================================
# Best Performance (Epoch 1807):
#   Best Train Loss:  0.003650
# ============================================================
# Final Performance (Epoch 2000):
#   Final Train Loss: 0.003898
#   Final LR:         2.64e-03
# ============================================================
# Warmup completed at epoch 200 with peak LR: 8.33e-03
#
# ✅ Best model (Epoch 1807) successfully saved in memory!
#    Best model loss: 0.003650
#    Best model also saved to file: BMED_TF_250930.pth

# %%
# 전체 실험 데이터에 대한 종합적인 시각화 - 8개 feature별 개별 플롯 (수정됨)
# 각 플롯은 모든 실험을 서브플롯으로 표시

def denormalize_data(normalized_data, feature_name):
    """정규화된 데이터를 원래 단위로 복원"""
    if feature_name in range_mm:
        min_val = range_mm[feature_name]['min']
        max_val = range_mm[feature_name]['max']
        return normalized_data * (max_val - min_val) + min_val
    return normalized_data

print("🚀 전체 실험 데이터 comprehensive evaluation 시작...")

# Device 및 모델 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
evaluation_model = best_model if best_model is not None else model

# feature 정보 재정의
feature_names = ['VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']
feature_indices = [2, 3, 4, 5, 6, 7, 8, 9]
feature_units = ['L', 'L', 'L', 'mol/L', 'mol/L', 'mol/L', 'mol/L', 'A']
feature_titles = ['Feed Volume', 'Acid Volume', 'Base Volume', 'Feed LA Conc.', 'Acid LA Conc.', 'Feed K Conc.', 'Base K Conc.', 'Current']

# 전체 실험 데이터 수집
all_experiment_results = {}
available_exp_nums = sorted(ndf['exp'].unique())
total_experiments = len(available_exp_nums)

print(f"📋 전체 {total_experiments}개 실험 데이터 수집 중...")
print(f"🔧 데이터로더 배치 크기: {dataloader.batch_size}")
print(f"🔧 총 배치 개수: {len(dataloader)}")

evaluation_model.eval()
with torch.no_grad():
    experiment_counter = 0
    
    for batch_idx, (input_seq, seq_lengths) in enumerate(dataloader):
        try:
            batch_size = input_seq.size(0)
            print(f"📦 배치 {batch_idx}: {batch_size}개 실험 처리 중...")
            
            input_seq = input_seq.to(device)
            seq_lengths = seq_lengths.to(device)
            
            # Teacher forcing 데이터 준비
            inputs, targets, target_seq_lengths = tf_data(input_seq, seq_lengths)
            
            # 모델 예측
            predictions = evaluation_model(inputs, target_seq_lengths)
            
            # CPU로 이동
            predictions_cpu = predictions.cpu().numpy()
            targets_cpu = targets.cpu().numpy()
            input_seq_cpu = input_seq.cpu().numpy()
            
            # 배치 내 모든 샘플 처리
            for sample_idx in range(batch_size):
                if experiment_counter >= total_experiments:
                    break
                    
                # 현재 실험 번호
                actual_exp_num = available_exp_nums[experiment_counter]
                
                # 샘플 데이터 추출
                pred_sample = predictions_cpu[sample_idx]
                actual_sample = targets_cpu[sample_idx]
                initial_sample = input_seq_cpu[sample_idx]
                seq_len = target_seq_lengths[sample_idx].item()
                full_seq_len = seq_lengths[sample_idx].item()
                
                # 실제 시퀀스 길이만큼만 사용
                pred_sample = pred_sample[:seq_len]
                actual_sample = actual_sample[:seq_len]
                initial_sample = initial_sample[:full_seq_len]
                
                # 시간 축 생성
                time_points = np.arange(full_seq_len) * 0.25
                
                # 예측값을 초기값과 연결
                prediction_full = np.zeros((full_seq_len, 10))
                prediction_full[0] = initial_sample[0]
                prediction_full[1:seq_len+1] = pred_sample
                
                # 실험 조건 정보
                voltage = denormalize_data(initial_sample[0, 0], 'V')
                electrolyte = denormalize_data(initial_sample[0, 1], 'E')
                
                # 결과 저장
                all_experiment_results[actual_exp_num] = {
                    'time_points': time_points,
                    'actual_data': initial_sample,
                    'predicted_data': prediction_full,
                    'seq_len': seq_len,
                    'full_seq_len': full_seq_len,
                    'voltage': voltage,
                    'electrolyte': electrolyte,
                    'actual_sample': actual_sample,
                    'pred_sample': pred_sample
                }
                
                print(f"✅ 실험 {actual_exp_num}: {full_seq_len*0.25:.1f}h, {voltage:.1f}V, {electrolyte:.3f}M")
                experiment_counter += 1
            
        except Exception as e:
            print(f"❌ 배치 {batch_idx} 오류: {str(e)}")
            import traceback
            traceback.print_exc()
            continue

print(f"📊 총 {len(all_experiment_results)}개 실험 데이터 수집 완료!")

# 서브플롯 배치 계산
import math
sqrt_exp = math.ceil(math.sqrt(total_experiments))
if sqrt_exp * (sqrt_exp - 1) >= total_experiments:
    grid_rows, grid_cols = sqrt_exp - 1, sqrt_exp
else:
    grid_rows, grid_cols = sqrt_exp, sqrt_exp

print(f"📐 각 feature당 {grid_rows}x{grid_cols} 서브플롯 그리드 사용")

# 8개 feature별로 개별 figure 생성
for feature_idx, (feature_name, feature_index, unit, title) in enumerate(zip(feature_names, feature_indices, feature_units, feature_titles)):
    print(f"🎨 Feature {feature_idx+1}/8: {feature_name} ({title}) 생성 중...")
    
    # 새 figure 생성
    fig, axes = plt.subplots(grid_rows, grid_cols, figsize=(4*grid_cols, 3*grid_rows))
    if best_model is not None:
        suptitle = f'{title} ({feature_name}) - All Experiments\nBest Model (Epoch {best_epoch}, Loss: {best_train_loss:.6f})'
    else:
        suptitle = f'{title} ({feature_name}) - All Experiments\nCurrent Model'
    fig.suptitle(suptitle, fontsize=16, fontweight='bold')
    
    # axes 처리 (1차원으로 변환)
    if grid_rows * grid_cols == 1:
        axes = [axes]
    else:
        axes = axes.flatten() if hasattr(axes, 'flatten') else [axes]
    
    # 성능 지표 수집
    rmse_values = []
    r2_values = []
    
    # 각 실험별 subplot
    for plot_idx, exp_num in enumerate(sorted(all_experiment_results.keys())):
        if plot_idx >= len(axes):
            break
            
        ax = axes[plot_idx]
        exp_data = all_experiment_results[exp_num]
        
        # 데이터 denormalize
        actual_denorm = denormalize_data(exp_data['actual_data'][:, feature_index], feature_name)
        pred_denorm = denormalize_data(exp_data['predicted_data'][:exp_data['seq_len']+1, feature_index], feature_name)
        
        # 플롯 생성
        ax.plot(exp_data['time_points'], actual_denorm, 'b-', linewidth=1.5, label='Actual', alpha=0.8)
        ax.plot(exp_data['time_points'][:exp_data['seq_len']+1], pred_denorm, 'r--', linewidth=1.5, label='Predicted', alpha=0.8)
        
        # 시작점 표시
        ax.plot(exp_data['time_points'][0], actual_denorm[0], 'go', markersize=3)
        ax.axvline(x=exp_data['time_points'][1], color='gray', linestyle=':', alpha=0.5)
        
        # 성능 지표 계산
        actual_pred_denorm = denormalize_data(exp_data['actual_sample'][:, feature_index], feature_name)
        pred_pred_denorm = denormalize_data(exp_data['pred_sample'][:, feature_index], feature_name)
        
        rmse = np.sqrt(np.mean((actual_pred_denorm - pred_pred_denorm)**2))
        if np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2) > 0:
            r2 = 1 - (np.sum((actual_pred_denorm - pred_pred_denorm)**2) / np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2))
        else:
            r2 = 0.0
            
        rmse_values.append(rmse)
        r2_values.append(r2)
        
        # 서브플롯 설정
        condition_text = f'{exp_data["voltage"]:.1f}V, {exp_data["electrolyte"]:.2f}M'
        ax.set_title(f'Exp {exp_num}: {condition_text}\nRMSE: {rmse:.3f} {unit}', fontsize=9)
        ax.set_xlabel('Time (hours)', fontsize=8)
        ax.set_ylabel(f'{feature_name} ({unit})', fontsize=8)
        ax.grid(True, alpha=0.3)
        ax.tick_params(labelsize=7)
        
        # 첫 번째 subplot에만 범례 추가
        if plot_idx == 0:
            ax.legend(fontsize=8, loc='upper right')
    
    # 빈 subplot 숨기기
    for plot_idx in range(len(all_experiment_results), len(axes)):
        axes[plot_idx].set_visible(False)
    
    # 전체 성능 요약
    avg_rmse = np.mean(rmse_values)
    std_rmse = np.std(rmse_values)
    avg_r2 = np.mean(r2_values)
    std_r2 = np.std(r2_values)
    
    # 성능 요약 텍스트 박스
    summary_text = f'Overall Performance:\nRMSE: {avg_rmse:.4f} ± {std_rmse:.4f} {unit}\nR²: {avg_r2:.3f} ± {std_r2:.3f}\nExperiments: {len(rmse_values)}'
    fig.text(0.02, 0.02, summary_text, fontsize=10, 
             bbox=dict(boxstyle='round,pad=0.5', facecolor='lightblue', alpha=0.8))
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.92, bottom=0.12, left=0.05, right=0.98)
    plt.show()
    
    print(f"✅ {feature_name} 완료: 평균 RMSE = {avg_rmse:.4f} {unit}, 평균 R² = {avg_r2:.3f}")

# 전체 요약 출력
print("\n" + "="*80)
print("COMPREHENSIVE EVALUATION SUMMARY - ALL EXPERIMENTS")
print("="*80)

for feature_idx, (feature_name, feature_index, unit) in enumerate(zip(feature_names, feature_indices, feature_units)):
    # 각 feature별 전체 성능 통계
    all_rmse = []
    all_mae = []
    all_r2 = []
    
    for exp_num in sorted(all_experiment_results.keys()):
        exp_data = all_experiment_results[exp_num]
        
        actual_pred_denorm = denormalize_data(exp_data['actual_sample'][:, feature_index], feature_name)
        pred_pred_denorm = denormalize_data(exp_data['pred_sample'][:, feature_index], feature_name)
        
        rmse = np.sqrt(np.mean((actual_pred_denorm - pred_pred_denorm)**2))
        mae = np.mean(np.abs(actual_pred_denorm - pred_pred_denorm))
        
        if np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2) > 0:
            r2 = 1 - (np.sum((actual_pred_denorm - pred_pred_denorm)**2) / np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2))
        else:
            r2 = 0.0
        
        all_rmse.append(rmse)
        all_mae.append(mae)
        all_r2.append(r2)
    
    print(f"{feature_name:6s}: RMSE={np.mean(all_rmse):.4f}±{np.std(all_rmse):.4f} {unit}, "
          f"MAE={np.mean(all_mae):.4f}±{np.std(all_mae):.4f} {unit}, "
          f"R²={np.mean(all_r2):.3f}±{np.std(all_r2):.3f}")

print("-"*80)
print(f"📊 Total experiments analyzed: {len(all_experiment_results)}")
if best_model is not None:
    print(f"🏆 Best model used: Epoch {best_epoch}, Loss: {best_train_loss:.6f}")
else:
    print("📋 Current model used")
print("="*80)

print("🎉 Comprehensive evaluation 완료! 8개의 feature별 플롯이 모든 실험 데이터를 포함하여 생성되었습니다.")
# Out:
# 🚀 전체 실험 데이터 comprehensive evaluation 시작...
# 📋 전체 15개 실험 데이터 수집 중...
# 🔧 데이터로더 배치 크기: 3
# 🔧 총 배치 개수: 5
# 📦 배치 0: 3개 실험 처리 중...
# ✅ 실험 0: 4.2h, 20.0V, 0.250M
# ✅ 실험 1: 5.2h, 30.0V, 0.250M
# ✅ 실험 2: 5.2h, 30.0V, 0.250M
# 📦 배치 1: 3개 실험 처리 중...
# ✅ 실험 3: 5.2h, 30.0V, 0.250M
# ✅ 실험 4: 7.2h, 20.0V, 0.250M
# ✅ 실험 5: 9.2h, 20.0V, 0.250M
# 📦 배치 2: 3개 실험 처리 중...
# ✅ 실험 6: 4.2h, 10.0V, 0.250M
# ✅ 실험 7: 7.2h, 10.0V, 0.250M
# ✅ 실험 8: 8.2h, 30.0V, 0.250M
# 📦 배치 3: 3개 실험 처리 중...
# ✅ 실험 9: 5.2h, 30.0V, 0.250M
# ✅ 실험 10: 6.2h, 30.0V, 0.250M
# ✅ 실험 11: 6.2h, 35.0V, 0.500M
# 📦 배치 4: 3개 실험 처리 중...
# ✅ 실험 12: 5.2h, 35.0V, 0.250M
# ✅ 실험 13: 5.2h, 35.0V, 1.000M
# ✅ 실험 14: 4.8h, 30.0V, 0.250M
# 📊 총 15개 실험 데이터 수집 완료!
# 📐 각 feature당 4x4 서브플롯 그리드 사용
# 🎨 Feature 1/8: VF (Feed Volume) 생성 중...
# ✅ VF 완료: 평균 RMSE = 0.0083 L, 평균 R² = 0.984
# 🎨 Feature 2/8: VA (Acid Volume) 생성 중...
# ✅ VA 완료: 평균 RMSE = 0.0048 L, 평균 R² = 0.975
# 🎨 Feature 3/8: VB (Base Volume) 생성 중...
# ✅ VB 완료: 평균 RMSE = 0.0063 L, 평균 R² = 0.973
# 🎨 Feature 4/8: CFLA (Feed LA Conc.) 생성 중...
# ✅ CFLA 완료: 평균 RMSE = 0.0204 mol/L, 평균 R² = 0.990
# 🎨 Feature 5/8: CALA (Acid LA Conc.) 생성 중...
# ✅ CALA 완료: 평균 RMSE = 0.0126 mol/L, 평균 R² = 0.925
# 🎨 Feature 6/8: CFK (Feed K Conc.) 생성 중...
# ✅ CFK 완료: 평균 RMSE = 0.0273 mol/L, 평균 R² = 0.996
# 🎨 Feature 7/8: CBK (Base K Conc.) 생성 중...
# ✅ CBK 완료: 평균 RMSE = 0.0136 mol/L, 평균 R² = 0.993
# 🎨 Feature 8/8: I (Current) 생성 중...
# ✅ I 완료: 평균 RMSE = 0.0483 A, 평균 R² = 0.929
#
# ================================================================================
# COMPREHENSIVE EVALUATION SUMMARY - ALL EXPERIMENTS
# ================================================================================
# VF    : RMSE=0.0083±0.0033 L, MAE=0.0065±0.0025 L, R²=0.984±0.022
# VA    : RMSE=0.0048±0.0024 L, MAE=0.0036±0.0018 L, R²=0.975±0.049
# VB    : RMSE=0.0063±0.0026 L, MAE=0.0050±0.0021 L, R²=0.973±0.026
# CFLA  : RMSE=0.0204±0.0112 mol/L, MAE=0.0151±0.0069 mol/L, R²=0.990±0.010
# CALA  : RMSE=0.0126±0.0075 mol/L, MAE=0.0096±0.0048 mol/L, R²=0.925±0.245
# CFK   : RMSE=0.0273±0.0092 mol/L, MAE=0.0212±0.0080 mol/L, R²=0.996±0.004
# CBK   : RMSE=0.0136±0.0073 mol/L, MAE=0.0106±0.0061 mol/L, R²=0.993±0.017
# I     : RMSE=0.0483±0.0165 A, MAE=0.0383±0.0141 A, R²=0.929±0.145
# --------------------------------------------------------------------------------
# 📊 Total experiments analyzed: 15
# 🏆 Best model used: Epoch 1807, Loss: 0.003650
# ================================================================================
# 🎉 Comprehensive evaluation 완료! 8개의 feature별 플롯이 모든 실험 데이터를 포함하여 생성되었습니다.
