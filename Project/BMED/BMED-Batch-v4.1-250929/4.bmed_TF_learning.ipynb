# %%
import pandas as pd
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# %%
def df_treat(name):
    df = pd.read_csv(name)
    ndf = pd.DataFrame()
    range_mm={
        'V': {'min':df['V'].min()*0.8, 'max': df['V'].max()*1.2},
        'E': {'min':df['E'].min()*0.8, 'max': df['E'].max()*1.2},
        'VF': {'min':df['VF'].min()*0.8, 'max': df['VF'].max()*1.2},
        'VA': {'min':df['VA'].min()*0.8, 'max': df['VA'].max()*1.2},
        'VB': {'min':df['VB'].min()*0.8, 'max': df['VB'].max()*1.2},
        'CFLA': {'min':0, 'max': df['CFLA'].max()*1.2},
        'CALA': {'min':0, 'max': df['CALA'].max()*1.2},
        'CFK': {'min':0, 'max': df['CFK'].max()*1.2},
        'CBK': {'min':0, 'max': df['CBK'].max()*1.2},
        'I': {'min':0, 'max': df['I'].max()*1.2},
    }
    ndf['exp'] = df['exp']; ndf['t'] = df['t']

    for col in ['V', 'E', 'VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']:
        if col in range_mm:
            ndf[col] = (df[col] - range_mm[col]['min'])/(range_mm[col]['max'] - range_mm[col]['min'])
        else:
            ndf[col] = df[col]

    exp_num_list = sorted(ndf['exp'].unique())

    return df, ndf, range_mm, exp_num_list

# %%
def seq_data(ndf, exp_num_list):
    seq = []
    feature_cols = ['V', 'E', 'VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']
    
    for exp in exp_num_list:
        exp_df = ndf[ndf['exp'] == exp]
        seq.append(exp_df[feature_cols].values)
    
    return seq

# %%
def pad_seq(seq):
    max_len = max([len(s) for s in seq])
    seq_len = [len(s) for s in seq]
    pad_seq = pad_sequence([torch.tensor(s) for s in seq], batch_first=True, padding_value=-1)

    return pad_seq, seq_len, max_len

# %%
def gen_dataset(pad_seq, seq_len):
    input_tensor = pad_seq.float()
    seq_len_tensor = torch.tensor(seq_len)
    dataset = TensorDataset(input_tensor, seq_len_tensor)
    return dataset

# %%
# LSTM with layer normalization
class LayerNormLSTM(nn.Module):
    def __init__(self, input_node, hidden_node):
        super().__init__()
        self.input_node = input_node
        self.hidden_node = hidden_node

        self.w_x = nn.Linear(input_node, 4*hidden_node, bias=False)
        self.w_h = nn.Linear(hidden_node, 4*hidden_node, bias=False)
        self.ln = nn.LayerNorm(4 * hidden_node)
        self.ln_c = nn.LayerNorm(hidden_node)

    def forward(self, x, hx):
        h, c = hx

        gates = self.w_x(x) + self.w_h(h)
        gates = self.ln(gates)

        i, f, g, o = gates.chunk(4, dim=1)

        i = torch.sigmoid(i)
        f = torch.sigmoid(f)
        o = torch.sigmoid(o)
        g = torch.tanh(g)

        c_new = f * c + i * g
        c_new = self.ln_c(c_new)
        h_new = o * torch.tanh(c_new)

        return h_new, c_new

# %%
# State feature extractor using LayerNorm LSTM
class StateExtr(nn.Module):
    def __init__(self, input_node, hidden_node, n_layer, dropout):
        super().__init__()
        self.hidden_node = hidden_node
        self.n_layer = n_layer
        self.input_node = input_node

        self.lstm_cells = nn.ModuleList()
        self.lstm_cells.append(LayerNormLSTM(input_node, hidden_node))

        for i in range(n_layer - 1):
            self.lstm_cells.append(LayerNormLSTM(hidden_node, hidden_node))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x, seq_len):
        batch_size, max_len, _ = x.size()
        device = x.device

        h_states = []
        c_states = []

        for _ in range(self.n_layer):
            h_states.append(torch.zeros(batch_size, self.hidden_node, device=device))
            c_states.append(torch.zeros(batch_size, self.hidden_node, device=device))

        outputs = []
        for t in range(max_len):
            x_t = x[:, t, :]

            layer_input = x_t # initialize layer input with input tensor
            for layer_idx, lstm_cell in enumerate(self.lstm_cells):
                h_new, c_new = lstm_cell(layer_input, (h_states[layer_idx], c_states[layer_idx]))
                
                h_states[layer_idx] = h_new
                c_states[layer_idx] = c_new

                if layer_idx < len(self.lstm_cells) - 1:
                    layer_input = self.dropout(h_new)
                else:
                    layer_input = h_new

            outputs.append(layer_input)

        output_tensor = torch.stack(outputs, dim=1)
        seq_len_cpu = seq_len.detach().cpu().long()
        mask = torch.arange(max_len, device='cpu')[None, :] < seq_len_cpu[:, None]
        mask = mask.float().to(device).unsqueeze(-1)

        masked_output = output_tensor * mask
        return self.dropout(masked_output)

# %%
# Physical change regressor
class PhysRegr(nn.Module):
    def __init__(self, input_node, output_node, n_layer, hidden_node, dropout):
        super().__init__()

        layers = []

        layers.extend([
            nn.Linear(input_node, hidden_node),
            nn.ReLU(),
            nn.Dropout(dropout)
        ])

        for _ in range(n_layer - 1):
            layers.extend([
                nn.Linear(hidden_node, hidden_node),
                nn.ReLU(),
                nn.Dropout(dropout)
            ])
        
        layers.append(nn.Linear(hidden_node, output_node))
        layers.append(nn.Sigmoid())

        self.layers = nn.Sequential(*layers)

    def forward(self, hidden_states):
        return self.layers(hidden_states)

# %%
# Current regressor
class CurrRegr(nn.Module):
    def __init__(self, input_node, hidden_node, n_layer, dropout):
        super().__init__()

        layers = []

        layers.extend([
            nn.Linear(input_node, hidden_node),
            nn.ReLU(),
            nn.Dropout(dropout)
        ])

        for _ in range(n_layer - 1):
            layers.extend([
                nn.Linear(hidden_node, hidden_node),
                nn.ReLU(),
                nn.Dropout(dropout)
            ])
        
        layers.append(nn.Linear(hidden_node, 1))

        self.layers = nn.Sequential(*layers)

    def forward(self, hidden_states):
        return self.layers(hidden_states)

# %%
class PhysConstr(nn.Module):
    def __init__(self, range_mm, curr_regr, eps=1e-2):
        super().__init__()
        self.eps = eps
        self.curr_regr = curr_regr
        self.register_buffer('range_mm_tensor', self._range2tensor(range_mm))

    def _range2tensor(self, range_mm):
        feature_names = ['V','E','VF','VA','VB','CFLA','CALA','CFK','CBK','I']
        ranges = torch.zeros(len(feature_names),2)

        for i, name in enumerate(feature_names):
            if name in range_mm:
                ranges[i, 0] = range_mm[name]['min']
                ranges[i, 1] = range_mm[name]['max']
        
        return ranges
    
    def _norm_tensor(self, data, feature_idx):
        min_val = self.range_mm_tensor[feature_idx, 0]
        max_val = self.range_mm_tensor[feature_idx, 1]
        return (data - min_val) / (max_val - min_val)

    def _denorm_tensor(self, norm_data, feature_idx):
        min_val = self.range_mm_tensor[feature_idx, 0]
        max_val = self.range_mm_tensor[feature_idx, 1]
        return norm_data * (max_val - min_val) + min_val

    def forward(self, phys_chng, cur_state):
        V_idx, E_idx, VF_idx, VA_idx, VB_idx = 0, 1, 2, 3, 4
        CFLA_idx, CALA_idx, CFK_idx, CBK_idx, I_idx = 5, 6, 7, 8, 9

        VF = self._denorm_tensor(cur_state[..., 2:3], VF_idx)
        VA = self._denorm_tensor(cur_state[..., 3:4], VA_idx)
        VB = self._denorm_tensor(cur_state[..., 4:5], VB_idx)
        CFLA = self._denorm_tensor(cur_state[..., 5:6], CFLA_idx)
        CALA = self._denorm_tensor(cur_state[..., 6:7], CALA_idx)
        CFK = self._denorm_tensor(cur_state[..., 7:8], CFK_idx)
        CBK = self._denorm_tensor(cur_state[..., 8:9], CBK_idx)

        NFLA = CFLA * VF
        NALA = CALA * VA
        NFK = CFK * VF
        NBK = CBK * VB

        rdVA = phys_chng[..., 0:1]
        rdVB = phys_chng[..., 1:2]
        rdNALA = phys_chng[..., 2:3]
        rdNBK = phys_chng[..., 3:4]

        dVA = VF*(rdVA -0.5)
        dVB = VF*(rdVB - 0.5)
        dNBK = NFK*rdNBK
        dNALA = NFLA*rdNALA

        nVF = VF - dVA - dVB
        nVA = VA + dVA
        nVB = VB + dVB
        
        nNFLA = NFLA - dNALA
        nNALA = NALA + dNALA
        nNFK = NFK - dNBK
        nNBK = NBK + dNBK

        nCFLA = nNFLA / nVF
        nCALA = nNALA / nVA
        nCFK = nNFK / nVF
        nCBK = nNBK / nVB

        V = cur_state[..., 0:1]
        E = cur_state[..., 1:2]
        nVF_norm = self._norm_tensor(nVF, VF_idx)
        nVA_norm = self._norm_tensor(nVA, VA_idx)
        nVB_norm = self._norm_tensor(nVB, VB_idx)
        nCFLA_norm = self._norm_tensor(nCFLA, CFLA_idx)
        nCALA_norm = self._norm_tensor(nCALA, CALA_idx)
        nCFK_norm = self._norm_tensor(nCFK, CFK_idx)
        nCBK_norm = self._norm_tensor(nCBK, CBK_idx)

        # Create temporary state without I for current prediction
        temp_state = torch.cat([
            V, E, nVF_norm, nVA_norm, nVB_norm, nCFLA_norm, nCALA_norm, nCFK_norm, nCBK_norm
        ], dim=-1)
        
        # Predict new I using the current predictor
        nI_pred = self.curr_regr(temp_state)
        nI_real = self._denorm_tensor(nI_pred, I_idx)
        nI_real = torch.clamp(nI_real, min=0.0)
        nI_norm = self._norm_tensor(nI_real, I_idx)

        # Create final next state with predicted I
        next_state = torch.cat([
            V, E, nVF_norm, nVA_norm, nVB_norm, nCFLA_norm, nCALA_norm, nCFK_norm, nCBK_norm, nI_norm
        ], dim=-1)
        
        return next_state

# %%
class BMEDAutoregressiveModel(nn.Module):
    def __init__(self, state_extr_params, phys_regr_params, curr_regr_params, range_mm):
        super().__init__()
        self.state_extr = StateExtr(**state_extr_params)
        self.phys_regr = PhysRegr(**phys_regr_params)
        self.curr_regr = CurrRegr(**curr_regr_params)
        self.phys_constr = PhysConstr(range_mm, self.curr_regr)

    def forward(self, x, seq_len):
        hidden_states = self.state_extr(x, seq_len)
        phys_chng = self.phys_regr(hidden_states)
        new_x = self.phys_constr(phys_chng, x)
        
        return new_x

# %%
def masked_mse_loss(pred, target, seq_len):
    _, max_len, _ = pred.shape
    seq_len_cpu = seq_len.detach().cpu().long()

    mask = torch.arange(max_len, device='cpu')[None, :] < seq_len_cpu[:, None]
    mask = mask.float().to(pred.device)

    loss = F.mse_loss(pred, target, reduction='none')
    masked_loss = loss * mask.unsqueeze(-1)

    total_loss = masked_loss.sum()
    total_elements = mask.sum()

    masked_loss = total_loss / total_elements
    return masked_loss

# %%
def tf_data(input_seq, seq_len):
    inputs = input_seq[:, :-1, :-1]
    targets = input_seq[:, 1:, :]

    target_seq_len = seq_len - 1

    return inputs, targets, target_seq_len

# %%
class NoamScheduler:
    def __init__(self, optimizer, model_size, warmup_epochs, factor=1.0):
        self.optimizer = optimizer
        self.model_size = model_size
        self.warmup_epochs = warmup_epochs
        self.factor = factor
        self.epoch_num = 0

    def step_epoch(self):
        self.epoch_num += 1
        lr = self.factor * (
            self.model_size ** (-0.5) *
            min(self.epoch_num ** (-0.5), self.epoch_num * self.warmup_epochs ** (-1.5))
        )
    
        for param_group in self.optimizer.param_groups:
            param_group['lr'] = lr

        return lr

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
df, ndf, range_mm, exp_num_list = df_treat('BMED_DATA_AG.csv')
seq = seq_data(ndf, exp_num_list)
pad, seq_len, max_len = pad_seq(seq)
dataset = gen_dataset(pad, seq_len)
dataloader = DataLoader(dataset, batch_size=3, shuffle=False)

# %%
state_extr_params = {
    'input_node': 9,
    'hidden_node': 96,
    'n_layer': 4,
    'dropout': 0.2
}

phys_regr_params = {
    'input_node': state_extr_params['hidden_node'],
    'hidden_node': 32,
    'n_layer': 3,
    'dropout': 0.1,
    'output_node': 4
}

curr_regr_params = {
    'input_node': 9,
    'hidden_node': 96,
    'n_layer': 3,
    'dropout': 0.1
}

model = BMEDAutoregressiveModel(state_extr_params, phys_regr_params, curr_regr_params, range_mm)
model = model.to(device)
print(f"Model architecture:")
print(f"  Input features: {state_extr_params['input_node']} (without current)")
print(f"  State Extractor Hidden size: {state_extr_params['hidden_node']}")
print(f"  State Extractor layers: {state_extr_params['n_layer']}")
print(f"  Phys Regressor layers: {phys_regr_params['n_layer']}")
print(f"  Phys Regressor Hidden size: {phys_regr_params['hidden_node']}")
print(f"  Current Predictor layers: {curr_regr_params['n_layer']}")
print(f"  Current Predictor Hidden size: {curr_regr_params['hidden_node']}")
print(f"  Model parameters: {sum(p.numel() for p in model.parameters()):,}")
print(f"  Physics constraints: Volume conservation with denormalization")

num_epochs = 2000
optimizer = torch.optim.AdamW(model.parameters(), lr=1.0)
warmup_epochs = int(num_epochs * 0.1)
scheduler = NoamScheduler(optimizer, model_size=state_extr_params['hidden_node'], warmup_epochs=warmup_epochs, factor=1)

print(f"\nTraining configuration:")
print(f"  Total epochs: {num_epochs:,}")
print(f"  Warmup epochs: {warmup_epochs:,} (10%)")
peak_lr = 1 * (48 ** (-0.5)) * (warmup_epochs ** (-0.5))
print(f"  Peak learning rate: {peak_lr:.2e}")
# Out:
# Model architecture:
#   Input features: 9 (without current)
#   State Extractor Hidden size: 96
#   State Extractor layers: 4
#   Phys Regressor layers: 3
#   Phys Regressor Hidden size: 32
#   Current Predictor layers: 3
#   Current Predictor Hidden size: 96
#   Model parameters: 290,373
#   Physics constraints: Volume conservation with denormalization
#
# Training configuration:
#   Total epochs: 2,000
#   Warmup epochs: 200 (10%)
#   Peak learning rate: 1.02e-02

# %%
train_samples = len(dataloader.dataset)
best_train_loss = float('inf')
best_epoch = 0
train_losses = []
learning_rates = []

best_model = None

print("Training started...")
print(f"Total batches per epoch: {len(dataloader)}")

for epoch in range(num_epochs):
    current_lr = scheduler.step_epoch()

    model.train()
    train_loss = 0.0
    train_batches = 0

    for batch_idx, (input_seq, seq_len) in enumerate(dataloader):
        try:
            input_seq = input_seq.to(device)
            seq_len = seq_len.to(device)

            inputs, targets, target_seq_len = tf_data(input_seq, seq_len)
            
            optimizer.zero_grad()
            pred = model(inputs, target_seq_len)
            loss = masked_mse_loss(pred, targets, target_seq_len)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            train_loss += loss.item()
            train_batches += 1

        except Exception as e:
            print(f"Training batch {batch_idx} error: {str(e)}")
            print(f"Input shape: {input_seq.shape if 'input_seq' in locals() else 'N/A'}")
            print(f"Seq lengths: {seq_len if 'seq_lengths' in locals() else 'N/A'}")
            import traceback
            traceback.print_exc()
            continue
    
    if train_batches == 0:
        print("No valid training batches")
        break

    train_losses.append(train_loss)
    learning_rates.append(current_lr)

    if train_loss < best_train_loss:
        best_train_loss = train_loss
        best_epoch = epoch + 1
        best_status = " ★ NEW BEST"
        
        # Best model을 메모리에 복사하여 저장
        import copy
        best_model = copy.deepcopy(model)
        print(f"          Best model saved in memory at epoch {best_epoch}")
        
        # 오늘 날짜로 모델 파일 저장
        from datetime import datetime
        today = datetime.now().strftime("%y%m%d")
        model_filename = f"BMED_TF_{today}.pth"
        torch.save({
            'model_state_dict': best_model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'epoch': best_epoch,
            'best_train_loss': best_train_loss,
            'model_config': {
                'state_extr_params': state_extr_params,
                'phys_regr_params': phys_regr_params,
                'curr_regr_params': curr_regr_params,
                'range_mm': range_mm
            }
        }, model_filename)
        print(f"          Best model saved to {model_filename}")
    else:
        best_status = ""

    # Warmup 구간 표시
    if epoch + 1 <= warmup_epochs:
        warmup_status = " [WARMUP]"
    else:
        warmup_status = ""

    # 매 에포크마다 로깅 - best 성능 정보 포함
    print(f"Epoch {epoch+1:4d}: Train: {train_loss:.6f}, LR: {current_lr:.2e}{best_status}{warmup_status}")    

    if epoch == 0:
        print(f"          Best: Train: {best_train_loss:.6f}, (Epoch {best_epoch})")
    elif train_loss < best_train_loss:
        print(f"          ✓ Updated Best: Train: {best_train_loss:.6f}")
    else:
        print(f"          Best: Train: {best_train_loss:.6f} (Epoch {best_epoch})")

print(f"\nTraining completed!")
print(f"=" * 60)

# 안전한 결과 출력
if len(train_losses) > 0:
    print(f"Best Performance (Epoch {best_epoch}):")
    print(f"  Best Train Loss:  {best_train_loss:.6f}")
    print(f"=" * 60)
    print(f"Final Performance (Epoch {len(train_losses)}):")
    print(f"  Final Train Loss: {train_losses[-1]:.6f}")
    print(f"  Final LR:         {current_lr:.2e}")
    print(f"=" * 60)
    if len(learning_rates) > 0:
        print(f"Warmup completed at epoch {warmup_epochs} with peak LR: {max(learning_rates):.2e}")
else:
    print("⚠️ No training completed - check error messages above")

# Best model이 저장되었는지 확인
if best_model is not None:
    print(f"\n✅ Best model (Epoch {best_epoch}) successfully saved in memory!")
    print(f"   Best model loss: {best_train_loss:.6f}")
    from datetime import datetime
    today = datetime.now().strftime("%y%m%d")
    model_filename = f"BMED_TF_{today}.pth"
    print(f"   Best model also saved to file: {model_filename}")
else:
    print("\n⚠️ No best model was saved (training may have failed)")
    best_model = model  # fallback to current model
# Out:
# Training started...
# Total batches per epoch: 5
#           Best model saved in memory at epoch 1
#           Best model saved to BMED_TF_251010.pth
# Epoch    1: Train: 2.331818, LR: 3.61e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 2.331818, (Epoch 1)
#           Best model saved in memory at epoch 2
#           Best model saved to BMED_TF_251010.pth
# Epoch    2: Train: 2.318287, LR: 7.22e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 2.318287 (Epoch 2)
#           Best model saved in memory at epoch 3
#           Best model saved to BMED_TF_251010.pth
# Epoch    3: Train: 2.303853, LR: 1.08e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 2.303853 (Epoch 3)
#           Best model saved in memory at epoch 4
#           Best model saved to BMED_TF_251010.pth
# Epoch    4: Train: 2.283895, LR: 1.44e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 2.283895 (Epoch 4)
#           Best model saved in memory at epoch 5
#           Best model saved to BMED_TF_251010.pth
# Epoch    5: Train: 2.248638, LR: 1.80e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 2.248638 (Epoch 5)
#           Best model saved in memory at epoch 6
#           Best model saved to BMED_TF_251010.pth
# Epoch    6: Train: 2.195980, LR: 2.17e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 2.195980 (Epoch 6)
#           Best model saved in memory at epoch 7
#           Best model saved to BMED_TF_251010.pth
# Epoch    7: Train: 2.130665, LR: 2.53e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 2.130665 (Epoch 7)
#           Best model saved in memory at epoch 8
#           Best model saved to BMED_TF_251010.pth
# Epoch    8: Train: 2.029303, LR: 2.89e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 2.029303 (Epoch 8)
#           Best model saved in memory at epoch 9
#           Best model saved to BMED_TF_251010.pth
# Epoch    9: Train: 1.931138, LR: 3.25e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 1.931138 (Epoch 9)
#           Best model saved in memory at epoch 10
#           Best model saved to BMED_TF_251010.pth
# Epoch   10: Train: 1.743441, LR: 3.61e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 1.743441 (Epoch 10)
#           Best model saved in memory at epoch 11
#           Best model saved to BMED_TF_251010.pth
# Epoch   11: Train: 1.390818, LR: 3.97e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 1.390818 (Epoch 11)
#           Best model saved in memory at epoch 12
#           Best model saved to BMED_TF_251010.pth
# Epoch   12: Train: 1.078593, LR: 4.33e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 1.078593 (Epoch 12)
#           Best model saved in memory at epoch 13
#           Best model saved to BMED_TF_251010.pth
# Epoch   13: Train: 0.850716, LR: 4.69e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.850716 (Epoch 13)
#           Best model saved in memory at epoch 14
#           Best model saved to BMED_TF_251010.pth
# Epoch   14: Train: 0.805626, LR: 5.05e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.805626 (Epoch 14)
#           Best model saved in memory at epoch 15
#           Best model saved to BMED_TF_251010.pth
# Epoch   15: Train: 0.711234, LR: 5.41e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.711234 (Epoch 15)
#           Best model saved in memory at epoch 16
#           Best model saved to BMED_TF_251010.pth
# Epoch   16: Train: 0.575159, LR: 5.77e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.575159 (Epoch 16)
#           Best model saved in memory at epoch 17
#           Best model saved to BMED_TF_251010.pth
# Epoch   17: Train: 0.470190, LR: 6.13e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.470190 (Epoch 17)
#           Best model saved in memory at epoch 18
#           Best model saved to BMED_TF_251010.pth
# Epoch   18: Train: 0.395314, LR: 6.50e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.395314 (Epoch 18)
#           Best model saved in memory at epoch 19
#           Best model saved to BMED_TF_251010.pth
# Epoch   19: Train: 0.294381, LR: 6.86e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.294381 (Epoch 19)
#           Best model saved in memory at epoch 20
#           Best model saved to BMED_TF_251010.pth
# Epoch   20: Train: 0.237589, LR: 7.22e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.237589 (Epoch 20)
#           Best model saved in memory at epoch 21
#           Best model saved to BMED_TF_251010.pth
# Epoch   21: Train: 0.198973, LR: 7.58e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.198973 (Epoch 21)
#           Best model saved in memory at epoch 22
#           Best model saved to BMED_TF_251010.pth
# Epoch   22: Train: 0.175153, LR: 7.94e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.175153 (Epoch 22)
#           Best model saved in memory at epoch 23
#           Best model saved to BMED_TF_251010.pth
# Epoch   23: Train: 0.136675, LR: 8.30e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.136675 (Epoch 23)
#           Best model saved in memory at epoch 24
#           Best model saved to BMED_TF_251010.pth
# Epoch   24: Train: 0.123566, LR: 8.66e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.123566 (Epoch 24)
#           Best model saved in memory at epoch 25
#           Best model saved to BMED_TF_251010.pth
# Epoch   25: Train: 0.110474, LR: 9.02e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.110474 (Epoch 25)
#           Best model saved in memory at epoch 26
#           Best model saved to BMED_TF_251010.pth
# Epoch   26: Train: 0.106418, LR: 9.38e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.106418 (Epoch 26)
#           Best model saved in memory at epoch 27
#           Best model saved to BMED_TF_251010.pth
# Epoch   27: Train: 0.095867, LR: 9.74e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.095867 (Epoch 27)
# Epoch   28: Train: 0.096758, LR: 1.01e-03 [WARMUP]
#           Best: Train: 0.095867 (Epoch 27)
#           Best model saved in memory at epoch 29
#           Best model saved to BMED_TF_251010.pth
# Epoch   29: Train: 0.085901, LR: 1.05e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.085901 (Epoch 29)
#           Best model saved in memory at epoch 30
#           Best model saved to BMED_TF_251010.pth
# Epoch   30: Train: 0.079801, LR: 1.08e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.079801 (Epoch 30)
# Epoch   31: Train: 0.086632, LR: 1.12e-03 [WARMUP]
#           Best: Train: 0.079801 (Epoch 30)
#           Best model saved in memory at epoch 32
#           Best model saved to BMED_TF_251010.pth
# Epoch   32: Train: 0.076929, LR: 1.15e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.076929 (Epoch 32)
# Epoch   33: Train: 0.081641, LR: 1.19e-03 [WARMUP]
#           Best: Train: 0.076929 (Epoch 32)
#           Best model saved in memory at epoch 34
#           Best model saved to BMED_TF_251010.pth
# Epoch   34: Train: 0.072349, LR: 1.23e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.072349 (Epoch 34)
# Epoch   35: Train: 0.076678, LR: 1.26e-03 [WARMUP]
#           Best: Train: 0.072349 (Epoch 34)
# Epoch   36: Train: 0.076932, LR: 1.30e-03 [WARMUP]
#           Best: Train: 0.072349 (Epoch 34)
#           Best model saved in memory at epoch 37
#           Best model saved to BMED_TF_251010.pth
# Epoch   37: Train: 0.068301, LR: 1.34e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.068301 (Epoch 37)
#           Best model saved in memory at epoch 38
#           Best model saved to BMED_TF_251010.pth
# Epoch   38: Train: 0.063827, LR: 1.37e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.063827 (Epoch 38)
# Epoch   39: Train: 0.063970, LR: 1.41e-03 [WARMUP]
#           Best: Train: 0.063827 (Epoch 38)
#           Best model saved in memory at epoch 40
#           Best model saved to BMED_TF_251010.pth
# Epoch   40: Train: 0.058224, LR: 1.44e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.058224 (Epoch 40)
#           Best model saved in memory at epoch 41
#           Best model saved to BMED_TF_251010.pth
# Epoch   41: Train: 0.057001, LR: 1.48e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.057001 (Epoch 41)
#           Best model saved in memory at epoch 42
#           Best model saved to BMED_TF_251010.pth
# Epoch   42: Train: 0.054496, LR: 1.52e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.054496 (Epoch 42)
# Epoch   43: Train: 0.055571, LR: 1.55e-03 [WARMUP]
#           Best: Train: 0.054496 (Epoch 42)
#           Best model saved in memory at epoch 44
#           Best model saved to BMED_TF_251010.pth
# Epoch   44: Train: 0.051732, LR: 1.59e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.051732 (Epoch 44)
#           Best model saved in memory at epoch 45
#           Best model saved to BMED_TF_251010.pth
# Epoch   45: Train: 0.050090, LR: 1.62e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.050090 (Epoch 45)
# Epoch   46: Train: 0.050773, LR: 1.66e-03 [WARMUP]
#           Best: Train: 0.050090 (Epoch 45)
#           Best model saved in memory at epoch 47
#           Best model saved to BMED_TF_251010.pth
# Epoch   47: Train: 0.049198, LR: 1.70e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.049198 (Epoch 47)
# Epoch   48: Train: 0.057252, LR: 1.73e-03 [WARMUP]
#           Best: Train: 0.049198 (Epoch 47)
# Epoch   49: Train: 0.050886, LR: 1.77e-03 [WARMUP]
#           Best: Train: 0.049198 (Epoch 47)
# Epoch   50: Train: 0.050751, LR: 1.80e-03 [WARMUP]
#           Best: Train: 0.049198 (Epoch 47)
# Epoch   51: Train: 0.056871, LR: 1.84e-03 [WARMUP]
#           Best: Train: 0.049198 (Epoch 47)
# Epoch   52: Train: 0.059736, LR: 1.88e-03 [WARMUP]
#           Best: Train: 0.049198 (Epoch 47)
# Epoch   53: Train: 0.056833, LR: 1.91e-03 [WARMUP]
#           Best: Train: 0.049198 (Epoch 47)
# Epoch   54: Train: 0.060718, LR: 1.95e-03 [WARMUP]
#           Best: Train: 0.049198 (Epoch 47)
#           Best model saved in memory at epoch 55
#           Best model saved to BMED_TF_251010.pth
# Epoch   55: Train: 0.044944, LR: 1.98e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.044944 (Epoch 55)
# Epoch   56: Train: 0.048687, LR: 2.02e-03 [WARMUP]
#           Best: Train: 0.044944 (Epoch 55)
#           Best model saved in memory at epoch 57
#           Best model saved to BMED_TF_251010.pth
# Epoch   57: Train: 0.035035, LR: 2.06e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.035035 (Epoch 57)
# Epoch   58: Train: 0.040308, LR: 2.09e-03 [WARMUP]
#           Best: Train: 0.035035 (Epoch 57)
# Epoch   59: Train: 0.038983, LR: 2.13e-03 [WARMUP]
#           Best: Train: 0.035035 (Epoch 57)
# Epoch   60: Train: 0.038918, LR: 2.17e-03 [WARMUP]
#           Best: Train: 0.035035 (Epoch 57)
# Epoch   61: Train: 0.037550, LR: 2.20e-03 [WARMUP]
#           Best: Train: 0.035035 (Epoch 57)
#           Best model saved in memory at epoch 62
#           Best model saved to BMED_TF_251010.pth
# Epoch   62: Train: 0.032234, LR: 2.24e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   63: Train: 0.036819, LR: 2.27e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   64: Train: 0.037644, LR: 2.31e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   65: Train: 0.040317, LR: 2.35e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   66: Train: 0.040511, LR: 2.38e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   67: Train: 0.050804, LR: 2.42e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   68: Train: 0.044927, LR: 2.45e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   69: Train: 0.043808, LR: 2.49e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   70: Train: 0.036599, LR: 2.53e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   71: Train: 0.042484, LR: 2.56e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   72: Train: 0.034361, LR: 2.60e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   73: Train: 0.037639, LR: 2.63e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   74: Train: 0.037624, LR: 2.67e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   75: Train: 0.042832, LR: 2.71e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   76: Train: 0.036073, LR: 2.74e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   77: Train: 0.044437, LR: 2.78e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   78: Train: 0.043849, LR: 2.81e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   79: Train: 0.037970, LR: 2.85e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   80: Train: 0.037156, LR: 2.89e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   81: Train: 0.040521, LR: 2.92e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   82: Train: 0.033882, LR: 2.96e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
# Epoch   83: Train: 0.036469, LR: 3.00e-03 [WARMUP]
#           Best: Train: 0.032234 (Epoch 62)
#           Best model saved in memory at epoch 84
#           Best model saved to BMED_TF_251010.pth
# Epoch   84: Train: 0.031808, LR: 3.03e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.031808 (Epoch 84)
# Epoch   85: Train: 0.031817, LR: 3.07e-03 [WARMUP]
#           Best: Train: 0.031808 (Epoch 84)
#           Best model saved in memory at epoch 86
#           Best model saved to BMED_TF_251010.pth
# Epoch   86: Train: 0.027541, LR: 3.10e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.027541 (Epoch 86)
# Epoch   87: Train: 0.033150, LR: 3.14e-03 [WARMUP]
#           Best: Train: 0.027541 (Epoch 86)
# Epoch   88: Train: 0.028376, LR: 3.18e-03 [WARMUP]
#           Best: Train: 0.027541 (Epoch 86)
# Epoch   89: Train: 0.029341, LR: 3.21e-03 [WARMUP]
#           Best: Train: 0.027541 (Epoch 86)
#           Best model saved in memory at epoch 90
#           Best model saved to BMED_TF_251010.pth
# Epoch   90: Train: 0.026296, LR: 3.25e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch   91: Train: 0.032009, LR: 3.28e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch   92: Train: 0.031177, LR: 3.32e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch   93: Train: 0.041068, LR: 3.36e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch   94: Train: 0.040451, LR: 3.39e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch   95: Train: 0.038548, LR: 3.43e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch   96: Train: 0.035271, LR: 3.46e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch   97: Train: 0.044526, LR: 3.50e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch   98: Train: 0.034471, LR: 3.54e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch   99: Train: 0.042196, LR: 3.57e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch  100: Train: 0.029463, LR: 3.61e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch  101: Train: 0.034214, LR: 3.64e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch  102: Train: 0.027635, LR: 3.68e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch  103: Train: 0.036914, LR: 3.72e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch  104: Train: 0.029107, LR: 3.75e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch  105: Train: 0.031794, LR: 3.79e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch  106: Train: 0.027374, LR: 3.82e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
# Epoch  107: Train: 0.027894, LR: 3.86e-03 [WARMUP]
#           Best: Train: 0.026296 (Epoch 90)
#           Best model saved in memory at epoch 108
#           Best model saved to BMED_TF_251010.pth
# Epoch  108: Train: 0.023127, LR: 3.90e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.023127 (Epoch 108)
# Epoch  109: Train: 0.023589, LR: 3.93e-03 [WARMUP]
#           Best: Train: 0.023127 (Epoch 108)
#           Best model saved in memory at epoch 110
#           Best model saved to BMED_TF_251010.pth
# Epoch  110: Train: 0.022210, LR: 3.97e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.022210 (Epoch 110)
#           Best model saved in memory at epoch 111
#           Best model saved to BMED_TF_251010.pth
# Epoch  111: Train: 0.017766, LR: 4.01e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.017766 (Epoch 111)
# Epoch  112: Train: 0.018032, LR: 4.04e-03 [WARMUP]
#           Best: Train: 0.017766 (Epoch 111)
# Epoch  113: Train: 0.019768, LR: 4.08e-03 [WARMUP]
#           Best: Train: 0.017766 (Epoch 111)
# Epoch  114: Train: 0.019995, LR: 4.11e-03 [WARMUP]
#           Best: Train: 0.017766 (Epoch 111)
#           Best model saved in memory at epoch 115
#           Best model saved to BMED_TF_251010.pth
# Epoch  115: Train: 0.017165, LR: 4.15e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  116: Train: 0.019698, LR: 4.19e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  117: Train: 0.018134, LR: 4.22e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  118: Train: 0.017596, LR: 4.26e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  119: Train: 0.019408, LR: 4.29e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  120: Train: 0.020377, LR: 4.33e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  121: Train: 0.019265, LR: 4.37e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  122: Train: 0.021856, LR: 4.40e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  123: Train: 0.024815, LR: 4.44e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  124: Train: 0.020916, LR: 4.47e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  125: Train: 0.025960, LR: 4.51e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  126: Train: 0.032552, LR: 4.55e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  127: Train: 0.037747, LR: 4.58e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  128: Train: 0.045742, LR: 4.62e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  129: Train: 0.047692, LR: 4.65e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  130: Train: 0.075476, LR: 4.69e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  131: Train: 0.050222, LR: 4.73e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  132: Train: 0.071781, LR: 4.76e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  133: Train: 0.030965, LR: 4.80e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  134: Train: 0.036642, LR: 4.84e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  135: Train: 0.020955, LR: 4.87e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  136: Train: 0.022272, LR: 4.91e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  137: Train: 0.017785, LR: 4.94e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  138: Train: 0.018664, LR: 4.98e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
# Epoch  139: Train: 0.019462, LR: 5.02e-03 [WARMUP]
#           Best: Train: 0.017165 (Epoch 115)
#           Best model saved in memory at epoch 140
#           Best model saved to BMED_TF_251010.pth
# Epoch  140: Train: 0.016985, LR: 5.05e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.016985 (Epoch 140)
# Epoch  141: Train: 0.017435, LR: 5.09e-03 [WARMUP]
#           Best: Train: 0.016985 (Epoch 140)
#           Best model saved in memory at epoch 142
#           Best model saved to BMED_TF_251010.pth
# Epoch  142: Train: 0.015204, LR: 5.12e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.015204 (Epoch 142)
# Epoch  143: Train: 0.018266, LR: 5.16e-03 [WARMUP]
#           Best: Train: 0.015204 (Epoch 142)
# Epoch  144: Train: 0.018045, LR: 5.20e-03 [WARMUP]
#           Best: Train: 0.015204 (Epoch 142)
# Epoch  145: Train: 0.027541, LR: 5.23e-03 [WARMUP]
#           Best: Train: 0.015204 (Epoch 142)
# Epoch  146: Train: 0.025771, LR: 5.27e-03 [WARMUP]
#           Best: Train: 0.015204 (Epoch 142)
# Epoch  147: Train: 0.032704, LR: 5.30e-03 [WARMUP]
#           Best: Train: 0.015204 (Epoch 142)
# Epoch  148: Train: 0.029444, LR: 5.34e-03 [WARMUP]
#           Best: Train: 0.015204 (Epoch 142)
# Epoch  149: Train: 0.041531, LR: 5.38e-03 [WARMUP]
#           Best: Train: 0.015204 (Epoch 142)
# Epoch  150: Train: 0.033476, LR: 5.41e-03 [WARMUP]
#           Best: Train: 0.015204 (Epoch 142)
# Epoch  151: Train: 0.044340, LR: 5.45e-03 [WARMUP]
#           Best: Train: 0.015204 (Epoch 142)
# Epoch  152: Train: 0.021333, LR: 5.48e-03 [WARMUP]
#           Best: Train: 0.015204 (Epoch 142)
# Epoch  153: Train: 0.019109, LR: 5.52e-03 [WARMUP]
#           Best: Train: 0.015204 (Epoch 142)
# Epoch  154: Train: 0.018633, LR: 5.56e-03 [WARMUP]
#           Best: Train: 0.015204 (Epoch 142)
# Epoch  155: Train: 0.020635, LR: 5.59e-03 [WARMUP]
#           Best: Train: 0.015204 (Epoch 142)
#           Best model saved in memory at epoch 156
#           Best model saved to BMED_TF_251010.pth
# Epoch  156: Train: 0.014029, LR: 5.63e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.014029 (Epoch 156)
#           Best model saved in memory at epoch 157
#           Best model saved to BMED_TF_251010.pth
# Epoch  157: Train: 0.013059, LR: 5.67e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.013059 (Epoch 157)
# Epoch  158: Train: 0.016239, LR: 5.70e-03 [WARMUP]
#           Best: Train: 0.013059 (Epoch 157)
#           Best model saved in memory at epoch 159
#           Best model saved to BMED_TF_251010.pth
# Epoch  159: Train: 0.012266, LR: 5.74e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  160: Train: 0.013170, LR: 5.77e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  161: Train: 0.015094, LR: 5.81e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  162: Train: 0.013749, LR: 5.85e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  163: Train: 0.016336, LR: 5.88e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  164: Train: 0.019569, LR: 5.92e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  165: Train: 0.020078, LR: 5.95e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  166: Train: 0.019122, LR: 5.99e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  167: Train: 0.019477, LR: 6.03e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  168: Train: 0.023044, LR: 6.06e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  169: Train: 0.023178, LR: 6.10e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  170: Train: 0.035161, LR: 6.13e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  171: Train: 0.028319, LR: 6.17e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  172: Train: 0.030210, LR: 6.21e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  173: Train: 0.026644, LR: 6.24e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  174: Train: 0.038250, LR: 6.28e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  175: Train: 0.025323, LR: 6.31e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  176: Train: 0.024990, LR: 6.35e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  177: Train: 0.022326, LR: 6.39e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  178: Train: 0.025738, LR: 6.42e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  179: Train: 0.018098, LR: 6.46e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  180: Train: 0.020859, LR: 6.50e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  181: Train: 0.019832, LR: 6.53e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  182: Train: 0.018542, LR: 6.57e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  183: Train: 0.015148, LR: 6.60e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  184: Train: 0.016523, LR: 6.64e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  185: Train: 0.016215, LR: 6.68e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  186: Train: 0.019364, LR: 6.71e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  187: Train: 0.016493, LR: 6.75e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  188: Train: 0.016870, LR: 6.78e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  189: Train: 0.017533, LR: 6.82e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  190: Train: 0.022389, LR: 6.86e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  191: Train: 0.019012, LR: 6.89e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  192: Train: 0.020592, LR: 6.93e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  193: Train: 0.016355, LR: 6.96e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  194: Train: 0.019757, LR: 7.00e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  195: Train: 0.015913, LR: 7.04e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  196: Train: 0.015253, LR: 7.07e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  197: Train: 0.014336, LR: 7.11e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  198: Train: 0.015018, LR: 7.14e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  199: Train: 0.013088, LR: 7.18e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  200: Train: 0.012912, LR: 7.22e-03 [WARMUP]
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  201: Train: 0.012287, LR: 7.20e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  202: Train: 0.016468, LR: 7.18e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  203: Train: 0.016673, LR: 7.16e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  204: Train: 0.023705, LR: 7.15e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  205: Train: 0.020102, LR: 7.13e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  206: Train: 0.024199, LR: 7.11e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  207: Train: 0.022704, LR: 7.09e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  208: Train: 0.033992, LR: 7.08e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  209: Train: 0.028314, LR: 7.06e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  210: Train: 0.027611, LR: 7.04e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  211: Train: 0.022524, LR: 7.03e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  212: Train: 0.024098, LR: 7.01e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  213: Train: 0.016846, LR: 6.99e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  214: Train: 0.016512, LR: 6.98e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  215: Train: 0.013848, LR: 6.96e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  216: Train: 0.014931, LR: 6.94e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  217: Train: 0.014356, LR: 6.93e-03
#           Best: Train: 0.012266 (Epoch 159)
# Epoch  218: Train: 0.014300, LR: 6.91e-03
#           Best: Train: 0.012266 (Epoch 159)
#           Best model saved in memory at epoch 219
#           Best model saved to BMED_TF_251010.pth
# Epoch  219: Train: 0.010969, LR: 6.90e-03 ★ NEW BEST
#           Best: Train: 0.010969 (Epoch 219)
# Epoch  220: Train: 0.011410, LR: 6.88e-03
#           Best: Train: 0.010969 (Epoch 219)
#           Best model saved in memory at epoch 221
#           Best model saved to BMED_TF_251010.pth
# Epoch  221: Train: 0.010494, LR: 6.87e-03 ★ NEW BEST
#           Best: Train: 0.010494 (Epoch 221)
# Epoch  222: Train: 0.010506, LR: 6.85e-03
#           Best: Train: 0.010494 (Epoch 221)
# Epoch  223: Train: 0.011546, LR: 6.83e-03
#           Best: Train: 0.010494 (Epoch 221)
#           Best model saved in memory at epoch 224
#           Best model saved to BMED_TF_251010.pth
# Epoch  224: Train: 0.009556, LR: 6.82e-03 ★ NEW BEST
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  225: Train: 0.011156, LR: 6.80e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  226: Train: 0.010376, LR: 6.79e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  227: Train: 0.011572, LR: 6.77e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  228: Train: 0.014338, LR: 6.76e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  229: Train: 0.015289, LR: 6.74e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  230: Train: 0.018403, LR: 6.73e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  231: Train: 0.015211, LR: 6.72e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  232: Train: 0.015592, LR: 6.70e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  233: Train: 0.017959, LR: 6.69e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  234: Train: 0.027243, LR: 6.67e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  235: Train: 0.020837, LR: 6.66e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  236: Train: 0.020839, LR: 6.64e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  237: Train: 0.012949, LR: 6.63e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  238: Train: 0.011927, LR: 6.62e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  239: Train: 0.010780, LR: 6.60e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  240: Train: 0.011944, LR: 6.59e-03
#           Best: Train: 0.009556 (Epoch 224)
# Epoch  241: Train: 0.009560, LR: 6.57e-03
#           Best: Train: 0.009556 (Epoch 224)
#           Best model saved in memory at epoch 242
#           Best model saved to BMED_TF_251010.pth
# Epoch  242: Train: 0.008981, LR: 6.56e-03 ★ NEW BEST
#           Best: Train: 0.008981 (Epoch 242)
# Epoch  243: Train: 0.011000, LR: 6.55e-03
#           Best: Train: 0.008981 (Epoch 242)
# Epoch  244: Train: 0.012951, LR: 6.53e-03
#           Best: Train: 0.008981 (Epoch 242)
# Epoch  245: Train: 0.013182, LR: 6.52e-03
#           Best: Train: 0.008981 (Epoch 242)
# Epoch  246: Train: 0.009554, LR: 6.51e-03
#           Best: Train: 0.008981 (Epoch 242)
# Epoch  247: Train: 0.009244, LR: 6.49e-03
#           Best: Train: 0.008981 (Epoch 242)
# Epoch  248: Train: 0.009097, LR: 6.48e-03
#           Best: Train: 0.008981 (Epoch 242)
#           Best model saved in memory at epoch 249
#           Best model saved to BMED_TF_251010.pth
# Epoch  249: Train: 0.008170, LR: 6.47e-03 ★ NEW BEST
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  250: Train: 0.010696, LR: 6.45e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  251: Train: 0.011859, LR: 6.44e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  252: Train: 0.014712, LR: 6.43e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  253: Train: 0.013582, LR: 6.42e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  254: Train: 0.012900, LR: 6.40e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  255: Train: 0.010786, LR: 6.39e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  256: Train: 0.011433, LR: 6.38e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  257: Train: 0.011902, LR: 6.37e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  258: Train: 0.012058, LR: 6.35e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  259: Train: 0.010742, LR: 6.34e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  260: Train: 0.010595, LR: 6.33e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  261: Train: 0.009299, LR: 6.32e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  262: Train: 0.012845, LR: 6.31e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  263: Train: 0.013416, LR: 6.29e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  264: Train: 0.018767, LR: 6.28e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  265: Train: 0.013932, LR: 6.27e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  266: Train: 0.009922, LR: 6.26e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  267: Train: 0.009531, LR: 6.25e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  268: Train: 0.010994, LR: 6.23e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  269: Train: 0.010384, LR: 6.22e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  270: Train: 0.009887, LR: 6.21e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  271: Train: 0.010266, LR: 6.20e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  272: Train: 0.009455, LR: 6.19e-03
#           Best: Train: 0.008170 (Epoch 249)
# Epoch  273: Train: 0.008276, LR: 6.18e-03
#           Best: Train: 0.008170 (Epoch 249)
#           Best model saved in memory at epoch 274
#           Best model saved to BMED_TF_251010.pth
# Epoch  274: Train: 0.008039, LR: 6.17e-03 ★ NEW BEST
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  275: Train: 0.009202, LR: 6.15e-03
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  276: Train: 0.010047, LR: 6.14e-03
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  277: Train: 0.009329, LR: 6.13e-03
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  278: Train: 0.008647, LR: 6.12e-03
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  279: Train: 0.008379, LR: 6.11e-03
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  280: Train: 0.009117, LR: 6.10e-03
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  281: Train: 0.009602, LR: 6.09e-03
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  282: Train: 0.008616, LR: 6.08e-03
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  283: Train: 0.008704, LR: 6.07e-03
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  284: Train: 0.008504, LR: 6.06e-03
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  285: Train: 0.009535, LR: 6.05e-03
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  286: Train: 0.008866, LR: 6.04e-03
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  287: Train: 0.009268, LR: 6.02e-03
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  288: Train: 0.008205, LR: 6.01e-03
#           Best: Train: 0.008039 (Epoch 274)
# Epoch  289: Train: 0.008082, LR: 6.00e-03
#           Best: Train: 0.008039 (Epoch 274)
#           Best model saved in memory at epoch 290
#           Best model saved to BMED_TF_251010.pth
# Epoch  290: Train: 0.007443, LR: 5.99e-03 ★ NEW BEST
#           Best: Train: 0.007443 (Epoch 290)
#           Best model saved in memory at epoch 291
#           Best model saved to BMED_TF_251010.pth
# Epoch  291: Train: 0.006173, LR: 5.98e-03 ★ NEW BEST
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  292: Train: 0.006866, LR: 5.97e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  293: Train: 0.007726, LR: 5.96e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  294: Train: 0.008384, LR: 5.95e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  295: Train: 0.008394, LR: 5.94e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  296: Train: 0.008028, LR: 5.93e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  297: Train: 0.007574, LR: 5.92e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  298: Train: 0.008056, LR: 5.91e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  299: Train: 0.009162, LR: 5.90e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  300: Train: 0.007996, LR: 5.89e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  301: Train: 0.010269, LR: 5.88e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  302: Train: 0.010707, LR: 5.87e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  303: Train: 0.010184, LR: 5.86e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  304: Train: 0.010929, LR: 5.85e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  305: Train: 0.009425, LR: 5.84e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  306: Train: 0.009765, LR: 5.83e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  307: Train: 0.008497, LR: 5.82e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  308: Train: 0.008606, LR: 5.82e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  309: Train: 0.008234, LR: 5.81e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  310: Train: 0.007241, LR: 5.80e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  311: Train: 0.007731, LR: 5.79e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  312: Train: 0.007511, LR: 5.78e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  313: Train: 0.007735, LR: 5.77e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  314: Train: 0.009299, LR: 5.76e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  315: Train: 0.007876, LR: 5.75e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  316: Train: 0.006915, LR: 5.74e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  317: Train: 0.006481, LR: 5.73e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  318: Train: 0.006253, LR: 5.72e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  319: Train: 0.006566, LR: 5.71e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  320: Train: 0.007033, LR: 5.71e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  321: Train: 0.006362, LR: 5.70e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  322: Train: 0.007681, LR: 5.69e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  323: Train: 0.006353, LR: 5.68e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  324: Train: 0.007640, LR: 5.67e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  325: Train: 0.007895, LR: 5.66e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  326: Train: 0.008618, LR: 5.65e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  327: Train: 0.009238, LR: 5.64e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  328: Train: 0.010599, LR: 5.64e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  329: Train: 0.010309, LR: 5.63e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  330: Train: 0.009471, LR: 5.62e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  331: Train: 0.008648, LR: 5.61e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  332: Train: 0.009301, LR: 5.60e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  333: Train: 0.010201, LR: 5.59e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  334: Train: 0.008371, LR: 5.58e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  335: Train: 0.007129, LR: 5.58e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  336: Train: 0.006656, LR: 5.57e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  337: Train: 0.008495, LR: 5.56e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  338: Train: 0.011493, LR: 5.55e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  339: Train: 0.011139, LR: 5.54e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  340: Train: 0.013199, LR: 5.54e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  341: Train: 0.007364, LR: 5.53e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  342: Train: 0.008369, LR: 5.52e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  343: Train: 0.009428, LR: 5.51e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  344: Train: 0.009179, LR: 5.50e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  345: Train: 0.010353, LR: 5.49e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  346: Train: 0.010878, LR: 5.49e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  347: Train: 0.008116, LR: 5.48e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  348: Train: 0.009047, LR: 5.47e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  349: Train: 0.006542, LR: 5.46e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  350: Train: 0.008698, LR: 5.46e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  351: Train: 0.008217, LR: 5.45e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  352: Train: 0.007434, LR: 5.44e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  353: Train: 0.007621, LR: 5.43e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  354: Train: 0.008917, LR: 5.42e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  355: Train: 0.009423, LR: 5.42e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  356: Train: 0.009671, LR: 5.41e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  357: Train: 0.009033, LR: 5.40e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  358: Train: 0.012267, LR: 5.39e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  359: Train: 0.009065, LR: 5.39e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  360: Train: 0.010583, LR: 5.38e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  361: Train: 0.011624, LR: 5.37e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  362: Train: 0.012719, LR: 5.36e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  363: Train: 0.010493, LR: 5.36e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  364: Train: 0.007210, LR: 5.35e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  365: Train: 0.006240, LR: 5.34e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  366: Train: 0.006870, LR: 5.33e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  367: Train: 0.008530, LR: 5.33e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  368: Train: 0.006760, LR: 5.32e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  369: Train: 0.006586, LR: 5.31e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  370: Train: 0.006394, LR: 5.31e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  371: Train: 0.008443, LR: 5.30e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  372: Train: 0.007336, LR: 5.29e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  373: Train: 0.007177, LR: 5.28e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  374: Train: 0.007003, LR: 5.28e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  375: Train: 0.007410, LR: 5.27e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  376: Train: 0.006339, LR: 5.26e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  377: Train: 0.006248, LR: 5.26e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  378: Train: 0.007444, LR: 5.25e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  379: Train: 0.007643, LR: 5.24e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  380: Train: 0.008643, LR: 5.24e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  381: Train: 0.008506, LR: 5.23e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  382: Train: 0.010049, LR: 5.22e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  383: Train: 0.010273, LR: 5.22e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  384: Train: 0.011154, LR: 5.21e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  385: Train: 0.016440, LR: 5.20e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  386: Train: 0.015585, LR: 5.19e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  387: Train: 0.024007, LR: 5.19e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  388: Train: 0.012546, LR: 5.18e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  389: Train: 0.013387, LR: 5.17e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  390: Train: 0.012144, LR: 5.17e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  391: Train: 0.009639, LR: 5.16e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  392: Train: 0.009222, LR: 5.15e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  393: Train: 0.008510, LR: 5.15e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  394: Train: 0.007062, LR: 5.14e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  395: Train: 0.006826, LR: 5.14e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  396: Train: 0.007268, LR: 5.13e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  397: Train: 0.008961, LR: 5.12e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  398: Train: 0.009428, LR: 5.12e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  399: Train: 0.008082, LR: 5.11e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  400: Train: 0.007935, LR: 5.10e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  401: Train: 0.006495, LR: 5.10e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  402: Train: 0.006520, LR: 5.09e-03
#           Best: Train: 0.006173 (Epoch 291)
# Epoch  403: Train: 0.006804, LR: 5.08e-03
#           Best: Train: 0.006173 (Epoch 291)
#           Best model saved in memory at epoch 404
#           Best model saved to BMED_TF_251010.pth
# Epoch  404: Train: 0.005595, LR: 5.08e-03 ★ NEW BEST
#           Best: Train: 0.005595 (Epoch 404)
# Epoch  405: Train: 0.006966, LR: 5.07e-03
#           Best: Train: 0.005595 (Epoch 404)
# Epoch  406: Train: 0.007145, LR: 5.07e-03
#           Best: Train: 0.005595 (Epoch 404)
# Epoch  407: Train: 0.005999, LR: 5.06e-03
#           Best: Train: 0.005595 (Epoch 404)
# Epoch  408: Train: 0.006491, LR: 5.05e-03
#           Best: Train: 0.005595 (Epoch 404)
# Epoch  409: Train: 0.006203, LR: 5.05e-03
#           Best: Train: 0.005595 (Epoch 404)
# Epoch  410: Train: 0.007139, LR: 5.04e-03
#           Best: Train: 0.005595 (Epoch 404)
# Epoch  411: Train: 0.005948, LR: 5.03e-03
#           Best: Train: 0.005595 (Epoch 404)
#           Best model saved in memory at epoch 412
#           Best model saved to BMED_TF_251010.pth
# Epoch  412: Train: 0.005355, LR: 5.03e-03 ★ NEW BEST
#           Best: Train: 0.005355 (Epoch 412)
# Epoch  413: Train: 0.006166, LR: 5.02e-03
#           Best: Train: 0.005355 (Epoch 412)
# Epoch  414: Train: 0.006006, LR: 5.02e-03
#           Best: Train: 0.005355 (Epoch 412)
# Epoch  415: Train: 0.006031, LR: 5.01e-03
#           Best: Train: 0.005355 (Epoch 412)
# Epoch  416: Train: 0.005904, LR: 5.00e-03
#           Best: Train: 0.005355 (Epoch 412)
#           Best model saved in memory at epoch 417
#           Best model saved to BMED_TF_251010.pth
# Epoch  417: Train: 0.004876, LR: 5.00e-03 ★ NEW BEST
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  418: Train: 0.005639, LR: 4.99e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  419: Train: 0.007521, LR: 4.99e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  420: Train: 0.007262, LR: 4.98e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  421: Train: 0.007808, LR: 4.97e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  422: Train: 0.007169, LR: 4.97e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  423: Train: 0.008228, LR: 4.96e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  424: Train: 0.007875, LR: 4.96e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  425: Train: 0.007071, LR: 4.95e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  426: Train: 0.007364, LR: 4.94e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  427: Train: 0.007714, LR: 4.94e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  428: Train: 0.007472, LR: 4.93e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  429: Train: 0.007991, LR: 4.93e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  430: Train: 0.009969, LR: 4.92e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  431: Train: 0.009065, LR: 4.92e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  432: Train: 0.010023, LR: 4.91e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  433: Train: 0.010814, LR: 4.90e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  434: Train: 0.016442, LR: 4.90e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  435: Train: 0.010432, LR: 4.89e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  436: Train: 0.011362, LR: 4.89e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  437: Train: 0.009434, LR: 4.88e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  438: Train: 0.008340, LR: 4.88e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  439: Train: 0.007407, LR: 4.87e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  440: Train: 0.010943, LR: 4.87e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  441: Train: 0.008163, LR: 4.86e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  442: Train: 0.005972, LR: 4.85e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  443: Train: 0.005679, LR: 4.85e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  444: Train: 0.005742, LR: 4.84e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  445: Train: 0.006551, LR: 4.84e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  446: Train: 0.005883, LR: 4.83e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  447: Train: 0.005568, LR: 4.83e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  448: Train: 0.005139, LR: 4.82e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  449: Train: 0.004983, LR: 4.82e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  450: Train: 0.004918, LR: 4.81e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  451: Train: 0.005926, LR: 4.81e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  452: Train: 0.005766, LR: 4.80e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  453: Train: 0.005827, LR: 4.80e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  454: Train: 0.005524, LR: 4.79e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  455: Train: 0.005187, LR: 4.78e-03
#           Best: Train: 0.004876 (Epoch 417)
# Epoch  456: Train: 0.005650, LR: 4.78e-03
# ...
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1824: Train: 0.004358, LR: 2.39e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1825: Train: 0.004532, LR: 2.39e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1826: Train: 0.004228, LR: 2.39e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1827: Train: 0.003615, LR: 2.39e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1828: Train: 0.003535, LR: 2.39e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1829: Train: 0.003401, LR: 2.39e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1830: Train: 0.003828, LR: 2.39e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1831: Train: 0.004392, LR: 2.39e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1832: Train: 0.004504, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1833: Train: 0.004356, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1834: Train: 0.003693, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1835: Train: 0.004049, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1836: Train: 0.004570, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1837: Train: 0.005148, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1838: Train: 0.004720, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1839: Train: 0.005090, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1840: Train: 0.004852, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1841: Train: 0.007111, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1842: Train: 0.006466, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1843: Train: 0.005278, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1844: Train: 0.004229, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1845: Train: 0.004828, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1846: Train: 0.003523, LR: 2.38e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1847: Train: 0.003602, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1848: Train: 0.004444, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1849: Train: 0.004644, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1850: Train: 0.003559, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1851: Train: 0.003541, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1852: Train: 0.003895, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1853: Train: 0.003069, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1854: Train: 0.003249, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1855: Train: 0.003336, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1856: Train: 0.003486, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1857: Train: 0.003630, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1858: Train: 0.003473, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1859: Train: 0.003463, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1860: Train: 0.003184, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1861: Train: 0.003267, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1862: Train: 0.003595, LR: 2.37e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1863: Train: 0.003517, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1864: Train: 0.003763, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1865: Train: 0.003944, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1866: Train: 0.003996, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1867: Train: 0.003040, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1868: Train: 0.003579, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1869: Train: 0.003878, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1870: Train: 0.004144, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1871: Train: 0.003960, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1872: Train: 0.003625, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1873: Train: 0.005310, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1874: Train: 0.005106, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1875: Train: 0.005387, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1876: Train: 0.004979, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1877: Train: 0.005399, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1878: Train: 0.005715, LR: 2.36e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1879: Train: 0.004935, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1880: Train: 0.003891, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1881: Train: 0.003536, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1882: Train: 0.004399, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1883: Train: 0.003597, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1884: Train: 0.003558, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1885: Train: 0.003291, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1886: Train: 0.003690, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1887: Train: 0.003402, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1888: Train: 0.003358, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1889: Train: 0.003777, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1890: Train: 0.003245, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1891: Train: 0.003222, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1892: Train: 0.003746, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1893: Train: 0.003392, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1894: Train: 0.002927, LR: 2.35e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1895: Train: 0.004540, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1896: Train: 0.004068, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1897: Train: 0.005177, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1898: Train: 0.004627, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1899: Train: 0.005123, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1900: Train: 0.003421, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1901: Train: 0.004687, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1902: Train: 0.004102, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1903: Train: 0.004358, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1904: Train: 0.003894, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1905: Train: 0.003645, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1906: Train: 0.003999, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1907: Train: 0.003819, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1908: Train: 0.003713, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1909: Train: 0.003908, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1910: Train: 0.004262, LR: 2.34e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1911: Train: 0.003578, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1912: Train: 0.003939, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1913: Train: 0.004356, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1914: Train: 0.004658, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1915: Train: 0.004124, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1916: Train: 0.004067, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1917: Train: 0.003351, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1918: Train: 0.003385, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1919: Train: 0.003494, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1920: Train: 0.004387, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1921: Train: 0.003399, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1922: Train: 0.003914, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1923: Train: 0.003120, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1924: Train: 0.002991, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1925: Train: 0.003731, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1926: Train: 0.003837, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1927: Train: 0.004062, LR: 2.33e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1928: Train: 0.003997, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1929: Train: 0.004450, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1930: Train: 0.004489, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1931: Train: 0.005058, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1932: Train: 0.005005, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1933: Train: 0.003762, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1934: Train: 0.004920, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1935: Train: 0.004617, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1936: Train: 0.004036, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1937: Train: 0.003560, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1938: Train: 0.004794, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1939: Train: 0.004157, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1940: Train: 0.003680, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1941: Train: 0.003481, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1942: Train: 0.004863, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1943: Train: 0.004115, LR: 2.32e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1944: Train: 0.004244, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1945: Train: 0.003759, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1946: Train: 0.004693, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1947: Train: 0.005044, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1948: Train: 0.004130, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1949: Train: 0.003383, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1950: Train: 0.003128, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1951: Train: 0.003261, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1952: Train: 0.003078, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1953: Train: 0.003122, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1954: Train: 0.003899, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1955: Train: 0.003438, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1956: Train: 0.004080, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1957: Train: 0.003792, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1958: Train: 0.003469, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1959: Train: 0.004169, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1960: Train: 0.003893, LR: 2.31e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1961: Train: 0.003575, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1962: Train: 0.003603, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1963: Train: 0.003132, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1964: Train: 0.003739, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1965: Train: 0.004179, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1966: Train: 0.003228, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1967: Train: 0.003832, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1968: Train: 0.003578, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1969: Train: 0.004022, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1970: Train: 0.004179, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1971: Train: 0.004305, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1972: Train: 0.005577, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1973: Train: 0.007753, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1974: Train: 0.006421, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1975: Train: 0.006439, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1976: Train: 0.005470, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1977: Train: 0.006166, LR: 2.30e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1978: Train: 0.004547, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1979: Train: 0.003825, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1980: Train: 0.003549, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1981: Train: 0.003384, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1982: Train: 0.003631, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1983: Train: 0.003560, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1984: Train: 0.003308, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1985: Train: 0.003741, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1986: Train: 0.003534, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1987: Train: 0.004038, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1988: Train: 0.004358, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1989: Train: 0.004422, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1990: Train: 0.005775, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1991: Train: 0.006229, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1992: Train: 0.004153, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1993: Train: 0.003422, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1994: Train: 0.003558, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1995: Train: 0.004073, LR: 2.29e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1996: Train: 0.003178, LR: 2.28e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1997: Train: 0.004011, LR: 2.28e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1998: Train: 0.003563, LR: 2.28e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 1999: Train: 0.003417, LR: 2.28e-03
#           Best: Train: 0.002870 (Epoch 1767)
# Epoch 2000: Train: 0.003738, LR: 2.28e-03
#           Best: Train: 0.002870 (Epoch 1767)
#
# Training completed!
# ============================================================
# Best Performance (Epoch 1767):
#   Best Train Loss:  0.002870
# ============================================================
# Final Performance (Epoch 2000):
#   Final Train Loss: 0.003738
#   Final LR:         2.28e-03
# ============================================================
# Warmup completed at epoch 200 with peak LR: 7.22e-03
#
# ✅ Best model (Epoch 1767) successfully saved in memory!
#    Best model loss: 0.002870
#    Best model also saved to file: BMED_TF_251010.pth

# %%
# 전체 실험 데이터에 대한 종합적인 시각화 - 8개 feature별 개별 플롯 (수정됨)
# 각 플롯은 모든 실험을 서브플롯으로 표시

def denormalize_data(normalized_data, feature_name):
    """정규화된 데이터를 원래 단위로 복원"""
    if feature_name in range_mm:
        min_val = range_mm[feature_name]['min']
        max_val = range_mm[feature_name]['max']
        return normalized_data * (max_val - min_val) + min_val
    return normalized_data

print("🚀 전체 실험 데이터 comprehensive evaluation 시작...")

# Device 및 모델 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
evaluation_model = best_model if best_model is not None else model

# feature 정보 재정의
feature_names = ['VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']
feature_indices = [2, 3, 4, 5, 6, 7, 8, 9]
feature_units = ['L', 'L', 'L', 'mol/L', 'mol/L', 'mol/L', 'mol/L', 'A']
feature_titles = ['Feed Volume', 'Acid Volume', 'Base Volume', 'Feed LA Conc.', 'Acid LA Conc.', 'Feed K Conc.', 'Base K Conc.', 'Current']

# 전체 실험 데이터 수집
all_experiment_results = {}
available_exp_nums = sorted(ndf['exp'].unique())
total_experiments = len(available_exp_nums)

print(f"📋 전체 {total_experiments}개 실험 데이터 수집 중...")
print(f"🔧 데이터로더 배치 크기: {dataloader.batch_size}")
print(f"🔧 총 배치 개수: {len(dataloader)}")

evaluation_model.eval()
with torch.no_grad():
    experiment_counter = 0
    
    for batch_idx, (input_seq, seq_lengths) in enumerate(dataloader):
        try:
            batch_size = input_seq.size(0)
            print(f"📦 배치 {batch_idx}: {batch_size}개 실험 처리 중...")
            
            input_seq = input_seq.to(device)
            seq_lengths = seq_lengths.to(device)
            
            # Teacher forcing 데이터 준비
            inputs, targets, target_seq_lengths = tf_data(input_seq, seq_lengths)
            
            # 모델 예측
            predictions = evaluation_model(inputs, target_seq_lengths)
            
            # CPU로 이동
            predictions_cpu = predictions.cpu().numpy()
            targets_cpu = targets.cpu().numpy()
            input_seq_cpu = input_seq.cpu().numpy()
            
            # 배치 내 모든 샘플 처리
            for sample_idx in range(batch_size):
                if experiment_counter >= total_experiments:
                    break
                    
                # 현재 실험 번호
                actual_exp_num = available_exp_nums[experiment_counter]
                
                # 샘플 데이터 추출
                pred_sample = predictions_cpu[sample_idx]
                actual_sample = targets_cpu[sample_idx]
                initial_sample = input_seq_cpu[sample_idx]
                seq_len = target_seq_lengths[sample_idx].item()
                full_seq_len = seq_lengths[sample_idx].item()
                
                # 실제 시퀀스 길이만큼만 사용
                pred_sample = pred_sample[:seq_len]
                actual_sample = actual_sample[:seq_len]
                initial_sample = initial_sample[:full_seq_len]
                
                # 시간 축 생성
                time_points = np.arange(full_seq_len) * 0.25
                
                # 예측값을 초기값과 연결
                prediction_full = np.zeros((full_seq_len, 10))
                prediction_full[0] = initial_sample[0]
                prediction_full[1:seq_len+1] = pred_sample
                
                # 실험 조건 정보
                voltage = denormalize_data(initial_sample[0, 0], 'V')
                electrolyte = denormalize_data(initial_sample[0, 1], 'E')
                
                # 결과 저장
                all_experiment_results[actual_exp_num] = {
                    'time_points': time_points,
                    'actual_data': initial_sample,
                    'predicted_data': prediction_full,
                    'seq_len': seq_len,
                    'full_seq_len': full_seq_len,
                    'voltage': voltage,
                    'electrolyte': electrolyte,
                    'actual_sample': actual_sample,
                    'pred_sample': pred_sample
                }
                
                print(f"✅ 실험 {actual_exp_num}: {full_seq_len*0.25:.1f}h, {voltage:.1f}V, {electrolyte:.3f}M")
                experiment_counter += 1
            
        except Exception as e:
            print(f"❌ 배치 {batch_idx} 오류: {str(e)}")
            import traceback
            traceback.print_exc()
            continue

print(f"📊 총 {len(all_experiment_results)}개 실험 데이터 수집 완료!")

# 서브플롯 배치 계산
import math
sqrt_exp = math.ceil(math.sqrt(total_experiments))
if sqrt_exp * (sqrt_exp - 1) >= total_experiments:
    grid_rows, grid_cols = sqrt_exp - 1, sqrt_exp
else:
    grid_rows, grid_cols = sqrt_exp, sqrt_exp

print(f"📐 각 feature당 {grid_rows}x{grid_cols} 서브플롯 그리드 사용")

# 8개 feature별로 개별 figure 생성
for feature_idx, (feature_name, feature_index, unit, title) in enumerate(zip(feature_names, feature_indices, feature_units, feature_titles)):
    print(f"🎨 Feature {feature_idx+1}/8: {feature_name} ({title}) 생성 중...")
    
    # 새 figure 생성
    fig, axes = plt.subplots(grid_rows, grid_cols, figsize=(4*grid_cols, 3*grid_rows))
    if best_model is not None:
        suptitle = f'{title} ({feature_name}) - All Experiments\nBest Model (Epoch {best_epoch}, Loss: {best_train_loss:.6f})'
    else:
        suptitle = f'{title} ({feature_name}) - All Experiments\nCurrent Model'
    fig.suptitle(suptitle, fontsize=16, fontweight='bold')
    
    # axes 처리 (1차원으로 변환)
    if grid_rows * grid_cols == 1:
        axes = [axes]
    else:
        axes = axes.flatten() if hasattr(axes, 'flatten') else [axes]
    
    # 성능 지표 수집
    rmse_values = []
    r2_values = []
    
    # 각 실험별 subplot
    for plot_idx, exp_num in enumerate(sorted(all_experiment_results.keys())):
        if plot_idx >= len(axes):
            break
            
        ax = axes[plot_idx]
        exp_data = all_experiment_results[exp_num]
        
        # 데이터 denormalize
        actual_denorm = denormalize_data(exp_data['actual_data'][:, feature_index], feature_name)
        pred_denorm = denormalize_data(exp_data['predicted_data'][:exp_data['seq_len']+1, feature_index], feature_name)
        
        # 플롯 생성
        ax.plot(exp_data['time_points'], actual_denorm, 'b-', linewidth=1.5, label='Actual', alpha=0.8)
        ax.plot(exp_data['time_points'][:exp_data['seq_len']+1], pred_denorm, 'r--', linewidth=1.5, label='Predicted', alpha=0.8)
        
        # 시작점 표시
        ax.plot(exp_data['time_points'][0], actual_denorm[0], 'go', markersize=3)
        ax.axvline(x=exp_data['time_points'][1], color='gray', linestyle=':', alpha=0.5)
        
        # 성능 지표 계산
        actual_pred_denorm = denormalize_data(exp_data['actual_sample'][:, feature_index], feature_name)
        pred_pred_denorm = denormalize_data(exp_data['pred_sample'][:, feature_index], feature_name)
        
        rmse = np.sqrt(np.mean((actual_pred_denorm - pred_pred_denorm)**2))
        if np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2) > 0:
            r2 = 1 - (np.sum((actual_pred_denorm - pred_pred_denorm)**2) / np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2))
        else:
            r2 = 0.0
            
        rmse_values.append(rmse)
        r2_values.append(r2)
        
        # 서브플롯 설정
        condition_text = f'{exp_data["voltage"]:.1f}V, {exp_data["electrolyte"]:.2f}M'
        ax.set_title(f'Exp {exp_num}: {condition_text}\nRMSE: {rmse:.3f} {unit}', fontsize=9)
        ax.set_xlabel('Time (hours)', fontsize=8)
        ax.set_ylabel(f'{feature_name} ({unit})', fontsize=8)
        ax.grid(True, alpha=0.3)
        ax.tick_params(labelsize=7)
        
        # 첫 번째 subplot에만 범례 추가
        if plot_idx == 0:
            ax.legend(fontsize=8, loc='upper right')
    
    # 빈 subplot 숨기기
    for plot_idx in range(len(all_experiment_results), len(axes)):
        axes[plot_idx].set_visible(False)
    
    # 전체 성능 요약
    avg_rmse = np.mean(rmse_values)
    std_rmse = np.std(rmse_values)
    avg_r2 = np.mean(r2_values)
    std_r2 = np.std(r2_values)
    
    # 성능 요약 텍스트 박스
    summary_text = f'Overall Performance:\nRMSE: {avg_rmse:.4f} ± {std_rmse:.4f} {unit}\nR²: {avg_r2:.3f} ± {std_r2:.3f}\nExperiments: {len(rmse_values)}'
    fig.text(0.02, 0.02, summary_text, fontsize=10, 
             bbox=dict(boxstyle='round,pad=0.5', facecolor='lightblue', alpha=0.8))
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.92, bottom=0.12, left=0.05, right=0.98)
    plt.show()
    
    print(f"✅ {feature_name} 완료: 평균 RMSE = {avg_rmse:.4f} {unit}, 평균 R² = {avg_r2:.3f}")

# 전체 요약 출력
print("\n" + "="*80)
print("COMPREHENSIVE EVALUATION SUMMARY - ALL EXPERIMENTS")
print("="*80)

for feature_idx, (feature_name, feature_index, unit) in enumerate(zip(feature_names, feature_indices, feature_units)):
    # 각 feature별 전체 성능 통계
    all_rmse = []
    all_mae = []
    all_r2 = []
    
    for exp_num in sorted(all_experiment_results.keys()):
        exp_data = all_experiment_results[exp_num]
        
        actual_pred_denorm = denormalize_data(exp_data['actual_sample'][:, feature_index], feature_name)
        pred_pred_denorm = denormalize_data(exp_data['pred_sample'][:, feature_index], feature_name)
        
        rmse = np.sqrt(np.mean((actual_pred_denorm - pred_pred_denorm)**2))
        mae = np.mean(np.abs(actual_pred_denorm - pred_pred_denorm))
        
        if np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2) > 0:
            r2 = 1 - (np.sum((actual_pred_denorm - pred_pred_denorm)**2) / np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2))
        else:
            r2 = 0.0
        
        all_rmse.append(rmse)
        all_mae.append(mae)
        all_r2.append(r2)
    
    print(f"{feature_name:6s}: RMSE={np.mean(all_rmse):.4f}±{np.std(all_rmse):.4f} {unit}, "
          f"MAE={np.mean(all_mae):.4f}±{np.std(all_mae):.4f} {unit}, "
          f"R²={np.mean(all_r2):.3f}±{np.std(all_r2):.3f}")

print("-"*80)
print(f"📊 Total experiments analyzed: {len(all_experiment_results)}")
if best_model is not None:
    print(f"🏆 Best model used: Epoch {best_epoch}, Loss: {best_train_loss:.6f}")
else:
    print("📋 Current model used")
print("="*80)

print("🎉 Comprehensive evaluation 완료! 8개의 feature별 플롯이 모든 실험 데이터를 포함하여 생성되었습니다.")
# Out:
# 🚀 전체 실험 데이터 comprehensive evaluation 시작...
# 📋 전체 15개 실험 데이터 수집 중...
# 🔧 데이터로더 배치 크기: 3
# 🔧 총 배치 개수: 5
# 📦 배치 0: 3개 실험 처리 중...
# ✅ 실험 0: 4.2h, 20.0V, 0.250M
# ✅ 실험 1: 5.2h, 30.0V, 0.250M
# ✅ 실험 2: 5.2h, 30.0V, 0.250M
# 📦 배치 1: 3개 실험 처리 중...
# ✅ 실험 3: 5.2h, 30.0V, 0.250M
# ✅ 실험 4: 7.2h, 20.0V, 0.250M
# ✅ 실험 5: 9.2h, 20.0V, 0.250M
# 📦 배치 2: 3개 실험 처리 중...
# ✅ 실험 6: 4.2h, 10.0V, 0.250M
# ✅ 실험 7: 7.2h, 10.0V, 0.250M
# ✅ 실험 8: 8.2h, 30.0V, 0.250M
# 📦 배치 3: 3개 실험 처리 중...
# ✅ 실험 9: 5.2h, 30.0V, 0.250M
# ✅ 실험 10: 6.2h, 30.0V, 0.250M
# ✅ 실험 11: 6.2h, 35.0V, 0.500M
# 📦 배치 4: 3개 실험 처리 중...
# ✅ 실험 12: 5.2h, 35.0V, 0.250M
# ✅ 실험 13: 5.2h, 35.0V, 1.000M
# ✅ 실험 14: 4.8h, 30.0V, 0.250M
# 📊 총 15개 실험 데이터 수집 완료!
# 📐 각 feature당 4x4 서브플롯 그리드 사용
# 🎨 Feature 1/8: VF (Feed Volume) 생성 중...
# ✅ VF 완료: 평균 RMSE = 0.0051 L, 평균 R² = 0.991
# 🎨 Feature 2/8: VA (Acid Volume) 생성 중...
# ✅ VA 완료: 평균 RMSE = 0.0036 L, 평균 R² = 0.974
# 🎨 Feature 3/8: VB (Base Volume) 생성 중...
# ✅ VB 완료: 평균 RMSE = 0.0047 L, 평균 R² = 0.983
# 🎨 Feature 4/8: CFLA (Feed LA Conc.) 생성 중...
# ✅ CFLA 완료: 평균 RMSE = 0.0116 mol/L, 평균 R² = 0.996
# 🎨 Feature 5/8: CALA (Acid LA Conc.) 생성 중...
# ✅ CALA 완료: 평균 RMSE = 0.0078 mol/L, 평균 R² = 0.995
# 🎨 Feature 6/8: CFK (Feed K Conc.) 생성 중...
# ✅ CFK 완료: 평균 RMSE = 0.0164 mol/L, 평균 R² = 0.999
# 🎨 Feature 7/8: CBK (Base K Conc.) 생성 중...
# ✅ CBK 완료: 평균 RMSE = 0.0089 mol/L, 평균 R² = 0.999
# 🎨 Feature 8/8: I (Current) 생성 중...
# ✅ I 완료: 평균 RMSE = 0.0594 A, 평균 R² = 0.712
#
# ================================================================================
# COMPREHENSIVE EVALUATION SUMMARY - ALL EXPERIMENTS
# ================================================================================
# VF    : RMSE=0.0051±0.0016 L, MAE=0.0040±0.0012 L, R²=0.991±0.016
# VA    : RMSE=0.0036±0.0014 L, MAE=0.0029±0.0011 L, R²=0.974±0.064
# VB    : RMSE=0.0047±0.0024 L, MAE=0.0037±0.0018 L, R²=0.983±0.018
# CFLA  : RMSE=0.0116±0.0063 mol/L, MAE=0.0090±0.0044 mol/L, R²=0.996±0.005
# CALA  : RMSE=0.0078±0.0037 mol/L, MAE=0.0062±0.0028 mol/L, R²=0.995±0.008
# CFK   : RMSE=0.0164±0.0067 mol/L, MAE=0.0125±0.0058 mol/L, R²=0.999±0.001
# CBK   : RMSE=0.0089±0.0044 mol/L, MAE=0.0066±0.0036 mol/L, R²=0.999±0.001
# I     : RMSE=0.0594±0.0148 A, MAE=0.0524±0.0166 A, R²=0.712±0.718
# --------------------------------------------------------------------------------
# 📊 Total experiments analyzed: 15
# 🏆 Best model used: Epoch 1767, Loss: 0.002870
# ================================================================================
# 🎉 Comprehensive evaluation 완료! 8개의 feature별 플롯이 모든 실험 데이터를 포함하여 생성되었습니다.
