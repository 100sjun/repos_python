# %%
import pandas as pd
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# %%
def df_treat(name):
    df = pd.read_csv(name)
    ndf = pd.DataFrame()
    range_mm={
        'V': {'min':df['V'].min()*0.8, 'max': df['V'].max()*1.2},
        'E': {'min':df['E'].min()*0.8, 'max': df['E'].max()*1.2},
        'VF': {'min':df['VF'].min()*0.8, 'max': df['VF'].max()*1.2},
        'VA': {'min':df['VA'].min()*0.8, 'max': df['VA'].max()*1.2},
        'VB': {'min':df['VB'].min()*0.8, 'max': df['VB'].max()*1.2},
        'CFLA': {'min':0, 'max': df['CFLA'].max()*1.2},
        'CALA': {'min':0, 'max': df['CALA'].max()*1.2},
        'CFK': {'min':0, 'max': df['CFK'].max()*1.2},
        'CBK': {'min':0, 'max': df['CBK'].max()*1.2},
        'I': {'min':0, 'max': df['I'].max()*1.2},
    }
    ndf['exp'] = df['exp']; ndf['t'] = df['t']

    for col in ['V', 'E', 'VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']:
        if col in range_mm:
            ndf[col] = (df[col] - range_mm[col]['min'])/(range_mm[col]['max'] - range_mm[col]['min'])
        else:
            ndf[col] = df[col]

    exp_num_list = sorted(ndf['exp'].unique())

    return df, ndf, range_mm, exp_num_list

# %%
def seq_data(ndf, exp_num_list):
    seq = []
    feature_cols = ['V', 'E', 'VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']
    
    for exp in exp_num_list:
        exp_df = ndf[ndf['exp'] == exp]
        seq.append(exp_df[feature_cols].values)
    
    return seq

# %%
def pad_seq(seq):
    max_len = max([len(s) for s in seq])
    seq_len = [len(s) for s in seq]
    pad_seq = pad_sequence([torch.tensor(s) for s in seq], batch_first=True, padding_value=-1)

    return pad_seq, seq_len, max_len

# %%
def gen_dataset(pad_seq, seq_len):
    input_tensor = pad_seq.float()
    seq_len_tensor = torch.tensor(seq_len)
    dataset = TensorDataset(input_tensor, seq_len_tensor)
    return dataset

# %%
# LSTM with layer normalization
class LayerNormLSTM(nn.Module):
    def __init__(self, input_node, hidden_node):
        super().__init__()
        self.input_node = input_node
        self.hidden_node = hidden_node

        self.w_i = nn.Linear(input_node, 4*hidden_node, bias=False)
        self.w_h = nn.Linear(hidden_node, 4*hidden_node, bias=False)

        self.ln_i = nn.LayerNorm(hidden_node)
        self.ln_f = nn.LayerNorm(hidden_node)
        self.ln_w = nn.LayerNorm(hidden_node)
        self.ln_o = nn.LayerNorm(hidden_node)
        self.ln_c = nn.LayerNorm(hidden_node)

    def forward(self, input, hidden):
        h_prev, c_prev = hidden

        gi = self.w_i(input)
        gh = self.w_h(h_prev)
        i_i, i_f, i_w, i_o = gi.chunk(4, dim=-1)
        h_i, h_f, h_w, h_o = gh.chunk(4, dim=-1)

        i_g = torch.sigmoid(self.ln_i(i_i + h_i))
        f_g = torch.sigmoid(self.ln_f(i_f + h_f))
        w_g = torch.tanh(self.ln_w(i_w + h_w))
        o_g = torch.sigmoid(self.ln_o(i_o + h_o))
        

        c_new = f_g * c_prev + i_g * w_g
        c_new = self.ln_c(c_new)

        h_new = o_g * torch.tanh(c_new)

        return h_new, c_new

# %%
# State feature extractor using LayerNorm LSTM
class StateExtr(nn.Module):
    def __init__(self, input_node, hidden_node, n_layer, dropout):
        super().__init__()
        self.hidden_node = hidden_node
        self.n_layer = n_layer
        self.input_node = input_node

        self.lstm_cells = nn.ModuleList()
        self.lstm_cells.append(LayerNormLSTM(input_node, hidden_node))

        for i in range(n_layer - 1):
            self.lstm_cells.append(LayerNormLSTM(hidden_node, hidden_node))

        self.dropout = nn.Dropout(dropout)
        self.layernorm = nn.LayerNorm(hidden_node)

    def forward(self, x, seq_len):
        batch_size, max_len, _ = x.size()
        device = x.device

        h_states = []
        c_states = []

        for _ in range(self.n_layer):
            h_states.append(torch.zeros(batch_size, self.hidden_node, device=device))
            c_states.append(torch.zeros(batch_size, self.hidden_node, device=device))

        outputs = []
        for t in range(max_len):
            x_t = x[:, t, :]

            layer_input = x_t # initialize layer input with input tensor
            for layer_idx, lstm_cell in enumerate(self.lstm_cells):
                h_new, c_new = lstm_cell(layer_input, (h_states[layer_idx], c_states[layer_idx]))
                
                h_states[layer_idx] = h_new
                c_states[layer_idx] = c_new

                if layer_idx < len(self.lstm_cells) - 1:
                    layer_input = self.dropout(h_new)
                else:
                    layer_input = h_new

            outputs.append(layer_input)

        output_tensor = torch.stack(outputs, dim=1)
        seq_len_cpu = seq_len.detach().cpu().long()
        mask = torch.arange(max_len, device='cpu')[None, :] < seq_len_cpu[:, None]
        mask = mask.float().to(device).unsqueeze(-1)

        masked_output = output_tensor * mask
        normed_output = self.layernorm(masked_output)
        return self.dropout(normed_output)

# %%
# Physical change regressor
class PhysRegr(nn.Module):
    def __init__(self, input_node, output_node, n_layer, hidden_node, dropout):
        super().__init__()

        layers = []

        layers.extend([
            nn.Linear(input_node, hidden_node),
            nn.LayerNorm(hidden_node),
            nn.ReLU(),
            nn.Dropout(dropout)
        ])

        for _ in range(n_layer - 1):
            layers.extend([
                nn.Linear(hidden_node, hidden_node),
                nn.LayerNorm(hidden_node),
                nn.ReLU(),
                nn.Dropout(dropout)
            ])
        
        layers.append(nn.Linear(hidden_node, output_node))

        self.layers = nn.Sequential(*layers)

    def forward(self, hidden_states):
        return self.layers(hidden_states)

# %%
# Current regressor
class CurrRegr(nn.Module):
    def __init__(self, input_node, hidden_node, n_layer, dropout):
        super().__init__()

        layers = []

        layers.extend([
            nn.Linear(input_node, hidden_node),
            nn.LayerNorm(hidden_node),
            nn.ReLU(),
            nn.Dropout(dropout)
        ])

        for _ in range(n_layer - 1):
            layers.extend([
                nn.Linear(hidden_node, hidden_node),
                nn.LayerNorm(hidden_node),
                nn.ReLU(),
                nn.Dropout(dropout)
            ])
        
        layers.append(nn.Linear(hidden_node, 1))

        self.layers = nn.Sequential(*layers)

    def forward(self, hidden_states):
        return self.layers(hidden_states)

# %%
class PhysConstr(nn.Module):
    def __init__(self, range_mm, curr_regr, eps=1e-2):
        super().__init__()
        self.eps = eps
        self.curr_regr = curr_regr
        self.register_buffer('range_mm_tensor', self._range2tensor(range_mm))

    def _range2tensor(self, range_mm):
        feature_names = ['V','E','VF','VA','VB','CFLA','CALA','CFK','CBK','I']
        ranges = torch.zeros(len(feature_names),2)

        for i, name in enumerate(feature_names):
            if name in range_mm:
                ranges[i, 0] = range_mm[name]['min']
                ranges[i, 1] = range_mm[name]['max']
        
        return ranges
    
    def _norm_tensor(self, data, feature_idx):
        min_val = self.range_mm_tensor[feature_idx, 0]
        max_val = self.range_mm_tensor[feature_idx, 1]
        return (data - min_val) / (max_val - min_val)

    def _denorm_tensor(self, norm_data, feature_idx):
        min_val = self.range_mm_tensor[feature_idx, 0]
        max_val = self.range_mm_tensor[feature_idx, 1]
        return norm_data * (max_val - min_val) + min_val

    def forward(self, phys_chng, cur_state):
        V_idx, E_idx, VF_idx, VA_idx, VB_idx = 0, 1, 2, 3, 4
        CFLA_idx, CALA_idx, CFK_idx, CBK_idx, I_idx = 5, 6, 7, 8, 9

        VF = self._denorm_tensor(cur_state[..., 2:3], VF_idx)
        VA = self._denorm_tensor(cur_state[..., 3:4], VA_idx)
        VB = self._denorm_tensor(cur_state[..., 4:5], VB_idx)
        CFLA = self._denorm_tensor(cur_state[..., 5:6], CFLA_idx)
        CALA = self._denorm_tensor(cur_state[..., 6:7], CALA_idx)
        CFK = self._denorm_tensor(cur_state[..., 7:8], CFK_idx)
        CBK = self._denorm_tensor(cur_state[..., 8:9], CBK_idx)

        dVA = phys_chng[..., 0:1]
        dVB = phys_chng[..., 1:2]
        rratio = phys_chng[..., 2:3]
        dNBK = phys_chng[..., 3:4]

        ## physical boundary: dNALA <= dNBK
        ratio = torch.sigmoid(rratio)
        dNALA = ratio * dNBK

        NFLA = CFLA * VF
        NALA = CALA * VA
        NFK = CFK * VF
        NBK = CBK * VB

        ### conservation
        dVA = torch.where(VF < dVA + dVB, torch.zeros_like(dVA), dVA)
        dVB = torch.where(VF < dVA + dVB, torch.zeros_like(dVB), dVB)
        dNALA = torch.where(NFLA < dNALA, torch.zeros_like(dNALA), dNALA)
        dNBK = torch.where(NFK < dNBK, torch.zeros_like(dNBK), dNBK)

        nVF = VF - dVA - dVB
        nVA = VA + dVA
        nVB = VB + dVB

        nVF = torch.clamp(nVF, min=self.eps)
        nVA = torch.clamp(nVA, min=self.eps)
        nVB = torch.clamp(nVB, min=self.eps)
        
        nNFLA = NFLA - dNALA
        nNALA = NALA + dNALA
        nNFK = NFK - dNBK
        nNBK = NBK + dNBK

        nCFLA = nNFLA / nVF
        nCALA = nNALA / nVA
        nCFK = nNFK / nVF
        nCBK = nNBK / nVB

        V = cur_state[..., 0:1]
        E = cur_state[..., 1:2]
        nVF_norm = self._norm_tensor(nVF, VF_idx)
        nVA_norm = self._norm_tensor(nVA, VA_idx)
        nVB_norm = self._norm_tensor(nVB, VB_idx)
        nCFLA_norm = self._norm_tensor(nCFLA, CFLA_idx)
        nCALA_norm = self._norm_tensor(nCALA, CALA_idx)
        nCFK_norm = self._norm_tensor(nCFK, CFK_idx)
        nCBK_norm = self._norm_tensor(nCBK, CBK_idx)

        # Create temporary state without I for current prediction
        temp_state = torch.cat([
            V, E, nVF_norm, nVA_norm, nVB_norm, nCFLA_norm, nCALA_norm, nCFK_norm, nCBK_norm
        ], dim=-1)
        
        # Predict new I using the current predictor
        nI_pred = self.curr_regr(temp_state)
        nI_real = self._denorm_tensor(nI_pred, I_idx)
        nI_real = torch.clamp(nI_real, min=0.0)
        nI_norm = self._norm_tensor(nI_real, I_idx)

        # Create final next state with predicted I
        next_state = torch.cat([
            V, E, nVF_norm, nVA_norm, nVB_norm, nCFLA_norm, nCALA_norm, nCFK_norm, nCBK_norm, nI_norm
        ], dim=-1)
        
        return next_state

# %%
class BMEDAutoregressiveModel(nn.Module):
    def __init__(self, state_extr_params, phys_regr_params, curr_regr_params, range_mm):
        super().__init__()
        self.state_extr = StateExtr(**state_extr_params)
        self.phys_regr = PhysRegr(**phys_regr_params)
        self.curr_regr = CurrRegr(**curr_regr_params)
        self.phys_constr = PhysConstr(range_mm, self.curr_regr)

    def forward(self, x, seq_len):
        hidden_states = self.state_extr(x, seq_len)
        phys_chng = self.phys_regr(hidden_states)
        new_x = self.phys_constr(phys_chng, x)
        
        return new_x

# %%
def masked_mse_loss(pred, target, seq_len):
    _, max_len, _ = pred.shape
    seq_len_cpu = seq_len.detach().cpu().long()

    mask = torch.arange(max_len, device='cpu')[None, :] < seq_len_cpu[:, None]
    mask = mask.float().to(pred.device)

    loss = F.mse_loss(pred, target, reduction='none')
    masked_loss = loss * mask.unsqueeze(-1)

    total_loss = masked_loss.sum()
    total_elements = mask.sum()

    masked_loss = total_loss / total_elements
    return masked_loss

# %%
def tf_data(input_seq, seq_len):
    inputs = input_seq[:, :-1, :-1]
    targets = input_seq[:, 1:, :]

    target_seq_len = seq_len - 1

    return inputs, targets, target_seq_len

# %%
class NoamScheduler:
    def __init__(self, optimizer, model_size, warmup_epochs, factor=1.0):
        self.optimizer = optimizer
        self.model_size = model_size
        self.warmup_epochs = warmup_epochs
        self.factor = factor
        self.epoch_num = 0

    def step_epoch(self):
        self.epoch_num += 1
        lr = self.factor * (
            self.model_size ** (-0.5) *
            min(self.epoch_num ** (-0.5), self.epoch_num * self.warmup_epochs ** (-1.5))
        )
    
        for param_group in self.optimizer.param_groups:
            param_group['lr'] = lr

        return lr

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
df, ndf, range_mm, exp_num_list = df_treat('BMED_DATA_AG.csv')
seq = seq_data(ndf, exp_num_list)
pad, seq_len, max_len = pad_seq(seq)
dataset = gen_dataset(pad, seq_len)
dataloader = DataLoader(dataset, batch_size=3, shuffle=False)

# %%
state_extr_params = {
    'input_node': 9,
    'hidden_node': 72,
    'n_layer': 4,
    'dropout': 0.1
}

phys_regr_params = {
    'input_node': state_extr_params['hidden_node'],
    'hidden_node': 32,
    'n_layer': 6,
    'dropout': 0.1,
    'output_node': 4
}

curr_regr_params = {
    'input_node': 9,
    'hidden_node': 72,
    'n_layer': 2,
    'dropout': 0.3
}

model = BMEDAutoregressiveModel(state_extr_params, phys_regr_params, curr_regr_params, range_mm)
model = model.to(device)
print(f"Model architecture:")
print(f"  Input features: {state_extr_params['input_node']} (without current)")
print(f"  State Extractor Hidden size: {state_extr_params['hidden_node']}")
print(f"  State Extractor layers: {state_extr_params['n_layer']}")
print(f"  Phys Regressor layers: {phys_regr_params['n_layer']}")
print(f"  Phys Regressor Hidden size: {phys_regr_params['hidden_node']}")
print(f"  Current Predictor layers: {curr_regr_params['n_layer']}")
print(f"  Current Predictor Hidden size: {curr_regr_params['hidden_node']}")
print(f"  Model parameters: {sum(p.numel() for p in model.parameters()):,}")
print(f"  Physics constraints: Volume conservation with denormalization")

num_epochs = 2000
optimizer = torch.optim.AdamW(model.parameters(), lr=1.0)
warmup_epochs = int(num_epochs * 0.1)
scheduler = NoamScheduler(optimizer, model_size=state_extr_params['hidden_node'], warmup_epochs=warmup_epochs, factor=1)

print(f"\nTraining configuration:")
print(f"  Total epochs: {num_epochs:,}")
print(f"  Warmup epochs: {warmup_epochs:,} (10%)")
peak_lr = 1 * (48 ** (-0.5)) * (warmup_epochs ** (-0.5))
print(f"  Peak learning rate: {peak_lr:.2e}")
# Out:
# Model architecture:
#   Input features: 9 (without current)
#   State Extractor Hidden size: 72
#   State Extractor layers: 4
#   Phys Regressor layers: 6
#   Phys Regressor Hidden size: 32
#   Current Predictor layers: 2
#   Current Predictor Hidden size: 72
#   Model parameters: 165,237
#   Physics constraints: Volume conservation with denormalization
#
# Training configuration:
#   Total epochs: 2,000
#   Warmup epochs: 200 (10%)
#   Peak learning rate: 1.02e-02

# %%
train_samples = len(dataloader.dataset)
best_train_loss = float('inf')
best_epoch = 0
train_losses = []
learning_rates = []

best_model = None

print("Training started...")
print(f"Total batches per epoch: {len(dataloader)}")

for epoch in range(num_epochs):
    current_lr = scheduler.step_epoch()

    model.train()
    train_loss = 0.0
    train_batches = 0

    for batch_idx, (input_seq, seq_len) in enumerate(dataloader):
        try:
            input_seq = input_seq.to(device)
            seq_len = seq_len.to(device)

            inputs, targets, target_seq_len = tf_data(input_seq, seq_len)
            
            optimizer.zero_grad()
            pred = model(inputs, target_seq_len)
            loss = masked_mse_loss(pred, targets, target_seq_len)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            train_loss += loss.item()
            train_batches += 1

        except Exception as e:
            print(f"Training batch {batch_idx} error: {str(e)}")
            print(f"Input shape: {input_seq.shape if 'input_seq' in locals() else 'N/A'}")
            print(f"Seq lengths: {seq_len if 'seq_lengths' in locals() else 'N/A'}")
            import traceback
            traceback.print_exc()
            continue
    
    if train_batches == 0:
        print("No valid training batches")
        break

    train_losses.append(train_loss)
    learning_rates.append(current_lr)

    if train_loss < best_train_loss:
        best_train_loss = train_loss
        best_epoch = epoch + 1
        best_status = " ★ NEW BEST"
        
        # Best model을 메모리에 복사하여 저장
        import copy
        best_model = copy.deepcopy(model)
        print(f"          Best model saved in memory at epoch {best_epoch}")
        
        # 오늘 날짜로 모델 파일 저장
        from datetime import datetime
        today = datetime.now().strftime("%y%m%d")
        model_filename = f"BMED_TF_{today}.pth"
        torch.save({
            'model_state_dict': best_model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'epoch': best_epoch,
            'best_train_loss': best_train_loss,
            'model_config': {
                'state_extr_params': state_extr_params,
                'phys_regr_params': phys_regr_params,
                'curr_regr_params': curr_regr_params,
                'range_mm': range_mm
            }
        }, model_filename)
        print(f"          Best model saved to {model_filename}")
    else:
        best_status = ""

    # Warmup 구간 표시
    if epoch + 1 <= warmup_epochs:
        warmup_status = " [WARMUP]"
    else:
        warmup_status = ""

    # 매 에포크마다 로깅 - best 성능 정보 포함
    print(f"Epoch {epoch+1:4d}: Train: {train_loss:.6f}, LR: {current_lr:.2e}{best_status}{warmup_status}")    

    if epoch == 0:
        print(f"          Best: Train: {best_train_loss:.6f}, (Epoch {best_epoch})")
    elif train_loss < best_train_loss:
        print(f"          ✓ Updated Best: Train: {best_train_loss:.6f}")
    else:
        print(f"          Best: Train: {best_train_loss:.6f} (Epoch {best_epoch})")

print(f"\nTraining completed!")
print(f"=" * 60)

# 안전한 결과 출력
if len(train_losses) > 0:
    print(f"Best Performance (Epoch {best_epoch}):")
    print(f"  Best Train Loss:  {best_train_loss:.6f}")
    print(f"=" * 60)
    print(f"Final Performance (Epoch {len(train_losses)}):")
    print(f"  Final Train Loss: {train_losses[-1]:.6f}")
    print(f"  Final LR:         {current_lr:.2e}")
    print(f"=" * 60)
    if len(learning_rates) > 0:
        print(f"Warmup completed at epoch {warmup_epochs} with peak LR: {max(learning_rates):.2e}")
else:
    print("⚠️ No training completed - check error messages above")

# Best model이 저장되었는지 확인
if best_model is not None:
    print(f"\n✅ Best model (Epoch {best_epoch}) successfully saved in memory!")
    print(f"   Best model loss: {best_train_loss:.6f}")
    from datetime import datetime
    today = datetime.now().strftime("%y%m%d")
    model_filename = f"BMED_TF_{today}.pth"
    print(f"   Best model also saved to file: {model_filename}")
else:
    print("\n⚠️ No best model was saved (training may have failed)")
    best_model = model  # fallback to current model
# Out:
# Training started...
# Total batches per epoch: 5
#           Best model saved in memory at epoch 1
#           Best model saved to BMED_TF_250916.pth
# Epoch    1: Train: 60.898311, LR: 4.17e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 60.898311, (Epoch 1)
#           Best model saved in memory at epoch 2
#           Best model saved to BMED_TF_250916.pth
# Epoch    2: Train: 38.706789, LR: 8.33e-05 ★ NEW BEST [WARMUP]
#           Best: Train: 38.706789 (Epoch 2)
# Epoch    3: Train: 67.886155, LR: 1.25e-04 [WARMUP]
#           Best: Train: 38.706789 (Epoch 2)
# Epoch    4: Train: 110.934541, LR: 1.67e-04 [WARMUP]
#           Best: Train: 38.706789 (Epoch 2)
# Epoch    5: Train: 81.314712, LR: 2.08e-04 [WARMUP]
#           Best: Train: 38.706789 (Epoch 2)
#           Best model saved in memory at epoch 6
#           Best model saved to BMED_TF_250916.pth
# Epoch    6: Train: 16.150933, LR: 2.50e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 16.150933 (Epoch 6)
# Epoch    7: Train: 61.747581, LR: 2.92e-04 [WARMUP]
#           Best: Train: 16.150933 (Epoch 6)
# Epoch    8: Train: 52.331624, LR: 3.33e-04 [WARMUP]
#           Best: Train: 16.150933 (Epoch 6)
#           Best model saved in memory at epoch 9
#           Best model saved to BMED_TF_250916.pth
# Epoch    9: Train: 13.386159, LR: 3.75e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 13.386159 (Epoch 9)
#           Best model saved in memory at epoch 10
#           Best model saved to BMED_TF_250916.pth
# Epoch   10: Train: 1.557510, LR: 4.17e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 1.557510 (Epoch 10)
#           Best model saved in memory at epoch 11
#           Best model saved to BMED_TF_250916.pth
# Epoch   11: Train: 1.414347, LR: 4.58e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 1.414347 (Epoch 11)
#           Best model saved in memory at epoch 12
#           Best model saved to BMED_TF_250916.pth
# Epoch   12: Train: 0.874239, LR: 5.00e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.874239 (Epoch 12)
#           Best model saved in memory at epoch 13
#           Best model saved to BMED_TF_250916.pth
# Epoch   13: Train: 0.850226, LR: 5.42e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.850226 (Epoch 13)
#           Best model saved in memory at epoch 14
#           Best model saved to BMED_TF_250916.pth
# Epoch   14: Train: 0.667656, LR: 5.83e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.667656 (Epoch 14)
#           Best model saved in memory at epoch 15
#           Best model saved to BMED_TF_250916.pth
# Epoch   15: Train: 0.548130, LR: 6.25e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.548130 (Epoch 15)
#           Best model saved in memory at epoch 16
#           Best model saved to BMED_TF_250916.pth
# Epoch   16: Train: 0.458396, LR: 6.67e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.458396 (Epoch 16)
#           Best model saved in memory at epoch 17
#           Best model saved to BMED_TF_250916.pth
# Epoch   17: Train: 0.383862, LR: 7.08e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.383862 (Epoch 17)
#           Best model saved in memory at epoch 18
#           Best model saved to BMED_TF_250916.pth
# Epoch   18: Train: 0.366198, LR: 7.50e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.366198 (Epoch 18)
# Epoch   19: Train: 0.383154, LR: 7.92e-04 [WARMUP]
#           Best: Train: 0.366198 (Epoch 18)
#           Best model saved in memory at epoch 20
#           Best model saved to BMED_TF_250916.pth
# Epoch   20: Train: 0.293152, LR: 8.33e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.293152 (Epoch 20)
#           Best model saved in memory at epoch 21
#           Best model saved to BMED_TF_250916.pth
# Epoch   21: Train: 0.235817, LR: 8.75e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.235817 (Epoch 21)
#           Best model saved in memory at epoch 22
#           Best model saved to BMED_TF_250916.pth
# Epoch   22: Train: 0.204959, LR: 9.17e-04 ★ NEW BEST [WARMUP]
#           Best: Train: 0.204959 (Epoch 22)
# Epoch   23: Train: 0.216064, LR: 9.58e-04 [WARMUP]
#           Best: Train: 0.204959 (Epoch 22)
#           Best model saved in memory at epoch 24
#           Best model saved to BMED_TF_250916.pth
# Epoch   24: Train: 0.178014, LR: 1.00e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.178014 (Epoch 24)
#           Best model saved in memory at epoch 25
#           Best model saved to BMED_TF_250916.pth
# Epoch   25: Train: 0.157123, LR: 1.04e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.157123 (Epoch 25)
# Epoch   26: Train: 0.177030, LR: 1.08e-03 [WARMUP]
#           Best: Train: 0.157123 (Epoch 25)
#           Best model saved in memory at epoch 27
#           Best model saved to BMED_TF_250916.pth
# Epoch   27: Train: 0.147267, LR: 1.12e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.147267 (Epoch 27)
#           Best model saved in memory at epoch 28
#           Best model saved to BMED_TF_250916.pth
# Epoch   28: Train: 0.142666, LR: 1.17e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.142666 (Epoch 28)
#           Best model saved in memory at epoch 29
#           Best model saved to BMED_TF_250916.pth
# Epoch   29: Train: 0.138327, LR: 1.21e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.138327 (Epoch 29)
#           Best model saved in memory at epoch 30
#           Best model saved to BMED_TF_250916.pth
# Epoch   30: Train: 0.132301, LR: 1.25e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.132301 (Epoch 30)
#           Best model saved in memory at epoch 31
#           Best model saved to BMED_TF_250916.pth
# Epoch   31: Train: 0.119583, LR: 1.29e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.119583 (Epoch 31)
#           Best model saved in memory at epoch 32
#           Best model saved to BMED_TF_250916.pth
# Epoch   32: Train: 0.110525, LR: 1.33e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.110525 (Epoch 32)
#           Best model saved in memory at epoch 33
#           Best model saved to BMED_TF_250916.pth
# Epoch   33: Train: 0.106781, LR: 1.37e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.106781 (Epoch 33)
# Epoch   34: Train: 0.110158, LR: 1.42e-03 [WARMUP]
#           Best: Train: 0.106781 (Epoch 33)
#           Best model saved in memory at epoch 35
#           Best model saved to BMED_TF_250916.pth
# Epoch   35: Train: 0.104528, LR: 1.46e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.104528 (Epoch 35)
#           Best model saved in memory at epoch 36
#           Best model saved to BMED_TF_250916.pth
# Epoch   36: Train: 0.090138, LR: 1.50e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.090138 (Epoch 36)
#           Best model saved in memory at epoch 37
#           Best model saved to BMED_TF_250916.pth
# Epoch   37: Train: 0.083843, LR: 1.54e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.083843 (Epoch 37)
# Epoch   38: Train: 0.093269, LR: 1.58e-03 [WARMUP]
#           Best: Train: 0.083843 (Epoch 37)
# Epoch   39: Train: 0.087615, LR: 1.62e-03 [WARMUP]
#           Best: Train: 0.083843 (Epoch 37)
#           Best model saved in memory at epoch 40
#           Best model saved to BMED_TF_250916.pth
# Epoch   40: Train: 0.075648, LR: 1.67e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.075648 (Epoch 40)
# Epoch   41: Train: 0.087989, LR: 1.71e-03 [WARMUP]
#           Best: Train: 0.075648 (Epoch 40)
# Epoch   42: Train: 0.083588, LR: 1.75e-03 [WARMUP]
#           Best: Train: 0.075648 (Epoch 40)
# Epoch   43: Train: 0.081519, LR: 1.79e-03 [WARMUP]
#           Best: Train: 0.075648 (Epoch 40)
# Epoch   44: Train: 0.083362, LR: 1.83e-03 [WARMUP]
#           Best: Train: 0.075648 (Epoch 40)
#           Best model saved in memory at epoch 45
#           Best model saved to BMED_TF_250916.pth
# Epoch   45: Train: 0.071361, LR: 1.87e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.071361 (Epoch 45)
#           Best model saved in memory at epoch 46
#           Best model saved to BMED_TF_250916.pth
# Epoch   46: Train: 0.063664, LR: 1.92e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.063664 (Epoch 46)
#           Best model saved in memory at epoch 47
#           Best model saved to BMED_TF_250916.pth
# Epoch   47: Train: 0.063067, LR: 1.96e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.063067 (Epoch 47)
# Epoch   48: Train: 0.068132, LR: 2.00e-03 [WARMUP]
#           Best: Train: 0.063067 (Epoch 47)
# Epoch   49: Train: 0.067512, LR: 2.04e-03 [WARMUP]
#           Best: Train: 0.063067 (Epoch 47)
# Epoch   50: Train: 0.065313, LR: 2.08e-03 [WARMUP]
#           Best: Train: 0.063067 (Epoch 47)
#           Best model saved in memory at epoch 51
#           Best model saved to BMED_TF_250916.pth
# Epoch   51: Train: 0.061390, LR: 2.12e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.061390 (Epoch 51)
# Epoch   52: Train: 0.066844, LR: 2.17e-03 [WARMUP]
#           Best: Train: 0.061390 (Epoch 51)
#           Best model saved in memory at epoch 53
#           Best model saved to BMED_TF_250916.pth
# Epoch   53: Train: 0.059027, LR: 2.21e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.059027 (Epoch 53)
# Epoch   54: Train: 0.065249, LR: 2.25e-03 [WARMUP]
#           Best: Train: 0.059027 (Epoch 53)
# Epoch   55: Train: 0.060798, LR: 2.29e-03 [WARMUP]
#           Best: Train: 0.059027 (Epoch 53)
#           Best model saved in memory at epoch 56
#           Best model saved to BMED_TF_250916.pth
# Epoch   56: Train: 0.051248, LR: 2.33e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.051248 (Epoch 56)
# Epoch   57: Train: 0.054588, LR: 2.37e-03 [WARMUP]
#           Best: Train: 0.051248 (Epoch 56)
#           Best model saved in memory at epoch 58
#           Best model saved to BMED_TF_250916.pth
# Epoch   58: Train: 0.046846, LR: 2.42e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.046846 (Epoch 58)
# Epoch   59: Train: 0.054591, LR: 2.46e-03 [WARMUP]
#           Best: Train: 0.046846 (Epoch 58)
# Epoch   60: Train: 0.061311, LR: 2.50e-03 [WARMUP]
#           Best: Train: 0.046846 (Epoch 58)
# Epoch   61: Train: 0.057261, LR: 2.54e-03 [WARMUP]
#           Best: Train: 0.046846 (Epoch 58)
# Epoch   62: Train: 0.056087, LR: 2.58e-03 [WARMUP]
#           Best: Train: 0.046846 (Epoch 58)
# Epoch   63: Train: 0.051425, LR: 2.63e-03 [WARMUP]
#           Best: Train: 0.046846 (Epoch 58)
# Epoch   64: Train: 0.056722, LR: 2.67e-03 [WARMUP]
#           Best: Train: 0.046846 (Epoch 58)
# Epoch   65: Train: 0.050911, LR: 2.71e-03 [WARMUP]
#           Best: Train: 0.046846 (Epoch 58)
#           Best model saved in memory at epoch 66
#           Best model saved to BMED_TF_250916.pth
# Epoch   66: Train: 0.045436, LR: 2.75e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.045436 (Epoch 66)
# Epoch   67: Train: 0.052374, LR: 2.79e-03 [WARMUP]
#           Best: Train: 0.045436 (Epoch 66)
# Epoch   68: Train: 0.046289, LR: 2.83e-03 [WARMUP]
#           Best: Train: 0.045436 (Epoch 66)
# Epoch   69: Train: 0.054508, LR: 2.87e-03 [WARMUP]
#           Best: Train: 0.045436 (Epoch 66)
#           Best model saved in memory at epoch 70
#           Best model saved to BMED_TF_250916.pth
# Epoch   70: Train: 0.041736, LR: 2.92e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.041736 (Epoch 70)
# Epoch   71: Train: 0.047963, LR: 2.96e-03 [WARMUP]
#           Best: Train: 0.041736 (Epoch 70)
# Epoch   72: Train: 0.046728, LR: 3.00e-03 [WARMUP]
#           Best: Train: 0.041736 (Epoch 70)
# Epoch   73: Train: 0.044302, LR: 3.04e-03 [WARMUP]
#           Best: Train: 0.041736 (Epoch 70)
#           Best model saved in memory at epoch 74
#           Best model saved to BMED_TF_250916.pth
# Epoch   74: Train: 0.040358, LR: 3.08e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.040358 (Epoch 74)
# Epoch   75: Train: 0.044037, LR: 3.12e-03 [WARMUP]
#           Best: Train: 0.040358 (Epoch 74)
# Epoch   76: Train: 0.044051, LR: 3.17e-03 [WARMUP]
#           Best: Train: 0.040358 (Epoch 74)
# Epoch   77: Train: 0.048997, LR: 3.21e-03 [WARMUP]
#           Best: Train: 0.040358 (Epoch 74)
# Epoch   78: Train: 0.042939, LR: 3.25e-03 [WARMUP]
#           Best: Train: 0.040358 (Epoch 74)
# Epoch   79: Train: 0.044582, LR: 3.29e-03 [WARMUP]
#           Best: Train: 0.040358 (Epoch 74)
# Epoch   80: Train: 0.048460, LR: 3.33e-03 [WARMUP]
#           Best: Train: 0.040358 (Epoch 74)
# Epoch   81: Train: 0.067934, LR: 3.37e-03 [WARMUP]
#           Best: Train: 0.040358 (Epoch 74)
# Epoch   82: Train: 0.049261, LR: 3.42e-03 [WARMUP]
#           Best: Train: 0.040358 (Epoch 74)
# Epoch   83: Train: 0.042574, LR: 3.46e-03 [WARMUP]
#           Best: Train: 0.040358 (Epoch 74)
# Epoch   84: Train: 0.043961, LR: 3.50e-03 [WARMUP]
#           Best: Train: 0.040358 (Epoch 74)
#           Best model saved in memory at epoch 85
#           Best model saved to BMED_TF_250916.pth
# Epoch   85: Train: 0.037005, LR: 3.54e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.037005 (Epoch 85)
# Epoch   86: Train: 0.040392, LR: 3.58e-03 [WARMUP]
#           Best: Train: 0.037005 (Epoch 85)
# Epoch   87: Train: 0.043758, LR: 3.62e-03 [WARMUP]
#           Best: Train: 0.037005 (Epoch 85)
# Epoch   88: Train: 0.037741, LR: 3.67e-03 [WARMUP]
#           Best: Train: 0.037005 (Epoch 85)
# Epoch   89: Train: 0.041703, LR: 3.71e-03 [WARMUP]
#           Best: Train: 0.037005 (Epoch 85)
#           Best model saved in memory at epoch 90
#           Best model saved to BMED_TF_250916.pth
# Epoch   90: Train: 0.035568, LR: 3.75e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.035568 (Epoch 90)
#           Best model saved in memory at epoch 91
#           Best model saved to BMED_TF_250916.pth
# Epoch   91: Train: 0.033414, LR: 3.79e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.033414 (Epoch 91)
# Epoch   92: Train: 0.035897, LR: 3.83e-03 [WARMUP]
#           Best: Train: 0.033414 (Epoch 91)
# Epoch   93: Train: 0.033750, LR: 3.87e-03 [WARMUP]
#           Best: Train: 0.033414 (Epoch 91)
# Epoch   94: Train: 0.038623, LR: 3.92e-03 [WARMUP]
#           Best: Train: 0.033414 (Epoch 91)
#           Best model saved in memory at epoch 95
#           Best model saved to BMED_TF_250916.pth
# Epoch   95: Train: 0.033014, LR: 3.96e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.033014 (Epoch 95)
# Epoch   96: Train: 0.033933, LR: 4.00e-03 [WARMUP]
#           Best: Train: 0.033014 (Epoch 95)
# Epoch   97: Train: 0.039870, LR: 4.04e-03 [WARMUP]
#           Best: Train: 0.033014 (Epoch 95)
# Epoch   98: Train: 0.034704, LR: 4.08e-03 [WARMUP]
#           Best: Train: 0.033014 (Epoch 95)
# Epoch   99: Train: 0.036357, LR: 4.13e-03 [WARMUP]
#           Best: Train: 0.033014 (Epoch 95)
# Epoch  100: Train: 0.033952, LR: 4.17e-03 [WARMUP]
#           Best: Train: 0.033014 (Epoch 95)
# Epoch  101: Train: 0.034006, LR: 4.21e-03 [WARMUP]
#           Best: Train: 0.033014 (Epoch 95)
#           Best model saved in memory at epoch 102
#           Best model saved to BMED_TF_250916.pth
# Epoch  102: Train: 0.027155, LR: 4.25e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  103: Train: 0.034621, LR: 4.29e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  104: Train: 0.037365, LR: 4.33e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  105: Train: 0.029423, LR: 4.38e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  106: Train: 0.033619, LR: 4.42e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  107: Train: 0.034062, LR: 4.46e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  108: Train: 0.030949, LR: 4.50e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  109: Train: 0.029608, LR: 4.54e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  110: Train: 0.033754, LR: 4.58e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  111: Train: 0.030090, LR: 4.62e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  112: Train: 0.029476, LR: 4.67e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  113: Train: 0.032197, LR: 4.71e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  114: Train: 0.035686, LR: 4.75e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  115: Train: 0.042020, LR: 4.79e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  116: Train: 0.041034, LR: 4.83e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  117: Train: 0.043860, LR: 4.87e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  118: Train: 0.041877, LR: 4.92e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  119: Train: 0.039031, LR: 4.96e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  120: Train: 0.042247, LR: 5.00e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  121: Train: 0.040181, LR: 5.04e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  122: Train: 0.032866, LR: 5.08e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  123: Train: 0.029601, LR: 5.13e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  124: Train: 0.031072, LR: 5.17e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  125: Train: 0.033575, LR: 5.21e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  126: Train: 0.031345, LR: 5.25e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
# Epoch  127: Train: 0.032641, LR: 5.29e-03 [WARMUP]
#           Best: Train: 0.027155 (Epoch 102)
#           Best model saved in memory at epoch 128
#           Best model saved to BMED_TF_250916.pth
# Epoch  128: Train: 0.025497, LR: 5.33e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.025497 (Epoch 128)
# Epoch  129: Train: 0.031218, LR: 5.37e-03 [WARMUP]
#           Best: Train: 0.025497 (Epoch 128)
# Epoch  130: Train: 0.026169, LR: 5.42e-03 [WARMUP]
#           Best: Train: 0.025497 (Epoch 128)
# Epoch  131: Train: 0.028006, LR: 5.46e-03 [WARMUP]
#           Best: Train: 0.025497 (Epoch 128)
# Epoch  132: Train: 0.025624, LR: 5.50e-03 [WARMUP]
#           Best: Train: 0.025497 (Epoch 128)
#           Best model saved in memory at epoch 133
#           Best model saved to BMED_TF_250916.pth
# Epoch  133: Train: 0.025268, LR: 5.54e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.025268 (Epoch 133)
#           Best model saved in memory at epoch 134
#           Best model saved to BMED_TF_250916.pth
# Epoch  134: Train: 0.022386, LR: 5.58e-03 ★ NEW BEST [WARMUP]
#           Best: Train: 0.022386 (Epoch 134)
# Epoch  135: Train: 0.030112, LR: 5.62e-03 [WARMUP]
#           Best: Train: 0.022386 (Epoch 134)
# Epoch  136: Train: 0.036243, LR: 5.67e-03 [WARMUP]
#           Best: Train: 0.022386 (Epoch 134)
# Epoch
-03 [WARMUP]
#           Best: Train: 0.017533 (Epoch 174)
# Epoch  200: Train: 0.020673, LR: 8.33e-03 [WARMUP]
#           Best: Train: 0.017533 (Epoch 174)
# Epoch  201: Train: 0.018825, LR: 8.31e-03
#           Best: Train: 0.017533 (Epoch 174)
# Epoch  202: Train: 0.020017, LR: 8.29e-03
#           Best: Train: 0.017533 (Epoch 174)
# Epoch  203: Train: 0.020760, LR: 8.27e-03
#           Best: Train: 0.017533 (Epoch 174)
# Epoch  204: Train: 0.020686, LR: 8.25e-03
#           Best: Train: 0.017533 (Epoch 174)
# Epoch  205: Train: 0.019884, LR: 8.23e-03
#           Best: Train: 0.017533 (Epoch 174)
# Epoch  206: Train: 0.020895, LR: 8.21e-03
#           Best: Train: 0.017533 (Epoch 174)
# Epoch  207: Train: 0.022213, LR: 8.19e-03
#           Best: Train: 0.017533 (Epoch 174)
# Epoch  208: Train: 0.023213, LR: 8.17e-03
#           Best: Train: 0.017533 (Epoch 174)
# Epoch  209: Train: 0.027500, LR: 8.15e-03
#           Best: Train: 0.017533 (Epoch 174)
# Epoch  210: Train: 0.022680, LR: 8.13e-03
#           Best: Train: 0.017533 (Epoch 174)
# Epoch  211: Train: 0.024481, LR: 8.11e-03
#           Best: Train: 0.017533 (Epoch 174)
# Epoch  212: Train: 0.021183, LR: 8.09e-03
#           Best: Train: 0.017533 (Epoch 174)
# Epoch  213: Train: 0.019032, LR: 8.08e-03
#           Best: Train: 0.017533 (Epoch 174)
#           Best model saved in memory at epoch 214
#           Best model saved to BMED_TF_250916.pth
# Epoch  214: Train: 0.017329, LR: 8.06e-03 ★ NEW BEST
#           Best: Train: 0.017329 (Epoch 214)
# Epoch  215: Train: 0.020688, LR: 8.04e-03
#           Best: Train: 0.017329 (Epoch 214)
# Epoch  216: Train: 0.021929, LR: 8.02e-03
#           Best: Train: 0.017329 (Epoch 214)
#           Best model saved in memory at epoch 217
#           Best model saved to BMED_TF_250916.pth
# Epoch  217: Train: 0.015612, LR: 8.00e-03 ★ NEW BEST
#           Best: Train: 0.015612 (Epoch 217)
# Epoch  218: Train: 0.018822, LR: 7.98e-03
#           Best: Train: 0.015612 (Epoch 217)
# Epoch  219: Train: 0.016433, LR: 7.96e-03
#           Best: Train: 0.015612 (Epoch 217)
# Epoch  220: Train: 0.017374, LR: 7.95e-03
#           Best: Train: 0.015612 (Epoch 217)
# Epoch  221: Train: 0.016657, LR: 7.93e-03
#           Best: Train: 0.015612 (Epoch 217)
#           Best model saved in memory at epoch 222
#           Best model saved to BMED_TF_250916.pth
# Epoch  222: Train: 0.015354, LR: 7.91e-03 ★ NEW BEST
#           Best: Train: 0.015354 (Epoch 222)
# Epoch  223: Train: 0.018193, LR: 7.89e-03
#           Best: Train: 0.015354 (Epoch 222)
# Epoch  224: Train: 0.017557, LR: 7.87e-03
#           Best: Train: 0.015354 (Epoch 222)
#           Best model saved in memory at epoch 225
#           Best model saved to BMED_TF_250916.pth
# Epoch  225: Train: 0.015236, LR: 7.86e-03 ★ NEW BEST
#           Best: Train: 0.015236 (Epoch 225)
#           Best model saved in memory at epoch 226
#           Best model saved to BMED_TF_250916.pth
# Epoch  226: Train: 0.015027, LR: 7.84e-03 ★ NEW BEST
#           Best: Train: 0.015027 (Epoch 226)
# Epoch  227: Train: 0.017846, LR: 7.82e-03
#           Best: Train: 0.015027 (Epoch 226)
# Epoch  228: Train: 0.016899, LR: 7.80e-03
#           Best: Train: 0.015027 (Epoch 226)
# Epoch  229: Train: 0.015656, LR: 7.79e-03
#           Best: Train: 0.015027 (Epoch 226)
# Epoch  230: Train: 0.017164, LR: 7.77e-03
#           Best: Train: 0.015027 (Epoch 226)
# Epoch  231: Train: 0.017252, LR: 7.75e-03
#           Best: Train: 0.015027 (Epoch 226)
# Epoch  232: Train: 0.018686, LR: 7.74e-03
#           Best: Train: 0.015027 (Epoch 226)
# Epoch  233: Train: 0.017215, LR: 7.72e-03
#           Best: Train: 0.015027 (Epoch 226)
#           Best model saved in memory at epoch 234
#           Best model saved to BMED_TF_250916.pth
# Epoch  234: Train: 0.013854, LR: 7.70e-03 ★ NEW BEST
#           Best: Train: 0.013854 (Epoch 234)
# Epoch  235: Train: 0.018952, LR: 7.69e-03
LR: 2.66e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1967: Train: 0.008149, LR: 2.66e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1968: Train: 0.008365, LR: 2.66e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1969: Train: 0.009070, LR: 2.66e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1970: Train: 0.007923, LR: 2.66e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1971: Train: 0.009173, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1972: Train: 0.008140, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1973: Train: 0.008564, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1974: Train: 0.008114, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1975: Train: 0.008945, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1976: Train: 0.010012, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1977: Train: 0.009122, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1978: Train: 0.008320, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1979: Train: 0.007885, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1980: Train: 0.008742, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1981: Train: 0.007942, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1982: Train: 0.008797, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1983: Train: 0.008614, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1984: Train: 0.007306, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1985: Train: 0.009073, LR: 2.65e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1986: Train: 0.007421, LR: 2.64e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1987: Train: 0.007185, LR: 2.64e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1988: Train: 0.009344, LR: 2.64e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1989: Train: 0.008290, LR: 2.64e-03
#           Best: Train: 0.006179 (Epoch 1883)
# Epoch 1990: Train: 0.006455, LR: 2.64e-03
#           Best: Train: 0.006179 (Epoch 1883)
#           Best model saved in memory at epoch 1991
#           Best model saved to BMED_TF_250916.pth
# Epoch 1991: Train: 0.005699, LR: 2.64e-03 ★ NEW BEST
#           Best: Train: 0.005699 (Epoch 1991)
# Epoch 1992: Train: 0.007675, LR: 2.64e-03
#           Best: Train: 0.005699 (Epoch 1991)
# Epoch 1993: Train: 0.007335, LR: 2.64e-03
#           Best: Train: 0.005699 (Epoch 1991)
# Epoch 1994: Train: 0.007320, LR: 2.64e-03
#           Best: Train: 0.005699 (Epoch 1991)
# Epoch 1995: Train: 0.006986, LR: 2.64e-03
#           Best: Train: 0.005699 (Epoch 1991)
# Epoch 1996: Train: 0.008441, LR: 2.64e-03
#           Best: Train: 0.005699 (Epoch 1991)
# Epoch 1997: Train: 0.008084, LR: 2.64e-03
#           Best: Train: 0.005699 (Epoch 1991)
# Epoch 1998: Train: 0.008098, LR: 2.64e-03
#           Best: Train: 0.005699 (Epoch 1991)
# Epoch 1999: Train: 0.006913, LR: 2.64e-03
#           Best: Train: 0.005699 (Epoch 1991)
# Epoch 2000: Train: 0.008911, LR: 2.64e-03
#           Best: Train: 0.005699 (Epoch 1991)
#
# Training completed!
# ============================================================
# Best Performance (Epoch 1991):
#   Best Train Loss:  0.005699
# ============================================================
# Final Performance (Epoch 2000):
#   Final Train Loss: 0.008911
#   Final LR:         2.64e-03
# ============================================================
# Warmup completed at epoch 200 with peak LR: 8.33e-03
#
# ✅ Best model (Epoch 1991) successfully saved in memory!
#    Best model loss: 0.005699
#    Best model also saved to file: BMED_TF_250916.pth

# %%
# 전체 실험 데이터에 대한 종합적인 시각화 - 8개 feature별 개별 플롯 (수정됨)
# 각 플롯은 모든 실험을 서브플롯으로 표시

def denormalize_data(normalized_data, feature_name):
    """정규화된 데이터를 원래 단위로 복원"""
    if feature_name in range_mm:
        min_val = range_mm[feature_name]['min']
        max_val = range_mm[feature_name]['max']
        return normalized_data * (max_val - min_val) + min_val
    return normalized_data

print("🚀 전체 실험 데이터 comprehensive evaluation 시작...")

# Device 및 모델 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
evaluation_model = best_model if best_model is not None else model

# feature 정보 재정의
feature_names = ['VF', 'VA', 'VB', 'CFLA', 'CALA', 'CFK', 'CBK', 'I']
feature_indices = [2, 3, 4, 5, 6, 7, 8, 9]
feature_units = ['L', 'L', 'L', 'mol/L', 'mol/L', 'mol/L', 'mol/L', 'A']
feature_titles = ['Feed Volume', 'Acid Volume', 'Base Volume', 'Feed LA Conc.', 'Acid LA Conc.', 'Feed K Conc.', 'Base K Conc.', 'Current']

# 전체 실험 데이터 수집
all_experiment_results = {}
available_exp_nums = sorted(ndf['exp'].unique())
total_experiments = len(available_exp_nums)

print(f"📋 전체 {total_experiments}개 실험 데이터 수집 중...")
print(f"🔧 데이터로더 배치 크기: {dataloader.batch_size}")
print(f"🔧 총 배치 개수: {len(dataloader)}")

evaluation_model.eval()
with torch.no_grad():
    experiment_counter = 0
    
    for batch_idx, (input_seq, seq_lengths) in enumerate(dataloader):
        try:
            batch_size = input_seq.size(0)
            print(f"📦 배치 {batch_idx}: {batch_size}개 실험 처리 중...")
            
            input_seq = input_seq.to(device)
            seq_lengths = seq_lengths.to(device)
            
            # Teacher forcing 데이터 준비
            inputs, targets, target_seq_lengths = tf_data(input_seq, seq_lengths)
            
            # 모델 예측
            predictions = evaluation_model(inputs, target_seq_lengths)
            
            # CPU로 이동
            predictions_cpu = predictions.cpu().numpy()
            targets_cpu = targets.cpu().numpy()
            input_seq_cpu = input_seq.cpu().numpy()
            
            # 배치 내 모든 샘플 처리
            for sample_idx in range(batch_size):
                if experiment_counter >= total_experiments:
                    break
                    
                # 현재 실험 번호
                actual_exp_num = available_exp_nums[experiment_counter]
                
                # 샘플 데이터 추출
                pred_sample = predictions_cpu[sample_idx]
                actual_sample = targets_cpu[sample_idx]
                initial_sample = input_seq_cpu[sample_idx]
                seq_len = target_seq_lengths[sample_idx].item()
                full_seq_len = seq_lengths[sample_idx].item()
                
                # 실제 시퀀스 길이만큼만 사용
                pred_sample = pred_sample[:seq_len]
                actual_sample = actual_sample[:seq_len]
                initial_sample = initial_sample[:full_seq_len]
                
                # 시간 축 생성
                time_points = np.arange(full_seq_len) * 0.25
                
                # 예측값을 초기값과 연결
                prediction_full = np.zeros((full_seq_len, 10))
                prediction_full[0] = initial_sample[0]
                prediction_full[1:seq_len+1] = pred_sample
                
                # 실험 조건 정보
                voltage = denormalize_data(initial_sample[0, 0], 'V')
                electrolyte = denormalize_data(initial_sample[0, 1], 'E')
                
                # 결과 저장
                all_experiment_results[actual_exp_num] = {
                    'time_points': time_points,
                    'actual_data': initial_sample,
                    'predicted_data': prediction_full,
                    'seq_len': seq_len,
                    'full_seq_len': full_seq_len,
                    'voltage': voltage,
                    'electrolyte': electrolyte,
                    'actual_sample': actual_sample,
                    'pred_sample': pred_sample
                }
                
                print(f"✅ 실험 {actual_exp_num}: {full_seq_len*0.25:.1f}h, {voltage:.1f}V, {electrolyte:.3f}M")
                experiment_counter += 1
            
        except Exception as e:
            print(f"❌ 배치 {batch_idx} 오류: {str(e)}")
            import traceback
            traceback.print_exc()
            continue

print(f"📊 총 {len(all_experiment_results)}개 실험 데이터 수집 완료!")

# 서브플롯 배치 계산
import math
sqrt_exp = math.ceil(math.sqrt(total_experiments))
if sqrt_exp * (sqrt_exp - 1) >= total_experiments:
    grid_rows, grid_cols = sqrt_exp - 1, sqrt_exp
else:
    grid_rows, grid_cols = sqrt_exp, sqrt_exp

print(f"📐 각 feature당 {grid_rows}x{grid_cols} 서브플롯 그리드 사용")

# 8개 feature별로 개별 figure 생성
for feature_idx, (feature_name, feature_index, unit, title) in enumerate(zip(feature_names, feature_indices, feature_units, feature_titles)):
    print(f"🎨 Feature {feature_idx+1}/8: {feature_name} ({title}) 생성 중...")
    
    # 새 figure 생성
    fig, axes = plt.subplots(grid_rows, grid_cols, figsize=(4*grid_cols, 3*grid_rows))
    if best_model is not None:
        suptitle = f'{title} ({feature_name}) - All Experiments\nBest Model (Epoch {best_epoch}, Loss: {best_train_loss:.6f})'
    else:
        suptitle = f'{title} ({feature_name}) - All Experiments\nCurrent Model'
    fig.suptitle(suptitle, fontsize=16, fontweight='bold')
    
    # axes 처리 (1차원으로 변환)
    if grid_rows * grid_cols == 1:
        axes = [axes]
    else:
        axes = axes.flatten() if hasattr(axes, 'flatten') else [axes]
    
    # 성능 지표 수집
    rmse_values = []
    r2_values = []
    
    # 각 실험별 subplot
    for plot_idx, exp_num in enumerate(sorted(all_experiment_results.keys())):
        if plot_idx >= len(axes):
            break
            
        ax = axes[plot_idx]
        exp_data = all_experiment_results[exp_num]
        
        # 데이터 denormalize
        actual_denorm = denormalize_data(exp_data['actual_data'][:, feature_index], feature_name)
        pred_denorm = denormalize_data(exp_data['predicted_data'][:exp_data['seq_len']+1, feature_index], feature_name)
        
        # 플롯 생성
        ax.plot(exp_data['time_points'], actual_denorm, 'b-', linewidth=1.5, label='Actual', alpha=0.8)
        ax.plot(exp_data['time_points'][:exp_data['seq_len']+1], pred_denorm, 'r--', linewidth=1.5, label='Predicted', alpha=0.8)
        
        # 시작점 표시
        ax.plot(exp_data['time_points'][0], actual_denorm[0], 'go', markersize=3)
        ax.axvline(x=exp_data['time_points'][1], color='gray', linestyle=':', alpha=0.5)
        
        # 성능 지표 계산
        actual_pred_denorm = denormalize_data(exp_data['actual_sample'][:, feature_index], feature_name)
        pred_pred_denorm = denormalize_data(exp_data['pred_sample'][:, feature_index], feature_name)
        
        rmse = np.sqrt(np.mean((actual_pred_denorm - pred_pred_denorm)**2))
        if np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2) > 0:
            r2 = 1 - (np.sum((actual_pred_denorm - pred_pred_denorm)**2) / np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2))
        else:
            r2 = 0.0
            
        rmse_values.append(rmse)
        r2_values.append(r2)
        
        # 서브플롯 설정
        condition_text = f'{exp_data["voltage"]:.1f}V, {exp_data["electrolyte"]:.2f}M'
        ax.set_title(f'Exp {exp_num}: {condition_text}\nRMSE: {rmse:.3f} {unit}', fontsize=9)
        ax.set_xlabel('Time (hours)', fontsize=8)
        ax.set_ylabel(f'{feature_name} ({unit})', fontsize=8)
        ax.grid(True, alpha=0.3)
        ax.tick_params(labelsize=7)
        
        # 첫 번째 subplot에만 범례 추가
        if plot_idx == 0:
            ax.legend(fontsize=8, loc='upper right')
    
    # 빈 subplot 숨기기
    for plot_idx in range(len(all_experiment_results), len(axes)):
        axes[plot_idx].set_visible(False)
    
    # 전체 성능 요약
    avg_rmse = np.mean(rmse_values)
    std_rmse = np.std(rmse_values)
    avg_r2 = np.mean(r2_values)
    std_r2 = np.std(r2_values)
    
    # 성능 요약 텍스트 박스
    summary_text = f'Overall Performance:\nRMSE: {avg_rmse:.4f} ± {std_rmse:.4f} {unit}\nR²: {avg_r2:.3f} ± {std_r2:.3f}\nExperiments: {len(rmse_values)}'
    fig.text(0.02, 0.02, summary_text, fontsize=10, 
             bbox=dict(boxstyle='round,pad=0.5', facecolor='lightblue', alpha=0.8))
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.92, bottom=0.12, left=0.05, right=0.98)
    plt.show()
    
    print(f"✅ {feature_name} 완료: 평균 RMSE = {avg_rmse:.4f} {unit}, 평균 R² = {avg_r2:.3f}")

# 전체 요약 출력
print("\n" + "="*80)
print("COMPREHENSIVE EVALUATION SUMMARY - ALL EXPERIMENTS")
print("="*80)

for feature_idx, (feature_name, feature_index, unit) in enumerate(zip(feature_names, feature_indices, feature_units)):
    # 각 feature별 전체 성능 통계
    all_rmse = []
    all_mae = []
    all_r2 = []
    
    for exp_num in sorted(all_experiment_results.keys()):
        exp_data = all_experiment_results[exp_num]
        
        actual_pred_denorm = denormalize_data(exp_data['actual_sample'][:, feature_index], feature_name)
        pred_pred_denorm = denormalize_data(exp_data['pred_sample'][:, feature_index], feature_name)
        
        rmse = np.sqrt(np.mean((actual_pred_denorm - pred_pred_denorm)**2))
        mae = np.mean(np.abs(actual_pred_denorm - pred_pred_denorm))
        
        if np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2) > 0:
            r2 = 1 - (np.sum((actual_pred_denorm - pred_pred_denorm)**2) / np.sum((actual_pred_denorm - np.mean(actual_pred_denorm))**2))
        else:
            r2 = 0.0
        
        all_rmse.append(rmse)
        all_mae.append(mae)
        all_r2.append(r2)
    
    print(f"{feature_name:6s}: RMSE={np.mean(all_rmse):.4f}±{np.std(all_rmse):.4f} {unit}, "
          f"MAE={np.mean(all_mae):.4f}±{np.std(all_mae):.4f} {unit}, "
          f"R²={np.mean(all_r2):.3f}±{np.std(all_r2):.3f}")

print("-"*80)
print(f"📊 Total experiments analyzed: {len(all_experiment_results)}")
if best_model is not None:
    print(f"🏆 Best model used: Epoch {best_epoch}, Loss: {best_train_loss:.6f}")
else:
    print("📋 Current model used")
print("="*80)

print("🎉 Comprehensive evaluation 완료! 8개의 feature별 플롯이 모든 실험 데이터를 포함하여 생성되었습니다.")
# Out:
# 🚀 전체 실험 데이터 comprehensive evaluation 시작...
# 📋 전체 15개 실험 데이터 수집 중...
# 🔧 데이터로더 배치 크기: 3
# 🔧 총 배치 개수: 5
# 📦 배치 0: 3개 실험 처리 중...
# ✅ 실험 0: 4.2h, 20.0V, 0.250M
# ✅ 실험 1: 5.2h, 30.0V, 0.250M
# ✅ 실험 2: 5.2h, 30.0V, 0.250M
# 📦 배치 1: 3개 실험 처리 중...
# ✅ 실험 3: 5.2h, 30.0V, 0.250M
# ✅ 실험 4: 7.2h, 20.0V, 0.250M
# ✅ 실험 5: 9.2h, 20.0V, 0.250M
# 📦 배치 2: 3개 실험 처리 중...
# ✅ 실험 6: 4.2h, 10.0V, 0.250M
# ✅ 실험 7: 7.2h, 10.0V, 0.250M
# ✅ 실험 8: 8.2h, 30.0V, 0.250M
# 📦 배치 3: 3개 실험 처리 중...
# ✅ 실험 9: 5.2h, 30.0V, 0.250M
# ✅ 실험 10: 6.2h, 30.0V, 0.250M
# ✅ 실험 11: 6.2h, 35.0V, 0.500M
# 📦 배치 4: 3개 실험 처리 중...
# ✅ 실험 12: 5.2h, 35.0V, 0.250M
# ✅ 실험 13: 5.2h, 35.0V, 1.000M
# ✅ 실험 14: 4.8h, 30.0V, 0.250M
# 📊 총 15개 실험 데이터 수집 완료!
# 📐 각 feature당 4x4 서브플롯 그리드 사용
# 🎨 Feature 1/8: VF (Feed Volume) 생성 중...
# ✅ VF 완료: 평균 RMSE = 0.0093 L, 평균 R² = 0.982
# 🎨 Feature 2/8: VA (Acid Volume) 생성 중...
# ✅ VA 완료: 평균 RMSE = 0.0055 L, 평균 R² = 0.965
# 🎨 Feature 3/8: VB (Base Volume) 생성 중...
# ✅ VB 완료: 평균 RMSE = 0.0065 L, 평균 R² = 0.973
# 🎨 Feature 4/8: CFLA (Feed LA Conc.) 생성 중...
# ✅ CFLA 완료: 평균 RMSE = 0.0175 mol/L, 평균 R² = 0.990
# 🎨 Feature 5/8: CALA (Acid LA Conc.) 생성 중...
# ✅ CALA 완료: 평균 RMSE = 0.0114 mol/L, 평균 R² = 0.879
# 🎨 Feature 6/8: CFK (Feed K Conc.) 생성 중...
# ✅ CFK 완료: 평균 RMSE = 0.0330 mol/L, 평균 R² = 0.994
# 🎨 Feature 7/8: CBK (Base K Conc.) 생성 중...
# ✅ CBK 완료: 평균 RMSE = 0.0153 mol/L, 평균 R² = 0.991
# 🎨 Feature 8/8: I (Current) 생성 중...
# ✅ I 완료: 평균 RMSE = 0.0667 A, 평균 R² = 0.837
#
# ================================================================================
# COMPREHENSIVE EVALUATION SUMMARY - ALL EXPERIMENTS
# ================================================================================
# VF    : RMSE=0.0093±0.0029 L, MAE=0.0078±0.0025 L, R²=0.982±0.019
# VA    : RMSE=0.0055±0.0027 L, MAE=0.0044±0.0020 L, R²=0.965±0.052
# VB    : RMSE=0.0065±0.0024 L, MAE=0.0056±0.0020 L, R²=0.973±0.024
# CFLA  : RMSE=0.0175±0.0089 mol/L, MAE=0.0137±0.0049 mol/L, R²=0.990±0.012
# CALA  : RMSE=0.0114±0.0073 mol/L, MAE=0.0091±0.0052 mol/L, R²=0.879±0.426
# CFK   : RMSE=0.0330±0.0136 mol/L, MAE=0.0259±0.0099 mol/L, R²=0.994±0.010
# CBK   : RMSE=0.0153±0.0076 mol/L, MAE=0.0121±0.0048 mol/L, R²=0.991±0.025
# I     : RMSE=0.0667±0.0345 A, MAE=0.0511±0.0227 A, R²=0.837±0.348
# --------------------------------------------------------------------------------
# 📊 Total experiments analyzed: 15
# 🏆 Best model used: Epoch 1991, Loss: 0.005699
# ================================================================================
# 🎉 Comprehensive evaluation 완료! 8개의 feature별 플롯이 모든 실험 데이터를 포함하여 생성되었습니다.
