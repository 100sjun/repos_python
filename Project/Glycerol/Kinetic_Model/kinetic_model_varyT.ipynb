# %%
import pandas as pd
import numpy as np
from scipy.integrate import solve_ivp
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib as mpl

# 한글 폰트 설정
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %%
df = pd.read_csv('data2.csv')
df1 = df[df['label']=='temp']

# %%
df1
# Out:
#    label  T [degC]    P [bar]  W_cat [g]  Time [h]  N_Gly [mmol]  \
# 6   temp       200  15.518495        0.3       0.0        250.00
# 7   temp       170  39.227423        0.3       2.0        139.75
# 8   temp       180  56.811922        0.3       2.0         88.25
# 9   temp       190  73.437851        0.3       2.0         47.25
# 10  temp       200  92.654542        0.3       2.0         14.00
#
#     N_KOH [mmol]  N_H2 [mmol]  N_LA [mmol]  N_PDO [mmol]  N_FA [mmol]  \
# 6     375.000000     0.000000     0.000000      0.000000     0.000000
# 7     275.725604    88.298793    92.250001     13.609762     3.762201
# 8     229.636367   128.977265   135.999999     19.663635     4.931810
# 9     191.540244   164.169513   168.499990     24.408048     8.229886
# 10    155.283828   203.432345   201.249991     22.830920     9.608083
#
#     N_GA [mmol]  N_ME [mmol]  N_EG [mmol]
# 6      0.000000     0.000000     0.000000
# 7      3.262195     0.878040     0.878040
# 8      4.431824     1.404550     1.404550
# 9      6.729881     2.362078     2.362078
# 10     8.858098     2.685998     2.685998

# %%
# parameters initialization
Wi = 66.625
VL = 41.253968 # mL# h2 solubility parameter
p00 = 0.2638
p01 = 5.443e-4
p02 = -2.45e-7
p10 = -1.545e-3
p20 = 2.205e-6
p11 = 9.105e-7
mw_h2o = 18 # g/mol, water molweight
mw_h2 = 2 # g/mol, hydrogen molweight

# %%
# Concentration initialization
N0 = np.array([
    df1.iloc[0]['N_Gly [mmol]'],    # 글리세롤
    df1.iloc[0]['N_KOH [mmol]'],    # KOH
    df1.iloc[0]['N_H2 [mmol]'],     # 수소
    df1.iloc[0]['N_LA [mmol]'],     # 젖산
    df1.iloc[0]['N_PDO [mmol]'],    # 1,3-PDO
    df1.iloc[0]['N_FA [mmol]'],     # 포름산
    df1.iloc[0]['N_GA [mmol]'],     # 글리콜산
    df1.iloc[0]['N_ME [mmol]'],     # 메탄올
    df1.iloc[0]['N_EG [mmol]']      # 에틸렌글리콜
], dtype=np.float32)

# 각 온도별 실험 데이터 준비
temp_data = []
for i in range(1, len(df1)):
    temp_data.append({
        'T': df1.iloc[i]['T [degC]'],
        'time': df1.iloc[i]['Time [h]'],
        'N_exp': np.array([
            df1.iloc[i]['N_Gly [mmol]'],
            df1.iloc[i]['N_KOH [mmol]'],
            df1.iloc[i]['N_H2 [mmol]'],
            df1.iloc[i]['N_LA [mmol]'],
            df1.iloc[i]['N_PDO [mmol]'],
            df1.iloc[i]['N_FA [mmol]'],
            df1.iloc[i]['N_GA [mmol]'],
            df1.iloc[i]['N_ME [mmol]'],
            df1.iloc[i]['N_EG [mmol]']
        ])
    })

# %%
temp_data
# Out:
# [{'T': np.int64(170),
#   'time': np.float64(2.0),
#   'N_exp': array([139.75      , 275.7256037 ,  88.29879264,  92.25000068,
#           13.60976173,   3.76220072,   3.26219492,   0.87803977,
#            0.87803977])},
#  {'T': np.int64(180),
#   'time': np.float64(2.0),
#   'N_exp': array([ 88.25      , 229.6363674 , 128.9772653 , 135.9999985 ,
#           19.66363477,   4.9318098 ,   4.43182437,   1.40454967,
#            1.40454967])},
#  {'T': np.int64(190),
#   'time': np.float64(2.0),
#   'N_exp': array([ 47.25      , 191.5402436 , 164.1695127 , 168.4999899 ,
#           24.40804839,   8.22988588,   6.72988056,   2.36207847,
#            2.36207847])},
#  {'T': np.int64(200),
#   'time': np.float64(2.0),
#   'N_exp': array([ 14.        , 155.2838276 , 203.4323448 , 201.2499912 ,
#           22.83092013,   9.6080828 ,   8.8580984 ,   2.68599806,
#            2.68599806])}]

# %%
def ode_system(t, N, Ea_params,T):

    wcat = 0.3*0.02 # Pt 함량 0.3 g의 2%
    wpet = 0.3

    VL = 41.253968 # mL
    VG = 145 - VL
    C = N/VL # mmol/mL = M
    
    T = T
    P_H2O = 10**(8.14019-1810.94/(244.485+T))/750.062 # Antoine equation
    vg = 8.314*(T+273.15)/(P_H2O*1e5)
    NG_H2O = 1/(vg*1e3)*VG

    P_H2 = (N[2]/1e3)/(VG/1e6)*8.314*(T+273.15)/1e5
    S_H2 = p00 + (T)*p10 + P_H2*p01 + (T)**2*p20 + P_H2**2*p02 + (T)*P_H2*p11
    WL = Wi - (N[2])*mw_h2/1000 - NG_H2O*mw_h2o/1000
    NL_H2 = S_H2*WL
    NLf_H2 = min(N[2], NL_H2)

    C[2] = NLf_H2/VL
        # C의 0인 성분을 1e-8로 수정
    C[C < 0] = 1e-8
    # kg1 0 # KGly 1 # KH2 2 # KPDO 3 # kd1 4 # kd2 5 # kd3 6 # kp1 7 # kp2 8

    # 글리세롤 0 # KOH 1 # 수소 2 # 젖산 3 # 1,3-PDO 4 # 포름산 5 # 글리콜산 6 # 메탄올 7 # 에틸렌글리콜 8
    
    # parameter
    k00 = 10**(10.51217796)
    k10 = 10**(2.16562813)
    k20 = 10**(3.08069057)
    k30 = 10**(3.10522888)
    k40 = 10**(2.2663773)
    k50 = 10**(-0.76737823)
    k60 = 10**(2.14433915)
    k70 = 10**(-4.31393815)
    k80 = 10**(7.98508563)

    k0 = k00*np.exp(-Ea_params[0]/8.314*(1/(T+273.15)-1/(200+273.15))) # kg1
    k1 = k10*np.exp(Ea_params[1]/8.314*(1/(T+273.15)-1/(200+273.15))) # KGly
    k2 = k20*np.exp(Ea_params[2]/8.314*(1/(T+273.15)-1/(200+273.15))) # KH2
    k3 = k30*np.exp(Ea_params[3]/8.314*(1/(T+273.15)-1/(200+273.15))) # KPDO
    k4 = k40*np.exp(-Ea_params[4]/8.314*(1/(T+273.15)-1/(200+273.15))) # kd1
    k5 = k50*np.exp(-Ea_params[5]/8.314*(1/(T+273.15)-1/(200+273.15))) # kd2
    k6 = k60*np.exp(-Ea_params[6]/8.314*(1/(T+273.15)-1/(200+273.15))) # kd3
    k7 = k70*np.exp(-Ea_params[7]/8.314*(1/(T+273.15)-1/(200+273.15))) # kp1
    k8 = k80*np.exp(Ea_params[8]/8.314*(1/(T+273.15)-1/(200+273.15))) # kp2
    
    theta = 1 + k1*C[0] + (k2*C[2])**0.5 + k3*C[4]
    rg1= k0*k1*C[0]/(theta**3)*wcat # Glycerol -> DHA + H2
    rd1 = k4 # DHA -> PRA + H2O
    rd2 = k5*(C[1]**2) # DHA + 2KOH -> FA + GA + 2H2
    rd3 = k6*(C[2]**2) # DHA + 2H2 -> ME + EG
    rp1 = k7*C[1] # PRA + KOH -> LA
    rp2 = k8*k2**2*C[2]**2/(theta**5) # PRA + H2 -> PDO

    fd1 = rd1/(rd1+rd2+rd3)
    fd2 = rd2/(rd1+rd2+rd3)
    fd3 = rd3/(rd1+rd2+rd3)

    fp1 = rp1/(rp1+rp2)
    fp2 = rp2/(rp1+rp2)

    dN0dt = -rg1 
    dN1dt = -2*rg1*fd2 - rg1*fd1*fp1
    dN2dt = rg1 + 2*rg1*fd2 - 2*rg1*fd3 - 2*rg1*fd1*fp2
    dN3dt = rg1*fd1*fp1
    dN4dt = rg1*fd1*fp2
    dN5dt = rg1*fd2
    dN6dt = rg1*fd2
    dN7dt = rg1*fd3
    dN8dt = rg1*fd3

    return np.array([dN0dt, dN1dt, dN2dt, dN3dt, dN4dt, dN5dt, dN6dt, dN7dt, dN8dt])

# %%
t_eval = np.array(df1.iloc[0:]['Time [h]'].values, dtype=np.float32)

# %%
# 각 온도별로 ODE 풀기
def solve_ode_for_temp(Ea_params, T, time_end):
    t_eval = np.array([0, time_end])
    sol = solve_ivp(
        ode_system,
        t_span=(0, time_end),
        y0=N0,
        t_eval=t_eval,
        args=(Ea_params, T),
        method='RK45'
    )
    return sol.y[:, -1]  # 마지막 시점의 결과만 반환

# %%
# 수정된 목적 함수 - 모든 온도 조건을 동시에 고려
def objective_function(Ea_params):
    total_error = 0
    
    for data in temp_data:
        try:
            # 각 온도별로 ODE 계산
            N_pred = solve_ode_for_temp(Ea_params, data['T'], data['time'])
            
            # 각 성분별 상대 오차 계산
            error = 0
            for i in range(9):
                if data['N_exp'][i] != 0:
                    relative_error = ((N_pred[i] - data['N_exp'][i]) / data['N_exp'][i])**2
                else:
                    relative_error = N_pred[i]**2
                error += relative_error
            
            total_error += error
            
        except Exception as e:
            print(f"Error at T={data['T']}°C: {e}")
            return 1e10
    
    return total_error

# %%
best_loss = float('inf')
best_x = np.ones(9)
x0 = np.ones(9)*1000
for i in range(100):  # 100번 반복
    result = minimize(
        objective_function,
        x0=x0,
        method='L-BFGS-B',
        bounds = [(0, 50000) for _ in range(9)]  # Ea 값의 범위 (J/mol)
    )
    
    # 현재 시도의 loss 출력
    print(f'시도 {i+1} - Loss: {result.fun:.6f}, Best Loss: {best_loss:.6f}')
    
    if result.fun < best_loss:
        best_loss = result.fun
        best_x = result.x.copy()
        x0 = result.x.copy()  # 더 나은 결과를 얻은 경우 x0를 result.x로 갱신
    else:
        x0 = best_x.copy()  # 더 나은 결과를 얻지 못한 경우 best_x를 x0로 사용
        
    # x0에 랜덤 변화 추가
    x0 = x0 * (1 + np.random.randn(len(x0)) * 0.05)
# Out:
# 시도 1 - Loss: 30.741691, Best Loss: inf
# 시도 2 - Loss: 25.528667, Best Loss: 30.741691
# 시도 3 - Loss: 25.677497, Best Loss: 25.528667
# 시도 4 - Loss: 25.534909, Best Loss: 25.528667
# 시도 5 - Loss: 25.921023, Best Loss: 25.528667
# 시도 6 - Loss: 25.951621, Best Loss: 25.528667
# 시도 7 - Loss: 25.402216, Best Loss: 25.528667
# 시도 8 - Loss: 25.609675, Best Loss: 25.402216
# 시도 9 - Loss: 25.584504, Best Loss: 25.402216
# 시도 10 - Loss: 25.904126, Best Loss: 25.402216
# 시도 11 - Loss: 25.442844, Best Loss: 25.402216
# 시도 12 - Loss: 25.404765, Best Loss: 25.402216
# 시도 13 - Loss: 25.529339, Best Loss: 25.402216
# 시도 14 - Loss: 25.468543, Best Loss: 25.402216
# 시도 15 - Loss: 25.141027, Best Loss: 25.402216
# 시도 16 - Loss: 25.166209, Best Loss: 25.141027
# 시도 17 - Loss: 25.408352, Best Loss: 25.141027
# 시도 18 - Loss: 25.473957, Best Loss: 25.141027
# 시도 19 - Loss: 25.196707, Best Loss: 25.141027
# 시도 20 - Loss: 24.758673, Best Loss: 25.141027
# 시도 21 - Loss: 24.599356, Best Loss: 24.758673
# 시도 22 - Loss: 24.576779, Best Loss: 24.599356
# 시도 23 - Loss: 24.609717, Best Loss: 24.576779
# 시도 24 - Loss: 24.684721, Best Loss: 24.576779
# 시도 25 - Loss: 24.256553, Best Loss: 24.576779
# 시도 26 - Loss: 24.141376, Best Loss: 24.256553
# 시도 27 - Loss: 24.101009, Best Loss: 24.141376
# 시도 28 - Loss: 24.363346, Best Loss: 24.101009
# 시도 29 - Loss: 24.117485, Best Loss: 24.101009
# 시도 30 - Loss: 24.155417, Best Loss: 24.101009
# 시도 31 - Loss: 23.969865, Best Loss: 24.101009
# 시도 32 - Loss: 24.193452, Best Loss: 23.969865
# 시도 33 - Loss: 24.261910, Best Loss: 23.969865
# 시도 34 - Loss: 24.563508, Best Loss: 23.969865
# 시도 35 - Loss: 23.445934, Best Loss: 23.969865
# 시도 36 - Loss: 23.879751, Best Loss: 23.445934
# 시도 37 - Loss: 23.695385, Best Loss: 23.445934
# 시도 38 - Loss: 22.817416, Best Loss: 23.445934
# 시도 39 - Loss: 22.851256, Best Loss: 22.817416
# 시도 40 - Loss: 7.957758, Best Loss: 22.817416
# 시도 41 - Loss: 8.254608, Best Loss: 7.957758
# 시도 42 - Loss: 7.750761, Best Loss: 7.957758
# 시도 43 - Loss: 7.603838, Best Loss: 7.750761
# 시도 44 - Loss: 7.322400, Best Loss: 7.603838
# 시도 45 - Loss: 0.514797, Best Loss: 7.322400
# 시도 46 - Loss: 0.545506, Best Loss: 0.514797
# 시도 47 - Loss: 0.537921, Best Loss: 0.514797
# 시도 48 - Loss: 0.539839, Best Loss: 0.514797
# 시도 49 - Loss: 0.534199, Best Loss: 0.514797
# 시도 50 - Loss: 0.518435, Best Loss: 0.514797
# 시도 51 - Loss: 0.514289, Best Loss: 0.514797
# 시도 52 - Loss: 0.517455, Best Loss: 0.514289
# 시도 53 - Loss: 0.538678, Best Loss: 0.514289
# 시도 54 - Loss: 0.515781, Best Loss: 0.514289
# 시도 55 - Loss: 0.524153, Best Loss: 0.514289
# 시도 56 - Loss: 0.522767, Best Loss: 0.514289
# 시도 57 - Loss: 0.519858, Best Loss: 0.514289
# 시도 58 - Loss: 0.516064, Best Loss: 0.514289
# 시도 59 - Loss: 0.518283, Best Loss: 0.514289
# 시도 60 - Loss: 0.515537, Best Loss: 0.514289
# 시도 61 - Loss: 0.528124, Best Loss: 0.514289
# 시도 62 - Loss: 0.516254, Best Loss: 0.514289
# 시도 63 - Loss: 0.522239, Best Loss: 0.514289
# 시도 64 - Loss: 0.540444, Best Loss: 0.514289
# 시도 65 - Loss: 0.562082, Best Loss: 0.514289
# 시도 66 - Loss: 0.522228, Best Loss: 0.514289
# 시도 67 - Loss: 0.573150, Best Loss: 0.514289
# 시도 68 - Loss: 0.526268, Best Loss: 0.514289
# 시도 69 - Loss: 0.523013, Best Loss: 0.514289
# 시도 70 - Loss: 0.519597, Best Loss: 0.514289
# 시도 71 - Loss: 0.518753, Best Loss: 0.514289
# 시도 72 - Loss: 0.518384, Best Loss: 0.514289
# 시도 73 - Loss: 0.516101, Best Loss: 0.514289
# 시도 74 - Loss: 0.562306, Best Loss: 0.514289
# 시도 75 - Loss: 0.516719, Best Loss: 0.514289
# 시도 76 - Loss: 0.541133, Best Loss: 0.514289
# 시도 77 - Loss: 0.521266, Best Loss: 0.514289
# 시도 78 - Loss: 0.536256, Best Loss: 0.514289
# 시도 79 - Loss: 0.537478, Best Loss: 0.514289
# 시도 80 - Loss: 0.551636, Best Loss: 0.514289
# 시도 81 - Loss: 0.518635, Best Loss: 0.514289
# 시도 82 - Loss: 0.546521, Best Loss: 0.514289
# 시도 83 - Loss: 0.519296, Best Loss: 0.514289
# 시도 84 - Loss: 0.526754, Best Loss: 0.514289
# 시도 85 - Loss: 0.564843, Best Loss: 0.514289
# 시도 86 - Loss: 0.523359, Best Loss: 0.514289
# 시도 87 - Loss: 0.540495, Best Loss: 0.514289
# 시도 88 - Loss: 0.523295, Best Loss: 0.514289
# 시도 89 - Loss: 0.530208, Best Loss: 0.514289
# 시도 90 - Loss: 0.540308, Best Loss: 0.514289
# 시도 91 - Loss: 0.520833, Best Loss: 0.514289
# 시도 92 - Loss: 0.563223, Best Loss: 0.514289
# 시도 93 - Loss: 0.543228, Best Loss: 0.514289
# 시도 94 - Loss: 0.515893, Best Loss: 0.514289
# 시도 95 - Loss: 0.547192, Best Loss: 0.514289
# 시도 96 - Loss: 0.534711, Best Loss: 0.514289
# 시도 97 - Loss: 0.514614, Best Loss: 0.514289
# 시도 98 - Loss: 0.538148, Best Loss: 0.514289
# 시도 99 - Loss: 0.543434, Best Loss: 0.514289
# 시도 100 - Loss: 0.521122, Best Loss: 0.514289

# %%
print("최적화 완료!")
print(f"최적 Ea 값: {best_x}")
print(f"최종 오차: {best_loss}")

# 결과 확인
optimal_Ea = best_x

# 데이터 준비
temperatures = [data['T'] for data in temp_data]
components = ['Gly', 'KOH', 'H2', 'LA', 'PDO', 'FA', 'GA', 'ME', 'EG']

# 실험값과 예측값 저장
exp_values = {comp: [] for comp in components}
pred_values = {comp: [] for comp in components}

for data in temp_data:
    N_pred = solve_ode_for_temp(optimal_Ea, data['T'], data['time'])
    for i, comp in enumerate(components):
        exp_values[comp].append(data['N_exp'][i])
        pred_values[comp].append(N_pred[i])

# 그래프 그리기
import matplotlib.pyplot as plt

fig, axs = plt.subplots(3, 3, figsize=(15, 15))
fig.suptitle('온도에 따른 각 성분의 농도 변화', fontsize=16)

for i, comp in enumerate(components):
    row = i // 3
    col = i % 3
    
    axs[row, col].plot(temperatures, exp_values[comp], 'o', label='실험값')
    axs[row, col].plot(temperatures, pred_values[comp], '-', label='예측값')
    axs[row, col].set_title(comp)
    axs[row, col].set_xlabel('온도 (°C)')
    axs[row, col].set_ylabel('농도 (mmol)')
    axs[row, col].legend()
    axs[row, col].grid(True)

plt.tight_layout()
plt.show()
# Out:
# 최적화 완료!
# 최적 Ea 값: [16158.77458067  1107.38454706 21902.35897524 37500.01967926
#  13870.46299681 49693.22844081 30022.37439454 50000.
#  47250.19057909]
# 최종 오차: 0.5142894050167433
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 45453 (\N{HANGUL SYLLABLE NONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 54744 (\N{HANGUL SYLLABLE HEOM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 50640 (\N{HANGUL SYLLABLE E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 46384 (\N{HANGUL SYLLABLE DDA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 47480 (\N{HANGUL SYLLABLE REUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 48320 (\N{HANGUL SYLLABLE BYEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\USER\AppData\Local\Temp\ipykernel_17692\2970214010.py:40: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45453 (\N{HANGUL SYLLABLE NONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54744 (\N{HANGUL SYLLABLE HEOM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50640 (\N{HANGUL SYLLABLE E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46384 (\N{HANGUL SYLLABLE DDA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47480 (\N{HANGUL SYLLABLE REUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48320 (\N{HANGUL SYLLABLE BYEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\.conda\envs\NNenv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
